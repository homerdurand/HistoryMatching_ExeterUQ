# %% [markdown]
# ## Preliminaries

# %%
mogp_dir <- "/home/homer/Documents/Locean/BayesExeter/mogp-emulator" #File of mogp_emulator

setwd('/home/homer/Documents/Locean/BayesExeter/dev_ExeterUQ_MOGP')

library(reticulate)

source("BuildEmulator/BuildEmulator.R")
source("HistoryMatching/HistoryMatching.R")
source("HistoryMatching/impLayoutplot.R")

L96 <- import("L96")
np <- import("numpy")
smt <- import("smt")

# %% [markdown]
# * You can select the number of variables X you want to keep (var *n_k*)
# * Data should be with format c(inputs, Noise, outputs) and named *tData*

# %%
library(BBmisc)#For normalization
library(comprehenr)#For comprehension loop
library(caret)


#How many variables you want to keep
n_k = 36
columns_to_keep = c()
columns_to_keep = to_vec(for(i in seq(1, n_k)) c(columns_to_keep, seq(i, 180, 36)))

#Load and normalize inputs (parameters)
inputs <- read.csv("/home/homer/Documents/Locean/Data/clean_inputs_20.csv", header = TRUE)
inputs_names = c('h', 'F', 'c', 'b')
names(inputs) <- inputs_names
normalizer <- preProcess(inputs, method=c("range"), rangeBounds = c(-1, 1))
inputs <- predict(normalizer, inputs)


#Load outputs and select variables you want to keep
outputs <- read.csv("/home/homer/Documents/Locean/Data/clean_outputs_100_20.csv", header = FALSE)
outputs_names  = c('index', rep('X', 36), rep('Y_mean', 36), rep('X_sq', 36), rep('XY_mean', 36), rep('Y_mean_sq', 36))
names(outputs) <- outputs_names
outputs <- outputs[2:nrow(outputs), ]
outputs$index <- NULL
outputs <- outputs[, columns_to_keep]


#Add some noise (here no noise added)
N = nrow(inputs) 
noise <- rnorm(N, 0, 0)
tData <- cbind(inputs, noise, outputs)
names(tData)[names(tData) == "noise"] <- "Noise"
         
head(tData)
# Out:
#    h           F           c           b           Noise X          Y_mean
# 2  -0.01567134  0.77316445  0.45388956 -0.48707686 0      1.9095779  0.20891755
# 3   0.05525037 -1.00000000 -0.53669839  0.89638341 0     -2.3322867 -0.07405244
# 4   0.32093084 -0.14686271  0.88878220 -0.39402220 0      4.0553112 -0.06942575
# 5  -0.39372316  0.90708191 -0.78655701 -0.56361448 0     -0.8228515 -0.03072783
# 6   0.21026255  0.41304347 -0.07390919  0.83836473 0     -0.6555710  0.11114405
# 7   0.38951661 -0.49667536 -0.35183840  1.00000000 0      2.8259817  0.02562735
# 8  -0.64857078 -0.31188588 -0.15854576 -0.12533850 0     -2.8050650 -0.09173822
# 9  -0.14585773  0.31403792 -0.77066026  0.26946139 0     -1.7117458 -0.12079769
# 10 -0.49681077  0.63310682  0.73093168  0.38452930 0      0.5060077 -0.04761473
# 11  0.78278913  0.19415345 -0.02063897  0.03685573 0      2.9455465 -0.05016926
# 12  0.58418640  1.00000000  0.16648568 -0.74645742 0      0.1971920  0.03881336
# 13 -0.79416493 -0.07222457  0.61658114 -0.72901080 0      1.3167788 -0.14081426
# 14  0.87959610 -0.84737271 -0.88604529  0.46230366 0      3.0734175  0.08839241
# 15  0.52711128  0.02266673  0.20696525  0.57943920 0      2.6730390  0.02898893
# 16 -0.28498436 -0.63329745 -1.00000000  0.74143960 0      1.2237287 -0.01696693
# 17  0.69229151 -0.71814578  0.66421193  0.14635531 0     -2.9534401  0.08563527
# 18 -1.00000000 -0.35064545 -0.66504142 -0.23855518 0     -0.8963090 -0.06192854
# 19  1.00000000  0.52044048  1.00000000 -0.91815989 0     -3.5968295  0.19210247
# 20 -0.59018334 -0.90968562  0.39994976 -1.00000000 0      3.5635920 -0.06643535
# 21 -0.89779497  0.66613101 -0.24107598 -0.08225192 0     -0.8470053  0.06255530
#    X_sq        XY_mean      Y_mean_sq    ⋯ X.34       Y_mean.34   X_sq.34
# 2   4.03106022  0.418443580 0.0531130380 ⋯  1.9008949  0.20840692  3.99666311
# 3  37.23526934  0.947570987 0.1663966476 ⋯ -2.3860860 -0.07412791 39.63328844
# 4  73.20224579 -1.035750151 0.0372266677 ⋯  3.5748591 -0.06364549 65.06729828
# 5   0.67741429  0.025294573 0.0009697560 ⋯ -0.8245696 -0.03079072  0.68016969
# 6   0.42977340 -0.072862820 0.0123529996 ⋯ -0.6555710  0.11114405  0.42977339
# 7  27.72786242  0.284391968 0.0130859870 ⋯  2.4683630  0.02251139 23.94480888
# 8  30.37986324  0.814213870 0.0873805490 ⋯ -3.0231215 -0.09569548 30.50782969
# 9  10.85469718  0.800643296 0.0738634239 ⋯ -1.7081724 -0.12055632 10.85757564
# 10  0.25604381 -0.024093421 0.0026597723 ⋯  0.5060076 -0.04761462  0.25604375
# 11 36.11521086 -0.218719102 0.0115087742 ⋯  2.5980438 -0.05855105 36.53608433
# 12  0.03888468  0.007653684 0.0015064772 ⋯  0.1971920  0.03881336  0.03888468
# 13  4.62213140 -0.343944412 0.0451123491 ⋯  1.3309157 -0.14172177  4.65547812
# 14 43.99467581  0.901703379 0.1322659684 ⋯  3.0878457  0.08975390 42.84173276
# 15 23.25593844  0.234764476 0.0031094411 ⋯  2.4993783  0.02715469 23.01170976
# 16  3.33858065 -0.044355776 0.0006106836 ⋯  1.2299855 -0.01701907  3.45500825
# 17 12.03383946 -0.301953184 0.0213731222 ⋯ -2.9824700  0.08729781 12.22540785
# 18 13.86785276  0.815273506 0.0559355376 ⋯ -1.0278797 -0.07102377 14.01387142
# 19 19.17346410 -0.918893011 0.1597183091 ⋯ -3.7365946  0.19067925 20.49214825
# 20 43.93676767 -0.903632254 0.1042945131 ⋯  3.3922712 -0.06212280 39.38395150
# 21  1.76367776 -0.091192573 0.0159234274 ⋯ -0.8470205  0.06277244  1.71920250
#    XY_mean.34   Y_mean_sq.34 X.35       Y_mean.35    X_sq.35     XY_mean.35
# 2   0.415659544 0.0527644550  1.9024143  0.208552711  4.00393706  0.416324045
# 3   0.975561354 0.1736666749 -3.0052465 -0.094521712 44.02361029  1.113808966
# 4  -0.924992365 0.0333940027  3.2868281 -0.062498288 60.60988467 -0.875223335
# 5   0.025397181 0.0009738021 -0.2551337 -0.009787747  0.07341827  0.002831543
# 6  -0.072862820 0.0123529996 -0.6555710  0.111144048  0.42977339 -0.072862819
# 7   0.253602250 0.0117297600  2.6190270  0.020924132 26.30408348  0.261313007
# 8   0.816997092 0.0870503736 -1.4707647 -0.052992823 23.01066938  0.619266025
# 9   0.800958572 0.0738922343 -1.6505127 -0.116098042 10.73875296  0.792534116
# 10 -0.024093361 0.0026597627 -2.5774991  0.203044939  6.64350136 -0.523348138
# 11 -0.240867355 0.0129357615  3.0676573 -0.058558368 35.75640714 -0.233630251
# 12  0.007653684 0.0015064772  0.1971920  0.038813363  0.03888468  0.007653684
# 13 -0.347249183 0.0453346902  1.3227405 -0.140906723  4.63954016 -0.345398903
# 14  0.943102604 0.1312053831  3.2133160  0.083830558 50.38301272  0.995641901
# 15  0.230648810 0.0030400305  2.3103992  0.026579369 19.53859691  0.201889990
# 16 -0.045861050 0.0006301355  1.2052963 -0.016698270  3.38477857 -0.044881741
# 17 -0.313016966 0.0222480554  0.7324834 -0.030661237  2.08790149 -0.092913411
# 18  0.819324688 0.0562583818 -2.4201289 -0.166398280 17.81464125  1.077402580
# 19 -0.927767573 0.1606840278  0.6687073 -0.057740498  4.49862529 -0.302369911
# 20 -0.803484017 0.0946391177  3.4080283 -0.061225253 40.96620495 -0.847030067
# 21 -0.091107705 0.0159879222 -1.7215236  0.099741924  3.68059400 -0.198820528
#    Y_mean_sq.35
# 2  0.0528718954
# 3  0.1901719395
# 4  0.0323680301
# 5  0.0001143486
# 6  0.0123529993
# 7  0.0121373791
# 8  0.0677006739
# 9  0.0731322463
# 10 0.0456957327
# 11 0.0127517156
# 12 0.0015064772
# 13 0.0450305400
# 14 0.1368854623
# 15 0.0027582740
# 16 0.0006169141
# 17 0.0073880359
# 18 0.0739234801
# 19 0.0614909896
# 20 0.1001365325
# 21 0.0292577464

# %% [markdown]
# ### Training Emulators

# %%
TestEm <- BuildNewEmulators(tData, HowManyEmulators = 180, meanFun = "fitted", additionalVariables = names(tData)[1:4]) #
# Out:
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X ~ 1, data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.9803 -1.4836 -0.0319  2.3278  3.6719
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.3835     0.5310   0.722    0.479
#
# Residual standard error: 2.375 on 19 degrees of freedom
#
# [1] "Max reduction is 0.0118745817109317 using h"
# [1] "Max reduction is 0.00174116151708174 using F"
# [1] "Max reduction is 0.00159655579554485 using c"
# [1] "Max reduction is 0.0016229433151262 using F"
# [1] "Max reduction is 0.0226659439215434 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = Y_mean ~ h + F + I(F^2) + c + b + I(F * h) + I(c *
#     h) + I(b * h) + I(c * F) + I(b * F) + I(b * c), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.05396 -0.02811 -0.01019  0.01651  0.09652
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.13040    0.03335  -3.911  0.00448 **
# h            0.09695    0.02809   3.452  0.00867 **
# F            0.14861    0.03674   4.044  0.00371 **
# I(F^2)       0.17148    0.05298   3.237  0.01194 *
# c            0.03878    0.03052   1.271  0.23956
# b            0.02486    0.03450   0.721  0.49157
# I(F * h)    -0.11111    0.04829  -2.301  0.05038 .
# I(c * h)     0.27833    0.06481   4.295  0.00263 **
# I(b * h)     0.31047    0.09240   3.360  0.00993 **
# I(c * F)     0.21102    0.06037   3.495  0.00813 **
# I(b * F)     0.11408    0.05295   2.154  0.06335 .
# I(b * c)    -0.11713    0.06202  -1.889  0.09563 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0584 on 8 degrees of freedom
# Multiple R-squared:  0.8502,	Adjusted R-squared:  0.6442
# F-statistic: 4.127 on 11 and 8 DF,  p-value: 0.02711
#
# [1] "1 I(F * h)"
# [1] "2 I(b * h)"
# [1] "3 I(b * c)"
# [1] "4 I(b * F)"
# [1] "5 b"
# [1] "6 I(c * h)"
# [1] "7 I(F^2)"
# [1] "8 I(c * F)"
#
# Call:
# lm(formula = Y_mean ~ h + F + c, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.124485 -0.048592 -0.002075  0.055273  0.168461
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.003132   0.019024   0.165    0.871
# h           0.080048   0.031847   2.513    0.023 *
# F           0.044822   0.031325   1.431    0.172
# c           0.008647   0.032624   0.265    0.794
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08502 on 16 degrees of freedom
# Multiple R-squared:  0.3649,	Adjusted R-squared:  0.2458
# F-statistic: 3.064 on 3 and 16 DF,  p-value: 0.05816
#
# [1] "Max reduction is 3.05676972951665 using F"
# [1] "Max reduction is 0.197356031483892 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X_sq ~ F + h + I(h * F), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -25.141  -4.978  -1.407   4.758  48.574
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   19.265      3.728   5.168 9.33e-05 ***
# F            -17.569      5.984  -2.936  0.00969 **
# h              9.264      6.091   1.521  0.14778
# I(h * F)       4.035     10.446   0.386  0.70439
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 16.66 on 16 degrees of freedom
# Multiple R-squared:  0.4106,	Adjusted R-squared:  0.3001
# F-statistic: 3.715 on 3 and 16 DF,  p-value: 0.03349
#
# [1] "Max reduction is 0.157366072900477 using c"
# [1] "Max reduction is 0.00983584917178199 using c"
# [1] "Max reduction is 0.0253676030316998 using F"
# [1] "Max reduction is 0.0233713566879021 using b"
# [1] "Max reduction is 0.0399343482131028 using Three Way Interactions with c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = XY_mean ~ c + I(c^2) + F + b + I(F * c) + I(b *
#     c) + I(b * F) + I(c * F * c) + I(c * b * c) + I(c * b * F),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.44546 -0.14075 -0.03892  0.14603  0.36688
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    0.3501     0.1288   2.717  0.02372 *
# c             -0.6373     0.1776  -3.587  0.00586 **
# I(c^2)        -0.3389     0.2781  -1.219  0.25392
# F             -0.6405     0.2706  -2.367  0.04212 *
# b             -0.1786     0.2134  -0.837  0.42438
# I(F * c)       0.6920     0.3022   2.290  0.04776 *
# I(b * c)       0.7993     0.3516   2.273  0.04911 *
# I(b * F)      -0.3223     0.2400  -1.343  0.21215
# I(c * F * c)   1.0802     0.6438   1.678  0.12766
# I(c * b * c)   0.8353     0.6427   1.300  0.22598
# I(c * b * F)  -1.1293     0.5289  -2.135  0.06149 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3474 on 9 degrees of freedom
# Multiple R-squared:  0.8429,	Adjusted R-squared:  0.6684
# F-statistic:  4.83 on 10 and 9 DF,  p-value: 0.01328
#
# [1] "1 I(c * b * c)"
# [1] "2 I(c * F * c)"
# [1] "3 I(c^2)"
# [1] "4 I(F * c)"
# [1] "5 I(b * c)"
# [1] "6 I(c * b * F)"
# [1] "7 I(b * F)"
#
# Call:
# lm(formula = XY_mean ~ c + F + b, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.80305 -0.32410  0.07718  0.24256  0.71678
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.05370    0.10145   0.529  0.60383
# c           -0.56886    0.18833  -3.021  0.00812 **
# F            0.05597    0.17376   0.322  0.75154
# b            0.23141    0.19523   1.185  0.25319
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4535 on 16 degrees of freedom
# Multiple R-squared:  0.5242,	Adjusted R-squared:  0.435
# F-statistic: 5.876 on 3 and 16 DF,  p-value: 0.006655
#
# [1] "Max reduction is 0.00378926310446448 using F"
# [1] "Max reduction is 0.00262127384438678 using b"
# [1] "Max reduction is 0.000881345524832093 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = Y_mean_sq ~ F + b + c + I(b * F) + I(c * F) + I(c *
#     b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.096994 -0.019808  0.000818  0.021192  0.075241
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.038834   0.012354   3.143  0.00777 **
# F           -0.035499   0.021246  -1.671  0.11865
# b           -0.036501   0.022310  -1.636  0.12579
# c           -0.007264   0.020670  -0.351  0.73089
# I(b * F)    -0.007136   0.031222  -0.229  0.82276
# I(c * F)     0.039969   0.037927   1.054  0.31115
# I(c * b)    -0.036989   0.044083  -0.839  0.41659
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0467 on 13 degrees of freedom
# Multiple R-squared:  0.4881,	Adjusted R-squared:  0.2519
# F-statistic: 2.066 on 6 and 13 DF,  p-value: 0.1284
#
# [1] "1 I(c * b)"
# [1] "2 I(b * F)"
# [1] "3 b"
#
# Call:
# lm(formula = Y_mean_sq ~ F + c + I(c * F), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.084541 -0.029396 -0.006607  0.031158  0.097040
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04619    0.01141   4.048 0.000932 ***
# F           -0.03293    0.01853  -1.777 0.094522 .
# c            0.01029    0.01866   0.552 0.588795
# I(c * F)     0.04485    0.03035   1.478 0.158877
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.04969 on 16 degrees of freedom
# Multiple R-squared:  0.2867,	Adjusted R-squared:  0.153
# F-statistic: 2.144 on 3 and 16 DF,  p-value: 0.1347
#
# [1] "Max reduction is 0.239548145818867 using h"
# [1] "Max reduction is 0.426924683349285 using b"
# [1] "Max reduction is 0.113038480784808 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X.1 ~ h + b + c + I(b * h) + I(c * h) + I(c * b),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.16103 -0.91331  0.01747  0.67341  2.29821
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.08753    0.39443  -0.222  0.82782
# h            2.32095    0.58541   3.965  0.00162 **
# b           -1.10042    0.60881  -1.808  0.09387 .
# c            0.27155    0.60163   0.451  0.65917
# I(b * h)     4.02421    1.27971   3.145  0.00775 **
# I(c * h)    -0.21416    1.03639  -0.207  0.83949
# I(c * b)    -2.26525    0.98333  -2.304  0.03840 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.348 on 13 degrees of freedom
# Multiple R-squared:  0.7254,	Adjusted R-squared:  0.5986
# F-statistic: 5.723 on 6 and 13 DF,  p-value: 0.004169
#
# [1] "1 I(c * h)"
# [1] "2 I(c * b)"
# [1] "3 c"
#
# Call:
# lm(formula = X.1 ~ h + b + I(b * h), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6263 -1.0695 -0.0842  0.3869  3.4136
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.3150     0.3347   0.941  0.36053
# h             2.6817     0.5936   4.518  0.00035 ***
# b            -1.2849     0.5584  -2.301  0.03516 *
# I(b * h)      3.6993     1.0708   3.455  0.00326 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.461 on 16 degrees of freedom
# Multiple R-squared:  0.6029,	Adjusted R-squared:  0.5285
# F-statistic: 8.098 on 3 and 16 DF,  p-value: 0.001659
#
# [1] "Max reduction is 0.0060639755548549 using F"
# [1] "Max reduction is 0.00825113346698 using h"
# [1] "Max reduction is 0.0102331145539263 using c"
# [1] "Max reduction is 0.0037756451398233 using h"
# [1] "Max reduction is 0.00442840519248335 using c"
# [1] "Max reduction is 0.00419553402732747 using c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = Y_mean.1 ~ F + h + I(h^2) + c + I(c^2) + I(c^3) +
#     I(h * F) + I(c * F) + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.112813 -0.025274 -0.000351  0.030313  0.110824
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.051620   0.029301   1.762  0.10860
# F            0.074647   0.025817   2.891  0.01607 *
# h            0.006725   0.026548   0.253  0.80517
# I(h^2)      -0.075549   0.050646  -1.492  0.16663
# c            0.143985   0.073955   1.947  0.08016 .
# I(c^2)      -0.112278   0.055602  -2.019  0.07106 .
# I(c^3)      -0.166071   0.106646  -1.557  0.15048
# I(h * F)    -0.167417   0.050889  -3.290  0.00815 **
# I(c * F)     0.155975   0.048712   3.202  0.00946 **
# I(c * h)     0.025573   0.057076   0.448  0.66367
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06681 on 10 degrees of freedom
# Multiple R-squared:  0.7818,	Adjusted R-squared:  0.5854
# F-statistic: 3.981 on 9 and 10 DF,  p-value: 0.02108
#
# [1] "1 I(c * h)"
# [1] "2 I(h^2)"
# [1] "3 I(c^3)"
# [1] "4 I(c^2)"
# [1] "5 I(c * F)"
# [1] "6 c"
#
# Call:
# lm(formula = Y_mean.1 ~ F + h + I(h * F), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.138026 -0.063359  0.006568  0.048426  0.156181
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.002924   0.020009  -0.146   0.8856
# F            0.070562   0.032122   2.197   0.0431 *
# h            0.025386   0.032695   0.776   0.4488
# I(h * F)    -0.122360   0.056070  -2.182   0.0443 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08944 on 16 degrees of freedom
# Multiple R-squared:  0.3742,	Adjusted R-squared:  0.2569
# F-statistic: 3.189 on 3 and 16 DF,  p-value: 0.05217
#
# [1] "Max reduction is 3.06027011376526 using F"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X_sq.1 ~ F, data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -27.385  -4.608  -0.210   0.963  45.125
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   17.293      3.505   4.934 0.000107 ***
# F            -16.971      5.612  -3.024 0.007296 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 15.67 on 18 degrees of freedom
# Multiple R-squared:  0.3369,	Adjusted R-squared:    0.3
# F-statistic: 9.144 on 1 and 18 DF,  p-value: 0.007296
#
# [1] "Max reduction is 0.141964493437797 using c"
# [1] "Max reduction is 0.00787741780378604 using F"
# [1] "Max reduction is 0.00180417170423447 using b"
# [1] "Max reduction is 0.000416655508998387 using F"
# [1] "Max reduction is 0.119073168267643 using Three Way Interactions with F"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = XY_mean.1 ~ c + F + I(F^2) + b + I(F * c) + I(b *
#     c) + I(b * F) + I(F * F * c) + I(F * b * c) + I(F * b * F),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.37817 -0.13748  0.00491  0.14403  0.40366
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.13155    0.12672   1.038   0.3263
# c            -0.74168    0.24663  -3.007   0.0148 *
# F            -0.39417    0.17754  -2.220   0.0535 .
# I(F^2)        0.43369    0.34635   1.252   0.2421
# b            -0.16462    0.25492  -0.646   0.5345
# I(F * c)      0.43043    0.26507   1.624   0.1389
# I(b * c)      0.69574    0.29591   2.351   0.0432 *
# I(b * F)     -0.08136    0.30548  -0.266   0.7960
# I(F * F * c) -0.15987    0.68647  -0.233   0.8211
# I(F * b * c) -1.93725    0.65575  -2.954   0.0161 *
# I(F * b * F)  0.44715    0.48964   0.913   0.3849
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3053 on 9 degrees of freedom
# Multiple R-squared:  0.8671,	Adjusted R-squared:  0.7195
# F-statistic: 5.874 on 10 and 9 DF,  p-value: 0.006828
#
# [1] "1 I(F^2)"
# [1] "2 I(F * b * F)"
# [1] "3 I(b * F)"
# [1] "4 I(F * F * c)"
# [1] "5 I(F * c)"
# [1] "6 I(F * b * c)"
# [1] "7 I(b * c)"
#
# Call:
# lm(formula = XY_mean.1 ~ c + F + b, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.78317 -0.28519  0.05945  0.32086  0.67426
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.07592    0.10209   0.744  0.46784
# c           -0.57365    0.18952  -3.027  0.00802 **
# F           -0.03860    0.17487  -0.221  0.82807
# b            0.08475    0.19647   0.431  0.67195
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4563 on 16 degrees of freedom
# Multiple R-squared:  0.4722,	Adjusted R-squared:  0.3732
# F-statistic: 4.771 on 3 and 16 DF,  p-value: 0.01463
#
# [1] "Max reduction is 0.00512201417199618 using F"
# [1] "Max reduction is 0.00143639268042158 using F"
# [1] "Max reduction is 0.00615132283725849 using F"
# [1] "Max reduction is 0.000594649219418743 using b"
# [1] "Max reduction is 0.00545613710852342 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = Y_mean_sq.1 ~ F + I(F^2) + I(F^3) + b + c + I(b *
#     F) + I(c * F) + I(c * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.045019 -0.010717  0.002995  0.012398  0.037072
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04319    0.01143   3.778  0.00306 **
# F            0.05963    0.02728   2.186  0.05133 .
# I(F^2)       0.00699    0.02376   0.294  0.77411
# I(F^3)      -0.16503    0.04350  -3.794  0.00298 **
# b           -0.04782    0.01557  -3.071  0.01063 *
# c           -0.02093    0.01237  -1.692  0.11879
# I(b * F)    -0.01496    0.02337  -0.640  0.53500
# I(c * F)     0.05612    0.02221   2.527  0.02814 *
# I(c * b)     0.04387    0.02830   1.550  0.14935
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0273 on 11 degrees of freedom
# Multiple R-squared:  0.7966,	Adjusted R-squared:  0.6487
# F-statistic: 5.386 on 8 and 11 DF,  p-value: 0.006168
#
# [1] "1 I(b * F)"
# [1] "2 I(c * b)"
# [1] "3 b"
# [1] "4 I(c * F)"
# [1] "5 c"
#
# Call:
# lm(formula = Y_mean_sq.1 ~ F + I(F^2) + I(F^3), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.055117 -0.021801  0.004485  0.018594  0.049729
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03033    0.01155   2.626   0.0184 *
# F            0.04471    0.03093   1.446   0.1676
# I(F^2)       0.03885    0.02263   1.717   0.1054
# I(F^3)      -0.11953    0.04266  -2.802   0.0128 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03335 on 16 degrees of freedom
# Multiple R-squared:  0.5585,	Adjusted R-squared:  0.4757
# F-statistic: 6.747 on 3 and 16 DF,  p-value: 0.003753
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X.2 ~ 1, data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.8807 -1.4100  0.0227  1.8126  3.3956
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.3289     0.5249   0.627    0.538
#
# Residual standard error: 2.347 on 19 degrees of freedom
#
# [1] "Max reduction is 0.0119172883365488 using h"
# [1] "Max reduction is 0.0019673047350407 using F"
# [1] "Max reduction is 0.00201023228296522 using c"
# [1] "Max reduction is 0.00180088472554786 using F"
# [1] "Max reduction is 0.0232105373824408 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = Y_mean.2 ~ h + F + I(F^2) + c + b + I(F * h) + I(c *
#     h) + I(b * h) + I(c * F) + I(b * F) + I(b * c), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.05349 -0.02790 -0.01217  0.01904  0.09168
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.13152    0.03261  -4.033  0.00377 **
# h            0.09709    0.02747   3.534  0.00769 **
# F            0.14809    0.03593   4.121  0.00334 **
# I(F^2)       0.17150    0.05181   3.310  0.01070 *
# c            0.03853    0.02984   1.291  0.23271
# b            0.02341    0.03374   0.694  0.50746
# I(F * h)    -0.11589    0.04722  -2.454  0.03969 *
# I(c * h)     0.27894    0.06338   4.401  0.00228 **
# I(b * h)     0.30964    0.09036   3.427  0.00900 **
# I(c * F)     0.21345    0.05904   3.615  0.00683 **
# I(b * F)     0.11422    0.05179   2.206  0.05848 .
# I(b * c)    -0.11554    0.06065  -1.905  0.09324 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.05711 on 8 degrees of freedom
# Multiple R-squared:  0.857,	Adjusted R-squared:  0.6605
# F-statistic:  4.36 on 11 and 8 DF,  p-value: 0.02309
#
# [1] "1 I(b * h)"
# [1] "2 I(F * h)"
# [1] "3 I(b * c)"
# [1] "4 I(b * F)"
# [1] "5 b"
# [1] "6 I(c * h)"
# [1] "7 I(F^2)"
# [1] "8 I(c * F)"
#
# Call:
# lm(formula = Y_mean.2 ~ h + F + c, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.129583 -0.047197 -0.004519  0.058042  0.169375
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.001954   0.019045   0.103   0.9196
# h           0.080310   0.031883   2.519   0.0228 *
# F           0.044952   0.031360   1.433   0.1710
# c           0.008219   0.032661   0.252   0.8045
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08512 on 16 degrees of freedom
# Multiple R-squared:  0.365,	Adjusted R-squared:  0.246
# F-statistic: 3.066 on 3 and 16 DF,  p-value: 0.05808
#
# [1] "Max reduction is 3.2080491472829 using F"
# [1] "Max reduction is 0.263413155415217 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X_sq.2 ~ F + h + I(h * F), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -24.918  -8.652  -1.067   5.615  37.386
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   18.770      3.419   5.489 4.95e-05 ***
# F            -17.329      5.489  -3.157  0.00611 **
# h              8.549      5.587   1.530  0.14553
# I(h * F)       5.559      9.582   0.580  0.56988
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 15.29 on 16 degrees of freedom
# Multiple R-squared:  0.4408,	Adjusted R-squared:  0.3359
# F-statistic: 4.203 on 3 and 16 DF,  p-value: 0.02262
#
# [1] "Max reduction is 0.149041849552597 using c"
# [1] "Max reduction is 0.00529158373847682 using c"
# [1] "Max reduction is 0.0235272387483609 using F"
# [1] "Max reduction is 0.022394433864913 using b"
# [1] "Max reduction is 0.0234696179722544 using Three Way Interactions with c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = XY_mean.2 ~ c + I(c^2) + F + b + I(F * c) + I(b *
#     c) + I(b * F) + I(c * F * c) + I(c * b * c) + I(c * b * F),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.48180 -0.17325 -0.05048  0.24108  0.39409
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    0.3395     0.1409   2.409   0.0393 *
# c             -0.6083     0.1943  -3.131   0.0121 *
# I(c^2)        -0.3097     0.3041  -1.018   0.3352
# F             -0.6326     0.2959  -2.137   0.0613 .
# b             -0.1636     0.2334  -0.701   0.5012
# I(F * c)       0.6839     0.3305   2.069   0.0685 .
# I(b * c)       0.8069     0.3846   2.098   0.0653 .
# I(b * F)      -0.3488     0.2625  -1.329   0.2165
# I(c * F * c)   1.0269     0.7041   1.458   0.1787
# I(c * b * c)   0.7847     0.7029   1.116   0.2932
# I(c * b * F)  -1.0799     0.5784  -1.867   0.0947 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3799 on 9 degrees of freedom
# Multiple R-squared:  0.8124,	Adjusted R-squared:  0.6039
# F-statistic: 3.896 on 10 and 9 DF,  p-value: 0.02636
#
# [1] "1 I(c * b * c)"
# [1] "2 I(c * F * c)"
# [1] "3 I(c^2)"
# [1] "4 I(F * c)"
# [1] "5 I(b * c)"
# [1] "6 I(c * b * F)"
# [1] "7 I(b * F)"
#
# Call:
# lm(formula = XY_mean.2 ~ c + F + b, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.80331 -0.35595  0.05151  0.25191  0.80253
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.06150    0.10346   0.594   0.5605
# c           -0.55158    0.19207  -2.872   0.0111 *
# F            0.04531    0.17721   0.256   0.8015
# b            0.23457    0.19910   1.178   0.2560
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4625 on 16 degrees of freedom
# Multiple R-squared:  0.5058,	Adjusted R-squared:  0.4131
# F-statistic: 5.458 on 3 and 16 DF,  p-value: 0.008891
#
# [1] "Max reduction is 0.00413662183610617 using F"
# [1] "Max reduction is 0.0024394644895365 using b"
# [1] "Max reduction is 0.000186726096226671 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = Y_mean_sq.2 ~ F + b + c + I(b * F) + I(c * F) +
#     I(c * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.098776 -0.019275  0.001428  0.021008  0.083742
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.039492   0.012936   3.053  0.00925 **
# F           -0.037908   0.022247  -1.704  0.11216
# b           -0.036320   0.023361  -1.555  0.14401
# c           -0.007226   0.021644  -0.334  0.74382
# I(b * F)    -0.009738   0.032693  -0.298  0.77051
# I(c * F)     0.040064   0.039714   1.009  0.33147
# I(c * b)    -0.034599   0.046160  -0.750  0.46687
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0489 on 13 degrees of freedom
# Multiple R-squared:  0.472,	Adjusted R-squared:  0.2282
# F-statistic: 1.937 on 6 and 13 DF,  p-value: 0.1496
#
# [1] "1 I(c * b)"
# [1] "2 I(b * F)"
# [1] "3 b"
#
# Call:
# lm(formula = Y_mean_sq.2 ~ F + c + I(c * F), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.087151 -0.027870 -0.009063  0.031283  0.095995
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.046734   0.011756   3.975  0.00109 **
# F           -0.034556   0.019093  -1.810  0.08914 .
# c            0.009455   0.019224   0.492  0.62952
# I(c * F)     0.045170   0.031270   1.445  0.16789
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0512 on 16 degrees of freedom
# Multiple R-squared:  0.2875,	Adjusted R-squared:  0.1539
# F-statistic: 2.152 on 3 and 16 DF,  p-value: 0.1337
#
# [1] "Max reduction is 0.23404400186816 using h"
# [1] "Max reduction is 0.408335259394898 using b"
# [1] "Max reduction is 0.0489659706142567 using c"
# [1] "Max reduction is 0.0139064245666995 using h"
# [1] "Max reduction is 0.0486382675776336 using Three Way Interactions with h"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X.3 ~ h + I(h^2) + b + c + I(b * h) + I(c * h) +
#     I(c * b) + I(h * b * h) + I(h * c * h) + I(h * c * b), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.02018 -0.41961  0.06051  0.61477  1.45892
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.01469    0.58537  -0.025   0.9805
# h             1.91869    0.81632   2.350   0.0433 *
# I(h^2)       -0.14758    1.42175  -0.104   0.9196
# b            -2.50666    1.02487  -2.446   0.0370 *
# c             0.54296    0.95313   0.570   0.5828
# I(b * h)      3.76044    1.54816   2.429   0.0380 *
# I(c * h)      1.25949    1.22871   1.025   0.3321
# I(c * b)     -3.67817    1.35985  -2.705   0.0242 *
# I(h * b * h)  5.99730    4.07840   1.471   0.1755
# I(h * c * h)  0.70670    2.50033   0.283   0.7838
# I(h * c * b)  0.62596    2.10293   0.298   0.7727
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.395 on 9 degrees of freedom
# Multiple R-squared:  0.8004,	Adjusted R-squared:  0.5786
# F-statistic: 3.609 on 10 and 9 DF,  p-value: 0.03327
#
# [1] "1 I(h * c * b)"
# [1] "2 I(h * c * h)"
# [1] "3 I(c * h)"
# [1] "4 I(h^2)"
# [1] "5 I(h * b * h)"
# [1] "6 I(c * b)"
# [1] "7 c"
#
# Call:
# lm(formula = X.3 ~ h + b + I(b * h), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8704 -0.9771 -0.2434  0.6562  3.5335
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.2004     0.3451   0.581 0.569492
# h             2.6708     0.6121   4.363 0.000483 ***
# b            -1.3466     0.5758  -2.339 0.032662 *
# I(b * h)      3.6108     1.1042   3.270 0.004813 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.506 on 16 degrees of freedom
# Multiple R-squared:  0.5861,	Adjusted R-squared:  0.5085
# F-statistic: 7.553 on 3 and 16 DF,  p-value: 0.002283
#
# [1] "Max reduction is 0.007910390111927 using F"
# [1] "Max reduction is 0.0082706143032046 using h"
# [1] "Max reduction is 0.00935516551201016 using c"
# [1] "Max reduction is 0.00499300529145157 using h"
# [1] "Max reduction is 0.00318453769314432 using c"
# [1] "Max reduction is 0.00476078058048257 using c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = Y_mean.3 ~ F + h + I(h^2) + c + I(c^2) + I(c^3) +
#     I(h * F) + I(c * F) + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.109683 -0.023994  0.000903  0.030035  0.111694
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.048342   0.029382   1.645  0.13094
# F            0.079991   0.025888   3.090  0.01145 *
# h            0.008618   0.026622   0.324  0.75283
# I(h^2)      -0.082000   0.050787  -1.615  0.13747
# c            0.154026   0.074160   2.077  0.06453 .
# I(c^2)      -0.105449   0.055757  -1.891  0.08788 .
# I(c^3)      -0.173064   0.106942  -1.618  0.13667
# I(h * F)    -0.166673   0.051030  -3.266  0.00849 **
# I(c * F)     0.150376   0.048847   3.078  0.01167 *
# I(c * h)     0.027581   0.057235   0.482  0.64026
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.067 on 10 degrees of freedom
# Multiple R-squared:  0.7876,	Adjusted R-squared:  0.5965
# F-statistic: 4.121 on 9 and 10 DF,  p-value: 0.01878
#
# [1] "1 I(c * h)"
# [1] "2 I(c^3)"
# [1] "3 I(c^2)"
# [1] "4 I(h^2)"
# [1] "5 I(c * F)"
# [1] "6 c"
#
# Call:
# lm(formula = Y_mean.3 ~ F + h + I(h * F), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.136751 -0.060171  0.003943  0.043280  0.153999
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.006425   0.019974  -0.322   0.7519
# F            0.077383   0.032067   2.413   0.0282 *
# h            0.028108   0.032638   0.861   0.4019
# I(h * F)    -0.120423   0.055973  -2.151   0.0471 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08929 on 16 degrees of freedom
# Multiple R-squared:  0.3965,	Adjusted R-squared:  0.2833
# F-statistic: 3.503 on 3 and 16 DF,  p-value: 0.03994
#
# [1] "Max reduction is 2.87110517748696 using F"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X_sq.3 ~ F, data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -28.007  -4.362  -1.473   3.419  47.777
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   18.017      3.663   4.919 0.000111 ***
# F            -16.842      5.866  -2.871 0.010158 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 16.38 on 18 degrees of freedom
# Multiple R-squared:  0.3141,	Adjusted R-squared:  0.276
# F-statistic: 8.244 on 1 and 18 DF,  p-value: 0.01016
#
# [1] "Max reduction is 0.13823891369359 using c"
# [1] "Max reduction is 0.00331871743071416 using F"
# [1] "Max reduction is 0.00679971351354364 using b"
# [1] "Max reduction is 0.00564097808954495 using F"
# [1] "Max reduction is 0.129528338787853 using Three Way Interactions with F"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = XY_mean.3 ~ c + F + I(F^2) + b + I(F * c) + I(b *
#     c) + I(b * F) + I(F * F * c) + I(F * b * c) + I(F * b * F),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.40435 -0.11521 -0.02466  0.17949  0.37549
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.17385    0.13227   1.314  0.22123
# c            -0.84005    0.25743  -3.263  0.00979 **
# F            -0.40089    0.18531  -2.163  0.05874 .
# I(F^2)        0.38916    0.36151   1.076  0.30972
# b            -0.28043    0.26608  -1.054  0.31938
# I(F * c)      0.41921    0.27668   1.515  0.16404
# I(b * c)      0.78355    0.30886   2.537  0.03187 *
# I(b * F)     -0.15158    0.31886  -0.475  0.64584
# I(F * F * c)  0.09446    0.71652   0.132  0.89802
# I(F * b * c) -1.88231    0.68446  -2.750  0.02247 *
# I(F * b * F)  0.65314    0.51107   1.278  0.23323
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3186 on 9 degrees of freedom
# Multiple R-squared:  0.8674,	Adjusted R-squared:   0.72
# F-statistic: 5.886 on 10 and 9 DF,  p-value: 0.006781
#
# [1] "1 I(F^2)"
# [1] "2 I(F * b * F)"
# [1] "3 I(b * F)"
# [1] "4 I(F * F * c)"
# [1] "5 I(F * c)"
# [1] "6 I(F * b * c)"
# [1] "7 I(b * c)"
#
# Call:
# lm(formula = XY_mean.3 ~ c + F + b, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.79817 -0.32317  0.05697  0.27387  0.75604
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.08241    0.10917   0.755   0.4613
# c           -0.58531    0.20267  -2.888   0.0107 *
# F           -0.04087    0.18700  -0.219   0.8298
# b            0.08140    0.21010   0.387   0.7035
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.488 on 16 degrees of freedom
# Multiple R-squared:  0.4469,	Adjusted R-squared:  0.3432
# F-statistic:  4.31 on 3 and 16 DF,  p-value: 0.02081
#
# [1] "Max reduction is 0.00561744198947315 using F"
# [1] "Max reduction is 0.00143689334066127 using F"
# [1] "Max reduction is 0.00642902847717994 using F"
# [1] "Max reduction is 0.000819064363628906 using b"
# [1] "Max reduction is 0.00512206210523909 using c"
# [1] "Max reduction is 0.000426706384166708 using F"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = Y_mean_sq.3 ~ F + I(F^2) + I(F^3) + I(F^4) + b +
#     c + I(b * F) + I(c * F) + I(c * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.049564 -0.006935 -0.000927  0.013408  0.034206
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.05388    0.01351   3.988  0.00257 **
# F            0.06230    0.02826   2.205  0.05202 .
# I(F^2)      -0.07202    0.07078  -1.018  0.33288
# I(F^3)      -0.17173    0.04543  -3.780  0.00360 **
# I(F^4)       0.08621    0.07463   1.155  0.27486
# b           -0.04717    0.01657  -2.847  0.01733 *
# c           -0.02066    0.01281  -1.612  0.13804
# I(b * F)    -0.01173    0.02525  -0.465  0.65210
# I(c * F)     0.05783    0.02320   2.492  0.03187 *
# I(c * b)     0.04741    0.02954   1.605  0.13957
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02828 on 10 degrees of freedom
# Multiple R-squared:  0.8183,	Adjusted R-squared:  0.6548
# F-statistic: 5.005 on 9 and 10 DF,  p-value: 0.009562
#
# [1] "1 I(b * F)"
# [1] "2 I(F^4)"
# [1] "3 I(c * b)"
# [1] "4 b"
# [1] "5 I(c * F)"
# [1] "6 c"
#
# Call:
# lm(formula = Y_mean_sq.3 ~ F + I(F^2) + I(F^3), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.057758 -0.024089  0.004805  0.021167  0.058300
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03137    0.01200   2.615   0.0188 *
# F            0.04577    0.03213   1.425   0.1735
# I(F^2)       0.03992    0.02351   1.698   0.1089
# I(F^3)      -0.12453    0.04432  -2.810   0.0126 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03464 on 16 degrees of freedom
# Multiple R-squared:  0.5636,	Adjusted R-squared:  0.4818
# F-statistic: 6.889 on 3 and 16 DF,  p-value: 0.003431
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X.4 ~ 1, data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.8556 -1.5985 -0.0126  1.9560  3.0848
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.3642     0.4939   0.737     0.47
#
# Residual standard error: 2.209 on 19 degrees of freedom
#
# [1] "Max reduction is 0.0116430200003994 using h"
# [1] "Max reduction is 0.00106370029432964 using F"
# [1] "Max reduction is 0.00123233922971624 using c"
# [1] "Max reduction is 0.00200312671039674 using F"
# [1] "Max reduction is 0.0169685501176173 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = Y_mean.4 ~ h + F + I(F^2) + c + b + I(F * h) + I(c *
#     h) + I(b * h) + I(c * F) + I(b * F) + I(b * c), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.05279 -0.02970 -0.00902  0.01670  0.11100
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.12412    0.03583  -3.464  0.00851 **
# h            0.09091    0.03018   3.012  0.01676 *
# F            0.13897    0.03948   3.520  0.00785 **
# I(F^2)       0.16814    0.05692   2.954  0.01832 *
# c            0.04293    0.03279   1.309  0.22678
# b            0.02770    0.03706   0.747  0.47627
# I(F * h)    -0.10207    0.05188  -1.967  0.08470 .
# I(c * h)     0.26219    0.06964   3.765  0.00550 **
# I(b * h)     0.28905    0.09928   2.912  0.01954 *
# I(c * F)     0.19413    0.06487   2.993  0.01726 *
# I(b * F)     0.10507    0.05690   1.847  0.10199
# I(b * c)    -0.11293    0.06663  -1.695  0.12857
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06275 on 8 degrees of freedom
# Multiple R-squared:  0.8188,	Adjusted R-squared:  0.5697
# F-statistic: 3.287 on 11 and 8 DF,  p-value: 0.05107
#
# [1] "1 I(F * h)"
# [1] "2 I(b * h)"
# [1] "3 I(b * c)"
# [1] "4 I(b * F)"
# [1] "5 b"
# [1] "6 I(c * h)"
# [1] "7 I(F^2)"
# [1] "8 I(c * F)"
#
# Call:
# lm(formula = Y_mean.4 ~ h + F + c, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.12204 -0.04990  0.00436  0.05055  0.16821
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.004326   0.018632   0.232   0.8193
# h           0.077475   0.031191   2.484   0.0245 *
# F           0.041299   0.030679   1.346   0.1970
# c           0.012177   0.031951   0.381   0.7081
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08327 on 16 degrees of freedom
# Multiple R-squared:  0.362,	Adjusted R-squared:  0.2423
# F-statistic: 3.026 on 3 and 16 DF,  p-value: 0.06018
#
# [1] "Max reduction is 3.27421926891546 using F"
# [1] "Max reduction is 0.283944824453139 using h"
# [1] "Max reduction is 0.0624685724996183 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X_sq.4 ~ F + h + b + I(h * F) + I(b * F) + I(b *
#     h), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -30.318  -5.275  -0.786   4.521  33.563
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   19.720      3.855   5.116 0.000198 ***
# F            -19.770      6.658  -2.969 0.010864 *
# h             12.322      6.373   1.933 0.075250 .
# b             -9.157      6.686  -1.370 0.194025
# I(h * F)      -4.788     11.515  -0.416 0.684319
# I(b * F)       8.710      9.931   0.877 0.396412
# I(b * h)      -1.037     14.217  -0.073 0.942935
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 15.1 on 13 degrees of freedom
# Multiple R-squared:  0.5549,	Adjusted R-squared:  0.3494
# F-statistic: 2.701 on 6 and 13 DF,  p-value: 0.06287
#
# [1] "1 I(b * h)"
# [1] "2 I(h * F)"
# [1] "3 I(b * F)"
#
# Call:
# lm(formula = X_sq.4 ~ F + h + b, data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -26.823  -5.295   1.654   5.238  36.222
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   18.539      3.155   5.875 2.35e-05 ***
# F            -20.261      5.398  -3.754  0.00173 **
# h             10.396      5.240   1.984  0.06469 .
# b             -8.977      5.565  -1.613  0.12624
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 14.11 on 16 degrees of freedom
# Multiple R-squared:  0.5216,	Adjusted R-squared:  0.4319
# F-statistic: 5.815 on 3 and 16 DF,  p-value: 0.006938
#
# [1] "Max reduction is 0.157162770692808 using c"
# [1] "Max reduction is 0.00606360290035035 using b"
# [1] "Max reduction is 0.0429468498269708 using F"
# [1] "Max reduction is 0.00403933538733547 using c"
# [1] "Max reduction is 0.0291371492483197 using Three Way Interactions with c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = XY_mean.4 ~ c + I(c^2) + b + F + I(b * c) + I(F *
#     c) + I(F * b) + I(c * b * c) + I(c * F * c) + I(c * F * b),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.40340 -0.13589 -0.04142  0.17662  0.38340
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    0.3242     0.1280   2.533  0.03206 *
# c             -0.6274     0.1764  -3.556  0.00616 **
# I(c^2)        -0.2736     0.2762  -0.990  0.34785
# b             -0.1603     0.2120  -0.756  0.46898
# F             -0.5737     0.2688  -2.135  0.06154 .
# I(b * c)       0.8001     0.3492   2.291  0.04770 *
# I(F * c)       0.6737     0.3001   2.245  0.05146 .
# I(F * b)      -0.2865     0.2384  -1.202  0.26007
# I(c * b * c)   0.7331     0.6383   1.149  0.28035
# I(c * F * c)   0.9081     0.6394   1.420  0.18925
# I(c * F * b)  -1.0828     0.5253  -2.061  0.06933 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.345 on 9 degrees of freedom
# Multiple R-squared:  0.8349,	Adjusted R-squared:  0.6514
# F-statistic:  4.55 on 10 and 9 DF,  p-value: 0.01614
#
# [1] "1 I(c * b * c)"
# [1] "2 I(b * c)"
# [1] "3 I(c * F * c)"
# [1] "4 I(c * F * b)"
# [1] "5 I(F * b)"
# [1] "6 b"
# [1] "7 I(c^2)"
#
# Call:
# lm(formula = XY_mean.4 ~ c + F + I(F * c), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.91966 -0.23722  0.01388  0.30365  0.61198
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.02234    0.09758   0.229   0.8218
# c           -0.63380    0.15958  -3.972   0.0011 **
# F            0.03986    0.15849   0.251   0.8047
# I(F * c)     0.38413    0.25957   1.480   0.1583
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.425 on 16 degrees of freedom
# Multiple R-squared:  0.5546,	Adjusted R-squared:  0.4711
# F-statistic: 6.642 on 3 and 16 DF,  p-value: 0.004014
#
# [1] "Max reduction is 0.00347250359306509 using F"
# [1] "Max reduction is 0.00259170610222011 using b"
# [1] "Max reduction is 0.00132889586205741 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = Y_mean_sq.4 ~ F + b + c + I(b * F) + I(c * F) +
#     I(c * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.094532 -0.020832  0.000497  0.020227  0.068225
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.037819   0.011889   3.181  0.00723 **
# F           -0.033167   0.020448  -1.622  0.12878
# b           -0.036746   0.021471  -1.711  0.11074
# c           -0.008507   0.019893  -0.428  0.67590
# I(b * F)    -0.003670   0.030048  -0.122  0.90465
# I(c * F)     0.039849   0.036501   1.092  0.29477
# I(c * b)    -0.037914   0.042426  -0.894  0.38775
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.04494 on 13 degrees of freedom
# Multiple R-squared:  0.4955,	Adjusted R-squared:  0.2626
# F-statistic: 2.128 on 6 and 13 DF,  p-value: 0.1196
#
# [1] "1 I(c * b)"
# [1] "2 I(b * F)"
# [1] "3 b"
#
# Call:
# lm(formula = Y_mean_sq.4 ~ F + c + I(c * F), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.081736 -0.028995 -0.004548  0.028170  0.096585
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.044995   0.011113   4.049 0.000931 ***
# F           -0.031265   0.018049  -1.732 0.102465
# c            0.009947   0.018173   0.547 0.591685
# I(c * F)     0.043442   0.029560   1.470 0.161048
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0484 on 16 degrees of freedom
# Multiple R-squared:  0.2798,	Adjusted R-squared:  0.1447
# F-statistic: 2.072 on 3 and 16 DF,  p-value: 0.1444
#
# [1] "Max reduction is 0.239002485728227 using h"
# [1] "Max reduction is 0.430388294183796 using b"
# [1] "Max reduction is 0.00586045856478368 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X.5 ~ h + b + c + I(b * h) + I(c * h) + I(c * b),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.87613 -0.77359 -0.08927  0.72299  2.87673
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.2039     0.4450  -0.458  0.65437
# h             2.4192     0.6604   3.663  0.00286 **
# b            -1.2439     0.6868  -1.811  0.09328 .
# c             0.3117     0.6787   0.459  0.65362
# I(b * h)      3.9649     1.4437   2.746  0.01665 *
# I(c * h)     -0.1566     1.1692  -0.134  0.89553
# I(c * b)     -1.8531     1.1093  -1.671  0.11870
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.52 on 13 degrees of freedom
# Multiple R-squared:  0.6719,	Adjusted R-squared:  0.5205
# F-statistic: 4.437 on 6 and 13 DF,  p-value: 0.01169
#
# [1] "1 I(c * h)"
# [1] "2 I(c * b)"
# [1] "3 c"
#
# Call:
# lm(formula = X.5 ~ h + b + I(b * h), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.3044 -0.9493 -0.1811  0.9139  3.7379
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.1271     0.3497   0.364 0.720930
# h             2.7364     0.6202   4.412 0.000436 ***
# b            -1.4412     0.5834  -2.470 0.025126 *
# I(b * h)      3.6707     1.1188   3.281 0.004704 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.526 on 16 degrees of freedom
# Multiple R-squared:  0.5931,	Adjusted R-squared:  0.5168
# F-statistic: 7.774 on 3 and 16 DF,  p-value: 0.002004
#
# [1] "Max reduction is 0.00839501503969092 using F"
# [1] "Max reduction is 0.00881932967097095 using h"
# [1] "Max reduction is 0.00930692622435697 using c"
# [1] "Max reduction is 0.00437072418377361 using h"
# [1] "Max reduction is 0.00196904993610342 using c"
# [1] "Max reduction is 0.00542967245647692 using c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = Y_mean.5 ~ F + h + I(h^2) + c + I(c^2) + I(c^3) +
#     I(h * F) + I(c * F) + I(c * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.11188 -0.02227 -0.00039  0.03072  0.11165
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.043650   0.029756   1.467   0.1731
# F            0.082478   0.026218   3.146   0.0104 *
# h            0.009738   0.026961   0.361   0.7255
# I(h^2)      -0.077206   0.051433  -1.501   0.1642
# c            0.159999   0.075104   2.130   0.0590 .
# I(c^2)      -0.098939   0.056466  -1.752   0.1103
# I(c^3)      -0.182226   0.108303  -1.683   0.1234
# I(h * F)    -0.167333   0.051680  -3.238   0.0089 **
# I(c * F)     0.146906   0.049469   2.970   0.0141 *
# I(c * h)     0.026132   0.057963   0.451   0.6617
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06785 on 10 degrees of freedom
# Multiple R-squared:  0.7849,	Adjusted R-squared:  0.5914
# F-statistic: 4.055 on 9 and 10 DF,  p-value: 0.01982
#
# [1] "1 I(c * h)"
# [1] "2 I(h^2)"
# [1] "3 I(c^3)"
# [1] "4 I(c^2)"
# [1] "5 I(c * F)"
# [1] "6 c"
#
# Call:
# lm(formula = Y_mean.5 ~ F + h + I(h * F), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.134087 -0.057942  0.000755  0.046658  0.153919
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.007238   0.019893  -0.364   0.7207
# F            0.079295   0.031936   2.483   0.0245 *
# h            0.028807   0.032505   0.886   0.3886
# I(h * F)    -0.122603   0.055745  -2.199   0.0429 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08893 on 16 degrees of freedom
# Multiple R-squared:  0.4089,	Adjusted R-squared:  0.2981
# F-statistic: 3.689 on 3 and 16 DF,  p-value: 0.03422
#
# [1] "Max reduction is 3.08554629893023 using F"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X_sq.5 ~ F, data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -28.552  -5.008  -1.614   6.671  37.717
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   18.318      3.555   5.152 6.69e-05 ***
# F            -17.165      5.693  -3.015  0.00744 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 15.9 on 18 degrees of freedom
# Multiple R-squared:  0.3355,	Adjusted R-squared:  0.2986
# F-statistic:  9.09 on 1 and 18 DF,  p-value: 0.00744
#
# [1] "Max reduction is 0.134855970403818 using c"
# [1] "Max reduction is 0.00424466915563093 using F"
# [1] "Max reduction is 0.00700942158131929 using b"
# [1] "Max reduction is 0.00405444230645818 using F"
# [1] "Max reduction is 0.112463413950809 using Three Way Interactions with F"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = XY_mean.5 ~ c + F + I(F^2) + b + I(F * c) + I(b *
#     c) + I(b * F) + I(F * F * c) + I(F * b * c) + I(F * b * F),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.39439 -0.13409 -0.02774  0.18918  0.39281
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    0.1778     0.1407   1.264   0.2379
# c             -0.7896     0.2737  -2.884   0.0181 *
# F             -0.4235     0.1971  -2.149   0.0601 .
# I(F^2)         0.4004     0.3844   1.042   0.3247
# b             -0.2697     0.2829  -0.953   0.3654
# I(F * c)       0.4195     0.2942   1.426   0.1876
# I(b * c)       0.7791     0.3285   2.372   0.0418 *
# ...
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.2797     0.5182    0.54    0.596
#
# Residual standard error: 2.317 on 19 degrees of freedom
#
# [1] "Max reduction is 0.0119987073109551 using h"
# [1] "Max reduction is 0.00170876152747734 using F"
# [1] "Max reduction is 0.0012516044827776 using c"
# [1] "Max reduction is 0.002222080064188 using F"
# [1] "Max reduction is 0.0228560530291471 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = Y_mean.34 ~ h + F + I(F^2) + c + b + I(F * h) +
#     I(c * h) + I(b * h) + I(c * F) + I(b * F) + I(b * c), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.05482 -0.02680 -0.01113  0.01774  0.09657
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.13326    0.03325  -4.007  0.00391 **
# h            0.09624    0.02801   3.436  0.00888 **
# F            0.14865    0.03664   4.057  0.00365 **
# I(F^2)       0.17693    0.05283   3.349  0.01010 *
# c            0.04042    0.03043   1.328  0.22078
# b            0.02613    0.03440   0.760  0.46934
# I(F * h)    -0.11505    0.04816  -2.389  0.04391 *
# I(c * h)     0.27590    0.06463   4.269  0.00273 **
# I(b * h)     0.30621    0.09215   3.323  0.01049 *
# I(c * F)     0.20545    0.06021   3.412  0.00919 **
# I(b * F)     0.11681    0.05281   2.212  0.05791 .
# I(b * c)    -0.12414    0.06185  -2.007  0.07962 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.05824 on 8 degrees of freedom
# Multiple R-squared:  0.8521,	Adjusted R-squared:  0.6488
# F-statistic: 4.191 on 11 and 8 DF,  p-value: 0.02592
#
# [1] "1 I(b * h)"
# [1] "2 I(F * h)"
# [1] "3 I(b * c)"
# [1] "4 I(b * F)"
# [1] "5 b"
# [1] "6 I(c * h)"
# [1] "7 I(F^2)"
# [1] "8 I(c * F)"
#
# Call:
# lm(formula = Y_mean.34 ~ h + F + c, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.132004 -0.048205 -0.003106  0.056418  0.168585
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.002368   0.019097   0.124   0.9029
# h           0.080176   0.031969   2.508   0.0233 *
# F           0.043977   0.031445   1.399   0.1810
# c           0.010373   0.032749   0.317   0.7555
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08535 on 16 degrees of freedom
# Multiple R-squared:  0.3649,	Adjusted R-squared:  0.2458
# F-statistic: 3.065 on 3 and 16 DF,  p-value: 0.05816
#
# [1] "Max reduction is 3.0494010750741 using F"
# [1] "Max reduction is 0.374562266692587 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X_sq.34 ~ F + h + I(h * F), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -23.873  -6.380  -0.791   4.888  41.236
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   18.607      3.376   5.513 4.73e-05 ***
# F            -16.776      5.419  -3.096  0.00694 **
# h              9.180      5.516   1.664  0.11549
# I(h * F)       3.950      9.459   0.418  0.68182
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 15.09 on 16 degrees of freedom
# Multiple R-squared:  0.4406,	Adjusted R-squared:  0.3357
# F-statistic:   4.2 on 3 and 16 DF,  p-value: 0.02267
#
# [1] "Max reduction is 0.155672944171258 using c"
# [1] "Max reduction is 0.00790179717074824 using c"
# [1] "Max reduction is 0.0236292410518616 using F"
# [1] "Max reduction is 0.0211539486441697 using b"
# [1] "Max reduction is 0.0236545770658881 using Three Way Interactions with c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = XY_mean.34 ~ c + I(c^2) + F + b + I(F * c) + I(b *
#     c) + I(b * F) + I(c * F * c) + I(c * b * c) + I(c * b * F),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.46710 -0.13467 -0.04677  0.19104  0.39224
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    0.3473     0.1335   2.602  0.02864 *
# c             -0.6249     0.1840  -3.396  0.00792 **
# I(c^2)        -0.3259     0.2880  -1.131  0.28710
# F             -0.6267     0.2803  -2.236  0.05217 .
# b             -0.1871     0.2211  -0.846  0.41939
# I(F * c)       0.6941     0.3130   2.218  0.05376 .
# I(b * c)       0.7907     0.3642   2.171  0.05802 .
# I(b * F)      -0.2899     0.2486  -1.166  0.27347
# I(c * F * c)   1.0037     0.6668   1.505  0.16653
# I(c * b * c)   0.7700     0.6657   1.157  0.27716
# I(c * b * F)  -1.0269     0.5478  -1.875  0.09360 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3598 on 9 degrees of freedom
# Multiple R-squared:  0.8249,	Adjusted R-squared:  0.6304
# F-statistic:  4.24 on 10 and 9 DF,  p-value: 0.02024
#
# [1] "1 I(c * b * c)"
# [1] "2 I(c * F * c)"
# [1] "3 I(c * b * F)"
# [1] "4 I(b * F)"
# [1] "5 I(c^2)"
# [1] "6 I(F * c)"
# [1] "7 F"
#
# Call:
# lm(formula = XY_mean.34 ~ c + b + I(b * c), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.63384 -0.37466  0.01704  0.28726  0.70857
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.1182     0.1102   1.072  0.29946
# c            -0.5468     0.1798  -3.041  0.00778 **
# b             0.1976     0.1786   1.106  0.28487
# I(b * c)      0.3015     0.2931   1.029  0.31899
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4327 on 16 degrees of freedom
# Multiple R-squared:  0.5499,	Adjusted R-squared:  0.4656
# F-statistic: 6.517 on 3 and 16 DF,  p-value: 0.004349
#
# [1] "Max reduction is 0.00359530966367931 using F"
# [1] "Max reduction is 0.00252129314515182 using b"
# [1] "Max reduction is 0.000580935972966504 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = Y_mean_sq.34 ~ F + b + c + I(b * F) + I(c * F) +
#     I(c * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.097978 -0.018845  0.000042  0.021373  0.078705
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.038238   0.012622   3.030  0.00967 **
# F           -0.035212   0.021707  -1.622  0.12876
# b           -0.034916   0.022793  -1.532  0.14952
# c           -0.006663   0.021118  -0.316  0.75737
# I(b * F)    -0.011695   0.031899  -0.367  0.71981
# I(c * F)     0.040847   0.038749   1.054  0.31102
# I(c * b)    -0.034980   0.045039  -0.777  0.45126
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.04771 on 13 degrees of freedom
# Multiple R-squared:  0.4739,	Adjusted R-squared:  0.2311
# F-statistic: 1.952 on 6 and 13 DF,  p-value: 0.147
#
# [1] "1 I(c * b)"
# [1] "2 I(b * F)"
# [1] "3 b"
#
# Call:
# lm(formula = Y_mean_sq.34 ~ F + c + I(c * F), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.086248 -0.027036 -0.005877  0.030615  0.097759
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.045661   0.011492   3.973  0.00109 **
# F           -0.031907   0.018664  -1.709  0.10668
# c            0.009114   0.018792   0.485  0.63427
# I(c * F)     0.047567   0.030568   1.556  0.13924
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.05005 on 16 degrees of freedom
# Multiple R-squared:  0.2874,	Adjusted R-squared:  0.1538
# F-statistic: 2.151 on 3 and 16 DF,  p-value: 0.1339
#
# [1] "Max reduction is 0.224211023174044 using h"
# [1] "Max reduction is 0.432489479465419 using b"
# [1] "Max reduction is 0.0166813129829593 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X.35 ~ h + b + c + I(b * h) + I(c * h) + I(c * b),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.90029 -0.85085 -0.02075  0.83216  2.63859
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.09689    0.42880  -0.226  0.82476
# h            2.34654    0.63642   3.687  0.00274 **
# b           -1.20640    0.66186  -1.823  0.09141 .
# c            0.29790    0.65406   0.455  0.65629
# I(b * h)     3.99786    1.39122   2.874  0.01305 *
# I(c * h)    -0.07923    1.12670  -0.070  0.94501
# I(c * b)    -1.87745    1.06901  -1.756  0.10256
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.465 on 13 degrees of freedom
# Multiple R-squared:  0.6788,	Adjusted R-squared:  0.5306
# F-statistic:  4.58 on 6 and 13 DF,  p-value: 0.01035
#
# [1] "1 I(c * h)"
# [1] "2 I(c * b)"
# [1] "3 c"
#
# Call:
# lm(formula = X.35 ~ h + b + I(b * h), data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.3236 -1.0073 -0.1911  0.7608  3.5242
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.2487     0.3395   0.733 0.474438
# h             2.6561     0.6021   4.411 0.000437 ***
# b            -1.4030     0.5664  -2.477 0.024795 *
# I(b * h)      3.6460     1.0862   3.357 0.004011 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.482 on 16 degrees of freedom
# Multiple R-squared:  0.5957,	Adjusted R-squared:  0.5199
# F-statistic: 7.857 on 3 and 16 DF,  p-value: 0.001908
#
# [1] "Max reduction is 0.00779125242311554 using F"
# [1] "Max reduction is 0.00730363770952323 using h"
# [1] "Max reduction is 0.00888046735013991 using c"
# [1] "Max reduction is 0.00308643064386065 using h"
# [1] "Max reduction is 0.00293543887645877 using c"
# [1] "Max reduction is 0.00519660201691012 using c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = Y_mean.35 ~ F + h + I(h^2) + c + I(c^2) + I(c^3) +
#     I(h * F) + I(c * F) + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.115936 -0.021730  0.005409  0.029532  0.108278
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.045577   0.030110   1.514   0.1611
# F            0.079235   0.026530   2.987   0.0137 *
# h            0.004044   0.027282   0.148   0.8851
# I(h^2)      -0.070293   0.052045  -1.351   0.2066
# c            0.156685   0.075998   2.062   0.0662 .
# I(c^2)      -0.106466   0.057138  -1.863   0.0920 .
# I(c^3)      -0.181016   0.109592  -1.652   0.1296
# I(h * F)    -0.164682   0.052295  -3.149   0.0103 *
# I(c * F)     0.150103   0.050058   2.999   0.0134 *
# I(c * h)     0.030331   0.058653   0.517   0.6163
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06866 on 10 degrees of freedom
# Multiple R-squared:   0.77,	Adjusted R-squared:  0.5629
# F-statistic: 3.719 on 9 and 10 DF,  p-value: 0.02633
#
# [1] "1 I(c * h)"
# [1] "2 I(h^2)"
# [1] "3 I(c^3)"
# [1] "4 I(c^2)"
# [1] "5 I(c * F)"
# [1] "6 c"
#
# Call:
# lm(formula = Y_mean.35 ~ F + h + I(h * F), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.137187 -0.061547  0.009013  0.049955  0.153558
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.004887   0.019855  -0.246   0.8087
# F            0.076062   0.031875   2.386   0.0297 *
# h            0.022729   0.032443   0.701   0.4936
# I(h * F)    -0.117997   0.055638  -2.121   0.0499 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08876 on 16 degrees of freedom
# Multiple R-squared:  0.3849,	Adjusted R-squared:  0.2696
# F-statistic: 3.337 on 3 and 16 DF,  p-value: 0.04595
#
# [1] "Max reduction is 3.43221055807465 using F"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X_sq.35 ~ F, data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -28.645  -4.654  -0.464   3.240  40.091
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   17.893      3.476   5.147 6.76e-05 ***
# F            -17.879      5.567  -3.212  0.00484 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 15.55 on 18 degrees of freedom
# Multiple R-squared:  0.3643,	Adjusted R-squared:  0.329
# F-statistic: 10.32 on 1 and 18 DF,  p-value: 0.004836
#
# [1] "Max reduction is 0.139237529786282 using c"
# [1] "Max reduction is 0.00968596906549674 using F"
# [1] "Max reduction is 0.00698706244625397 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = XY_mean.35 ~ c + F + b + I(F * c) + I(b * c) + I(b *
#     F), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.75862 -0.27068  0.04709  0.22363  0.73076
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.10322    0.11438   0.902    0.383
# c           -0.46956    0.19137  -2.454    0.029 *
# F           -0.23883    0.19671  -1.214    0.246
# b           -0.09809    0.20655  -0.475    0.643
# I(F * c)     0.56142    0.35114   1.599    0.134
# I(b * c)     0.64123    0.40814   1.571    0.140
# I(b * F)    -0.38826    0.28907  -1.343    0.202
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4323 on 13 degrees of freedom
# Multiple R-squared:  0.6304,	Adjusted R-squared:  0.4598
# F-statistic: 3.696 on 6 and 13 DF,  p-value: 0.0229
#
# [1] "1 I(b * c)"
# [1] "2 I(b * F)"
# [1] "3 b"
#
# Call:
# lm(formula = XY_mean.35 ~ c + F + I(F * c), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.97726 -0.28702  0.00511  0.40971  0.52321
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.05057    0.10087   0.501  0.62297
# c           -0.58444    0.16495  -3.543  0.00271 **
# F           -0.04641    0.16383  -0.283  0.78061
# I(F * c)     0.42315    0.26832   1.577  0.13435
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4393 on 16 degrees of freedom
# Multiple R-squared:  0.5303,	Adjusted R-squared:  0.4422
# F-statistic: 6.022 on 3 and 16 DF,  p-value: 0.00603
#
# [1] "Max reduction is 0.00571108982049529 using F"
# [1] "Max reduction is 0.00217379708220447 using F"
# [1] "Max reduction is 0.00793357740655245 using F"
# [1] "Max reduction is 0.00107421923371209 using b"
# [1] "Max reduction is 0.00522966356398034 using c"
# [1] "Max reduction is 0.000664515154152393 using F"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = Y_mean_sq.35 ~ F + I(F^2) + I(F^3) + I(F^4) + b +
#     c + I(b * F) + I(c * F) + I(c * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.047066 -0.007828  0.002313  0.010051  0.033528
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.05157    0.01301   3.964  0.00267 **
# F            0.07129    0.02721   2.620  0.02562 *
# I(F^2)      -0.07170    0.06816  -1.052  0.31761
# I(F^3)      -0.18631    0.04375  -4.259  0.00167 **
# I(F^4)       0.08929    0.07187   1.242  0.24245
# b           -0.04482    0.01596  -2.809  0.01849 *
# c           -0.01970    0.01234  -1.597  0.14144
# I(b * F)    -0.01952    0.02432  -0.803  0.44077
# I(c * F)     0.05848    0.02235   2.617  0.02572 *
# I(c * b)     0.04662    0.02845   1.639  0.13227
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02723 on 10 degrees of freedom
# Multiple R-squared:  0.844,	Adjusted R-squared:  0.7036
# F-statistic: 6.011 on 9 and 10 DF,  p-value: 0.004864
#
# [1] "1 I(b * F)"
# [1] "2 I(c * b)"
# [1] "3 b"
# [1] "4 I(F^4)"
# [1] "5 I(c * F)"
# [1] "6 c"
#
# Call:
# lm(formula = Y_mean_sq.35 ~ F + I(F^2) + I(F^3), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.057884 -0.023111  0.004767  0.021719  0.052179
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.02874    0.01184   2.427  0.02742 *
# F            0.05305    0.03172   1.673  0.11386
# I(F^2)       0.04633    0.02321   1.996  0.06320 .
# I(F^3)      -0.13697    0.04375  -3.131  0.00645 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0342 on 16 degrees of freedom
# Multiple R-squared:  0.6063,	Adjusted R-squared:  0.5325
# F-statistic: 8.214 on 3 and 16 DF,  p-value: 0.001553

# %% [markdown]
# ## Testing Emulators

# %%
LOO.score <- function(emulator){
    #Compute pourcentage of targets which not fall in 2*sigma interval
    scores <- c()
    for(which.emulator in 1:emulator$mogp$n_emulators){
        fit.loo <- virtual.LOO_MOGP(mogp.emulator=TestEm$mogp$emulators[[which.emulator]], lm.emulator=TestEm$fitting.elements$lm.object[[which.emulator]])
        errors = sum(emulator$mogp$emulators[[which.emulator]]$targets < fit.loo$`lower quantile` | emulator$mogp$emulators[[which.emulator]]$targets > fit.loo$`upper quantile`)
        score = errors/length(emulator$mogp$emulators[[which.emulator]]$targets)
        scores[which.emulator] = score
    }
    return(c(mean = mean(scores), min = max(scores), scores = data.frame(scores)))
}

# %%
loo = LOO.score(TestEm)
df = data.frame(loo)
library(ggplot2)
# Graphe basique
p <- ggplot(df, aes(x=scores.scores)) + geom_histogram(color="darkblue", fill="lightblue", binwidth = 0.025,) 
p + geom_vline(aes(xintercept=mean(scores.scores)), color="blue", linetype="dashed", size=2)
# Out:
# plot without title

# %% [markdown]
# ## History Matching
# * Observations discrepancy variances in *tDisc* (here set to 0)
# * Observations errors in *tObsErr* (here set to 0)

# %%
tDisc <- rep(0, length(outputs))
tObs <- read.csv("/home/homer/Documents/Locean/Data/observations.csv", header = FALSE)
tObs <-  as.vector(t(tObs[, columns_to_keep]))
tObsErr <- rep(0, length(outputs))
#varObsErr <- var(tObs)
#pvar = varObsErr*0.05
#tObsErr = abs(rnorm(180, 0, pvar))

# %%
sample_size <- 20000
nparam <- length(names(TestEm$fitting.elements$Design))
Xp <- as.data.frame(2*randomLHS(sample_size, nparam)-1)
names(Xp) <- names(TestEm$fitting.elements$Design)
system.time(Timps <- ImplausibilityMOGP(NewData=Xp, Emulator=TestEm, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))
# Out:
#    user  system elapsed
#  38.214   2.962  31.543

# %%
ImpData_wave1 = cbind(Xp, Timps)

# %%
VarNames <- names(Xp)
valmax = 0 #how many outputs can be above the implausibility cut off?
cutoff_vec <- 3 #the implausibility cut off
param.def = data.frame(h=c(1), F=c(10),c=c(10),b=c(10)) #the default parameters of the model (on [-1,1])
param.defaults.norm = predict(normalizer, param.def)
print(param.defaults.norm)
# Out:
#           h         F           c         b
# 1 0.5584798 0.5490996 -0.02233286 0.5522118

# %%
ImpListM1 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave1, nEms=TestEm$mogp$n_emulators, whichMax=valmax+1)
NROY1 <- which(rowSums(Timps <= cutoff_vec[1]) >= TestEm$mogp$n_emulators -valmax)
scoreNROY <- length(NROY1)/dim(Xp)[1]
scoreNROY
# Out:
# [1] 0.44575

# %%
imp.layoutm11(ImpListM1,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",length(NROY1)/dim(Xp)[1],sep=""), side=1)
# Out:
# plot without title

# %%
Xp2 = Xp[NROY1,]
min(Xp2$F)
max(Xp2$F)
# Out:
# [1] -0.992936
# [1] 0.9996656

# %% [markdown]
# ## Fine Tuning

# %%
RO_Xp <- function(emulator=TestEm, sample_size = 40, valmax = 0, cutoff_vec = 3, disc = tDisc, obs = tObs, obserr = tObsErr)
{
    nparam <- length(names(TestEm$fitting.elements$Design))
    Xp <- as.data.frame(2*randomLHS(sample_size, nparam)-1)
    names(Xp) <- names(emulator$fitting.elements$Design)
    Timps <- ImplausibilityMOGP(NewData=Xp, Emulator=emulator, Discrepancy=disc, Obs=obs, ObsErr=obs)
    NROY <- which(rowSums(Timps <= cutoff_vec[1]) >= emulator$mogp$n_emulators -valmax)
    return(Xp[NROY, ])
}

extract_metrics <- function(p, n_iter) {
    l96 = L96$L96TwoLevel(h=p[1], F=p[2], c=p[3], b=p[4])
    #l96$iterate(1)
    #l96$erase_history()
    l96$iterate(n_iter)
    return(l96$mean_stats())
}

# %%
library("future.apply")
plan(multicore) ## Run in parallel on local computer

# %%
system.time(x <- apply(data.matrix(inputs), 1, function(p) extract_metrics(p,10)))
# Out:
#    user  system elapsed
# 146.360   0.087 146.723

# %%
system.time(x <- future_apply(data.matrix(inputs), 1, function(p) extract_metrics(p,10), future.seed = TRUE))

# %%
x
# Out:
#      [,1]          [,2]        [,3]          [,4]        [,5]
# [1,]  7.459385e-01 -0.70422180 -7.764204e-02   0.5710580  0.4154878116
# [2,] -9.043130e-04  0.10204885 -2.059529e-03   0.9554522 -0.0042279080
# [3,]  5.664225e-01  0.69062961  2.994200e-02   0.5792614  0.1775658295
# [4,] -6.906764e-04 -0.07128424  5.438050e-04  -0.5364905 -0.0017520072
# [5,]  9.271804e-07  0.03171644  1.627488e-05 383.2156713  0.0000259091
#      [,6]        [,7]          [,8]        [,9]          [,10]
# [1,] -0.38193512 -0.2319727686  0.25074829  0.6136615729  2.197906e-01
# [2,]  0.06335206 -0.0135413303  0.85133211 -0.0261652087 -2.076999e-03
# [3,]  0.19759833  0.0833489388  0.09050110  0.3831146154  5.573041e-02
# [4,] -0.03057586  0.0042983341  0.02639897 -0.0162590651 -4.223466e-04
# [5,]  0.01090585  0.0004265947 12.78508298  0.0007433161  5.743434e-06
#      [,11]       [,12]         [,13]        [,14]        [,15]
# [1,] 0.934617605 -1.836994e-02  -0.40815187 6.614138e-02  -0.4747799
# [2,] 0.027427445  7.718951e-04   0.05920566 2.528091e-03   0.2586437
# [3,] 0.902878504  1.642672e-02   2.07104825 1.678922e-02   0.3795931
# [4,] 0.026556675 -4.508615e-04   3.87571608 1.806715e-04  -0.5233577
# [5,] 0.000937704  3.355039e-05 954.68205696 8.748232e-06 442.2913737
#      [,16]        [,17]      [,18]      [,19]        [,20]
# [1,] -0.569148152 -0.1856345 0.48337329 -0.683690748 0.61955224
# [2,] -0.032589594 -0.3451510 0.04336731  0.030265859 0.17868505
# [3,]  0.398708562  0.3361611 0.23944944  0.604471022 0.39059414
# [4,]  0.022624150 -0.5020568 0.02100728 -0.025715898 0.10910023
# [5,]  0.001397723  4.4419516 0.00199026  0.001260846 0.05742125

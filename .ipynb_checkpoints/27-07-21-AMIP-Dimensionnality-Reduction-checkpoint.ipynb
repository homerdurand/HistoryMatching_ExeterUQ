# %% [markdown]
# # History Matching for L96
# Author : Redaoune Lguensat, Homer Durand
#
# Date : 27-07-21

# %% [markdown]
# ### Loading libs

# %%
mogp_dir <- "/home/homer/Documents/Locean/HistoryMatching/mogp-emulator" #mogp_emulator lib

setwd('/home/homer/Documents/Locean/HistoryMatching/dev_ExeterUQ_MOGP/') #setting working directory to dev_ExeterUQ_MOGP and load libs

source("BuildEmulator/BuildEmulator.R")
source("HistoryMatching/HistoryMatching.R")
source("HistoryMatching/impLayoutplot.R")

setwd('/home/homer/Documents/Locean/HistoryMatching/libs/') #setting wd to libs and load personnal libs for preprocessing and refocussing
source("../libs/unPreProc.R")

setwd('/home/homer/Documents/Locean/AMIP/') #setting wd to libs and load personnal libs for preprocessing and refocussing
L96_amip <- import("L96_amip")
data_generation <- import("data_generation")
setwd('/home/homer/Documents/Locean/HistoryMatching/libs/') #setting wd to libs and load personnal libs for preprocessing and refocussing
np <- import("numpy")
smt <- import("smt")
sklearn <- import("sklearn")

packages <- c("FactoMineR", "factoextra", "corrplot", 'kernlab', 'pca3d', 'BBmisc', 'comprehenr', 'caret', "future.apply", 'tgp', 'ANN2', 'ramify', 'keras', 'MLmetrics')
# Install packages not yet installed
installed_packages <- packages %in% rownames(installed.packages())
if (any(installed_packages == FALSE)) {
  install.packages(packages[!installed_packages])
}

# Packages loading
invisible(lapply(packages, library, character.only = TRUE))
# Out:
# far library : Modelization for Functional AutoRegressive processes
#
#
# version 0.6-4 (2014-12-07)
#
#
# Spam version 2.6-0 (2020-12-14) is loaded.
# Type 'help( Spam)' or 'demo( spam)' for a short introduction
# and overview of this package.
# Help for individual functions is also obtained by adding the
# suffix '.spam' to the function name, e.g. 'help( chol.spam)'.
#
#
# Attaching package: ‘spam’
#
#
# The following objects are masked from ‘package:base’:
#
#     backsolve, forwardsolve
#
#
# See https://github.com/NCAR/Fields for
#  an extensive vignette, other supplements and source code
#
# This is loo version 2.4.1
#
# - Online documentation and vignettes at mc-stan.org/loo
#
# - As of v2.0.0 loo defaults to 1 core but we recommend using as many as possible. Use the 'cores' argument or set options(mc.cores = NUM_CORES) for an entire session.
#
# Loading required package: future
#
# Loading required package: ggplot2
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
#
# corrplot 0.88 loaded
#
#
# Attaching package: ‘corrplot’
#
#
# The following object is masked from ‘package:shape’:
#
#     colorlegend
#
#
#
# Attaching package: ‘kernlab’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     alpha
#
#
# The following objects are masked from ‘package:pracma’:
#
#     cross, eig, size
#
#
#
# Attaching package: ‘BBmisc’
#
#
# The following object is masked from ‘package:grid’:
#
#     explode
#
#
# The following object is masked from ‘package:nlme’:
#
#     collapse
#
#
# The following object is masked from ‘package:base’:
#
#     isFALSE
#
#
# Loading required package: lattice
#
#
# Attaching package: ‘caret’
#
#
# The following object is masked from ‘package:future’:
#
#     cluster
#
#
#
# Attaching package: ‘ANN2’
#
#
# The following object is masked from ‘package:caret’:
#
#     train
#
#
#
# Attaching package: ‘ramify’
#
#
# The following object is masked from ‘package:kernlab’:
#
#     size
#
#
# The following objects are masked from ‘package:pracma’:
#
#     eye, inv, linspace, logspace, meshgrid, ones, rand, randi, randn,
#     repmat, size, tril, triu, zeros
#
#
# The following object is masked from ‘package:graphics’:
#
#     clip
#
#
#
# Attaching package: ‘keras’
#
#
# The following object is masked from ‘package:BBmisc’:
#
#     normalize
#
#
# The following object is masked from ‘package:future’:
#
#     %<-%
#
#
#
# Attaching package: ‘MLmetrics’
#
#
# The following objects are masked from ‘package:caret’:
#
#     MAE, RMSE
#
#
# The following object is masked from ‘package:base’:
#
#     Recall

# %% [markdown]
# # History Matching with dimensionality reduction
#
# 1. Space filling design of parameters space
# 2. Data simulation
# 3. Dimensionality reduction with PCA (EOF) or AE
# 4. Training of statistical emulator
# 5. Computation of implausibility
# 6. Refocussing
#     * If stoping criterion is reached stop HM
#     * Else, redefining parameters space and go to 1.
#
# ## Observations generation

# %%
np$random$seed(as.integer(42))

X_init = 10*np$ones(as.integer(36))
X_init[19]=1.0001 #ATtention X_init[19] !!!

l96_two = L96_amip$L96TwoLevel(save_dt=0.001, X_init=X_init, integration_type='coupled') # True params J=10, h=1, F=10, c=10, b=10

# %% [markdown]
# We first iterate 10 iterations in order to access to the steady state of the L96 model.
# We then iterate for n_iter iterations and use this history as an observation of the real model.
# We save the history of X in order to reinject it during the Y integration.

# %%
n_iter <- 50
dt <- 0.001
l96_two$iterate(10)
Newinit = l96_two$X
np$random$seed(as.integer(42))
l96_two = L96_amip$L96TwoLevel(save_dt=dt, X_init=Newinit, integration_type='coupled') 
l96_two$iterate(n_iter)
X_hist <- l96_two$history$X$values

# %% [markdown]
# We save the metrics generate with the ground truth parameters (observations).

# %%
system.time(observations <- l96_two$mean_stats(ax=as.integer(0)))
# Out:
#    user  system elapsed
#   7.589   0.522   8.171

# %% [markdown]
# ### Generation of metrics for the first wave

# %%
sampler <- import('skopt.sampler')
skSpace <- import('skopt.space')

# %%
n_samples <- 30

# %%
space <- skSpace$Space(list(c(-2, 2), c(0, 20), c(-20, 20))) ##only h,c,b
lhs <- sampler$Lhs()  #(lhs_type='classic', criterion='maximin', iterations=1000)
inputs_wave1 <- np$array(lhs$generate(space$dimensions, as.integer(n_samples), random_state=as.integer(42)))

# %%
extract_metrics_AMIP <- function(p, n_iter, dt, X_hist) {
    initX <- as.matrix(X_hist[1,])
    l96_mip = L96_amip$L96TwoLevel(X_init=initX, save_dt=dt, dt=dt, noYhist=FALSE, h=p[[1]], F=10, c=p[[2]], b=p[[3]])
    l96_mip$iterate_AMIP(X_hist, n_iter)
    return(l96_mip$mean_stats(ax=as.integer(0)))
}

# %%
plan(multicore)
metrics_wave1 = future_sapply(1:nrow(inputs_wave1), function(r) extract_metrics_AMIP(inputs_wave1[r,], n_iter, 0.001, X_hist), future.seed=NULL)

# %% [markdown]
# ## Dimensonality reduction of metrics space

# %%
n_samples_test <- 30
inputs_test <- np$array(lhs$generate(space$dimensions, as.integer(n_samples_test), random_state=as.integer(21)))

# %%
metrics_test = future_sapply(1:nrow(inputs_test), function(r) extract_metrics_AMIP(inputs_test[r,], n_iter, 0.001, X_hist), future.seed=NULL)

# %%
# Scale metrics
my.scaler <- sklearn$preprocessing$StandardScaler()
X <- my.scaler$fit_transform(t(metrics_wave1))
X_test <- my.scaler$fit_transform(t(metrics_test))
input_size = dim(X)[[2]]

# %% [markdown]
# ### Principal Component Analysis

# %%
pca <- sklearn$decomposition$PCA(n_components=as.integer(16))
X_pca <- pca$fit_transform(X)
X_pca_test <- pca$transform(X_test)
X_inverse_transform <- pca$inverse_transform(X_pca)
X_test_inverse_transform <- pca$inverse_transform(X_pca_test)
mse <- MSE(X_inverse_transform, X)
val_mse <- MSE(X_test_inverse_transform, X_test)
mse
val_mse
# Out:
# [1] 0.0001583287
# [1] 0.004399537

# %% [markdown]
# ### Autoencoder

# %%
latent_size <- 512

#Create encoder
enc_input = layer_input(shape = input_size)
enc_output = enc_input %>% 
  layer_dense(units=latent_size, activation = "sigmoid") 
encoder = keras_model(enc_input, enc_output)

#Create decoder
dec_input = layer_input(shape = latent_size)
dec_output = dec_input %>% 
  layer_dense(units = input_size, activation = "linear") %>%
  layer_dropout(rate=0.2)
decoder = keras_model(dec_input, dec_output)

#Create autoencoder
aen_input = layer_input(shape = input_size)
aen_output = aen_input %>% 
  encoder() %>% 
  decoder()
   
ae = keras_model(aen_input, aen_output)
summary(ae)
# Out:
# Model: "model_2"
# ________________________________________________________________________________
# Layer (type)                        Output Shape                    Param #
# ================================================================================
# input_3 (InputLayer)                [(None, 2340)]                  0
# ________________________________________________________________________________
# model (Functional)                  (None, 512)                     1198592
# ________________________________________________________________________________
# model_1 (Functional)                (None, 2340)                    1200420
# ================================================================================
# Total params: 2,399,012
# Trainable params: 2,399,012
# Non-trainable params: 0
# ________________________________________________________________________________

# %%
ae %>% compile(optimizer="Adam", loss="mean_squared_error")
ae %>% fit(X,X, epochs=300, batch_size=16, validation_data =list(X_test, X_test))

# %%
loss <- ae$history$history$loss
val.loss <- ae$history$history$val_loss
max.loss <- max(c(loss, val.loss))
plot(loss, type='b', ylim=c(0, max.loss))
lines(val.loss, col='red', type='b')
abline(h=val_mse, col='blue', lwd=5)
abline(h=mse, col='green', lwd=5)
legend(700, 1, legend=c("AE mse", "AE val mse", "PCA mse", "PCA val mse"), 
       col=c('black', 'red', 'blue', 'green'),
       lty=1:4,
       title="Losses")
# Out:
# plot without title

# %%
bottleneck.size <- 64
AE <- autoencoder(X, c(bottleneck.size), loss.type = 'squared',
                  activ.functions = c('tanh'),
                  batch.size = 5, optim.type = 'adam',
                  n.epochs = 1000, val.prop = 0)

plot(AE)
# Out:
# Artificial Neural Network:
#   Layer - 2340 nodes - input
#   Layer - 64 nodes - tanh
#   Layer - 2340 nodes - linear
# With squared loss and Adam optimizer
# Training progress:
# [++++++++++++++++++++++++++++++++++++++++++++++++++] 100% - Training loss: 12.6517
# plot without title

# %%
MSE(decode(AE,encode(AE,X_test)), X_test)
# Out:
# [1] 0.197569

# %% [markdown]
# ### Create the data matrix

# %%
#Inputs scaling
inputs_wave1 <- data.frame(inputs_wave1)
my_bounds <- data.frame(list(c(-2, 2), c(0, 20), c(-20, 20)))
inputs_wave1 <- rangeScale(inputs_wave1, my_bounds, range = c(-1, 1))
names(inputs_wave1) <- c('h', 'c', 'b')

#Classic metrics with k=0
k <- 0 # Select k in K for tunning 
metrics_index_k <- (k*65+1):((k+1)*65)
metrics_k_wave1 <- data.frame(t(metrics_wave1)[, metrics_index_k])
N = nrow(inputs_wave1) 
noise <- rnorm(N, 0, 0)
tData <- data.frame(cbind(inputs_wave1, noise, metrics_k_wave1))
names(tData)[names(tData) == "noise"] <- "Noise"

#Reduced data
tData_pca <- data.frame(cbind(inputs_wave1, noise, X_pca))
names(tData_pca)[names(tData_pca) == "noise"] <- "Noise"

X_ae <- encoder %>% predict(X)
tData_ae <- data.frame(cbind(inputs_wave1, noise, X_ae))
names(tData_ae)[names(tData_ae) == "noise"] <- "Noise"

X_auto <- encode(AE, X)
tData_auto <- data.frame(cbind(inputs_wave1, noise, X_auto))
names(tData_auto)[names(tData_auto) == "noise"] <- "Noise"

# %% [markdown]
# ### Training emulator

# %%
cands <- names(tData)[1:3]
em_wave1 <- BuildNewEmulators(tData, HowManyEmulators = ncol(metrics_k_wave1), meanFun = "fitted", additionalVariables = cands) # 
em_wave1_pca <- BuildNewEmulators(tData_pca, HowManyEmulators = ncol(X_pca), meanFun = "fitted", additionalVariables = cands) # 
em_wave1_ae <- BuildNewEmulators(tData_ae, HowManyEmulators = ncol(X_ae), meanFun = "fitted", additionalVariables = cands) # 
em_wave1_auto <- BuildNewEmulators(tData_auto, HowManyEmulators = ncol(X_auto), meanFun = "fitted", additionalVariables = cands) #
# Out:
# [1] "Max reduction is 0.038070400360393 using h"
# [1] "Max reduction is 0.00343926977438136 using b"
# [1] "Max reduction is 0.000523361270626549 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X1 ~ h + b + c + I(b * h) + I(c * h) + I(c * b),
#     data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.173574 -0.041700  0.006267  0.037875  0.206833
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.002978   0.013455  -0.221   0.8268
# h            0.146596   0.023972   6.115 3.08e-06 ***
# b            0.057239   0.023439   2.442   0.0227 *
# c           -0.041390   0.023577  -1.756   0.0925 .
# I(b * h)     0.002428   0.045440   0.053   0.9578
# I(c * h)     0.017603   0.043148   0.408   0.6871
# I(c * b)     0.011571   0.035831   0.323   0.7497
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07244 on 23 degrees of freedom
# Multiple R-squared:  0.6824,	Adjusted R-squared:  0.5995
# F-statistic: 8.236 on 6 and 23 DF,  p-value: 7.911e-05
#
# [1] "1 I(b * h)"
# [1] "2 I(c * b)"
#
# Call:
# lm(formula = X1 ~ h + b + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.174215 -0.042427  0.003215  0.037132  0.206031
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.002326   0.012792  -0.182   0.8572
# h            0.146145   0.022750   6.424    1e-06 ***
# b            0.057156   0.022378   2.554   0.0171 *
# c           -0.042177   0.022518  -1.873   0.0728 .
# I(c * h)     0.018025   0.041457   0.435   0.6674
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06965 on 25 degrees of freedom
# Multiple R-squared:  0.6809,	Adjusted R-squared:  0.6298
# F-statistic: 13.34 on 4 and 25 DF,  p-value: 5.989e-06
#
# [1] "Max reduction is 0.0769604591917449 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X2 ~ h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.165757 -0.029635  0.004091  0.026765  0.180767
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.008288   0.014182  -0.584    0.564
# h            0.231477   0.024826   9.324 4.41e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07768 on 28 degrees of freedom
# Multiple R-squared:  0.7564,	Adjusted R-squared:  0.7477
# F-statistic: 86.93 on 1 and 28 DF,  p-value: 4.411e-10
#
# [1] "Max reduction is 0.032882712792788 using h"
# [1] "Max reduction is 0.00718993251096252 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X3 ~ h + b + I(b * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.247731 -0.041498  0.004294  0.032958  0.242335
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.004276   0.015404  -0.278   0.7835
# h            0.148030   0.027309   5.421 1.11e-05 ***
# b            0.070361   0.026840   2.622   0.0144 *
# I(b * h)     0.002837   0.052744   0.054   0.9575
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08437 on 26 degrees of freedom
# Multiple R-squared:  0.5879,	Adjusted R-squared:  0.5403
# F-statistic: 12.36 on 3 and 26 DF,  p-value: 3.25e-05
#
# [1] "Max reduction is 0.0699230187620769 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X4 ~ h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.173013 -0.009680 -0.001641  0.018384  0.199119
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.01052    0.01363  -0.772    0.446
# h            0.21441    0.02385   8.989 9.59e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07463 on 28 degrees of freedom
# Multiple R-squared:  0.7426,	Adjusted R-squared:  0.7335
# F-statistic:  80.8 on 1 and 28 DF,  p-value: 9.587e-10
#
# [1] "Max reduction is 0.0320341111948727 using h"
# [1] "Max reduction is 0.00664051593551483 using b"
# [1] "Max reduction is 0.00101368413760125 using c"
# [1] "Max reduction is 0.000497063600802941 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X5 ~ h + b + c + I(c^2) + I(b * h) + I(c * h) +
#     I(c * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.209138 -0.039283 -0.009519  0.039538  0.208684
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.022059   0.023848  -0.925  0.36501
# h            0.140926   0.028089   5.017 5.05e-05 ***
# b            0.082790   0.027673   2.992  0.00672 **
# c           -0.054561   0.027687  -1.971  0.06147 .
# I(c^2)       0.061150   0.054242   1.127  0.27174
# I(b * h)    -0.002191   0.053167  -0.041  0.96750
# I(c * h)     0.031645   0.051946   0.609  0.54864
# I(c * b)     0.014466   0.042129   0.343  0.73458
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08464 on 22 degrees of freedom
# Multiple R-squared:  0.6512,	Adjusted R-squared:  0.5402
# F-statistic: 5.868 on 7 and 22 DF,  p-value: 0.0006193
#
# [1] "1 I(b * h)"
# [1] "2 I(c * b)"
# [1] "3 I(c * h)"
#
# Call:
# lm(formula = X5 ~ h + b + c + I(c^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.226357 -0.030928  0.006728  0.034652  0.195409
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.01898    0.02209  -0.859  0.39852
# h            0.13824    0.02596   5.324 1.61e-05 ***
# b            0.08091    0.02595   3.118  0.00454 **
# c           -0.05334    0.02594  -2.057  0.05031 .
# I(c^2)       0.05110    0.04955   1.031  0.31227
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08027 on 25 degrees of freedom
# Multiple R-squared:  0.6435,	Adjusted R-squared:  0.5864
# F-statistic: 11.28 on 4 and 25 DF,  p-value: 2.278e-05
#
# [1] "Max reduction is 0.075040573286997 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X6 ~ h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.192291 -0.037635  0.004051  0.032348  0.189754
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.009238   0.013988  -0.660    0.514
# h            0.226595   0.024488   9.253 5.19e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07662 on 28 degrees of freedom
# Multiple R-squared:  0.7536,	Adjusted R-squared:  0.7448
# F-statistic: 85.63 on 1 and 28 DF,  p-value: 5.186e-10
#
# [1] "Max reduction is 0.0326555320468552 using h"
# [1] "Max reduction is 0.00553869584885183 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X7 ~ h + b + I(b * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.264942 -0.041170 -0.003318  0.041854  0.234134
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.004253   0.015974  -0.266   0.7922
# h            0.149920   0.028320   5.294 1.55e-05 ***
# b            0.064078   0.027834   2.302   0.0296 *
# I(b * h)     0.019751   0.054698   0.361   0.7210
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08749 on 26 degrees of freedom
# Multiple R-squared:  0.5656,	Adjusted R-squared:  0.5154
# F-statistic: 11.28 on 3 and 26 DF,  p-value: 6.347e-05
#
# [1] "Max reduction is 0.0729830219421649 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X8 ~ h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.168187 -0.016507  0.003241  0.019268  0.195391
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.01154    0.01318  -0.876    0.389
# h            0.21801    0.02307   9.449 3.31e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07219 on 28 degrees of freedom
# Multiple R-squared:  0.7613,	Adjusted R-squared:  0.7527
# F-statistic: 89.28 on 1 and 28 DF,  p-value: 3.314e-10
#
# [1] "Max reduction is 0.0312394171783142 using h"
# [1] "Max reduction is 0.00915319413703305 using b"
# [1] "Max reduction is 0.00110811443133974 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X9 ~ h + b + c + I(b * h) + I(c * h) + I(c * b),
#     data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.278293 -0.047469  0.009714  0.049936  0.248102
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.001564   0.018910  -0.083 0.934818
# h            0.157387   0.033689   4.672 0.000106 ***
# b            0.097511   0.032941   2.960 0.007015 **
# c           -0.057686   0.033134  -1.741 0.095054 .
# I(b * h)     0.005238   0.063860   0.082 0.935341
# I(c * h)     0.049177   0.060640   0.811 0.425703
# I(c * b)     0.008689   0.050356   0.173 0.864511
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1018 on 23 degrees of freedom
# Multiple R-squared:  0.5997,	Adjusted R-squared:  0.4953
# F-statistic: 5.744 on 6 and 23 DF,  p-value: 0.0009022
#
# [1] "1 I(b * h)"
# [1] "2 I(c * b)"
#
# Call:
# lm(formula = X9 ~ h + b + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.278781 -0.048676  0.007198  0.053343  0.247717
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.001067   0.017950  -0.059  0.95306
# h            0.156764   0.031924   4.911  4.7e-05 ***
# b            0.097648   0.031401   3.110  0.00463 **
# c           -0.058404   0.031598  -1.848  0.07642 .
# I(c * h)     0.049578   0.058173   0.852  0.40217
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09773 on 25 degrees of freedom
# Multiple R-squared:  0.5991,	Adjusted R-squared:  0.5349
# F-statistic: 9.339 on 4 and 25 DF,  p-value: 9.27e-05
#
# [1] "Max reduction is 0.0767054993629879 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X10 ~ h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.246002 -0.040448  0.005031  0.042702  0.155525
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.00714    0.01494  -0.478    0.636
# h            0.23517    0.02615   8.992 9.53e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08183 on 28 degrees of freedom
# Multiple R-squared:  0.7428,	Adjusted R-squared:  0.7336
# F-statistic: 80.85 on 1 and 28 DF,  p-value: 9.526e-10
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X11 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.07210 -0.06002 -0.03698  0.02509  0.37573
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.07218    0.01730   4.172 0.000251 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09476 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X12 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04041 -0.03591 -0.02711 -0.00636  0.36151
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03637    0.01454   2.501   0.0183 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07966 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X13 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03349 -0.02816 -0.02367 -0.01068  0.33968
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03356    0.01351   2.484    0.019 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07399 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X14 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03610 -0.02984 -0.02470 -0.00996  0.31870
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03434    0.01311    2.62   0.0139 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07179 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X15 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03933 -0.03335 -0.02645 -0.00497  0.31756
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03940    0.01336   2.949  0.00624 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07317 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X16 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04187 -0.03423 -0.02690 -0.00464  0.33671
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03788    0.01396   2.714   0.0111 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07644 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X17 ~ 1, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.031847 -0.027669 -0.022764 -0.007184  0.285494
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03192    0.01198   2.664   0.0125 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06564 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X18 ~ 1, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.034176 -0.029480 -0.022053 -0.008967  0.298527
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03425    0.01240   2.763  0.00985 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0679 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X19 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03576 -0.03163 -0.02630 -0.00417  0.33703
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03583    0.01387   2.584   0.0151 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07595 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X20 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03977 -0.03001 -0.02323 -0.01004  0.31700
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03426    0.01306   2.624   0.0137 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07151 on 29 degrees of freedom
#
# [1] "Max reduction is 0.000846206092795204 using h"
# [1] "Max reduction is 0.0316418976436161 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X21 ~ h + I(h^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.175360 -0.026040 -0.002505  0.010011  0.191390
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.001435   0.018543   0.077   0.9389
# h           -0.037727   0.021458  -1.758   0.0901 .
# I(h^2)       0.247203   0.042638   5.798 3.61e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06714 on 27 degrees of freedom
# Multiple R-squared:  0.5772,	Adjusted R-squared:  0.5459
# F-statistic: 18.43 on 2 and 27 DF,  p-value: 8.975e-06
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X22 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03924 -0.03528 -0.02662 -0.00763  0.36108
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03562    0.01448    2.46   0.0201 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07931 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00169078562982362 using h"
# [1] "Max reduction is 0.0118291319156638 using h"
# [1] "Max reduction is 0.00133768350901668 using h"
# [1] "Max reduction is 0.00136258665959633 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X23 ~ h + I(h^2) + I(h^3) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.163641 -0.034161 -0.002744  0.024200  0.171783
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.006469   0.021379  -0.303  0.76483
# h            0.056533   0.063632   0.888  0.38312
# I(h^2)       0.162896   0.049471   3.293  0.00307 **
# I(h^3)      -0.179489   0.102213  -1.756  0.09184 .
# c            0.016490   0.024971   0.660  0.51531
# I(c * h)    -0.075868   0.046223  -1.641  0.11376
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07617 on 24 degrees of freedom
# Multiple R-squared:  0.4375,	Adjusted R-squared:  0.3203
# F-statistic: 3.733 on 5 and 24 DF,  p-value: 0.01217
#
# [1] "1 I(h^3)"
#
# Call:
# lm(formula = X23 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.121464 -0.044300  0.002313  0.014429  0.200279
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.005612   0.022247  -0.252   0.8029
# h           -0.046303   0.025907  -1.787   0.0860 .
# I(h^2)       0.162715   0.051491   3.160   0.0041 **
# c            0.011676   0.025834   0.452   0.6552
# I(c * h)    -0.059619   0.047137  -1.265   0.2176
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07928 on 25 degrees of freedom
# Multiple R-squared:  0.3652,	Adjusted R-squared:  0.2636
# F-statistic: 3.596 on 4 and 25 DF,  p-value: 0.01898
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X24 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03424 -0.03277 -0.02379 -0.01482  0.34303
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03362    0.01388   2.422   0.0219 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07601 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00210881215366783 using h"
# [1] "Max reduction is 0.0150192657623739 using h"
# [1] "Max reduction is 0.000355834167116889 using c"
# [1] "Max reduction is 0.00137490508858296 using h"
# [1] "Max reduction is 0.00103196912732863 using Three Way Interactions with h"
# [1] "Max reduction is 8.11516193519046e-05 using c"
# [1] "Max reduction is 0.00131441389965266 using c"
# [1] "Max reduction is 0.0044739790256407 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X25 ~ h + I(h^2) + I(h^3) + c + I(c^2) + I(c^3) +
#     I(c^4) + I(c * h) + I(h * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.146984 -0.027765 -0.000918  0.023336  0.181816
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.02752    0.03170  -0.868 0.395661
# h             0.04543    0.06099   0.745 0.464954
# I(h^2)        0.23378    0.05022   4.655 0.000153 ***
# I(h^3)       -0.15645    0.09654  -1.621 0.120769
# c             0.04094    0.06792   0.603 0.553381
# I(c^2)        0.27792    0.17019   1.633 0.118120
# I(c^3)       -0.13057    0.09532  -1.370 0.185903
# I(c^4)       -0.37696    0.19497  -1.933 0.067460 .
# I(c * h)     -0.08452    0.04626  -1.827 0.082628 .
# I(h * c * h)  0.23592    0.11144   2.117 0.046987 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07079 on 20 degrees of freedom
# Multiple R-squared:  0.6293,	Adjusted R-squared:  0.4624
# F-statistic: 3.772 on 9 and 20 DF,  p-value: 0.00643
#
# [1] "1 I(h^3)"
# [1] "2 I(c^4)"
# [1] "3 I(h * c * h)"
# [1] "4 I(c * h)"
# [1] "5 I(c^3)"
#
# Call:
# lm(formula = X25 ~ h + I(h^2) + c + I(c^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.173228 -0.035297 -0.007662  0.011633  0.236924
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.006895   0.029417   0.234  0.81660
# h           -0.042413   0.026423  -1.605  0.12102
# I(h^2)       0.183014   0.053330   3.432  0.00209 **
# c            0.015446   0.026560   0.582  0.56607
# I(c^2)      -0.021561   0.050326  -0.428  0.67201
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08172 on 25 degrees of freedom
# Multiple R-squared:  0.3824,	Adjusted R-squared:  0.2836
# F-statistic:  3.87 on 4 and 25 DF,  p-value: 0.01399
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X26 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03803 -0.03385 -0.02368 -0.00876  0.32108
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03630    0.01343   2.703   0.0114 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07356 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00137785033338457 using h"
# [1] "Max reduction is 0.0134146644289364 using h"
# [1] "Max reduction is 0.000347796331071543 using h"
# [1] "Max reduction is 0.00155555784323094 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X27 ~ h + I(h^2) + I(h^3) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.162578 -0.032340 -0.001404  0.024385  0.166086
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.004734   0.019958  -0.237  0.81453
# h            0.040055   0.059400   0.674  0.50655
# I(h^2)       0.167679   0.046181   3.631  0.00133 **
# I(h^3)      -0.143823   0.095415  -1.507  0.14478
# c            0.018522   0.023310   0.795  0.43464
# I(c * h)    -0.071637   0.043149  -1.660  0.10988
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07111 on 24 degrees of freedom
# Multiple R-squared:  0.4572,	Adjusted R-squared:  0.3441
# F-statistic: 4.043 on 5 and 24 DF,  p-value: 0.008376
#
# [1] "1 I(h^3)"
#
# Call:
# lm(formula = X27 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.128782 -0.034669 -0.001024  0.014224  0.188919
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.004048   0.020454  -0.198   0.8447
# h           -0.042347   0.023819  -1.778   0.0876 .
# I(h^2)       0.167534   0.047341   3.539   0.0016 **
# c            0.014665   0.023751   0.617   0.5425
# I(c * h)    -0.058617   0.043337  -1.353   0.1883
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07289 on 25 degrees of freedom
# Multiple R-squared:  0.4058,	Adjusted R-squared:  0.3108
# F-statistic: 4.269 on 4 and 25 DF,  p-value: 0.009061
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X28 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03838 -0.03598 -0.02553 -0.00519  0.36819
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03730    0.01491   2.502   0.0183 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08167 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00163144967489061 using h"
# [1] "Max reduction is 0.0134502676983164 using h"
# [1] "Max reduction is 0.000595787924902239 using h"
# [1] "Max reduction is 0.00129421280135357 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X29 ~ h + I(h^2) + I(h^3) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.180698 -0.033037 -0.001393  0.026328  0.172763
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.005724   0.022077  -0.259  0.79764
# h            0.046443   0.065708   0.707  0.48649
# I(h^2)       0.175838   0.051085   3.442  0.00213 **
# I(h^3)      -0.163030   0.105547  -1.545  0.13552
# c            0.018292   0.025786   0.709  0.48491
# I(c * h)    -0.076406   0.047731  -1.601  0.12251
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07866 on 24 degrees of freedom
# Multiple R-squared:  0.4401,	Adjusted R-squared:  0.3234
# F-statistic: 3.773 on 5 and 24 DF,  p-value: 0.01159
#
# [1] "1 I(h^3)"
#
# Call:
# lm(formula = X29 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.142388 -0.039489 -0.000722  0.014422  0.199988
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.004946   0.022675  -0.218  0.82909
# h           -0.046963   0.026405  -1.779  0.08747 .
# I(h^2)       0.175673   0.052482   3.347  0.00258 **
# c            0.013920   0.026330   0.529  0.60169
# I(c * h)    -0.061646   0.048043  -1.283  0.21121
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08081 on 25 degrees of freedom
# Multiple R-squared:  0.3844,	Adjusted R-squared:  0.2859
# F-statistic: 3.903 on 4 and 25 DF,  p-value: 0.01348
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X30 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.06917 -0.05866 -0.03342  0.02105  0.35339
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.06924    0.01617   4.283 0.000185 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08855 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X31 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03956 -0.03627 -0.02699 -0.00798  0.35916
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03689    0.01458    2.53   0.0171 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07985 on 29 degrees of freedom
#
# [1] "Max reduction is 0.000360055279690727 using h"
# [1] "Max reduction is 0.00890162709318842 using h"
# [1] "Max reduction is 0.00331409750106884 using c"
# [1] "Max reduction is 0.00166087082213522 using h"
# [1] "Max reduction is 0.00159835192608583 using Three Way Interactions with h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X32 ~ h + I(h^2) + I(h^3) + c + I(c * h) + I(h *
#     c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.125180 -0.025370  0.000829  0.020167  0.169575
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.00840    0.01768  -0.475  0.63920
# h             0.04435    0.05266   0.842  0.40834
# I(h^2)        0.14567    0.04159   3.502  0.00192 **
# I(h^3)       -0.13745    0.08457  -1.625  0.11773
# c            -0.02290    0.03365  -0.681  0.50293
# I(c * h)     -0.09956    0.03827  -2.601  0.01596 *
# I(h * c * h)  0.13839    0.09259   1.495  0.14858
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06295 on 23 degrees of freedom
# Multiple R-squared:  0.4937,	Adjusted R-squared:  0.3616
# F-statistic: 3.737 on 6 and 23 DF,  p-value: 0.009656
#
# [1] "1 I(h^3)"
# [1] "2 I(h * c * h)"
#
# Call:
# lm(formula = X32 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.110304 -0.031942  0.004256  0.016390  0.231490
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.008687   0.018579  -0.468  0.64415
# h           -0.035087   0.021635  -1.622  0.11740
# I(h^2)       0.134142   0.043002   3.119  0.00452 **
# c            0.013303   0.021574   0.617  0.54306
# I(c * h)    -0.084210   0.039365  -2.139  0.04237 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06621 on 25 degrees of freedom
# Multiple R-squared:  0.3912,	Adjusted R-squared:  0.2938
# F-statistic: 4.016 on 4 and 25 DF,  p-value: 0.01192
#
# [1] "Max reduction is 0.000104780568726107 using h"
# [1] "Max reduction is 0.00680915340740315 using h"
# [1] "Max reduction is 0.00451870529057272 using c"
# [1] "Max reduction is 0.00401807903928292 using Three Way Interactions with h"
# [1] "Max reduction is 0.000394661972201657 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X33 ~ h + I(h^2) + I(h^3) + c + I(c * h) + I(h *
#     c * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.13815 -0.03470 -0.00914  0.01926  0.20068
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.008486   0.019493  -0.435  0.66737
# h             0.025112   0.058062   0.432  0.66941
# I(h^2)        0.145925   0.045856   3.182  0.00415 **
# I(h^3)       -0.105233   0.093243  -1.129  0.27071
# c            -0.040275   0.037104  -1.085  0.28896
# I(c * h)     -0.113249   0.042196  -2.684  0.01325 *
# I(h * c * h)  0.209566   0.102086   2.053  0.05164 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06941 on 23 degrees of freedom
# Multiple R-squared:  0.4743,	Adjusted R-squared:  0.3372
# F-statistic: 3.459 on 6 and 23 DF,  p-value: 0.0139
#
# [1] "1 I(h^3)"
# [1] "2 I(h * c * h)"
#
# Call:
# lm(formula = X33 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.111657 -0.031727 -0.004964  0.018899  0.277196
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.009412   0.020714  -0.454   0.6535
# h           -0.036222   0.024122  -1.502   0.1457
# I(h^2)       0.128579   0.047945   2.682   0.0128 *
# c            0.017311   0.024054   0.720   0.4784
# I(c * h)    -0.099326   0.043890  -2.263   0.0326 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07382 on 25 degrees of freedom
# Multiple R-squared:  0.3536,	Adjusted R-squared:  0.2502
# F-statistic: 3.419 on 4 and 25 DF,  p-value: 0.02318
#
# [1] "Max reduction is 0.000238925501351406 using h"
# [1] "Max reduction is 0.0103772778201478 using h"
# [1] "Max reduction is 0.00351743529625961 using c"
# [1] "Max reduction is 0.00354942939195911 using Three Way Interactions with h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X34 ~ h + I(h^2) + c + I(c * h) + I(h * c * h),
#     data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.121046 -0.032240 -0.006868  0.018908  0.178467
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.005441   0.017637  -0.308 0.760375
# h            -0.033540   0.020530  -1.634 0.115377
# I(h^2)        0.160300   0.041496   3.863 0.000744 ***
# c            -0.036881   0.033563  -1.099 0.282731
# I(c * h)     -0.088786   0.037395  -2.374 0.025927 *
# I(h * c * h)  0.182361   0.092281   1.976 0.059741 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06281 on 24 degrees of freedom
# Multiple R-squared:  0.4961,	Adjusted R-squared:  0.3911
# F-statistic: 4.725 on 5 and 24 DF,  p-value: 0.00381
#
# [1] "1 I(h * c * h)"
#
# Call:
# lm(formula = X34 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.102586 -0.025568  0.005423  0.017924  0.229705
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.006683   0.018621  -0.359  0.72268
# h           -0.034446   0.021685  -1.588  0.12474
# I(h^2)       0.145298   0.043100   3.371  0.00244 **
# c            0.015685   0.021624   0.725  0.47497
# I(c * h)    -0.084961   0.039455  -2.153  0.04113 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06636 on 25 degrees of freedom
# Multiple R-squared:  0.4141,	Adjusted R-squared:  0.3203
# F-statistic: 4.417 on 4 and 25 DF,  p-value: 0.007739
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X35 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03880 -0.03310 -0.02475 -0.00521  0.33500
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03848    0.01382   2.785  0.00934 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0757 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X36 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04091 -0.03452 -0.02908 -0.01028  0.38152
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04098    0.01538   2.665   0.0124 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08422 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X37 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04055 -0.03309 -0.02575 -0.01032  0.39298
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03524    0.01533   2.298    0.029 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08399 on 29 degrees of freedom
#
# [1] "Max reduction is 0.000477293490316819 using h"
# [1] "Max reduction is 0.0344453322638022 using h"
# [1] "Max reduction is 0.00085276903020625 using c"
# [1] "Max reduction is 0.00118689747971615 using Three Way Interactions with h"
# [1] "Max reduction is 0.000703546144182603 using c"
# [1] "Max reduction is 0.00146462221182445 using c"
# [1] "Max reduction is 0.00176588517352828 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X38 ~ h + I(h^2) + c + I(c^2) + I(c^3) + I(c^4) +
#     I(c * h) + I(h * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.101957 -0.019724 -0.000889  0.015371  0.146254
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.01708    0.02485  -0.687   0.4995
# h            -0.03364    0.01861  -1.808   0.0850 .
# I(h^2)        0.29401    0.03936   7.469 2.43e-07 ***
# c             0.03935    0.05299   0.743   0.4659
# I(c^2)        0.16167    0.13331   1.213   0.2387
# I(c^3)       -0.11152    0.07412  -1.505   0.1473
# I(c^4)       -0.23722    0.15242  -1.556   0.1346
# I(c * h)     -0.05502    0.03514  -1.566   0.1323
# I(h * c * h)  0.18508    0.08716   2.123   0.0458 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0555 on 21 degrees of freedom
# Multiple R-squared:   0.76,	Adjusted R-squared:  0.6685
# F-statistic: 8.311 on 8 and 21 DF,  p-value: 4.797e-05
#
# [1] "1 I(c^4)"
# [1] "2 I(h * c * h)"
# [1] "3 I(c * h)"
# [1] "4 I(c^3)"
#
# Call:
# lm(formula = X38 ~ h + I(h^2) + c + I(c^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.154538 -0.016269 -0.004506  0.016681  0.171390
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.00609    0.02241   0.272    0.788
# h           -0.03040    0.02013  -1.510    0.144
# I(h^2)       0.25479    0.04063   6.271 1.46e-06 ***
# c            0.01808    0.02024   0.893    0.380
# I(c^2)      -0.02897    0.03834  -0.755    0.457
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06226 on 25 degrees of freedom
# Multiple R-squared:  0.6403,	Adjusted R-squared:  0.5827
# F-statistic: 11.13 on 4 and 25 DF,  p-value: 2.533e-05
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X39 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04089 -0.03604 -0.02664 -0.00681  0.34201
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03728    0.01420   2.626   0.0137 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07776 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00194798396845916 using h"
# [1] "Max reduction is 0.0121063138323613 using h"
# [1] "Max reduction is 0.00156829830594608 using h"
# [1] "Max reduction is 0.00266441051233036 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X40 ~ h + I(h^2) + I(h^3) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.163123 -0.032956 -0.001505  0.026659  0.187952
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.007405   0.021791  -0.340  0.73695
# h            0.062140   0.064856   0.958  0.34756
# I(h^2)       0.168931   0.050423   3.350  0.00266 **
# I(h^3)      -0.195426   0.104180  -1.876  0.07289 .
# c            0.019895   0.025451   0.782  0.44205
# I(c * h)    -0.087668   0.047112  -1.861  0.07506 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07764 on 24 degrees of freedom
# Multiple R-squared:  0.4579,	Adjusted R-squared:  0.3449
# F-statistic: 4.054 on 5 and 24 DF,  p-value: 0.008271
#
# [1] "1 I(h^3)"
#
# Call:
# lm(formula = X40 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.128871 -0.047212  0.002235  0.015683  0.220696
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.006473   0.022856  -0.283  0.77936
# h           -0.049828   0.026616  -1.872  0.07294 .
# I(h^2)       0.168734   0.052902   3.190  0.00381 **
# c            0.014654   0.026541   0.552  0.58577
# I(c * h)    -0.069976   0.048428  -1.445  0.16089
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08146 on 25 degrees of freedom
# Multiple R-squared:  0.3784,	Adjusted R-squared:  0.2789
# F-statistic: 3.805 on 4 and 25 DF,  p-value: 0.01504
#
# [1] "Max reduction is 9.11661266290581e-05 using h"
# [1] "Max reduction is 0.0075032479744374 using h"
# [1] "Max reduction is 0.00389943924932687 using c"
# [1] "Max reduction is 0.0025644502923481 using Three Way Interactions with h"
# [1] "Max reduction is 7.61658749472496e-05 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X41 ~ h + I(h^2) + I(h^3) + c + I(c * h) + I(h *
#     c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.119268 -0.030931 -0.001149  0.017851  0.170412
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.009374   0.017397  -0.539  0.59518
# h             0.017938   0.051819   0.346  0.73236
# I(h^2)        0.138093   0.040924   3.374  0.00262 **
# I(h^3)       -0.085638   0.083216  -1.029  0.31413
# c            -0.029317   0.033114  -0.885  0.38514
# I(c * h)     -0.097311   0.037658  -2.584  0.01659 *
# I(h * c * h)  0.165140   0.091108   1.813  0.08297 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06195 on 23 degrees of freedom
# Multiple R-squared:  0.4742,	Adjusted R-squared:  0.3371
# F-statistic: 3.457 on 6 and 23 DF,  p-value: 0.01392
#
# [1] "1 I(h^3)"
# [1] "2 I(h * c * h)"
#
# Call:
# lm(formula = X41 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.098498 -0.026711  0.001673  0.016291  0.231161
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.01009    0.01812  -0.557  0.58261
# h           -0.03195    0.02110  -1.514  0.14261
# I(h^2)       0.12442    0.04195   2.966  0.00655 **
# c            0.01599    0.02104   0.760  0.45451
# I(c * h)    -0.08609    0.03840  -2.242  0.03407 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06459 on 25 degrees of freedom
# Multiple R-squared:  0.3787,	Adjusted R-squared:  0.2793
# F-statistic:  3.81 on 4 and 25 DF,  p-value: 0.01494
#
# [1] "Max reduction is 0.00145997444945883 using h"
# [1] "Max reduction is 0.0152439818939087 using h"
# [1] "Max reduction is 0.000504301187823838 using c"
# [1] "Max reduction is 0.000926383969195727 using h"
# [1] "Max reduction is 0.000165924420353417 using Three Way Interactions with h"
# [1] "Max reduction is 0.000190541320363599 using c"
# [1] "Max reduction is 0.00101275789040564 using c"
# [1] "Max reduction is 0.00370338870902293 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X42 ~ h + I(h^2) + I(h^3) + c + I(c^2) + I(c^3) +
#     I(c^4) + I(c * h) + I(h * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.136595 -0.026744 -0.001634  0.023549  0.173154
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.02519    0.03002  -0.839 0.411199
# h             0.03928    0.05774   0.680 0.504130
# I(h^2)        0.22122    0.04755   4.653 0.000153 ***
# I(h^3)       -0.13572    0.09140  -1.485 0.153190
# c             0.04276    0.06430   0.665 0.513681
# I(c^2)        0.24699    0.16114   1.533 0.141001
# I(c^3)       -0.11775    0.09025  -1.305 0.206789
# I(c^4)       -0.33961    0.18459  -1.840 0.080691 .
# I(c * h)     -0.07953    0.04380  -1.816 0.084405 .
# I(h * c * h)  0.19404    0.10551   1.839 0.080801 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06702 on 20 degrees of freedom
# Multiple R-squared:  0.6195,	Adjusted R-squared:  0.4482
# F-statistic: 3.618 on 9 and 20 DF,  p-value: 0.007964
#
# [1] "1 I(h^3)"
# [1] "2 I(c^4)"
# [1] "3 I(h * c * h)"
# [1] "4 I(c * h)"
# [1] "5 I(c^3)"
#
# Call:
# lm(formula = X42 ~ h + I(h^2) + c + I(c^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.159378 -0.032501 -0.005883  0.006925  0.206645
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.005925   0.027208   0.218  0.82937
# h           -0.036368   0.024438  -1.488  0.14922
# I(h^2)       0.177016   0.049325   3.589  0.00141 **
# c            0.014323   0.024565   0.583  0.56508
# I(c^2)      -0.022440   0.046546  -0.482  0.63392
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07559 on 25 degrees of freedom
# Multiple R-squared:  0.3951,	Adjusted R-squared:  0.2983
# F-statistic: 4.082 on 4 and 25 DF,  p-value: 0.01109
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X43 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04095 -0.03755 -0.02796 -0.00524  0.36298
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04006    0.01504   2.664   0.0125 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08237 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00155411759942227 using h"
# [1] "Max reduction is 0.0146903469277411 using h"
# [1] "Max reduction is 0.000713505953664414 using c"
# [1] "Max reduction is 0.00165727874234882 using h"
# [1] "Max reduction is 0.00054071974187557 using Three Way Interactions with h"
# [1] "Max reduction is 7.82111117644257e-05 using c"
# [1] "Max reduction is 0.00134543527458718 using c"
# [1] "Max reduction is 0.00487539615598513 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X44 ~ h + I(h^2) + I(h^3) + c + I(c^2) + I(c^3) +
#     I(c^4) + I(c * h) + I(h * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.139960 -0.034494  0.002711  0.019159  0.177621
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.03220    0.03109  -1.036 0.312715
# h             0.05169    0.05982   0.864 0.397721
# I(h^2)        0.23005    0.04925   4.671 0.000147 ***
# I(h^3)       -0.16084    0.09468  -1.699 0.104875
# c             0.04498    0.06661   0.675 0.507195
# I(c^2)        0.28522    0.16692   1.709 0.102975
# I(c^3)       -0.12984    0.09348  -1.389 0.180148
# I(c^4)       -0.38496    0.19122  -2.013 0.057754 .
# I(c * h)     -0.08768    0.04537  -1.933 0.067578 .
# I(h * c * h)  0.22164    0.10930   2.028 0.056104 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06943 on 20 degrees of freedom
# Multiple R-squared:  0.6307,	Adjusted R-squared:  0.4646
# F-statistic: 3.796 on 9 and 20 DF,  p-value: 0.006221
#
# [1] "1 I(h^3)"
# [1] "2 I(c^4)"
# [1] "3 I(h * c * h)"
# [1] "4 I(c * h)"
# [1] "5 I(c^3)"
#
# Call:
# lm(formula = X44 ~ h + I(h^2) + c + I(c^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.163067 -0.033444 -0.005550  0.008636  0.237846
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.002944   0.029132   0.101  0.92031
# h           -0.038522   0.026167  -1.472  0.15345
# I(h^2)       0.180291   0.052813   3.414  0.00219 **
# c            0.015433   0.026302   0.587  0.56264
# I(c^2)      -0.020434   0.049838  -0.410  0.68529
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08093 on 25 degrees of freedom
# Multiple R-squared:  0.3728,	Adjusted R-squared:  0.2725
# F-statistic: 3.716 on 4 and 25 DF,  p-value: 0.0166
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X45 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.06913 -0.05610 -0.03093  0.02319  0.31832
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.06920    0.01527   4.533 9.27e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08362 on 29 degrees of freedom
#
# [1] "Max reduction is 0.000127128418197259 using h"
# [1] "Max reduction is 0.00826168925311321 using h"
# [1] "Max reduction is 0.00426242316188383 using c"
# [1] "Max reduction is 0.00412551582499329 using Three Way Interactions with h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X46 ~ h + I(h^2) + c + I(c * h) + I(h * c * h),
#     data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.130768 -0.032185 -0.004761  0.018579  0.195258
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.007885   0.018628  -0.423  0.67584
# h            -0.034012   0.021684  -1.569  0.12985
# I(h^2)        0.153103   0.043827   3.493  0.00187 **
# c            -0.039330   0.035449  -1.109  0.27822
# I(c * h)     -0.097771   0.039497  -2.475  0.02076 *
# I(h * c * h)  0.199886   0.097467   2.051  0.05136 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06634 on 24 degrees of freedom
# Multiple R-squared:  0.4728,	Adjusted R-squared:  0.3629
# F-statistic: 4.304 on 5 and 24 DF,  p-value: 0.006165
#
# [1] "1 I(h * c * h)"
#
# Call:
# lm(formula = X46 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.101636 -0.025827  0.002797  0.017361  0.251421
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# ...
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.70580 -0.07249  0.23832  0.40094  0.49757
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.02178    0.11551   0.189    0.852
#
# Residual standard error: 0.6327 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = node_52 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.41286 -0.28482 -0.19844 -0.06922  1.72191
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.02746    0.10219  -0.269     0.79
#
# Residual standard error: 0.5597 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00694807204831693 using b"
# [1] "Max reduction is 0.0267315092244048 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = node_53 ~ b + I(b^2), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.84947 -0.23334 -0.04402  0.10153  1.50608
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.1957     0.1408   1.390   0.1758
# b             0.2250     0.1619   1.390   0.1760
# I(b^2)       -0.6332     0.3165  -2.001   0.0556 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5115 on 27 degrees of freedom
# Multiple R-squared:  0.1804,	Adjusted R-squared:  0.1197
# F-statistic: 2.972 on 2 and 27 DF,  p-value: 0.06812
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = node_54 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.76808 -0.37338 -0.08956  0.00750  1.72491
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.02579    0.11500  -0.224    0.824
#
# Residual standard error: 0.6299 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = node_55 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.74160  0.03461  0.19403  0.39087  0.56885
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04786    0.12459   0.384    0.704
#
# Residual standard error: 0.6824 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = node_56 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.66624  0.01787  0.17751  0.33304  0.40100
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.01013    0.10230   0.099    0.922
#
# Residual standard error: 0.5603 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = node_57 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.62675 -0.17062 -0.04513  0.25463  0.76932
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.003437   0.085939   -0.04    0.968
#
# Residual standard error: 0.4707 on 29 degrees of freedom
#
# [1] "Max reduction is 0.0124125573132888 using h"
# [1] "Max reduction is 0.0242045885149971 using h"
# [1] "Max reduction is 0.0229958218949898 using c"
# [1] "Max reduction is 0.0102060780434993 using Three Way Interactions with h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = node_58 ~ h + I(h^2) + c + I(c * h) + I(h * c *
#     h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.99244 -0.21886 -0.00761  0.23678  1.15548
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -0.2314     0.1347  -1.718   0.0986 .
# h              0.2135     0.1567   1.362   0.1858
# I(h^2)         0.7305     0.3168   2.306   0.0301 *
# c             -0.2248     0.2563  -0.877   0.3891
# I(c * h)      -0.6412     0.2855  -2.246   0.0342 *
# I(h * c * h)   1.0150     0.7046   1.441   0.1626
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4796 on 24 degrees of freedom
# Multiple R-squared:  0.3694,	Adjusted R-squared:  0.238
# F-statistic: 2.812 on 5 and 24 DF,  p-value: 0.03891
#
# [1] "1 I(h * c * h)"
#
# Call:
# lm(formula = node_58 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.09896 -0.23669  0.02634  0.15941  1.33925
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.23829    0.13743  -1.734   0.0953 .
# h            0.20848    0.16004   1.303   0.2046
# I(h^2)       0.64696    0.31810   2.034   0.0527 .
# c            0.06781    0.15959   0.425   0.6746
# I(c * h)    -0.61996    0.29119  -2.129   0.0433 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4898 on 25 degrees of freedom
# Multiple R-squared:  0.3149,	Adjusted R-squared:  0.2052
# F-statistic: 2.872 on 4 and 25 DF,  p-value: 0.04371
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = node_59 ~ 1, data = tData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.5979 -0.3970 -0.1819 -0.0077  1.7202
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.0338     0.1195  -0.283    0.779
#
# Residual standard error: 0.6543 on 29 degrees of freedom
#
# [1] "Max reduction is 0.0880202339019692 using h"
# [1] "Max reduction is 0.131133027419851 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = node_60 ~ h + I(h^2), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.77754 -0.10953  0.00343  0.08657  0.81732
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.36353    0.08679   4.189 0.000268 ***
# h            0.52081    0.10044   5.186 1.85e-05 ***
# I(h^2)      -1.07925    0.19957  -5.408 1.02e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3142 on 27 degrees of freedom
# Multiple R-squared:  0.6769,	Adjusted R-squared:  0.6529
# F-statistic: 28.28 on 2 and 27 DF,  p-value: 2.381e-07
#
# [1] "Max reduction is 0.0300319488644802 using h"
# [1] "Max reduction is 0.0204153224258 using b"
# [1] "Max reduction is 0.00635252980820467 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = node_61 ~ h + I(h^2) + b + I(b * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.35194 -0.11026  0.01906  0.18690  1.42148
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.143793   0.134525   1.069   0.2953
# h           -0.345838   0.155931  -2.218   0.0359 *
# I(h^2)      -0.405922   0.312200  -1.300   0.2054
# b           -0.353455   0.154718  -2.285   0.0311 *
# I(b * h)     0.005943   0.303715   0.020   0.9845
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4815 on 25 degrees of freedom
# Multiple R-squared:  0.3102,	Adjusted R-squared:  0.1999
# F-statistic: 2.811 on 4 and 25 DF,  p-value: 0.04698
#
# [1] "Max reduction is 0.197774322438777 using h"
# [1] "Max reduction is 0.0166124547181835 using b"
# [1] "Max reduction is 0.00220117725213309 using h"
# [1] "Max reduction is 0.000297208264020743 using Three Way Interactions with h"
# [1] "Max reduction is 0.0450185674825304 using c"
# [1] "Max reduction is 0.00216101256775192 using h"
# [1] "Max reduction is 0.00409072498227148 using c"
# [1] "Max reduction is 0.0087678442986695 using c"
# [1] "Max reduction is 0.00916214047251257 using Three Way Interactions with c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = node_62 ~ h + I(h^2) + I(h^3) + b + c + I(c^2) +
#     I(c^3) + I(b * h) + I(c * h) + I(c * b) + I(h * b * h) +
#     I(h * c * h) + I(h * c * b) + I(c * c * h) + I(c * c * b),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.51306 -0.10564  0.03025  0.12165  0.32164
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.12528    0.10702   1.171  0.26132
# h             0.61715    0.39060   1.580  0.13642
# I(h^2)       -0.62250    0.19942  -3.122  0.00750 **
# I(h^3)        0.03456    0.58272   0.059  0.95355
# b             0.13253    0.18995   0.698  0.49678
# c            -0.21657    0.30035  -0.721  0.48274
# I(c^2)       -0.04872    0.22541  -0.216  0.83199
# I(c^3)        1.11113    0.50413   2.204  0.04476 *
# I(b * h)      0.43721    0.22306   1.960  0.07021 .
# I(c * h)     -0.45144    0.31885  -1.416  0.17868
# I(c * b)      0.10848    0.19355   0.560  0.58402
# I(h * b * h)  1.09992    0.47571   2.312  0.03650 *
# I(h * c * h) -1.83326    0.53389  -3.434  0.00403 **
# I(h * c * b) -0.95335    0.49708  -1.918  0.07575 .
# I(c * c * h)  0.55105    0.42874   1.285  0.21954
# I(c * c * b) -0.56094    0.39130  -1.434  0.17366
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2617 on 14 degrees of freedom
# Multiple R-squared:  0.8898,	Adjusted R-squared:  0.7717
# F-statistic: 7.537 on 15 and 14 DF,  p-value: 0.0002507
#
# [1] "1 I(h^3)"
# [1] "2 I(c * c * h)"
# [1] "3 I(c^3)"
# [1] "4 I(c^2)"
# [1] "5 I(h * b * h)"
# [1] "6 I(b * h)"
# [1] "7 I(c * c * b)"
# [1] "8 I(h * c * b)"
# [1] "9 I(c * b)"
# [1] "10 I(h^2)"
# [1] "11 I(h * c * h)"
#
# Call:
# lm(formula = node_62 ~ h + b + c + I(c * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.91645 -0.11849  0.01806  0.19876  0.79476
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.0003227  0.0615331  -0.005   0.9959
# h            0.7255615  0.1094336   6.630 6.02e-07 ***
# b            0.2355677  0.1076426   2.188   0.0382 *
# c           -0.1334656  0.1083174  -1.232   0.2293
# I(c * h)     0.0575432  0.1994156   0.289   0.7753
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.335 on 25 degrees of freedom
# Multiple R-squared:  0.6776,	Adjusted R-squared:  0.626
# F-statistic: 13.13 on 4 and 25 DF,  p-value: 6.786e-06
#
# [1] "Max reduction is 0.117818844156276 using h"
# [1] "Max reduction is 0.0538982747015407 using h"
# [1] "Max reduction is 0.00990299569206887 using b"
# [1] "Max reduction is 0.00224691297698448 using b"
# [1] "Max reduction is 0.0459896932307786 using Three Way Interactions with b"
# [1] "Max reduction is 0.00134747488102938 using b"
# [1] "Max reduction is 0.0303251322337633 using c"
# [1] "Max reduction is 0.031176360220238 using c"
# [1] "Max reduction is 0.0179805753676942 using Three Way Interactions with c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = node_63 ~ h + I(h^2) + b + I(b^2) + I(b^3) + c +
#     I(c^2) + I(b * h) + I(c * h) + I(c * b) + I(b * b * h) +
#     I(b * c * h) + I(b * c * b) + I(c * c * h) + I(c * c * b),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.36906 -0.11454  0.03706  0.11107  0.38594
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    0.1220     0.1108   1.101 0.289611
# h              0.7279     0.1382   5.267 0.000119 ***
# I(h^2)        -0.8833     0.1855  -4.762 0.000304 ***
# b              0.8290     0.2558   3.241 0.005915 **
# I(b^2)         0.3186     0.2093   1.523 0.150142
# I(b^3)        -1.1574     0.4135  -2.799 0.014206 *
# c             -0.4871     0.1945  -2.504 0.025278 *
# I(c^2)         0.2854     0.2144   1.331 0.204387
# I(b * h)       0.3370     0.2026   1.663 0.118514
# I(c * h)      -0.3063     0.2035  -1.505 0.154502
# I(c * b)      -0.2369     0.1581  -1.498 0.156340
# I(b * b * h)  -1.8930     0.4099  -4.618 0.000398 ***
# I(b * c * h)   0.7577     0.3353   2.260 0.040295 *
# I(b * c * b)   1.1327     0.4025   2.814 0.013791 *
# I(c * c * h)   0.7817     0.3812   2.051 0.059515 .
# I(c * c * b)  -0.2366     0.3002  -0.788 0.443648
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2559 on 14 degrees of freedom
# Multiple R-squared:  0.9015,	Adjusted R-squared:  0.796
# F-statistic: 8.543 on 15 and 14 DF,  p-value: 0.0001229
#
# [1] "1 I(c * c * b)"
# [1] "2 I(b * c * h)"
# [1] "3 I(b^3)"
# [1] "4 I(c^2)"
# [1] "5 I(b * c * b)"
# [1] "6 I(c * b)"
# [1] "7 I(b^2)"
# [1] "8 I(c * c * h)"
# [1] "9 I(c * h)"
# [1] "10 c"
# [1] "11 I(b * b * h)"
#
# Call:
# lm(formula = node_63 ~ h + I(h^2) + b + I(b * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.82089 -0.09010 -0.01331  0.10803  1.05621
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.22393    0.10756   2.082   0.0477 *
# h            0.61480    0.12467   4.931 4.45e-05 ***
# I(h^2)      -0.68110    0.24961  -2.729   0.0115 *
# b            0.22213    0.12370   1.796   0.0846 .
# I(b * h)     0.06799    0.24283   0.280   0.7818
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.385 on 25 degrees of freedom
# Multiple R-squared:  0.602,	Adjusted R-squared:  0.5383
# F-statistic: 9.454 on 4 and 25 DF,  p-value: 8.496e-05
#
# [1] "Max reduction is 0.0097890314742759 using h"
# [1] "Max reduction is 0.184663385450204 using h"
# [1] "Max reduction is 0.0134787356121588 using c"
# [1] "Max reduction is 0.00874163049944521 using b"
# [1] "Max reduction is 0.0156206395158229 using b"
# [1] "Max reduction is 0.011609477057462 using h"
# [1] "Max reduction is 0.0364685571535504 using Three Way Interactions with h"
# [1] "Max reduction is 0.00845310875304744 using h"
# [1] "Max reduction is 0.00031822314719443 using Three Way Interactions with b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = node_64 ~ h + I(h^2) + I(h^3) + I(h^4) + c + b +
#     I(b^2) + I(c * h) + I(b * h) + I(b * c) + I(h * c * h) +
#     I(h * b * h) + I(h * b * c) + I(b * b * h) + I(b * b * c),
#     data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.38090 -0.18912  0.07002  0.13488  0.42978
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -0.2301     0.1501  -1.533  0.14757
# h              1.2933     0.3907   3.310  0.00516 **
# I(h^2)         0.3231     0.9603   0.336  0.74150
# I(h^3)        -1.6691     0.5582  -2.990  0.00974 **
# I(h^4)         1.5918     1.1850   1.343  0.20054
# c             -0.2086     0.3057  -0.682  0.50610
# b             -0.2328     0.1906  -1.221  0.24220
# I(b^2)        -0.6801     0.2363  -2.878  0.01217 *
# I(c * h)      -0.9687     0.2625  -3.690  0.00243 **
# I(b * h)       0.5215     0.2477   2.105  0.05381 .
# I(b * c)       0.5423     0.2178   2.490  0.02596 *
# I(h * c * h)   0.6253     0.6509   0.961  0.35302
# I(h * b * h)   0.4321     0.5126   0.843  0.41342
# I(h * b * c)  -1.1293     0.5158  -2.189  0.04601 *
# I(b * b * h)  -0.1369     0.5312  -0.258  0.80040
# I(b * b * c)   0.6250     0.4393   1.423  0.17669
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3176 on 14 degrees of freedom
# Multiple R-squared:  0.8677,	Adjusted R-squared:  0.726
# F-statistic: 6.122 on 15 and 14 DF,  p-value: 0.0007842
#
# [1] "1 I(b * b * h)"
# [1] "2 I(h * b * h)"
# [1] "3 I(h^4)"
# [1] "4 I(h^3)"
# [1] "5 I(b * b * c)"
# [1] "6 I(h * b * c)"
# [1] "7 I(b * c)"
# [1] "8 I(h * c * h)"
# [1] "9 I(c * h)"
# [1] "10 c"
# [1] "11 I(b * h)"
#
# Call:
# lm(formula = node_64 ~ h + I(h^2) + b + I(b^2), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.58064 -0.20553 -0.02872  0.07418  1.22673
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.27632    0.14833  -1.863   0.0743 .
# h            0.30113    0.12398   2.429   0.0227 *
# I(h^2)       1.36371    0.25559   5.336 1.57e-05 ***
# b            0.08779    0.12367   0.710   0.4844
# I(b^2)      -0.56310    0.24732  -2.277   0.0316 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3859 on 25 degrees of freedom
# Multiple R-squared:  0.6514,	Adjusted R-squared:  0.5956
# F-statistic: 11.68 on 4 and 25 DF,  p-value: 1.741e-05

# %% [markdown]
# ### Compute implausibility

# %%
tDisc <- rep(0, ncol(metrics_k_wave1)) # model discrepancy variance Var[g] 
tObsErr <- rep(0, ncol(metrics_k_wave1)) # observational error variance Var[e]
tObs <-  as.vector(observations[metrics_index_k]) # Observations

tDisc_pca <- rep(0, ncol(X_pca)) # model discrepancy variance Var[g] 
tObsErr_pca <- rep(0, ncol(X_pca)) # observational error variance Var[e]
tObs_pca <-  pca$transform(t(data.frame(observations))) # Observations with pca

tDisc_ae <- rep(0, ncol(X_ae)) # model discrepancy variance Var[g] 
tObsErr_ae <- rep(0, ncol(X_ae)) # observational error variance Var[e]
tObs_ae <-  encoder %>% predict(t(data.frame(observations))) # Observations with pca

tDisc_auto <- rep(0, ncol(X_auto)) # model discrepancy variance Var[g] 
tObsErr_auto <- rep(0, ncol(X_auto)) # observational error variance Var[e]
tObs_auto <-  encode(AE, (t(data.frame(observations)))) # Observations with pca

# %% [markdown]
# We generate a large sampling of the parameter space (that we have scaled) and will compute implausibility for each point of this parameters space.

# %%
sample_size <- 50000
nparam <- length(names(em_wave1$fitting.elements$Design))
Xp <- as.data.frame(2*randomLHS(sample_size, nparam)-1)
names(Xp) <- names(em_wave1$fitting.elements$Design)

# %%
system.time(Timps <- ImplausibilityMOGP(NewData=Xp, Emulator=em_wave1, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))
system.time(Timps_pca <- ImplausibilityMOGP(NewData=Xp, Emulator=em_wave1_pca, Discrepancy=tDisc_pca, Obs=tObs_pca, ObsErr=tObsErr_pca))
system.time(Timps_ae <- ImplausibilityMOGP(NewData=Xp, Emulator=em_wave1_ae, Discrepancy=tDisc_ae, Obs=tObs_ae, ObsErr=tObsErr_ae))
system.time(Timps_auto <- ImplausibilityMOGP(NewData=Xp, Emulator=em_wave1_auto, Discrepancy=tDisc_auto, Obs=tObs_auto, ObsErr=tObsErr_auto))
# Out:
#    user  system elapsed
#  23.578   5.090   5.484
#    user  system elapsed
#   4.062   2.313   1.521
#    user  system elapsed
# 618.762 340.120 151.752
#    user  system elapsed
#  18.946   5.231   5.679

# %%
VarNames <- names(Xp)
valmax = 0 #how many outputs can be above the implausibility cut off
cutoff <- 3 #the implausibility cut off
param.def = data.frame(h=c(1),c=c(10),b=c(10)) #the default parameters of the model (on [-1,1])
param.defaults.norm = rangeScale(param.def, my_bounds, range(-1,1))
print(param.defaults.norm)
# Out:
#     h c   b
# 1 0.5 0 0.5

# %%
NROY1 <- which(rowSums(Timps <= cutoff) >= em_wave1$mogp$n_emulators -valmax)
NROY_pca <- which(rowSums(Timps_pca <= cutoff) >= em_wave1_pca$mogp$n_emulators -valmax)
NROY_ae <- which(rowSums(Timps_ae <= cutoff) >= em_wave1_ae$mogp$n_emulators -valmax)
NROY_auto <- which(rowSums(Timps_auto <= cutoff) >= em_wave1_auto$mogp$n_emulators -valmax)


scoreNROY <- length(NROY1)/dim(Xp)[1]
scoreNROY_pca <- length(NROY_pca)/dim(Xp)[1]
scoreNROY_ae <- length(NROY_ae)/dim(Xp)[1]
scoreNROY_auto <- length(NROY_auto)/dim(Xp)[1]

# %% [markdown]
# ### Layout of NROY space

# %%
ImpData_wave1 = cbind(Xp, Timps)
ImpListM1 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave1, nEms=em_wave1$mogp$n_emulators, whichMax=valmax+1)
imp.layoutm11(ImpListM1,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",scoreNROY,sep=""), side=1)
# Out:
# plot without title

# %%
ImpData_wave1_pca = cbind(Xp, Timps_pca)
ImpListM1_pca = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave1_pca, nEms=em_wave1_pca$mogp$n_emulators, whichMax=valmax+1)
imp.layoutm11(ImpListM1_pca,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",scoreNROY_pca,sep=""), side=1)
# Out:
# plot without title

# %%
ImpData_wave1_ae = cbind(Xp, Timps_ae)
ImpListM1_ae = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave1_ae, nEms=em_wave1_ae$mogp$n_emulators, whichMax=valmax+1)
imp.layoutm11(ImpListM1_ae,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",scoreNROY_ae,sep=""), side=1)
# Out:
# plot without title

# %%
ImpData_wave1_auto = cbind(Xp, Timps_auto)
ImpListM1_auto = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave1_auto, nEms=em_wave1_auto$mogp$n_emulators, whichMax=valmax+1)
imp.layoutm11(ImpListM1_auto,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",scoreNROY_auto,sep=""), side=1)
# Out:
# plot without title

# %% [markdown]
# ## Second Wave

# %%
n <- ceiling(n_samples*1.3/scoreNROY1)
# Out:
# Error in eval(expr, envir, enclos): object 'scoreNROY1' not found
# Traceback:

# %%
space <- skSpace$Space(list(c(-1, 1), c(-1, 1), c(-1, 1))) ## we use a scaled space
lhs <- sampler$Lhs()  #(lhs_type='classic', criterion='maximin', iterations=1000)
inputs_wave2_scaled_temp <- np$array(lhs$generate(space$dimensions, as.integer(n), random_state=as.integer(42)))

# %%
imp_em1_wave2 <- ImplausibilityMOGP(NewData=inputs_wave2_scaled_temp, Emulator=em_wave1, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
NROY_temp_wave2 <- which(rowSums(imp_em1_wave2 <= cutoff) >= em_wave1$mogp$n_emulators -valmax)

# %%
input_wave2_scaled <- inputs_wave2_scaled_temp[sample(NROY_temp_wave2, n_samples),]
input_wave2 <- rangeUnscale(input_wave2_scaled, my_bounds, range = c(-1, 1))

# %%
par(mfrow=c(2,2))
plot(input_wave2[,1], input_wave2[,2], xlab="h", ylab="c", xlim=c(-2,2), ylim=c(0,20))
points(1, 10, col='red', pch=18, cex=2)
plot(input_wave2[,1], input_wave2[,3], xlab="h", ylab="b", xlim=c(-2,2), ylim=c(-20,20))
points(1, 10, col='red', pch=18, cex=2)
plot(input_wave2[,2], input_wave2[,3], xlab="c", ylab="b", xlim=c(0,20), ylim=c(-20,20))
points(10, 10, col='red', pch=18, cex=2)

# %%
metrics_wave2 = future_sapply(1:nrow(input_wave2), function(r) extract_metrics_AMIP(input_wave2[r,], n_iter, 0.001, X_hist), future.seed=NULL)

# %% [markdown]
# ### Create the data matrix

# %%
input_wave2_scaled <- data.frame(input_wave2_scaled)
names(input_wave2_scaled) <- c('h', 'c', 'b')


metrics_k_wave2 <- data.frame(t(metrics_wave2)[, metrics_index_k])
N = nrow(metrics_k_wave2) 
noise <- rnorm(N, 0, 0)
tData_wave2 <- data.frame(cbind(input_wave2_scaled, noise, metrics_k_wave2))
names(tData_wave2)[names(tData_wave2) == "noise"] <- "Noise"
         
head(tData_wave2)

# %% [markdown]
# ### Training emulator

# %%
em_wave2 <- BuildNewEmulators(tData_wave2, HowManyEmulators = ncol(metrics_wave2), meanFun = "fitted", additionalVariables = cands) #

# %%
tLOOs <- LOO.plot(Emulators = em_wave2, which.emulator = 4, ParamNames = cands)

# %% [markdown]
# ### Compute implausibility

# %%
sample_size <- 100000
nparam <- length(names(em_wave2$fitting.elements$Design))
Xp_wave2 <- as.data.frame(2*randomLHS(sample_size, nparam)-1)
names(Xp_wave2) <- names(em_wave2$fitting.elements$Design)
system.time(Timps_wave2 <- ImplausibilityMOGP(NewData=Xp_wave2, Emulator=em_wave2, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))

# %% [markdown]
# Warning : Here we set valmax to 3 to generate a more steady NROY space

# %%
valmax = 3 #Set to 3 in order to have a "more steady" NROY space
cutoff <- 3 #the implausibility cut off

# %%
NROY2 <- which(rowSums(Timps_wave2 <= cutoff) >= em_wave2$mogp$n_emulators -valmax)
scoreNROY2 <- length(NROY2)/dim(Xp_wave2)[1]

# %% [markdown]
# ### Layout of NROY space

# %%
ImpData_wave2 = cbind(Xp_wave2, Timps_wave2)
ImpListM2 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave2, nEms=em_wave2$mogp$n_emulators, whichMax=valmax+1)
imp.layoutm11(ImpListM2,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",scoreNROY2,sep=""), side=1)

# %% [markdown]
# ## Third Wave

# %%
n <- ceiling(n_samples*1.3/scoreNROY2)

# %%
inputs_wave3_scaled_temp <- np$array(lhs$generate(space$dimensions, as.integer(n), random_state=as.integer(42)))

# %%
imp_em1 <- ImplausibilityMOGP(NewData=inputs_wave3_scaled_temp, Emulator=em_wave1, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
NROY_em1 <- which(rowSums(imp_em1 <= cutoff) >= em_wave1$mogp$n_emulators -valmax)

imp_em2 <- ImplausibilityMOGP(NewData=inputs_wave3_scaled_temp, Emulator=em_wave2, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
NROY_em2 <- which(rowSums(imp_em2 <= cutoff) >= em_wave2$mogp$n_emulators -valmax)

# %%
NROY_temp_wave3 <- sample(intersect(NROY_em1, NROY_em2), n_samples)

# %%
input_wave3_scaled <- inputs_wave3_scaled_temp[sample(NROY_temp_wave3, n_samples),]
input_wave3 <- rangeUnscale(input_wave3_scaled, my_bounds, range = c(-1, 1))

# %%
par(mfrow=c(2,2))
plot(input_wave3[,1], input_wave3[,2], xlab="h", ylab="c", xlim=c(-2,2), ylim=c(0,20))
points(1, 10, col='red', pch=18, cex=2)
plot(input_wave3[,1], input_wave3[,3], xlab="h", ylab="b", xlim=c(-2,2), ylim=c(-20,20))
points(1, 10, col='red', pch=18, cex=2)
plot(input_wave3[,2], input_wave3[,3], xlab="c", ylab="b", xlim=c(0,20), ylim=c(-20,20))
points(10, 10, col='red', pch=18, cex=2)

# %%
metrics_wave3 = future_sapply(1:nrow(input_wave3), function(r) extract_metrics_AMIP(input_wave3[r,], n_iter, 0.001, X_hist), future.seed=NULL)

# %% [markdown]
# ### Create the data matrix

# %%
input_wave3_scaled <- data.frame(input_wave3_scaled)
names(input_wave3_scaled) <- c('h', 'c', 'b')


metrics_k_wave3 <- data.frame(t(metrics_wave3)[, metrics_index_k])
N = nrow(metrics_k_wave3) 
noise <- rnorm(N, 0, 0)
tData_wave3 <- data.frame(cbind(input_wave3_scaled, noise, metrics_k_wave3))
names(tData_wave3)[names(tData_wave3) == "noise"] <- "Noise"
         
head(tData_wave3)

# %% [markdown]
# ### Training emulator

# %%
em_wave3 <- BuildNewEmulators(tData_wave3, HowManyEmulators = ncol(metrics_wave3), meanFun = "fitted", additionalVariables = cands) #

# %%
tLOOs <- LOO.plot(Emulators = em_wave3, which.emulator = 12, ParamNames = cands)

# %% [markdown]
# ### Compute implausibility

# %%
sample_size <- 100000
nparam <- length(names(em_wave3$fitting.elements$Design))
Xp_wave3 <- as.data.frame(2*randomLHS(sample_size, nparam)-1)
names(Xp_wave3) <- names(em_wave3$fitting.elements$Design)
system.time(Timps_wave3 <- ImplausibilityMOGP(NewData=Xp_wave3, Emulator=em_wave3, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))

# %%
valmax = 1 #how many outputs can be above the implausibility cut off
cutoff <- 3 #the implausibility cut off

# %%
NROY3 <- which(rowSums(Timps_wave3 <= cutoff) >= em_wave3$mogp$n_emulators -valmax)
scoreNROY3 <- length(NROY3)/dim(Xp_wave3)[1]

# %% [markdown]
# ### Layout of NROY space

# %%
ImpData_wave3 = cbind(Xp_wave3, Timps_wave3)
ImpListM3 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave3, nEms=em_wave3$mogp$n_emulators, whichMax=valmax+1)
imp.layoutm11(ImpListM3,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",scoreNROY3,sep=""), side=1)

# %% [markdown]
# ## Fourth Wave

# %%
n <- ceiling(n_samples*3/scoreNROY3)

# %%
inputs_wave4_scaled_temp <- np$array(lhs$generate(space$dimensions, as.integer(n), random_state=as.integer(42)))

# %%
imp_em1 <- ImplausibilityMOGP(NewData=inputs_wave4_scaled_temp, Emulator=em_wave1, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
NROY_em1 <- which(rowSums(imp_em1 <= cutoff) >= em_wave1$mogp$n_emulators -valmax)

imp_em2 <- ImplausibilityMOGP(NewData=inputs_wave4_scaled_temp, Emulator=em_wave2, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
NROY_em2 <- which(rowSums(imp_em2 <= cutoff) >= em_wave2$mogp$n_emulators -valmax)

imp_em3 <- ImplausibilityMOGP(NewData=inputs_wave4_scaled_temp, Emulator=em_wave3, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
NROY_em3 <- which(rowSums(imp_em3 <= cutoff) >= em_wave3$mogp$n_emulators -valmax)

# %%
inter12 <- intersect(NROY_em1, NROY_em2)
NROY_em1.2.3 <- intersect(inter12, NROY_em3)

# %%
NROY_temp_wave4 <- sample(NROY_em1.2.3, n_samples)

# %%
input_wave4_scaled <- inputs_wave4_scaled_temp[sample(NROY_temp_wave4, n_samples),]
input_wave4 <- rangeUnscale(input_wave4_scaled, my_bounds, range = c(-1, 1))

# %%
par(mfrow=c(2,2))
plot(input_wave4[,1], input_wave4[,2], xlab="h", ylab="c", xlim=c(-2,2), ylim=c(0,20))
points(1, 10, col='red', pch=18, cex=2)
plot(input_wave4[,1], input_wave4[,3], xlab="h", ylab="b", xlim=c(-2,2), ylim=c(-20,20))
points(1, 10, col='red', pch=18, cex=2)
plot(input_wave4[,2], input_wave4[,3], xlab="c", ylab="b", xlim=c(0,20), ylim=c(-20,20))
points(10, 10, col='red', pch=18, cex=2)

# %%
metrics_wave4 = future_sapply(1:nrow(input_wave4), function(r) extract_metrics_AMIP(input_wave4[r,], n_iter, 0.001, X_hist), future.seed=NULL)

# %% [markdown]
# ### Create the data matrix

# %%
input_wave4_scaled <- data.frame(input_wave4_scaled)
names(input_wave4_scaled) <- c('h', 'c', 'b')


metrics_k_wave4 <- data.frame(t(metrics_wave4)[, metrics_index_k])
N = nrow(metrics_k_wave4) 
noise <- rnorm(N, 0, 0)
tData_wave4 <- data.frame(cbind(input_wave4_scaled, noise, metrics_k_wave4))
names(tData_wave4)[names(tData_wave4) == "noise"] <- "Noise"
         
head(tData_wave4)

# %% [markdown]
# ### Training emulator

# %%
em_wave4 <- BuildNewEmulators(tData_wave4, HowManyEmulators = ncol(metrics_wave4), meanFun = "fitted", additionalVariables = cands) #

# %% [markdown]
# We can use Leave One Out to verify if our GPs fit our metrics correctly.

# %%
tLOOs <- LOO.plot(Emulators = em_wave4, which.emulator = 12, ParamNames = cands)

# %% [markdown]
# ### Compute implausibility

# %%
sample_size <- 100000
nparam <- length(names(em_wave4$fitting.elements$Design))
Xp_wave4 <- as.data.frame(2*randomLHS(sample_size, nparam)-1)
names(Xp_wave4) <- names(em_wave4$fitting.elements$Design)
system.time(Timps_wave4 <- ImplausibilityMOGP(NewData=Xp_wave4, Emulator=em_wave4, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))

# %%
valmax = 0 #how many outputs can be above the implausibility cut off
cutoff <- 3 #the implausibility cut off

# %%
NROY4 <- which(rowSums(Timps_wave4 <= cutoff) >= em_wave4$mogp$n_emulators -valmax)
scoreNROY4 <- length(NROY4)/dim(Xp_wave4)[1]

# %% [markdown]
# ### Layout of NROY space

# %%
ImpData_wave4 = cbind(Xp_wave4, Timps_wave4)
ImpListM4 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave4, nEms=em_wave4$mogp$n_emulators, whichMax=valmax+1)
imp.layoutm11(ImpListM4,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",scoreNROY4,sep=""), side=1)

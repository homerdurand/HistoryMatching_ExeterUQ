# %% [markdown]
# # History Matching for L96
# Author : Homer Durand
#
# Date : 26-07-21

# %% [markdown]
# ### Loading libs

# %%
current_dir <- getwd()
mogp_dir <- paste0(current_dir, "/mogp-emulator") #mogp_emulator lib

setwd(paste0(current_dir, '/dev_ExeterUQ_MOGP/'))

source("BuildEmulator/BuildEmulator.R")
source("HistoryMatching/HistoryMatching.R")
source("HistoryMatching/impLayoutplot.R")

setwd(current_dir)

L96_amip <- import("L96_amip")
np <- import("numpy")
smt <- import("smt")
sklearn <- import("sklearn")

packages <- c("FactoMineR", "factoextra", "corrplot", 'kernlab', 'pca3d', 'BBmisc', 'comprehenr', 'caret', "future.apply", 'tgp', 'ANN2', 'ramify')
# Install packages not yet installed
installed_packages <- packages %in% rownames(installed.packages())
if (any(installed_packages == FALSE)) {
  install.packages(packages[!installed_packages])
}

# Packages loading
invisible(lapply(packages, library, character.only = TRUE))
# Out:
# far library : Modelization for Functional AutoRegressive processes
#
#
# version 0.6-4 (2014-12-07)
#
#
# Spam version 2.6-0 (2020-12-14) is loaded.
# Type 'help( Spam)' or 'demo( spam)' for a short introduction
# and overview of this package.
# Help for individual functions is also obtained by adding the
# suffix '.spam' to the function name, e.g. 'help( chol.spam)'.
#
#
# Attaching package: ‘spam’
#
#
# The following objects are masked from ‘package:base’:
#
#     backsolve, forwardsolve
#
#
# See https://github.com/NCAR/Fields for
#  an extensive vignette, other supplements and source code
#
# This is loo version 2.4.1
#
# - Online documentation and vignettes at mc-stan.org/loo
#
# - As of v2.0.0 loo defaults to 1 core but we recommend using as many as possible. Use the 'cores' argument or set options(mc.cores = NUM_CORES) for an entire session.
#
# Loading required package: future
#
# Loading required package: ggplot2
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
#
# corrplot 0.88 loaded
#
#
# Attaching package: ‘corrplot’
#
#
# The following object is masked from ‘package:shape’:
#
#     colorlegend
#
#
#
# Attaching package: ‘kernlab’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     alpha
#
#
# The following objects are masked from ‘package:pracma’:
#
#     cross, eig, size
#
#
#
# Attaching package: ‘BBmisc’
#
#
# The following object is masked from ‘package:grid’:
#
#     explode
#
#
# The following object is masked from ‘package:nlme’:
#
#     collapse
#
#
# The following object is masked from ‘package:base’:
#
#     isFALSE
#
#
# Loading required package: lattice
#
#
# Attaching package: ‘caret’
#
#
# The following object is masked from ‘package:future’:
#
#     cluster
#
#
#
# Attaching package: ‘ANN2’
#
#
# The following object is masked from ‘package:caret’:
#
#     train
#
#
#
# Attaching package: ‘ramify’
#
#
# The following object is masked from ‘package:kernlab’:
#
#     size
#
#
# The following objects are masked from ‘package:pracma’:
#
#     eye, inv, linspace, logspace, meshgrid, ones, rand, randi, randn,
#     repmat, size, tril, triu, zeros
#
#
# The following object is masked from ‘package:graphics’:
#
#     clip

# %% [markdown]
# # History Matching
#
# 1. Space filling design of parameters space
# 2. Data simulation
# 3. Training of statistical emulator
# 4. Computation of implausibility
# 5. Refocussing
#     * If stoping criterion is reached stop HM
#     * Else, redefining parameters space and go to 1.
#
# ## Observations generation
#
# As our model is a toy model we need to generate *observations* based on the ground truth parameters in order to use them to tune our model. In a realistic model (e.g. an ocean model), observations are metrics based on real observations of the state of the ocean threw time.
#
# $\frac{d X_{k}}{d t}=\underbrace{-X_{k-1}\left(X_{k-2}-X_{k+1}\right)}_{\text {Advection}} \underbrace{-X_{k}}_{\text {Diffusion}}+\underbrace{F}_{\text {Forcing}} \underbrace{-h c \bar{Y}_{k}}_{\text {Coupling}}$
#
# $\frac{1}{c} \frac{d Y_{j, k}}{d t}=\underbrace{-b Y_{j+1, k}\left(Y_{j+2, k}-Y_{j-1, k}\right)}_{\text {Advection }} \underbrace{-Y_{j, k}}_{\text {Diffusion }} \underbrace{+\frac{h}{J} X_{k}}_{\text {Coupling }}$
#
# We consider the correct parameters to be h=1, F=10, c=10, b=10 and we will first generate our metrics based on those inputs using the 65 terms depicted here as in Schneider et al. 2017.
#
# $$
# \boldsymbol{f}_k(Y)=\left(\begin{array}{c}
# Y_{j,k} \\
# Y_{j,k}Y_{j',k}
# \end{array}\right), \forall j, j' \in J \text{ and } k \in K
# $$

# %%
np$random$seed(as.integer(42))

X_init = 10*np$ones(as.integer(36))
X_init[19]=1.0001 #ATtention X_init[19] !!!

l96_two = L96_amip$L96TwoLevel(save_dt=0.001, X_init=X_init, integration_type='coupled') # True params J=10, h=1, F=10, c=10, b=10

# %% [markdown]
# We first iterate 10 iterations in order to access to the steady state of the L96 model

# %%
l96_two$iterate(10)

# %%
Newinit = l96_two$X
Newinit
# Out:
#  [1]  4.42757870 -1.95495041  4.02579735  7.58204632  1.62852532  0.39357305
#  [7] -0.27120997  0.50364081  1.39288414  7.19375682  4.24944906  4.31670564
# [13] 10.65758988  3.57441467  0.28612741  1.59561931  5.81580349 -0.01928225
# [19]  9.29077971  2.98459204  0.23466043 -1.10569887  5.99612019  5.39444981
# [25]  1.73690034  0.13736713  1.49172092 -1.82474446 -0.34535066 10.71303763
# [31]  1.52854734 -1.29510637  0.11986749  2.52317066  4.46499941 10.24747885

# %% [markdown]
# We can use *Newinit* to be sure to start from the attractor of the L96.

# %%
np$random$seed(as.integer(42))
n_iter <- 10 
dt <- 0.001
l96_two = L96_amip$L96TwoLevel(save_dt=dt, X_init=Newinit, integration_type='coupled')

# %%
l96_two$iterate(n_iter)

# %% [markdown]
# We save the history of X in order to reinject it during the Y integration.

# %%
X_hist <- l96_two$history$X$values

# %% [markdown]
# We save the metrics generate with the ground truth parameters (observations).

# %%
system.time(observations <- l96_two$mean_stats(ax=as.integer(0)))
# Out:
#    user  system elapsed
#   1.433   0.000   1.435

# %% [markdown]
# We now have our ground truth metrics and history of X wo we can tune our model.

# %% [markdown]
# ### Generation of metrics for the first wave
#
# We first sample the parameters space (input space) using a space filling design (latin hypercube sampling with maximin criterion) and then will generate our metrics for each of those points of the parameter space.

# %%
sampler <- import('skopt.sampler')
skSpace <- import('skopt.space')

# %%
n_samples <- 30

# %%
space <- skSpace$Space(list(c(-2, 2), c(0, 20), c(-20, 20))) ##only h,c,b
lhs <- sampler$Lhs()  #(lhs_type='classic', criterion='maximin', iterations=1000)
inputs_wave1 <- np$array(lhs$generate(space$dimensions, as.integer(n_samples), random_state=as.integer(42)))

# %%
par(mfrow=c(2,2))
plot(inputs_wave1[,1], inputs_wave1[,2], xlab="h", ylab="c", xlim=c(-2,2), ylim=c(0,20))
points(1, 10, col='red', pch=18, cex=2)
plot(inputs_wave1[,1], inputs_wave1[,3], xlab="h", ylab="b", xlim=c(-2,2), ylim=c(-20,20))
points(1, 10, col='red', pch=18, cex=2)
plot(inputs_wave1[,2], inputs_wave1[,3], xlab="c", ylab="b", xlim=c(0,20), ylim=c(-20,20))
points(10, 10, col='red', pch=18, cex=2)
# Out:
# plot without title

# %% [markdown]
# As a rule of thumb, we use 10 samples by paramaters. Here we have 3 parameters to tune (h, c, b), so we use 30 samples.

# %%
extract_metrics_AMIP <- function(p, n_iter, dt, X_hist) {
    initX <- as.matrix(X_hist[1,])
    l96_mip = L96_amip$L96TwoLevel(X_init=initX, save_dt=dt, dt=dt, noYhist=FALSE, h=p[[1]], F=10, c=p[[2]], b=p[[3]])
    l96_mip$iterate_AMIP(X_hist, n_iter)
    return(l96_mip$mean_stats(ax=as.integer(0)))
}

# %%
plan(multicore)
metrics_wave1 = future_sapply(1:nrow(inputs_wave1), function(r) extract_metrics_AMIP(inputs_wave1[r,], n_iter, 0.001, X_hist), future.seed=NULL)

# %% [markdown]
# ### Create the data matrix
# We create a data frame with correct format to train an emulator as it is describe in https://bayesexeter.github.io/ExeterUQ_MOGP/Testing_ExeterUQ_mogp.html
#
# We select 65 metrics for a given k (here $k=0$) in order to fit the emulators in a reasonable amount of time. Here we select the metrics
#
# $$
# \boldsymbol{f}_0(Y)=\left(\begin{array}{c}
# Y_{j,0} \\
# Y_{j,0}Y_{j',0}
# \end{array}\right), \forall j, j' \in J
# $$

# %% [markdown]
# #### Scaling and Unscaling functions

# %%
rangeScale <- function(df, scaler, range = c(-1, 1)){
    for (i in 1:ncol(df)){
        min <- scaler[[i]][1]
        max <- scaler[[i]][2]
        df[,i] = (range[2] - range[1])*(df[,i] - min)/(max - min) + range[1]
    }
    return(df)
}
                                        
rangeUnscale <- function(df, scaler, range = c(-1, 1)){
    for (i in 1:ncol(df)){
        min <- scaler[[i]][1]
        max <- scaler[[i]][2]
        df[,i] = (max - min)*(df[,i] - range[1])/(range[2] - range[1]) + min
    }
    return(df)
}

# %%
k <- 0 # Select k in K for tunning 
metrics_index_k <- (k*65+1):((k+1)*65)

# %%
# Arrange inputs (parameters) 
inputs_wave1 <- data.frame(inputs_wave1)
my_bounds <- data.frame(list(c(-2, 2), c(0, 20), c(-20, 20)))
inputs_wave1 <- rangeScale(inputs_wave1, my_bounds, range = c(-1, 1))
names(inputs_wave1) <- c('h', 'c', 'b')


metrics_k_wave1 <- data.frame(t(metrics_wave1)[, metrics_index_k])
N = nrow(inputs_wave1) 
noise <- rnorm(N, 0, 0)
tData <- data.frame(cbind(inputs_wave1, noise, metrics_k_wave1))
names(tData)[names(tData) == "noise"] <- "Noise"
         
head(tData)
# Out:
#   h           c          b          Noise X1           X2
# 1 -0.01201163 -0.3353458  0.2776930 0     -0.006420097 -0.006302724
# 2  0.34905567  0.8478337  0.5320322 0      0.105538421  0.068697174
# 3  0.50403953  0.3601328 -0.1518286 0     -0.006445521  0.237981995
# 4 -0.08859503  0.2247366  0.8196509 0      0.002876718 -0.045517209
# 5 -0.93853929 -0.4483700  0.6732339 0     -0.022457223 -0.094208743
# 6 -0.40272438  0.5477225  0.1426025 0     -0.011566117 -0.221381152
#   X3           X4           X5           X6           ⋯ X56
# 1 -0.006309862 -0.006309524 -0.006308370 -0.006309555 ⋯ 8.040896e-05
# 2  0.084799267  0.105912561  0.090199820  0.055292361 ⋯ 4.200927e-02
# 3 -0.007404240  0.186781565 -0.014454777  0.215586632 ⋯ 3.415417e-02
# 4  0.003144312 -0.035722238  0.002147645 -0.039496303 ⋯ 9.518025e-04
# 5 -0.013564450 -0.057858226 -0.028031658 -0.088548652 ⋯ 8.612916e-02
# 6 -0.010322716 -0.182587973 -0.013466155 -0.196105155 ⋯ 2.254414e-02
#   X57          X58          X59          X60          X61          X62
# 1 8.060961e-05 7.764213e-05 0.0000799824 8.081122e-05 7.783269e-05 8.018136e-05
# 2 2.072397e-02 6.217308e-03 0.0177629503 3.367242e-02 1.393381e-02 1.070093e-02
# 3 2.000427e-02 2.256316e-02 0.0055672893 1.079500e-01 8.928603e-03 9.770488e-02
# 4 6.397925e-04 7.712179e-04 0.0001814227 3.457189e-03 4.088819e-04 3.217118e-03
# 5 2.743404e-03 3.030475e-02 0.0159979632 1.194932e-01 7.985882e-03 3.803280e-02
# 6 1.924048e-02 1.833913e-02 0.0087921071 8.574896e-02 1.362513e-02 8.126697e-02
#   X63          X64           X65
# 1 7.502619e-05  7.721373e-05 7.967611e-05
# 2 2.560529e-02  1.471335e-02 4.267811e-02
# 3 2.672015e-02 -6.281238e-03 1.157048e-01
# 4 8.615864e-04 -1.074986e-04 3.813564e-03
# 5 8.717307e-02  2.249705e-03 1.051677e-01
# 6 1.866998e-02  3.380719e-03 9.326263e-02

# %% [markdown]
# ### Training emulator

# %%
cands <- names(tData)[1:3]
em_wave1 <- BuildNewEmulators(tData, HowManyEmulators = ncol(metrics_k_wave1), meanFun = "fitted", additionalVariables = cands) #
# Out:
# [1] "Max reduction is 0.0324866889484487 using h"
# [1] "Max reduction is 0.0080462388123647 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X1 ~ h + b + I(b * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.301661 -0.043256  0.003435  0.036234  0.284406
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.004889   0.018315  -0.267   0.7916
# h            0.159587   0.032470   4.915 4.21e-05 ***
# b            0.081021   0.031912   2.539   0.0174 *
# I(b * h)     0.013509   0.062711   0.215   0.8311
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1003 on 26 degrees of freedom
# Multiple R-squared:  0.5452,	Adjusted R-squared:  0.4928
# F-statistic: 10.39 on 3 and 26 DF,  p-value: 0.0001132
#
# [1] "Max reduction is 0.0945718566703141 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X2 ~ h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.198535 -0.032482  0.003387  0.028274  0.200972
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.007573   0.016157  -0.469    0.643
# h            0.277278   0.028285   9.803 1.49e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0885 on 28 degrees of freedom
# Multiple R-squared:  0.7744,	Adjusted R-squared:  0.7663
# F-statistic:  96.1 on 1 and 28 DF,  p-value: 1.491e-10
#
# [1] "Max reduction is 0.0364251380681622 using h"
# [1] "Max reduction is 0.00946765866526192 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X3 ~ h + b + I(b * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.294644 -0.048743  0.003606  0.036048  0.275126
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.0006341  0.0183559  -0.035   0.9727
# h            0.1710364  0.0325425   5.256 1.71e-05 ***
# b            0.0861493  0.0319837   2.694   0.0122 *
# I(b * h)     0.0151111  0.0628519   0.240   0.8119
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1005 on 26 degrees of freedom
# Multiple R-squared:  0.5774,	Adjusted R-squared:  0.5286
# F-statistic: 11.84 on 3 and 26 DF,  p-value: 4.476e-05
#
# [1] "Max reduction is 0.084585851774902 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X4 ~ h, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.20168 -0.02076  0.00448  0.02906  0.21799
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.005523   0.015479  -0.357    0.724
# h            0.253810   0.027098   9.366    4e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08478 on 28 degrees of freedom
# Multiple R-squared:  0.7581,	Adjusted R-squared:  0.7494
# F-statistic: 87.73 on 1 and 28 DF,  p-value: 4e-10
#
# [1] "Max reduction is 0.0278257069828241 using h"
# [1] "Max reduction is 0.00657410558538722 using b"
# [1] "Max reduction is 0.000860067471880888 using c"
# [1] "Max reduction is 0.00124297574975767 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X5 ~ h + b + c + I(c^2) + I(b * h) + I(c * h) +
#     I(c * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.228448 -0.036569 -0.008401  0.037857  0.264841
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.02814    0.02669  -1.055 0.303036
# h            0.13794    0.03143   4.389 0.000234 ***
# b            0.08860    0.03097   2.861 0.009079 **
# c           -0.06000    0.03098  -1.937 0.065753 .
# I(c^2)       0.07696    0.06070   1.268 0.218078
# I(b * h)     0.01085    0.05950   0.182 0.856984
# I(c * h)     0.04236    0.05813   0.729 0.473848
# I(c * b)     0.01890    0.04714   0.401 0.692386
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09471 on 22 degrees of freedom
# Multiple R-squared:  0.6048,	Adjusted R-squared:  0.479
# F-statistic: 4.809 on 7 and 22 DF,  p-value: 0.002088
#
# [1] "1 I(b * h)"
# [1] "2 I(c * b)"
# [1] "3 I(c * h)"
#
# Call:
# lm(formula = X5 ~ h + b + c + I(c^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.251619 -0.031478  0.006313  0.040608  0.247678
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.02424    0.02486  -0.975 0.338842
# h            0.13314    0.02922   4.557 0.000118 ***
# b            0.08692    0.02920   2.977 0.006380 **
# c           -0.05886    0.02919  -2.017 0.054590 .
# I(c^2)       0.06415    0.05576   1.151 0.260813
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09033 on 25 degrees of freedom
# Multiple R-squared:  0.5914,	Adjusted R-squared:  0.5261
# F-statistic: 9.048 on 4 and 25 DF,  p-value: 0.000116
#
# [1] "Max reduction is 0.0895290597251341 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X6 ~ h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.207969 -0.023707  0.000163  0.036466  0.217781
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.01251    0.01588  -0.788    0.437
# h            0.26579    0.02779   9.564 2.55e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08695 on 28 degrees of freedom
# Multiple R-squared:  0.7656,	Adjusted R-squared:  0.7572
# F-statistic: 91.46 on 1 and 28 DF,  p-value: 2.554e-10
#
# [1] "Max reduction is 0.0304409883206684 using h"
# [1] "Max reduction is 0.0143453004463671 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X7 ~ h + b + I(b * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.309434 -0.049334 -0.000471  0.049341  0.275780
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.006419   0.018555  -0.346  0.73218
# h            0.162892   0.032895   4.952 3.82e-05 ***
# b            0.096391   0.032330   2.981  0.00616 **
# I(b * h)     0.060067   0.063533   0.945  0.35314
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1016 on 26 degrees of freedom
# Multiple R-squared:  0.5681,	Adjusted R-squared:  0.5182
# F-statistic:  11.4 on 3 and 26 DF,  p-value: 5.899e-05
#
# [1] "Max reduction is 0.0786022287769227 using h"
# [1] "Max reduction is 0.0012346281474384 using c"
# [1] "Max reduction is 0.000567817813969668 using c"
# [1] "Max reduction is 2.85103083103588e-05 using Three Way Interactions with c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X8 ~ h + c + I(c^2) + I(c * h) + I(c * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.148195 -0.042158 -0.002278  0.030728  0.210534
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.02373    0.02218  -1.070   0.2953
# h             0.26205    0.03760   6.970 3.31e-07 ***
# c            -0.05240    0.02659  -1.971   0.0604 .
# I(c^2)        0.07196    0.05201   1.384   0.1792
# I(c * h)      0.04480    0.04957   0.904   0.3751
# I(c * c * h) -0.09119    0.09038  -1.009   0.3231
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07997 on 24 degrees of freedom
# Multiple R-squared:  0.7943,	Adjusted R-squared:  0.7514
# F-statistic: 18.54 on 5 and 24 DF,  p-value: 1.517e-07
#
# [1] "1 I(c * c * h)"
#
# Call:
# lm(formula = X8 ~ h + c + I(c^2) + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.158761 -0.039553  0.006297  0.048632  0.195411
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.02134    0.02206  -0.967   0.3426
# h            0.23483    0.02619   8.965 2.77e-09 ***
# c           -0.04507    0.02558  -1.762   0.0904 .
# I(c^2)       0.05902    0.05042   1.171   0.2528
# I(c * h)     0.03653    0.04891   0.747   0.4621
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08 on 25 degrees of freedom
# Multiple R-squared:  0.7856,	Adjusted R-squared:  0.7513
# F-statistic:  22.9 on 4 and 25 DF,  p-value: 4.732e-08
#
# [1] "Max reduction is 0.0302178446717707 using h"
# [1] "Max reduction is 0.0104313495835814 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X9 ~ h + b + I(b * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.34151 -0.05059 -0.00023  0.03857  0.33784
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.009721   0.021598  -0.450 0.656378
# h            0.165870   0.038291   4.332 0.000196 ***
# b            0.099819   0.037633   2.652 0.013440 *
# I(b * h)     0.005635   0.073954   0.076 0.939846
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1183 on 26 degrees of freedom
# Multiple R-squared:  0.5034,	Adjusted R-squared:  0.4461
# F-statistic: 8.785 on 3 and 26 DF,  p-value: 0.0003431
#
# [1] "Max reduction is 0.0904364197135487 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X10 ~ h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.252859 -0.053096  0.004795  0.022834  0.200223
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.006343   0.016908  -0.375     0.71
# h            0.273365   0.029600   9.235 5.41e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09261 on 28 degrees of freedom
# Multiple R-squared:  0.7528,	Adjusted R-squared:  0.744
# F-statistic: 85.29 on 1 and 28 DF,  p-value: 5.407e-10
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X11 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.08109 -0.06709 -0.04544  0.02119  0.48873
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.08117    0.02119    3.83 0.000633 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1161 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X12 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.05011 -0.04045 -0.02965 -0.00886  0.42219
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03991    0.01705   2.341   0.0263 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09338 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X13 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03850 -0.03192 -0.02690 -0.01507  0.38882
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03858    0.01561   2.472   0.0195 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08549 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X14 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.05077 -0.03693 -0.02755 -0.00858  0.36018
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03739    0.01506   2.482   0.0191 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08251 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X15 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04255 -0.03714 -0.03086 -0.00820  0.34522
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04264    0.01508   2.827  0.00842 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0826 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X16 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04839 -0.03917 -0.03068 -0.00136  0.37572
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03947    0.01573    2.51   0.0179 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08614 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X17 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03998 -0.03399 -0.02828 -0.00763  0.33994
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03632    0.01424    2.55   0.0163 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07801 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X18 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03848 -0.03390 -0.02566 -0.01173  0.33285
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03620    0.01407   2.574   0.0154 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07705 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X19 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04408 -0.03896 -0.03245 -0.00554  0.37487
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04047    0.01613   2.509   0.0179 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08833 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X20 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04099 -0.03614 -0.02892 -0.00544  0.35608
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03690    0.01508   2.446   0.0207 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08262 on 29 degrees of freedom
#
# [1] "Max reduction is 0.000516090509026651 using h"
# [1] "Max reduction is 0.0366021252937688 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X21 ~ h + I(h^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.184801 -0.031296  0.000294  0.010743  0.202841
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.001096   0.020923  -0.052    0.959
# h           -0.039362   0.024213  -1.626    0.116
# I(h^2)       0.282980   0.048113   5.882 2.89e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07576 on 27 degrees of freedom
# Multiple R-squared:  0.5806,	Adjusted R-squared:  0.5496
# F-statistic: 18.69 on 2 and 27 DF,  p-value: 8.04e-06
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X22 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04237 -0.03864 -0.02945 -0.01227  0.39412
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04067    0.01609   2.527   0.0172 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08815 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00152728672146114 using h"
# [1] "Max reduction is 0.013868011451872 using h"
# [1] "Max reduction is 0.00191437357891457 using h"
# [1] "Max reduction is 0.00180722710953303 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X23 ~ h + I(h^2) + I(h^3) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.181299 -0.031875 -0.002829  0.025880  0.197403
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.006468   0.023391  -0.277  0.78451
# h            0.069659   0.069620   1.001  0.32702
# I(h^2)       0.183070   0.054126   3.382  0.00246 **
# I(h^3)      -0.208692   0.111831  -1.866  0.07429 .
# c            0.013977   0.027321   0.512  0.61361
# I(c * h)    -0.087999   0.050572  -1.740  0.09466 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08334 on 24 degrees of freedom
# Multiple R-squared:  0.4524,	Adjusted R-squared:  0.3384
# F-statistic: 3.966 on 5 and 24 DF,  p-value: 0.009185
#
# [1] "1 I(h^3)"
#
# Call:
# lm(formula = X23 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.13334 -0.04933  0.00304  0.01409  0.23053
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.005473   0.024519  -0.223  0.82518
# h           -0.049909   0.028552  -1.748  0.09274 .
# I(h^2)       0.182859   0.056750   3.222  0.00352 **
# c            0.008381   0.028472   0.294  0.77092
# I(c * h)    -0.069106   0.051950  -1.330  0.19545
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08738 on 25 degrees of freedom
# Multiple R-squared:  0.373,	Adjusted R-squared:  0.2727
# F-statistic: 3.718 on 4 and 25 DF,  p-value: 0.01656
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X24 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04069 -0.03361 -0.02651 -0.01383  0.35245
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03729    0.01466   2.544   0.0165 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08028 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00162139368211422 using h"
# [1] "Max reduction is 0.0184478132762774 using h"
# [1] "Max reduction is 0.000128612732860967 using c"
# [1] "Max reduction is 0.00102266254076303 using h"
# [1] "Max reduction is 0.000176955258504738 using Three Way Interactions with h"
# [1] "Max reduction is 3.694620597533e-05 using c"
# [1] "Max reduction is 0.0010731955746473 using c"
# [1] "Max reduction is 0.00459454770261628 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X25 ~ h + I(h^2) + I(h^3) + c + I(c^2) + I(c^3) +
#     I(c^4) + I(c * h) + I(h * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.164107 -0.039942  0.001475  0.022081  0.212916
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.03206    0.03614  -0.887 0.385567
# h             0.04691    0.06953   0.675 0.507607
# I(h^2)        0.26433    0.05725   4.617 0.000167 ***
# I(h^3)       -0.16061    0.11006  -1.459 0.159990
# c             0.04581    0.07742   0.592 0.560707
# I(c^2)        0.30362    0.19402   1.565 0.133300
# I(c^3)       -0.13844    0.10866  -1.274 0.217262
# I(c^4)       -0.41339    0.22227  -1.860 0.077673 .
# I(c * h)     -0.09199    0.05273  -1.744 0.096445 .
# I(h * c * h)  0.23285    0.12704   1.833 0.081760 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0807 on 20 degrees of freedom
# Multiple R-squared:  0.6135,	Adjusted R-squared:  0.4396
# F-statistic: 3.528 on 9 and 20 DF,  p-value: 0.009041
#
# [1] "1 I(h^3)"
# [1] "2 I(c^4)"
# [1] "3 I(h * c * h)"
# [1] "4 I(c * h)"
# [1] "5 I(c^3)"
#
# Call:
# lm(formula = X25 ~ h + I(h^2) + c + I(c^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.190317 -0.037814 -0.003242  0.008256  0.247307
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.005881   0.032558   0.181  0.85812
# h           -0.043098   0.029244  -1.474  0.15303
# I(h^2)       0.211395   0.059024   3.582  0.00144 **
# c            0.013578   0.029396   0.462  0.64813
# I(c^2)      -0.025409   0.055699  -0.456  0.65220
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09045 on 25 degrees of freedom
# Multiple R-squared:  0.3932,	Adjusted R-squared:  0.2961
# F-statistic: 4.049 on 4 and 25 DF,  p-value: 0.01149
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X26 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04486 -0.03550 -0.02913 -0.00298  0.35977
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03964    0.01501    2.64   0.0132 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08224 on 29 degrees of freedom
#
# [1] "Max reduction is 0.000988758795031588 using h"
# [1] "Max reduction is 0.0150821139722735 using h"
# [1] "Max reduction is 0.000742446946443417 using h"
# [1] "Max reduction is 0.00125971797887331 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X27 ~ h + I(h^2) + I(h^3) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.169274 -0.028893 -0.002627  0.021176  0.191066
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.005593   0.021842  -0.256  0.80010
# h            0.051901   0.065010   0.798  0.43249
# I(h^2)       0.184141   0.050542   3.643  0.00129 **
# I(h^3)      -0.165508   0.104426  -1.585  0.12607
# c            0.016359   0.025512   0.641  0.52744
# I(c * h)    -0.076446   0.047224  -1.619  0.11856
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07782 on 24 degrees of freedom
# Multiple R-squared:  0.455,	Adjusted R-squared:  0.3414
# F-statistic: 4.007 on 5 and 24 DF,  p-value: 0.008749
#
# [1] "1 I(h^3)"
#
# Call:
# lm(formula = X27 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.130381 -0.032293  0.000463  0.012105  0.217342
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.004803   0.022487  -0.214  0.83260
# h           -0.042925   0.026187  -1.639  0.11370
# I(h^2)       0.183974   0.052048   3.535  0.00162 **
# c            0.011921   0.026113   0.457  0.65196
# I(c * h)    -0.061462   0.047646  -1.290  0.20887
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08014 on 25 degrees of freedom
# Multiple R-squared:  0.3979,	Adjusted R-squared:  0.3016
# F-statistic: 4.131 on 4 and 25 DF,  p-value: 0.01052
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X28 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04700 -0.03755 -0.02818 -0.00928  0.39274
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03899    0.01635   2.385   0.0238 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08953 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00173787047818744 using h"
# [1] "Max reduction is 0.0157706658925007 using h"
# [1] "Max reduction is 0.00101417870720905 using h"
# [1] "Max reduction is 0.00186487505060727 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X29 ~ h + I(h^2) + I(h^3) + c + I(c * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.19218 -0.03535 -0.00446  0.02849  0.19339
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.006103   0.024366  -0.250  0.80436
# h            0.057500   0.072522   0.793  0.43563
# I(h^2)       0.199431   0.056383   3.537  0.00168 **
# I(h^3)      -0.192415   0.116493  -1.652  0.11162
# c            0.017745   0.028460   0.624  0.53883
# I(c * h)    -0.090119   0.052681  -1.711  0.10004
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08682 on 24 degrees of freedom
# Multiple R-squared:  0.4573,	Adjusted R-squared:  0.3442
# F-statistic: 4.044 on 5 and 24 DF,  p-value: 0.00837
#
# [1] "1 I(h^3)"
#
# Call:
# lm(formula = X29 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.146964 -0.043861  0.000486  0.014600  0.223932
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.005185   0.025188  -0.206  0.83857
# h           -0.052743   0.029332  -1.798  0.08424 .
# I(h^2)       0.199237   0.058299   3.417  0.00217 **
# c            0.012585   0.029249   0.430  0.67069
# I(c * h)    -0.072699   0.053369  -1.362  0.18528
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08977 on 25 degrees of freedom
# Multiple R-squared:  0.3956,	Adjusted R-squared:  0.2989
# F-statistic:  4.09 on 4 and 25 DF,  p-value: 0.01099
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X30 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.07948 -0.06604 -0.03772  0.03173  0.39958
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.07956    0.01923   4.138 0.000274 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1053 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X31 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04689 -0.04211 -0.02968 -0.01007  0.40140
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04225    0.01658   2.548   0.0164 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09083 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X32 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04041 -0.03461 -0.02862 -0.01267  0.37412
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04050    0.01557     2.6   0.0145 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08531 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X33 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04163 -0.03858 -0.03100 -0.01115  0.45485
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04119    0.01775    2.32   0.0276 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09725 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X34 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.05604 -0.04429 -0.03451 -0.00269  0.41801
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.05056    0.01753   2.885  0.00731 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09599 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X35 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04126 -0.03555 -0.02961 -0.01154  0.35452
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04061    0.01504     2.7   0.0115 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08238 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X36 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04464 -0.03952 -0.03273 -0.01645  0.42191
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04472    0.01745   2.563   0.0158 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09556 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X37 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04444 -0.04011 -0.03256 -0.01940  0.46587
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04279    0.01842   2.323   0.0274 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1009 on 29 degrees of freedom
#
# [1] "Max reduction is 0.000517588035142971 using h"
# [1] "Max reduction is 0.0368060026958721 using h"
# [1] "Max reduction is 0.000996642401377687 using c"
# [1] "Max reduction is 0.00155226784399812 using Three Way Interactions with h"
# [1] "Max reduction is 0.000142921819052011 using c"
# [1] "Max reduction is 0.00149091086193423 using c"
# [1] "Max reduction is 0.00135213717842907 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X38 ~ h + I(h^2) + c + I(c^2) + I(c^3) + I(c^4) +
#     I(c * h) + I(h * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.123298 -0.018477 -0.002893  0.015734  0.164566
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.01769    0.02848  -0.621   0.5411
# h            -0.03787    0.02133  -1.775   0.0903 .
# I(h^2)        0.32167    0.04511   7.131 4.95e-07 ***
# c             0.04203    0.06073   0.692   0.4965
# I(c^2)        0.17047    0.15278   1.116   0.2771
# I(c^3)       -0.12300    0.08495  -1.448   0.1624
# I(c^4)       -0.24364    0.17468  -1.395   0.1777
# I(c * h)     -0.06077    0.04027  -1.509   0.1462
# I(h * c * h)  0.20754    0.09989   2.078   0.0502 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0636 on 21 degrees of freedom
# Multiple R-squared:  0.7416,	Adjusted R-squared:  0.6431
# F-statistic: 7.532 on 8 and 21 DF,  p-value: 9.773e-05
#
# [1] "1 I(c^4)"
# [1] "2 I(h * c * h)"
# [1] "3 I(c * h)"
# [1] "4 I(c^3)"
#
# Call:
# lm(formula = X38 ~ h + I(h^2) + c + I(c^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.182776 -0.021661 -0.003792  0.018078  0.187745
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.006089   0.025347   0.240    0.812
# h           -0.033947   0.022767  -1.491    0.148
# I(h^2)       0.278852   0.045951   6.068 2.43e-06 ***
# c            0.019809   0.022885   0.866    0.395
# I(c^2)      -0.024384   0.043363  -0.562    0.579
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07042 on 25 degrees of freedom
# Multiple R-squared:  0.6228,	Adjusted R-squared:  0.5625
# F-statistic: 10.32 on 4 and 25 DF,  p-value: 4.47e-05
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X39 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04238 -0.03949 -0.02898 -0.00388  0.35529
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04152    0.01508   2.753   0.0101 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08261 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00163233578222639 using h"
# [1] "Max reduction is 0.0131815930094461 using h"
# [1] "Max reduction is 0.00194154488615951 using h"
# [1] "Max reduction is 0.0031225684706528 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X40 ~ h + I(h^2) + I(h^3) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.181066 -0.031600 -0.002862  0.031503  0.209918
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.008553   0.024487  -0.349   0.7299
# h            0.075789   0.072881   1.040   0.3087
# I(h^2)       0.186315   0.056662   3.288   0.0031 **
# I(h^3)      -0.224394   0.117070  -1.917   0.0673 .
# c            0.019965   0.028601   0.698   0.4918
# I(c * h)    -0.101001   0.052942  -1.908   0.0685 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08725 on 24 degrees of freedom
# Multiple R-squared:  0.4511,	Adjusted R-squared:  0.3367
# F-statistic: 3.944 on 5 and 24 DF,  p-value: 0.009429
#
# [1] "1 I(h^3)"
#
# Call:
# lm(formula = X40 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.14300 -0.05038  0.00331  0.01650  0.24752
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.007483   0.025757  -0.291   0.7738
# h           -0.052775   0.029994  -1.760   0.0907 .
# I(h^2)       0.186089   0.059615   3.122   0.0045 **
# c            0.013947   0.029909   0.466   0.6450
# I(c * h)    -0.080686   0.054573  -1.478   0.1518
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09179 on 25 degrees of freedom
# Multiple R-squared:  0.367,	Adjusted R-squared:  0.2657
# F-statistic: 3.624 on 4 and 25 DF,  p-value: 0.01839
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X41 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04061 -0.03706 -0.03036 -0.00979  0.40482
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03806    0.01618   2.352   0.0257 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08863 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00111833408765098 using h"
# [1] "Max reduction is 0.0162131367977867 using h"
# [1] "Max reduction is 0.000758546820207526 using c"
# [1] "Max reduction is 0.00129914122796003 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X42 ~ h + I(h^2) + I(h^3) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.179924 -0.031941  0.000332  0.027486  0.172638
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.005009   0.021849  -0.229 0.820604
# h            0.036155   0.065030   0.556 0.583372
# I(h^2)       0.191790   0.050558   3.793 0.000886 ***
# I(h^3)      -0.141747   0.104458  -1.357 0.187415
# c            0.018260   0.025519   0.716 0.481195
# I(c * h)    -0.084662   0.047238  -1.792 0.085712 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07785 on 24 degrees of freedom
# Multiple R-squared:  0.4696,	Adjusted R-squared:  0.359
# F-statistic: 4.249 on 5 and 24 DF,  p-value: 0.006574
#
# [1] "1 I(h^3)"
#
# Call:
# lm(formula = X42 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.146615 -0.028494  0.000873  0.013599  0.195141
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.004333   0.022208  -0.195 0.846879
# h           -0.045058   0.025861  -1.742 0.093750 .
# I(h^2)       0.191647   0.051402   3.728 0.000992 ***
# c            0.014458   0.025789   0.561 0.580029
# I(c * h)    -0.071830   0.047054  -1.527 0.139433
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07915 on 25 degrees of freedom
# Multiple R-squared:  0.4289,	Adjusted R-squared:  0.3375
# F-statistic: 4.693 on 4 and 25 DF,  p-value: 0.005792
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X43 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04659 -0.04269 -0.03272  0.00021  0.39282
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04352    0.01674     2.6   0.0145 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09168 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00112031618146734 using h"
# [1] "Max reduction is 0.0160975308847543 using h"
# [1] "Max reduction is 0.00153644085870946 using c"
# [1] "Max reduction is 0.0021884341768731 using h"
# [1] "Max reduction is 0.000804813048030997 using Three Way Interactions with h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X44 ~ h + I(h^2) + I(h^3) + c + I(c * h) + I(h *
#     c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.167490 -0.044857  0.009471  0.027004  0.179970
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.007515   0.024158  -0.311 0.758547
# h             0.055957   0.071957   0.778 0.444702
# I(h^2)        0.218014   0.056829   3.836 0.000844 ***
# I(h^3)       -0.182380   0.115557  -1.578 0.128161
# c            -0.018584   0.045983  -0.404 0.689838
# I(c * h)     -0.105229   0.052294  -2.012 0.056046 .
# I(h * c * h)  0.152408   0.126516   1.205 0.240587
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08602 on 23 degrees of freedom
# Multiple R-squared:  0.4947,	Adjusted R-squared:  0.3629
# F-statistic: 3.753 on 6 and 23 DF,  p-value: 0.009464
#
# [1] "1 I(h^3)"
# [1] "2 I(h * c * h)"
#
# Call:
# lm(formula = X44 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.15510 -0.04583  0.00333  0.01388  0.24297
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.007683   0.024977  -0.308  0.76092
# h           -0.049293   0.029086  -1.695  0.10255
# I(h^2)       0.205292   0.057811   3.551  0.00155 **
# c            0.020457   0.029004   0.705  0.48713
# I(c * h)    -0.085520   0.052921  -1.616  0.11865
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08901 on 25 degrees of freedom
# Multiple R-squared:  0.4119,	Adjusted R-squared:  0.3178
# F-statistic: 4.377 on 4 and 25 DF,  p-value: 0.008076
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X45 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.07286 -0.06123 -0.03737  0.02379  0.31294
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.07294    0.01625   4.489 0.000105 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08899 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X46 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04387 -0.03938 -0.02868 -0.01025  0.39557
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04054    0.01617   2.507    0.018 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08858 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X47 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03899 -0.03365 -0.02554 -0.01009  0.36733
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03802    0.01512   2.515   0.0177 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08282 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X48 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03893 -0.03260 -0.02465 -0.00899  0.32488
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03735    0.01382   2.702   0.0114 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.07572 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X49 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04694 -0.04092 -0.03262 -0.00692  0.37462
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04702    0.01626   2.891   0.0072 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08907 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X50 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04249 -0.03752 -0.02854 -0.00829  0.39699
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03943    0.01621   2.433   0.0214 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08878 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00108464111775514 using h"
# [1] "Max reduction is 0.0366944817905759 using h"
# [1] "Max reduction is 0.000128000902251554 using c"
# [1] "Max reduction is 0.0042962414007581 using Three Way Interactions with h"
# [1] "Max reduction is 0.000673136116599873 using c"
# [1] "Max reduction is 0.00366045046086864 using c"
# [1] "Max reduction is 0.00512102457366118 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X51 ~ h + I(h^2) + c + I(c^2) + I(c^3) + I(c^4) +
#     I(c * h) + I(h * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.115206 -0.033803  0.003491  0.023095  0.155030
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.02995    0.03084  -0.971  0.34261
# h            -0.04470    0.02310  -1.935  0.06654 .
# I(h^2)        0.36474    0.04886   7.465 2.45e-07 ***
# c             0.04488    0.06578   0.682  0.50249
# I(c^2)        0.28912    0.16546   1.747  0.09518 .
# I(c^3)       -0.17756    0.09200  -1.930  0.06722 .
# I(c^4)       -0.39651    0.18918  -2.096  0.04839 *
# I(c * h)     -0.06531    0.04361  -1.498  0.14914
# I(h * c * h)  0.32414    0.10819   2.996  0.00688 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06888 on 21 degrees of freedom
# Multiple R-squared:  0.7635,	Adjusted R-squared:  0.6735
# F-statistic: 8.476 on 8 and 21 DF,  p-value: 4.151e-05
#
# [1] "1 I(c^4)"
# [1] "2 I(c^3)"
# [1] "3 I(c^2)"
# [1] "4 I(h * c * h)"
#
# Call:
# lm(formula = X51 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.17178 -0.02920  0.00434  0.02268  0.24737
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.005614   0.023186  -0.242   0.8106
# h           -0.050134   0.027001  -1.857   0.0752 .
# I(h^2)       0.302748   0.053666   5.641 7.16e-06 ***
# c            0.022360   0.026925   0.830   0.4141
# I(c * h)    -0.061186   0.049127  -1.245   0.2245
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08263 on 25 degrees of freedom
# Multiple R-squared:  0.5949,	Adjusted R-squared:  0.5301
# F-statistic: 9.178 on 4 and 25 DF,  p-value: 0.0001049
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X52 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04680 -0.04285 -0.03207 -0.00530  0.45355
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04333    0.01792   2.417   0.0222 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09817 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00152928656964116 using h"
# [1] "Max reduction is 0.0118487247198987 using h"
# [1] "Max reduction is 0.00250209456033547 using h"
# [1] "Max reduction is 0.00285036878789265 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X53 ~ h + I(h^2) + I(h^3) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.163926 -0.031392 -0.004768  0.027025  0.173449
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.007544   0.022774  -0.331  0.74332
# h            0.079261   0.067783   1.169  0.25375
# I(h^2)       0.170400   0.052698   3.234  0.00354 **
# I(h^3)      -0.224454   0.108880  -2.061  0.05025 .
# c            0.016960   0.026600   0.638  0.52977
# I(c * h)    -0.094225   0.049238  -1.914  0.06766 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08114 on 24 degrees of freedom
# Multiple R-squared:  0.4537,	Adjusted R-squared:  0.3399
# F-statistic: 3.987 on 5 and 24 DF,  p-value: 0.00896
#
# [1] "1 I(h^3)"
#
# Call:
# lm(formula = X53 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.13257 -0.05123  0.00341  0.01451  0.21106
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.006473   0.024203  -0.267  0.79130
# h           -0.049338   0.028184  -1.751  0.09229 .
# I(h^2)       0.170174   0.056018   3.038  0.00551 **
# c            0.010941   0.028105   0.389  0.70036
# I(c * h)    -0.073905   0.051281  -1.441  0.16194
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08625 on 25 degrees of freedom
# Multiple R-squared:  0.357,	Adjusted R-squared:  0.2541
# F-statistic:  3.47 on 4 and 25 DF,  p-value: 0.02188
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X54 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04518 -0.04010 -0.03136 -0.01264  0.45461
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04019    0.01824   2.203   0.0357 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09991 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00198434281623683 using h"
# [1] "Max reduction is 0.019502350725976 using h"
# [1] "Max reduction is 0.000996571505786789 using c"
# [1] "Max reduction is 0.00245216080832902 using Three Way Interactions with h"
# [1] "Max reduction is 0.00125969015320646 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X55 ~ h + I(h^2) + I(h^3) + c + I(c * h) + I(h *
#     c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.171694 -0.055524  0.008662  0.030839  0.206889
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.006537   0.026563  -0.246 0.807808
# h             0.035233   0.079123   0.445 0.660274
# I(h^2)        0.254755   0.062488   4.077 0.000465 ***
# I(h^3)       -0.162896   0.127065  -1.282 0.212617
# c            -0.036981   0.050562  -0.731 0.471918
# I(c * h)     -0.106264   0.057501  -1.848 0.077497 .
# I(h * c * h)  0.221807   0.139115   1.594 0.124494
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09459 on 23 degrees of freedom
# Multiple R-squared:  0.5136,	Adjusted R-squared:  0.3867
# F-statistic: 4.048 on 6 and 23 DF,  p-value: 0.006503
#
# [1] "1 I(h^3)"
# [1] "2 I(h * c * h)"
#
# Call:
# lm(formula = X55 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.176203 -0.043546  0.002388  0.023627  0.296505
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.007271   0.027582  -0.264  0.79424
# h           -0.059200   0.032120  -1.843  0.07720 .
# I(h^2)       0.236344   0.063841   3.702  0.00106 **
# c            0.022586   0.032029   0.705  0.48722
# I(c * h)    -0.086864   0.058442  -1.486  0.14969
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0983 on 25 degrees of freedom
# Multiple R-squared:  0.429,	Adjusted R-squared:  0.3376
# F-statistic: 4.696 on 4 and 25 DF,  p-value: 0.005775
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X56 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.07436 -0.06259 -0.03474  0.02633  0.41615
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.07444    0.01848   4.027 0.000372 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1012 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X57 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04475 -0.03791 -0.03064 -0.00284  0.36293
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03857    0.01508   2.558    0.016 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08257 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X58 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.03993 -0.03357 -0.02897 -0.01810  0.41831
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04001    0.01689   2.369   0.0247 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09251 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X59 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04785 -0.04104 -0.03225 -0.01113  0.47600
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04166    0.01858   2.242   0.0328 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1018 on 29 degrees of freedom
#
# [1] "Max reduction is 0.000621375430171198 using h"
# [1] "Max reduction is 0.0350555663239012 using h"
# [1] "Max reduction is 0.000788104886417465 using c"
# [1] "Max reduction is 0.000734583290081511 using h"
# [1] "Max reduction is 0.000528899296112904 using c"
# [1] "Max reduction is 0.000725475945277519 using c"
# [1] "Max reduction is 0.000461820736600477 using Three Way Interactions with h"
# [1] "Max reduction is 0.00159666919481029 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X60 ~ h + I(h^2) + I(h^3) + c + I(c^2) + I(c^3) +
#     I(c^4) + I(c * h) + I(h * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.110975 -0.017183 -0.003483  0.015173  0.150589
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.01688    0.02567  -0.658   0.5183
# h             0.02851    0.04938   0.577   0.5701
# I(h^2)        0.29247    0.04066   7.193 5.78e-07 ***
# I(h^3)       -0.11179    0.07816  -1.430   0.1681
# c             0.04618    0.05499   0.840   0.4109
# I(c^2)        0.15671    0.13780   1.137   0.2689
# I(c^3)       -0.10280    0.07717  -1.332   0.1978
# I(c^4)       -0.23341    0.15786  -1.479   0.1548
# I(c * h)     -0.06754    0.03745  -1.803   0.0864 .
# I(h * c * h)  0.14722    0.09023   1.632   0.1184
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.05732 on 20 degrees of freedom
# Multiple R-squared:  0.7633,	Adjusted R-squared:  0.6567
# F-statistic: 7.165 on 9 and 20 DF,  p-value: 0.0001299
#
# [1] "1 I(c^4)"
# [1] "2 I(h^3)"
# [1] "3 I(h * c * h)"
# [1] "4 I(c * h)"
# [1] "5 I(c^3)"
#
# Call:
# lm(formula = X60 ~ h + I(h^2) + c + I(c^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.130501 -0.025419 -0.003445  0.012422  0.155209
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.004723   0.022793   0.207    0.838
# h           -0.032341   0.020473  -1.580    0.127
# I(h^2)       0.258106   0.041321   6.246 1.56e-06 ***
# c            0.016155   0.020579   0.785    0.440
# I(c^2)      -0.025830   0.038993  -0.662    0.514
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06332 on 25 degrees of freedom
# Multiple R-squared:  0.6389,	Adjusted R-squared:  0.5811
# F-statistic: 11.06 on 4 and 25 DF,  p-value: 2.658e-05
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X61 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.04076 -0.03635 -0.02869 -0.00487  0.35146
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03715    0.01518   2.447   0.0207 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08314 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00158404662504383 using h"
# [1] "Max reduction is 0.0117670117169268 using h"
# [1] "Max reduction is 0.00211875091773055 using h"
# [1] "Max reduction is 0.00231398830624359 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X62 ~ h + I(h^2) + I(h^3) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.166867 -0.036270 -0.002649  0.027240  0.175871
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.007045   0.022934  -0.307  0.76137
# h            0.073104   0.068259   1.071  0.29483
# I(h^2)       0.169229   0.053068   3.189  0.00395 **
# I(h^3)      -0.213724   0.109645  -1.949  0.06305 .
# c            0.015957   0.026787   0.596  0.55695
# I(c * h)    -0.090412   0.049584  -1.823  0.08072 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08171 on 24 degrees of freedom
# Multiple R-squared:  0.4418,	Adjusted R-squared:  0.3255
# F-statistic: 3.799 on 5 and 24 DF,  p-value: 0.01122
#
# [1] "1 I(h^3)"
#
# Call:
# lm(formula = X62 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.130792 -0.053334  0.002936  0.014420  0.209801
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.006025   0.024178  -0.249  0.80524
# h           -0.049347   0.028155  -1.753  0.09191 .
# I(h^2)       0.169014   0.055961   3.020  0.00575 **
# c            0.010225   0.028076   0.364  0.71877
# I(c * h)    -0.071064   0.051228  -1.387  0.17762
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.08617 on 25 degrees of freedom
# Multiple R-squared:  0.3535,	Adjusted R-squared:   0.25
# F-statistic: 3.417 on 4 and 25 DF,  p-value: 0.02325
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X63 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.07498 -0.06444 -0.04889  0.02662  0.41549
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.07506    0.01961   3.828 0.000637 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1074 on 29 degrees of freedom
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X64 ~ 1, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.05291 -0.04194 -0.03320 -0.01227  0.46024
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04135    0.01871    2.21   0.0352 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1025 on 29 degrees of freedom
#
# [1] "Max reduction is 0.00225560835575403 using h"
# [1] "Max reduction is 0.0353868871056596 using h"
# [1] "Max reduction is 0.0012442427618518 using c"
# [1] "Max reduction is 0.00413666272750168 using Three Way Interactions with h"
# [1] "Max reduction is 0.0013344419565012 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X65 ~ h + I(h^2) + I(h^3) + c + I(c * h) + I(h *
#     c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.169849 -0.048503  0.008782  0.033394  0.196034
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.007201   0.025731  -0.280   0.7821
# h             0.028813   0.076644   0.376   0.7104
# I(h^2)        0.343344   0.060531   5.672 8.95e-06 ***
# I(h^3)       -0.160680   0.123085  -1.305   0.2047
# c            -0.039710   0.048978  -0.811   0.4258
# I(c * h)     -0.101990   0.055700  -1.831   0.0801 .
# I(h * c * h)  0.255475   0.134757   1.896   0.0706 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09162 on 23 degrees of freedom
# Multiple R-squared:  0.6399,	Adjusted R-squared:  0.546
# F-statistic: 6.813 on 6 and 23 DF,  p-value: 0.0002991
#
# [1] "1 I(h^3)"
# [1] "2 I(h * c * h)"
#
# Call:
# lm(formula = X65 ~ h + I(h^2) + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.183166 -0.040922  0.003877  0.032116  0.294739
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.008175   0.027245  -0.300   0.7666
# h           -0.064517   0.031727  -2.034   0.0527 .
# I(h^2)       0.322165   0.063059   5.109 2.81e-05 ***
# c            0.029622   0.031637   0.936   0.3581
# I(c * h)    -0.082085   0.057726  -1.422   0.1674
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0971 on 25 degrees of freedom
# Multiple R-squared:  0.5605,	Adjusted R-squared:  0.4902
# F-statistic:  7.97 on 4 and 25 DF,  p-value: 0.0002758

# %% [markdown]
# We can use Leave One Out to verify if our GPs fit our metrics correctly.

# %%
tLOOs <- LOO.plot(Emulators = em_wave1, which.emulator = 4, ParamNames = cands)
# Out:
# Plot with title “”

# %% [markdown]
# ### Compute implausibility
#
# We will compute implausibility as it is described in *Williamson & al. (2017)*.
#
# $$
# I_i(x_0) = \frac{|z_i - \mathbf{E}[f_i(x_0)]|}{|Var[z_i - \mathbf{E}[f_i(x_0)]]|} \\
# I(x_0) = max_i(I_i(x_0))
# $$
#
# We consider that $Var[z_i - \mathbf{E}[f_i(x_0)]] = Var[e] +
# Var[g] + Var[f(x_0)]$  like it is describe in *Williamson & al. (2017)*.
#
# With $Var[e]$ the observational
# error variance, $Var[g]$ the model discrepancy variance
# and $Var[f(x)]$ the variance of the emulator.

# %%
tDisc <- rep(0, ncol(metrics_k_wave1)) # model discrepancy variance Var[g] 
tObsErr <- rep(0, ncol(metrics_k_wave1)) # observational error variance Var[e]
tObs <-  as.vector(observations[metrics_index_k]) # Observations

# %% [markdown]
# We generate a large sampling of the parameter space (that we have scaled) and will compute implausibility for each point of this parameters space.

# %%
sample_size <- 100000
nparam <- length(names(em_wave1$fitting.elements$Design))
Xp <- as.data.frame(2*randomLHS(sample_size, nparam)-1)
names(Xp) <- names(em_wave1$fitting.elements$Design)
system.time(Timps <- ImplausibilityMOGP(NewData=Xp, Emulator=em_wave1, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))
# Out:
#    user  system elapsed
#  54.971  17.503  11.413

# %%
VarNames <- names(Xp)
valmax = 0 #how many outputs can be above the implausibility cut off
cutoff <- 3 #the implausibility cut off
param.def = data.frame(h=c(1),c=c(10),b=c(10)) #the default parameters of the model (on [-1,1])
param.defaults.norm = rangeScale(param.def, my_bounds, range(-1,1))
print(param.defaults.norm)
# Out:
#     h c   b
# 1 0.5 0 0.5

# %%
NROY1 <- which(rowSums(Timps <= cutoff) >= em_wave1$mogp$n_emulators -valmax)
scoreNROY1 <- length(NROY1)/dim(Xp)[1]
scoreNROY1
# Out:
# [1] 0.32205

# %% [markdown]
# The first wave of tuning allowed us to reject approximately 70% of the parameters space.

# %% [markdown]
# ### Layout of NROY space

# %%
ImpData_wave1 = cbind(Xp, Timps)
ImpListM1 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave1, nEms=em_wave1$mogp$n_emulators, whichMax=valmax+1)
imp.layoutm11(ImpListM1,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",scoreNROY1,sep=""), side=1)
# Out:
# plot without title

# %% [markdown]
# ## Second Wave
#
# We will generate a large number of samples in the entire parameters space in order to obtain *n_samples* samples in the NROY space created with the emulator *em_wave1*.

# %%
n <- ceiling(n_samples*1.3/scoreNROY1)

# %%
space <- skSpace$Space(list(c(-1, 1), c(-1, 1), c(-1, 1))) ## we use a scaled space
lhs <- sampler$Lhs(iterations=as.integer(10))  #(lhs_type='classic', criterion='maximin', iterations=1000)
inputs_wave2_scaled_temp <- np$array(lhs$generate(space$dimensions, as.integer(n), random_state=as.integer(42)))

# %% [markdown]
# We find the points of NewData wich fall in the NROY space of each emulator in *emulators*.

# %%
parameters_space <- function(emulators, NewData, n_samples=n_samples){
    NROY_em <- 1:nrow(NewData)
    for (em in emulators){
        imp_em <- ImplausibilityMOGP(NewData=NewData, Emulator=em, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr)
        NROY_temp <- which(rowSums(imp_em <= cutoff) >= em$mogp$n_emulators - valmax)
        NROY_em <- intersect(NROY_em, NROY_temp)
    }
    return(sample(NROY_em, n_samples))
}

# %%
emulators <- list(em_wave1)
NROY_temp_wave2 <- parameters_space(emulators, inputs_wave2_scaled_temp, 30)

# %% [markdown]
# We now have our new inputs for wave 2.
#
# We need to unscale those inputs for metrics simulations.

# %%
input_wave2_scaled <- inputs_wave2_scaled_temp[sample(NROY_temp_wave2, n_samples),]
input_wave2 <- rangeUnscale(input_wave2_scaled, my_bounds, range = c(-1, 1))

# %%
par(mfrow=c(2,2))
plot(input_wave2[,1], input_wave2[,2], xlab="h", ylab="c", xlim=c(-2,2), ylim=c(0,20))
points(1, 10, col='red', pch=18, cex=2)
plot(input_wave2[,1], input_wave2[,3], xlab="h", ylab="b", xlim=c(-2,2), ylim=c(-20,20))
points(1, 10, col='red', pch=18, cex=2)
plot(input_wave2[,2], input_wave2[,3], xlab="c", ylab="b", xlim=c(0,20), ylim=c(-20,20))
points(10, 10, col='red', pch=18, cex=2)
# Out:
# plot without title

# %%
metrics_wave2 = future_sapply(1:nrow(input_wave2), function(r) extract_metrics_AMIP(input_wave2[r,], n_iter, 0.001, X_hist), future.seed=NULL)

# %% [markdown]
# ### Create the data matrix

# %%
input_wave2_scaled <- data.frame(input_wave2_scaled)
names(input_wave2_scaled) <- c('h', 'c', 'b')


metrics_k_wave2 <- data.frame(t(metrics_wave2)[, metrics_index_k])
N = nrow(metrics_k_wave2) 
noise <- rnorm(N, 0, 0)
tData_wave2 <- data.frame(cbind(input_wave2_scaled, noise, metrics_k_wave2))
names(tData_wave2)[names(tData_wave2) == "noise"] <- "Noise"
         
head(tData_wave2)
# Out:
#   h          c          b          Noise X1          X2          X3
# 1 -0.1530526 -0.3361236  0.9720859 0     0.013912168 -0.05579715 0.014563931
# 2  0.2506088 -0.6294510  0.6758554 0     0.061621667  0.08210826 0.077673679
# 3  0.6610673 -0.9702002 -0.5311766 0     0.007720318  0.16360167 0.021531129
# 4  0.8675095  0.5975467  0.8481951 0     0.078405222  0.11833268 0.088859763
# 5  0.3784174  0.7133222  0.0502012 0     0.177288609  0.18985428 0.192695864
# 6  0.6172319  0.6306768 -0.7231771 0     0.033416101  0.06499862 0.001973093
#   X4          X5          X6          ⋯ X56         X57          X58
# 1 -0.03950046 0.015298586 -0.05018536 ⋯ 0.002153506  0.000530957 0.001465042
# 2  0.08798034 0.046312343  0.08627153 ⋯ 0.023628816  0.013595129 0.008402983
# 3  0.16377339 0.008857766  0.18850980 ⋯ 0.015420184  0.006843689 0.011053149
# 4  0.12360403 0.086594392  0.10144461 ⋯ 0.117055818  0.029048442 0.001176050
# 5  0.18980542 0.197794950  0.20603834 ⋯ 0.087298328  0.082859716 0.102508332
# 6  0.05518765 0.014186138  0.07658564 ⋯ 0.030172262 -0.002259494 0.009299290
#   X59           X60         X61           X62          X63
# 1 -0.0003610152 0.005752939  0.0003514342 0.0048220966 0.002005201
# 2  0.0076162148 0.019661428  0.0095410096 0.0049696264 0.020524109
# 3 -0.0019389181 0.030980568  0.0024712225 0.0382863696 0.010551442
# 4  0.0162350113 0.100369272  0.0209664142 0.0001775774 0.114117013
# 5  0.0988781917 0.079852733  0.0970266202 0.0924898854 0.125540819
# 6 -0.0025837387 0.038122785 -0.0057514259 0.0180297741 0.034270935
#   X64           X65
# 1 -0.0009941468 0.006993797
# 2  0.0128248352 0.019981965
# 3 -0.0034486584 0.070878902
# 4  0.0216536812 0.088160160
# 5  0.1175136603 0.118277220
# 6 -0.0081169164 0.044552153

# %% [markdown]
# ### Training emulator

# %%
em_wave2 <- BuildNewEmulators(tData_wave2, HowManyEmulators = ncol(metrics_wave2), meanFun = "fitted", additionalVariables = cands) #
# Out:
# [1] "Max reduction is 0.00446367957841858 using b"
# [1] "Max reduction is 0.00352491387952267 using h"
# [1] "Max reduction is 0.00670103694229086 using b"
# [1] "Max reduction is 0.00379310327331508 using b"
# [1] "Max reduction is 0.00243913026081448 using b"
# [1] "Max reduction is 0.0032238498710622 using Three Way Interactions with b"
# [1] "Max reduction is 0.00423436309282937 using c"
# [1] "Max reduction is 0.000808976056559149 using b"
# [1] "Max reduction is 0.00307063707663819 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X1 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + I(b^6) +
#     h + c + I(h * b) + I(c * b) + I(c * h) + I(b * h * b) + I(b *
#     c * b) + I(b * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.023325 -0.009979 -0.001574  0.007391  0.033100
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.03567    0.01077   3.312  0.00474 **
# b             0.06032    0.04788   1.260  0.22696
# I(b^2)       -0.50487    0.12532  -4.028  0.00109 **
# I(b^3)        0.06855    0.16291   0.421  0.67989
# I(b^4)        1.10874    0.36379   3.048  0.00814 **
# I(b^5)       -0.17649    0.12530  -1.409  0.17935
# I(b^6)       -0.61224    0.24957  -2.453  0.02687 *
# h             0.28531    0.03549   8.038 8.12e-07 ***
# c            -0.02626    0.01712  -1.534  0.14588
# I(h * b)      0.01927    0.02815   0.685  0.50399
# I(c * b)      0.02691    0.03695   0.728  0.47766
# I(c * h)      0.12037    0.03553   3.388  0.00406 **
# I(b * h * b) -0.30526    0.05783  -5.278 9.28e-05 ***
# I(b * c * b) -0.06490    0.03351  -1.937  0.07188 .
# I(b * c * h) -0.10865    0.06175  -1.759  0.09887 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02101 on 15 degrees of freedom
# Multiple R-squared:  0.9195,	Adjusted R-squared:  0.8444
# F-statistic: 12.24 on 14 and 15 DF,  p-value: 9.119e-06
#
# [1] "1 I(b^6)"
# [1] "2 I(b^5)"
# [1] "3 I(b^4)"
# [1] "4 I(b * c * b)"
# [1] "5 I(b * h * b)"
# [1] "6 I(h * b)"
# [1] "7 I(b * c * h)"
# [1] "8 I(c * h)"
# [1] "9 I(c * b)"
# [1] "10 c"
#
# Call:
# lm(formula = X1 ~ b + I(b^2) + I(b^3) + h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.075009 -0.019152  0.000055  0.014734  0.087179
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04825    0.01227   3.931 0.000591 ***
# b            0.11167    0.02817   3.965 0.000543 ***
# I(b^2)      -0.07836    0.02073  -3.779 0.000871 ***
# I(b^3)      -0.10375    0.03908  -2.655 0.013614 *
# h            0.09637    0.02190   4.401 0.000176 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03409 on 25 degrees of freedom
# Multiple R-squared:  0.647,	Adjusted R-squared:  0.5906
# F-statistic: 11.46 on 4 and 25 DF,  p-value: 2.019e-05
#
# [1] "Max reduction is 0.00906124841869863 using h"
# [1] "Max reduction is 0.0116795565019716 using h"
# [1] "Max reduction is 0.00152616746348384 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X2 ~ h + I(h^2) + I(h^3), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.064143 -0.021325  0.003089  0.014694  0.085958
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.02326    0.01232   1.888  0.07020 .
# h            0.43405    0.07118   6.098 1.91e-06 ***
# I(h^2)      -0.71821    0.22938  -3.131  0.00427 **
# I(h^3)       0.35499    0.19127   1.856  0.07483 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03446 on 26 degrees of freedom
# Multiple R-squared:  0.6691,	Adjusted R-squared:  0.631
# F-statistic: 17.53 on 3 and 26 DF,  p-value: 1.982e-06
#
# [1] "Max reduction is 0.00434793318600211 using b"
# [1] "Max reduction is 0.00504850735909025 using h"
# [1] "Max reduction is 0.00495086403511241 using b"
# [1] "Max reduction is 0.000379393504776816 using b"
# [1] "Max reduction is 0.00404020260780661 using b"
# [1] "Max reduction is 0.00265436103757472 using Three Way Interactions with b"
# [1] "Max reduction is 0.00222620068187693 using c"
# [1] "Max reduction is 0.00125227804599929 using h"
# [1] "Max reduction is 0.000892926206156539 using h"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X3 ~ b + I(b^2) + I(b^3) + I(b^4) + h + I(h^2) +
#     I(h^3) + c + I(h * b) + I(c * b) + I(c * h) + I(b * h * b) +
#     I(b * c * b) + I(b * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.043759 -0.013082 -0.004777  0.013652  0.056062
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.02730    0.01736   1.572 0.136689
# b             0.04445    0.04143   1.073 0.300268
# I(b^2)       -0.25732    0.10727  -2.399 0.029899 *
# I(b^3)       -0.07765    0.04698  -1.653 0.119125
# I(b^4)        0.28472    0.08203   3.471 0.003423 **
# h             0.46842    0.11396   4.110 0.000926 ***
# I(h^2)       -0.59118    0.32357  -1.827 0.087651 .
# I(h^3)        0.43011    0.30956   1.389 0.184990
# c            -0.01024    0.02493  -0.411 0.687067
# I(h * b)      0.07644    0.06135   1.246 0.231910
# I(c * b)     -0.04760    0.06820  -0.698 0.495912
# I(c * h)      0.12197    0.06486   1.880 0.079612 .
# I(b * h * b) -0.26708    0.13259  -2.014 0.062264 .
# I(b * c * b) -0.15361    0.06288  -2.443 0.027414 *
# I(b * c * h)  0.04823    0.11119   0.434 0.670619
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03115 on 15 degrees of freedom
# Multiple R-squared:  0.8452,	Adjusted R-squared:  0.7007
# F-statistic: 5.851 on 14 and 15 DF,  p-value: 0.0007973
#
# [1] "1 I(b * c * h)"
# [1] "2 I(h^3)"
# [1] "3 I(c * h)"
# [1] "4 I(b * c * b)"
# [1] "5 I(c * b)"
# [1] "6 c"
# [1] "7 I(b^4)"
# [1] "8 I(b * h * b)"
# [1] "9 I(h * b)"
# [1] "10 I(b^3)"
#
# Call:
# lm(formula = X3 ~ b + I(b^2) + h + I(h^2), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.07375 -0.02513 -0.00085  0.01971  0.09459
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04100    0.01759   2.330  0.02816 *
# b            0.04610    0.01248   3.693  0.00109 **
# I(b^2)      -0.05860    0.02926  -2.002  0.05619 .
# h            0.18971    0.07098   2.673  0.01306 *
# I(h^2)      -0.11763    0.08840  -1.331  0.19532
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.04152 on 25 degrees of freedom
# Multiple R-squared:  0.5416,	Adjusted R-squared:  0.4683
# F-statistic: 7.386 on 4 and 25 DF,  p-value: 0.0004524
#
# [1] "Max reduction is 0.00828302043386866 using h"
# [1] "Max reduction is 0.00875723861894904 using h"
# [1] "Max reduction is 0.00104383100339699 using b"
# [1] "Max reduction is 0.00449975165442433 using b"
# [1] "Max reduction is 0.000824492140124332 using Three Way Interactions with b"
# [1] "Max reduction is 0.00148131280255366 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X4 ~ h + I(h^2) + I(h^3) + b + I(b^2) + I(b * h) +
#     I(b * b * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.078785 -0.010401 -0.001248  0.012755  0.068176
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.023830   0.017503   1.361 0.187154
# h             0.420582   0.102064   4.121 0.000449 ***
# I(h^2)       -0.585938   0.271743  -2.156 0.042264 *
# I(h^3)        0.405813   0.228314   1.777 0.089325 .
# b             0.008335   0.023238   0.359 0.723257
# I(b^2)       -0.009324   0.034100  -0.273 0.787062
# I(b * h)      0.017583   0.035276   0.498 0.623121
# I(b * b * h) -0.177624   0.078173  -2.272 0.033200 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03228 on 22 degrees of freedom
# Multiple R-squared:  0.7581,	Adjusted R-squared:  0.6812
# F-statistic: 9.851 on 7 and 22 DF,  p-value: 1.543e-05
#
# [1] "1 I(h^3)"
# [1] "2 I(b * b * h)"
# [1] "3 I(b * h)"
#
# Call:
# lm(formula = X4 ~ h + I(h^2) + b + I(b^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.075508 -0.012069 -0.002637  0.015330  0.071492
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03756    0.01440   2.608  0.01515 *
# h            0.28312    0.05810   4.873 5.18e-05 ***
# I(h^2)      -0.18949    0.07235  -2.619  0.01477 *
# b            0.01852    0.01022   1.813  0.08193 .
# I(b^2)      -0.06885    0.02395  -2.875  0.00814 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03398 on 25 degrees of freedom
# Multiple R-squared:  0.6954,	Adjusted R-squared:  0.6467
# F-statistic: 14.27 on 4 and 25 DF,  p-value: 3.412e-06
#
# [1] "Max reduction is 0.00428351379784755 using b"
# [1] "Max reduction is 0.00317006290478623 using b"
# [1] "Max reduction is 0.0072307248860557 using h"
# [1] "Max reduction is 0.00137724848773545 using b"
# [1] "Max reduction is 0.00109916282660369 using b"
# [1] "Max reduction is 0.0016612464488631 using Three Way Interactions with b"
# [1] "Max reduction is 0.000523339272173927 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X5 ~ b + I(b^2) + I(b^3) + I(b^4) + h + c + I(h *
#     b) + I(c * b) + I(c * h) + I(b * h * b) + I(b * c * b) +
#     I(b * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.057759 -0.018278 -0.001155  0.014841  0.060692
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.03710    0.01860   1.994 0.062411 .
# b             0.06286    0.04323   1.454 0.164142
# I(b^2)       -0.20069    0.09269  -2.165 0.044891 *
# I(b^3)       -0.08046    0.04908  -1.639 0.119495
# I(b^4)        0.18722    0.08861   2.113 0.049694 *
# h             0.22770    0.05676   4.012 0.000904 ***
# c            -0.01992    0.02772  -0.719 0.482199
# I(h * b)      0.03711    0.04747   0.782 0.445108
# I(c * b)      0.01538    0.06218   0.247 0.807586
# I(c * h)      0.12406    0.06177   2.008 0.060753 .
# I(b * h * b) -0.20656    0.08718  -2.369 0.029928 *
# I(b * c * b) -0.05607    0.05710  -0.982 0.339893
# I(b * c * h) -0.07662    0.10695  -0.716 0.483449
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03661 on 17 degrees of freedom
# Multiple R-squared:  0.7491,	Adjusted R-squared:  0.5719
# F-statistic: 4.229 on 12 and 17 DF,  p-value: 0.003599
#
# [1] "1 I(b^4)"
# [1] "2 I(b * c * h)"
# [1] "3 I(c * h)"
# [1] "4 I(b * c * b)"
# [1] "5 I(b * h * b)"
# [1] "6 I(h * b)"
# [1] "7 I(c * b)"
# [1] "8 c"
#
# Call:
# lm(formula = X5 ~ b + I(b^2) + I(b^3) + h, data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.07227 -0.02070 -0.00588  0.02196  0.10795
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.05031    0.01407   3.575 0.001463 **
# b            0.09254    0.03230   2.865 0.008332 **
# I(b^2)      -0.09059    0.02378  -3.810 0.000806 ***
# I(b^3)      -0.07589    0.04482  -1.693 0.102870
# h            0.09282    0.02511   3.696 0.001077 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03909 on 25 degrees of freedom
# Multiple R-squared:  0.5793,	Adjusted R-squared:  0.5119
# F-statistic: 8.605 on 4 and 25 DF,  p-value: 0.0001645
#
# [1] "Max reduction is 0.0114791806255249 using h"
# [1] "Max reduction is 0.00848219132298654 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X6 ~ h + I(h^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.077278 -0.019931 -0.006373  0.025771  0.100285
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.01765    0.01359   1.299 0.204870
# h            0.33751    0.06400   5.274 1.46e-05 ***
# I(h^2)      -0.27667    0.07424  -3.727 0.000907 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.04069 on 27 degrees of freedom
# Multiple R-squared:  0.5809,	Adjusted R-squared:  0.5499
# F-statistic: 18.71 on 2 and 27 DF,  p-value: 7.959e-06
#
# [1] "Max reduction is 0.00671675923526263 using b"
# [1] "Max reduction is 0.00509694375839916 using h"
# [1] "Max reduction is 0.00604077419045555 using b"
# [1] "Max reduction is 0.00425462413145881 using b"
# [1] "Max reduction is 0.00328385623350676 using b"
# [1] "Max reduction is 0.00392593067921909 using Three Way Interactions with b"
# [1] "Max reduction is 0.000707863553272733 using c"
# [1] "Max reduction is 4.21855033845876e-05 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X7 ~ b + I(b^2) + I(b^3) + I(b^4) + h + c + I(c^2) +
#     I(h * b) + I(c * b) + I(c * h) + I(b * h * b) + I(b * c *
#     b) + I(b * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.039306 -0.011350 -0.002716  0.010744  0.048814
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.01917    0.01907   1.005  0.32977
# b             0.11324    0.03577   3.166  0.00599 **
# I(b^2)       -0.26333    0.07634  -3.449  0.00330 **
# I(b^3)       -0.14566    0.03994  -3.647  0.00217 **
# I(b^4)        0.28536    0.07582   3.764  0.00170 **
# h             0.26363    0.04696   5.614 3.88e-05 ***
# c            -0.02953    0.02239  -1.319  0.20575
# I(c^2)        0.02269    0.02215   1.024  0.32099
# I(h * b)      0.05154    0.03846   1.340  0.19898
# I(c * b)      0.01762    0.05041   0.350  0.73126
# I(c * h)      0.11984    0.05135   2.334  0.03297 *
# I(b * h * b) -0.23952    0.07049  -3.398  0.00368 **
# I(b * c * b) -0.06031    0.04582  -1.316  0.20656
# I(b * c * h) -0.07746    0.08741  -0.886  0.38862
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02933 on 16 degrees of freedom
# Multiple R-squared:  0.8655,	Adjusted R-squared:  0.7562
# F-statistic:  7.92 on 13 and 16 DF,  p-value: 0.0001061
#
# [1] "1 I(c^2)"
# [1] "2 I(b * c * h)"
# [1] "3 I(c * h)"
# [1] "4 I(b * c * b)"
# [1] "5 I(b^4)"
# [1] "6 I(c * b)"
# [1] "7 c"
# [1] "8 I(b * h * b)"
# [1] "9 I(h * b)"
#
# Call:
# lm(formula = X7 ~ b + I(b^2) + I(b^3) + h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.074687 -0.019158 -0.000873  0.019024  0.100027
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04499    0.01325   3.395 0.002296 **
# b            0.12763    0.03042   4.196 0.000299 ***
# I(b^2)      -0.08143    0.02239  -3.637 0.001250 **
# I(b^3)      -0.11246    0.04221  -2.665 0.013300 *
# h            0.10605    0.02365   4.485 0.000142 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03681 on 25 degrees of freedom
# Multiple R-squared:  0.6689,	Adjusted R-squared:  0.6159
# F-statistic: 12.63 on 4 and 25 DF,  p-value: 9.348e-06
#
# [1] "Max reduction is 0.00647027881449949 using h"
# [1] "Max reduction is 0.0122952890412051 using h"
# [1] "Max reduction is 0.000385809644699489 using b"
# [1] "Max reduction is 0.00379957916856702 using b"
# [1] "Max reduction is 0.000545494507316523 using Three Way Interactions with b"
# [1] "Max reduction is 0.000735797201511502 using h"
# [1] "Max reduction is 0.00270419649359944 using c"
# [1] "Max reduction is 0.000526874869896218 using Three Way Interactions with h"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X8 ~ h + I(h^2) + I(h^3) + b + I(b^2) + c + I(b *
#     h) + I(c * h) + I(c * b) + I(b * b * h) + I(b * c * h) +
#     I(b * c * b) + I(h * b * h) + I(h * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.052669 -0.006476 -0.000374  0.006959  0.039263
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.011417   0.017925   0.637  0.53377
# h             0.669684   0.169514   3.951  0.00128 **
# I(h^2)       -1.296821   0.425682  -3.046  0.00816 **
# I(h^3)        0.926288   0.298750   3.101  0.00731 **
# b            -0.008918   0.064063  -0.139  0.89114
# I(b^2)       -0.007255   0.051423  -0.141  0.88968
# c            -0.001602   0.020907  -0.077  0.93994
# I(b * h)     -0.091816   0.233906  -0.393  0.70018
# I(c * h)      0.215499   0.096184   2.240  0.04062 *
# I(c * b)     -0.030510   0.047579  -0.641  0.53104
# I(b * b * h) -0.205531   0.112338  -1.830  0.08726 .
# I(b * c * h)  0.073211   0.076816   0.953  0.35566
# I(b * c * b) -0.087602   0.063515  -1.379  0.18804
# I(h * b * h)  0.161877   0.197441   0.820  0.42512
# I(h * c * h) -0.225316   0.135216  -1.666  0.11639
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02331 on 15 degrees of freedom
# Multiple R-squared:  0.891,	Adjusted R-squared:  0.7892
# F-statistic: 8.756 on 14 and 15 DF,  p-value: 7.546e-05
#
# [1] "1 I(h * b * h)"
# [1] "2 I(b * c * h)"
# [1] "3 I(h^3)"
# [1] "4 I(h * c * h)"
# [1] "5 I(c * h)"
# [1] "6 I(b * c * b)"
# [1] "7 I(c * b)"
# [1] "8 c"
# [1] "9 I(b * b * h)"
# [1] "10 I(b * h)"
#
# Call:
# lm(formula = X8 ~ h + I(h^2) + b + I(b^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.070277 -0.014207 -0.002357  0.010755  0.070241
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.034666   0.011663   2.972 0.006453 **
# h            0.288765   0.047054   6.137 2.05e-06 ***
# I(h^2)      -0.224863   0.058602  -3.837 0.000752 ***
# b            0.011839   0.008276   1.430 0.164957
# I(b^2)      -0.056783   0.019399  -2.927 0.007189 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02752 on 25 degrees of freedom
# Multiple R-squared:  0.7467,	Adjusted R-squared:  0.7061
# F-statistic: 18.42 on 4 and 25 DF,  p-value: 3.635e-07
#
# [1] "Max reduction is 0.00760611573486081 using b"
# [1] "Max reduction is 0.00195289179342634 using b"
# [1] "Max reduction is 0.00477316136522844 using h"
# [1] "Max reduction is 0.00397129337950155 using b"
# [1] "Max reduction is 0.00990185585198046 using b"
# [1] "Max reduction is 0.00323990549105636 using Three Way Interactions with b"
# [1] "Max reduction is 0.00374785963130754 using c"
# [1] "Max reduction is 0.00384074136494999 using h"
# [1] "Max reduction is 0.0001948147792027 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X9 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + h +
#     I(h^2) + c + I(h * b) + I(c * b) + I(c * h) + I(b * h * b) +
#     I(b * c * b) + I(b * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.033125 -0.010208 -0.001776  0.010415  0.051042
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.03269    0.01569   2.083   0.0548 .
# b             0.08652    0.06531   1.325   0.2051
# I(b^2)       -0.53791    0.07806  -6.891 5.14e-06 ***
# I(b^3)        0.15432    0.21417   0.721   0.4823
# I(b^4)        0.47026    0.06950   6.766 6.35e-06 ***
# I(b^5)       -0.18791    0.16981  -1.107   0.2859
# h             0.43817    0.07868   5.569 5.37e-05 ***
# I(h^2)       -0.20656    0.09673  -2.135   0.0496 *
# c             0.01333    0.02305   0.578   0.5717
# I(h * b)     -0.04691    0.04750  -0.987   0.3391
# I(c * b)     -0.14019    0.05768  -2.430   0.0281 *
# I(c * h)      0.06869    0.05095   1.348   0.1976
# I(b * h * b) -0.10549    0.08607  -1.226   0.2393
# I(b * c * b) -0.05540    0.04530  -1.223   0.2402
# I(b * c * h)  0.19245    0.09653   1.994   0.0647 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02786 on 15 degrees of freedom
# Multiple R-squared:  0.9108,	Adjusted R-squared:  0.8276
# F-statistic: 10.94 on 14 and 15 DF,  p-value: 1.876e-05
#
# [1] "1 I(b^5)"
# [1] "2 I(b * c * b)"
# [1] "3 I(c * b)"
# [1] "4 I(b * c * h)"
# [1] "5 I(h^2)"
# [1] "6 I(c * h)"
# [1] "7 c"
# [1] "8 I(b * h * b)"
# [1] "9 I(h * b)"
# [1] "10 I(b^4)"
#
# Call:
# lm(formula = X9 ~ b + I(b^2) + I(b^3) + h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.080110 -0.031899 -0.001932  0.022485  0.149839
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04762    0.01721   2.767  0.01050 *
# b            0.14230    0.03950   3.603  0.00136 **
# I(b^2)      -0.08487    0.02908  -2.919  0.00733 **
# I(b^3)      -0.12791    0.05481  -2.334  0.02796 *
# h            0.09013    0.03071   2.935  0.00706 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0478 on 25 degrees of freedom
# Multiple R-squared:  0.5623,	Adjusted R-squared:  0.4922
# F-statistic: 8.028 on 4 and 25 DF,  p-value: 0.0002628
#
# [1] "Max reduction is 0.0108066177097251 using h"
# [1] "Max reduction is 0.0123241764581853 using h"
# [1] "Max reduction is 0.000740996483243377 using b"
# [1] "Max reduction is 0.00196825290530592 using b"
# [1] "Max reduction is 0.0015233265733865 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X10 ~ h + I(h^2) + b + I(b^2) + I(b^3) + I(b * h),
#     data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.117059 -0.014717 -0.005242  0.011984  0.088314
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.725e-02  1.883e-02   1.978  0.05998 .
# h            3.308e-01  7.957e-02   4.158  0.00038 ***
# I(h^2)      -2.512e-01  9.226e-02  -2.723  0.01213 *
# b           -7.463e-02  3.885e-02  -1.921  0.06719 .
# I(b^2)      -5.329e-02  2.717e-02  -1.961  0.06208 .
# I(b^3)       7.584e-02  4.427e-02   1.713  0.10014
# I(b * h)    -4.821e-05  4.128e-02  -0.001  0.99908
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03854 on 23 degrees of freedom
# Multiple R-squared:  0.7288,	Adjusted R-squared:  0.658
# F-statistic:  10.3 on 6 and 23 DF,  p-value: 1.448e-05
#
# [1] "1 I(b * h)"
# [1] "2 I(b^3)"
#
# Call:
# lm(formula = X10 ~ h + I(h^2) + b + I(b^2), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.09806 -0.02225 -0.00399  0.01883  0.10758
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03388    0.01664   2.037   0.0524 .
# h            0.32806    0.06712   4.888 4.98e-05 ***
# I(h^2)      -0.24769    0.08359  -2.963   0.0066 **
# b           -0.02373    0.01180  -2.011   0.0553 .
# I(b^2)      -0.05302    0.02767  -1.916   0.0669 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03926 on 25 degrees of freedom
# Multiple R-squared:  0.6941,	Adjusted R-squared:  0.6451
# F-statistic: 14.18 on 4 and 25 DF,  p-value: 3.599e-06
#
# [1] "Max reduction is 0.0151175943722891 using h"
# [1] "Max reduction is 0.00439211251875179 using b"
# [1] "Max reduction is 0.000394556160681868 using b"
# [1] "Max reduction is 0.00244412508979895 using b"
# [1] "Max reduction is 0.00152355925590683 using Three Way Interactions with b"
# [1] "Max reduction is 0.0029936640607599 using h"
# [1] "Max reduction is 0.00246462788612415 using c"
# [1] "Max reduction is 0.00152644852708274 using Three Way Interactions with h"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X11 ~ h + I(h^2) + b + I(b^2) + I(b^3) + c + I(b *
#     h) + I(c * h) + I(c * b) + I(b * b * h) + I(b * c * h) +
#     I(b * c * b) + I(h * b * h) + I(h * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.016452 -0.004427 -0.000652  0.001954  0.033719
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.007041   0.009074   0.776  0.44982
# h            -0.020812   0.050692  -0.411  0.68720
# I(h^2)        0.334472   0.072995   4.582  0.00036 ***
# b            -0.045760   0.037223  -1.229  0.23788
# I(b^2)        0.091860   0.030225   3.039  0.00828 **
# I(b^3)       -0.076291   0.021145  -3.608  0.00258 **
# c            -0.006994   0.012402  -0.564  0.58111
# I(b * h)      0.333522   0.114872   2.903  0.01092 *
# I(c * h)      0.087595   0.050340   1.740  0.10231
# I(c * b)      0.063653   0.029364   2.168  0.04668 *
# I(b * b * h) -0.336852   0.066029  -5.102  0.00013 ***
# I(b * c * h) -0.124263   0.047155  -2.635  0.01874 *
# I(b * c * b) -0.117837   0.036679  -3.213  0.00581 **
# I(h * b * h) -0.228409   0.094041  -2.429  0.02819 *
# I(h * c * h)  0.049734   0.065037   0.765  0.45631
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01366 on 15 degrees of freedom
# Multiple R-squared:  0.9513,	Adjusted R-squared:  0.9059
# F-statistic: 20.93 on 14 and 15 DF,  p-value: 2.514e-07
#
# [1] "1 I(h * c * h)"
# [1] "2 I(h^2)"
# [1] "3 I(b * c * h)"
# [1] "4 I(c * h)"
# [1] "5 I(b * c * b)"
# [1] "6 I(h * b * h)"
# [1] "7 I(c * b)"
# [1] "8 c"
# [1] "9 I(b * b * h)"
# [1] "10 I(b * h)"
#
# Call:
# lm(formula = X11 ~ h + b + I(b^2) + I(b^3), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.034767 -0.013251  0.000638  0.007702  0.056402
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.003572   0.007844  -0.455 0.652820
# h            0.124929   0.013997   8.925 3.02e-09 ***
# b            0.071173   0.018003   3.953 0.000559 ***
# I(b^2)      -0.018461   0.013252  -1.393 0.175876
# I(b^3)      -0.066787   0.024982  -2.673 0.013036 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02179 on 25 degrees of freedom
# Multiple R-squared:  0.7935,	Adjusted R-squared:  0.7604
# F-statistic: 24.01 on 4 and 25 DF,  p-value: 2.988e-08
#
# [1] "Max reduction is 0.00122900755520606 using b"
# [1] "Max reduction is 0.000992853516271961 using b"
# [1] "Max reduction is 0.00200574593357641 using h"
# [1] "Max reduction is 0.000786410984819731 using Three Way Interactions with b"
# [1] "Max reduction is 0.00108624406404445 using c"
# [1] "Max reduction is 7.39394287412268e-05 using b"
# [1] "Max reduction is 0.00348498281200873 using b"
# [1] "Max reduction is 0.000233143863917842 using b"
# [1] "Max reduction is 0.000848257673815562 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X12 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + I(b^6) +
#     h + c + I(h * b) + I(c * b) + I(c * h) + I(b * h * b) + I(b *
#     c * b) + I(b * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0142425 -0.0047409 -0.0004539  0.0048141  0.0171107
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.004285   0.005475   0.783 0.446010
# b             0.002006   0.024344   0.082 0.935412
# I(b^2)       -0.224073   0.063719  -3.517 0.003116 **
# I(b^3)        0.055217   0.082829   0.667 0.515129
# I(b^4)        0.454855   0.184963   2.459 0.026559 *
# I(b^5)       -0.075775   0.063705  -1.189 0.252742
# I(b^6)       -0.242146   0.126890  -1.908 0.075676 .
# h             0.130133   0.018046   7.211 3.02e-06 ***
# c             0.013157   0.008705   1.512 0.151432
# I(h * b)      0.015390   0.014311   1.075 0.299201
# I(c * b)     -0.031019   0.018787  -1.651 0.119494
# I(c * h)      0.021240   0.018065   1.176 0.258014
# I(b * h * b) -0.138222   0.029404  -4.701 0.000284 ***
# I(b * c * b) -0.050556   0.017039  -2.967 0.009595 **
# I(b * c * h)  0.036730   0.031397   1.170 0.260321
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01068 on 15 degrees of freedom
# Multiple R-squared:  0.8714,	Adjusted R-squared:  0.7513
# F-statistic: 7.259 on 14 and 15 DF,  p-value: 0.0002325
#
# [1] "1 I(b^6)"
# [1] "2 I(b^5)"
# [1] "3 I(b^4)"
# [1] "4 I(b * c * h)"
# [1] "5 I(c * h)"
# [1] "6 I(b * c * b)"
# [1] "7 I(c * b)"
# [1] "8 c"
# [1] "9 I(b^3)"
# [1] "10 I(b * h * b)"
#
# Call:
# lm(formula = X12 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.017279 -0.010222 -0.003069  0.003351  0.057177
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.014129   0.006394   2.210  0.03651 *
# b            0.008613   0.010452   0.824  0.41771
# I(b^2)      -0.030561   0.010886  -2.807  0.00955 **
# h            0.028593   0.012231   2.338  0.02771 *
# I(h * b)     0.010032   0.016375   0.613  0.54566
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0172 on 25 degrees of freedom
# Multiple R-squared:  0.4446,	Adjusted R-squared:  0.3557
# F-statistic: 5.003 on 4 and 25 DF,  p-value: 0.004211
#
# [1] "Max reduction is 0.000281447935329235 using h"
# [1] "Max reduction is 9.4243904632977e-05 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X13 ~ h + I(h^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.019802 -0.008753 -0.004309  0.005593  0.064496
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.006817   0.005561   1.226    0.231
# h            0.041786   0.026197   1.595    0.122
# I(h^2)      -0.034884   0.030389  -1.148    0.261
#
# Residual standard error: 0.01666 on 27 degrees of freedom
# Multiple R-squared:  0.1096,	Adjusted R-squared:  0.04363
# F-statistic: 1.661 on 2 and 27 DF,  p-value: 0.2087
#
# [1] "Max reduction is 0.000409231632546823 using b"
# [1] "Max reduction is 0.000840732533145445 using b"
# [1] "Max reduction is 0.00200523480076187 using h"
# [1] "Max reduction is 0.000861597081563834 using Three Way Interactions with b"
# [1] "Max reduction is 0.00119766886360266 using b"
# [1] "Max reduction is 0.00246177502949679 using b"
# [1] "Max reduction is 0.000619842222257163 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X14 ~ b + I(b^2) + I(b^3) + I(b^4) + h + c + I(h *
#     b) + I(c * b) + I(c * h) + I(b * h * b) + I(b * c * b) +
#     I(b * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0179380 -0.0060178 -0.0005765  0.0053918  0.0221505
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.001309   0.006454   0.203  0.84175
# b             0.022813   0.014997   1.521  0.14659
# I(b^2)       -0.102095   0.032157  -3.175  0.00554 **
# I(b^3)       -0.030651   0.017026  -1.800  0.08960 .
# I(b^4)        0.098349   0.030740   3.199  0.00525 **
# h             0.117267   0.019691   5.955 1.57e-05 ***
# c             0.010883   0.009617   1.132  0.27347
# I(h * b)      0.007346   0.016467   0.446  0.66117
# I(c * b)     -0.030351   0.021571  -1.407  0.17745
# I(c * h)      0.018969   0.021428   0.885  0.38837
# I(b * h * b) -0.109546   0.030246  -3.622  0.00211 **
# I(b * c * b) -0.038136   0.019809  -1.925  0.07110 .
# I(b * c * h)  0.030192   0.037104   0.814  0.42705
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0127 on 17 degrees of freedom
# Multiple R-squared:  0.7875,	Adjusted R-squared:  0.6376
# F-statistic: 5.251 on 12 and 17 DF,  p-value: 0.001083
#
# [1] "1 I(b^4)"
# [1] "2 I(b * c * h)"
# [1] "3 I(c * h)"
# [1] "4 I(b * c * b)"
# [1] "5 I(c * b)"
# [1] "6 c"
# [1] "7 I(b^3)"
# [1] "8 I(b * h * b)"
#
# Call:
# lm(formula = X14 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.022580 -0.010993 -0.003568  0.004693  0.054629
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.0132211  0.0066340   1.993  0.05729 .
# b            0.0106003  0.0108449   0.977  0.33771
# I(b^2)      -0.0320374  0.0112950  -2.836  0.00891 **
# h            0.0332778  0.0126905   2.622  0.01466 *
# I(h * b)    -0.0001175  0.0169903  -0.007  0.99454
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01784 on 25 degrees of freedom
# Multiple R-squared:  0.3834,	Adjusted R-squared:  0.2848
# F-statistic: 3.887 on 4 and 25 DF,  p-value: 0.01373
#
# [1] "Max reduction is 0.000722113958280955 using h"
# [1] "Max reduction is 0.000685162267876557 using h"
# [1] "Max reduction is 0.000278783839951016 using b"
# [1] "Max reduction is 0.0010187635232585 using b"
# [1] "Max reduction is 0.000643033210580412 using Three Way Interactions with b"
# [1] "Max reduction is 0.00291624750651035 using c"
# [1] "Max reduction is 0.000234924420648154 using Three Way Interactions with h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X15 ~ h + I(h^2) + b + I(b^2) + c + I(b * h) + I(c *
#     h) + I(c * b) + I(b * b * h) + I(b * c * h) + I(b * c * b) +
#     I(h * b * h) + I(h * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0174430 -0.0057439 -0.0008823  0.0043762  0.0228854
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.011634   0.007590   1.533  0.14483
# h             0.033299   0.043273   0.770  0.45281
# I(h^2)        0.082642   0.062244   1.328  0.20290
# b            -0.056488   0.028584  -1.976  0.06563 .
# I(b^2)        0.021716   0.025630   0.847  0.40933
# c             0.008452   0.010400   0.813  0.42832
# I(b * h)      0.176728   0.095966   1.842  0.08415 .
# I(c * h)      0.068049   0.042827   1.589  0.13164
# I(c * b)     -0.001385   0.023665  -0.059  0.95405
# I(b * b * h) -0.156462   0.056182  -2.785  0.01325 *
# I(b * c * h) -0.001578   0.037929  -0.042  0.96732
# I(b * c * b) -0.093122   0.031140  -2.990  0.00865 **
# I(h * b * h) -0.125609   0.076790  -1.636  0.12141
# I(h * c * h)  0.007111   0.055196   0.129  0.89910
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01166 on 16 degrees of freedom
# Multiple R-squared:  0.7725,	Adjusted R-squared:  0.5877
# F-statistic:  4.18 on 13 and 16 DF,  p-value: 0.00416
#
# [1] "1 I(h * c * h)"
# [1] "2 I(b * c * h)"
# [1] "3 I(c * h)"
# [1] "4 I(h * b * h)"
# [1] "5 I(b * c * b)"
# [1] "6 I(c * b)"
# [1] "7 c"
# [1] "8 I(b * b * h)"
# [1] "9 I(b * h)"
#
# Call:
# lm(formula = X15 ~ h + I(h^2) + b + I(b^2), data = tData)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.02342 -0.01025 -0.00106  0.00659  0.05543
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.011745   0.006433   1.826   0.0798 .
# h            0.052191   0.025952   2.011   0.0552 .
# I(h^2)      -0.027022   0.032321  -0.836   0.4110
# b            0.007387   0.004564   1.618   0.1181
# I(b^2)      -0.022781   0.010699  -2.129   0.0433 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01518 on 25 degrees of freedom
# Multiple R-squared:  0.3975,	Adjusted R-squared:  0.3011
# F-statistic: 4.124 on 4 and 25 DF,  p-value: 0.0106
#
# [1] "Max reduction is 0.000406962563446245 using b"
# [1] "Max reduction is 0.000813490162167595 using b"
# [1] "Max reduction is 0.00175731462909523 using h"
# [1] "Max reduction is 0.0007251711353482 using c"
# [1] "Max reduction is 0.00187376701738327 using Three Way Interactions with b"
# [1] "Max reduction is 0.000157896100741628 using b"
# [1] "Max reduction is 0.00206123353537348 using b"
# [1] "Max reduction is 0.000229925170272731 using b"
# [1] "Max reduction is 0.00117290216854249 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X16 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + I(b^6) +
#     h + c + I(h * b) + I(c * b) + I(c * h) + I(b * h * b) + I(b *
#     c * b) + I(b * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0143023 -0.0049152 -0.0002377  0.0044786  0.0181779
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.005552   0.004992   1.112 0.283592
# b             0.001204   0.022197   0.054 0.957456
# I(b^2)       -0.208366   0.058099  -3.586 0.002700 **
# I(b^3)        0.049301   0.075525   0.653 0.523777
# I(b^4)        0.455811   0.168652   2.703 0.016371 *
# I(b^5)       -0.070717   0.058087  -1.217 0.242245
# I(b^6)       -0.260901   0.115700  -2.255 0.039508 *
# h             0.119673   0.016455   7.273 2.73e-06 ***
# c             0.014914   0.007937   1.879 0.079799 .
# I(h * b)      0.007569   0.013049   0.580 0.570506
# I(c * b)     -0.022465   0.017130  -1.311 0.209431
# I(c * h)      0.025849   0.016472   1.569 0.137439
# I(b * h * b) -0.129208   0.026811  -4.819 0.000225 ***
# I(b * c * b) -0.057860   0.015537  -3.724 0.002036 **
# I(b * c * h)  0.019722   0.028628   0.689 0.501417
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.009741 on 15 degrees of freedom
# Multiple R-squared:  0.8632,	Adjusted R-squared:  0.7355
# F-statistic: 6.759 on 14 and 15 DF,  p-value: 0.0003521
#
# [1] "1 I(b * c * h)"
# [1] "2 I(c * h)"
# [1] "3 I(b^6)"
# [1] "4 I(b^5)"
# [1] "5 I(b^4)"
# [1] "6 I(b^3)"
# [1] "7 I(b * c * b)"
# [1] "8 I(c * b)"
# [1] "9 c"
# [1] "10 I(b * h * b)"
#
# Call:
# lm(formula = X16 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.019004 -0.010053 -0.001272  0.005454  0.060402
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.013430   0.005935   2.263  0.03259 *
# b            0.010305   0.009702   1.062  0.29832
# I(b^2)      -0.029301   0.010105  -2.900  0.00767 **
# h            0.029874   0.011353   2.631  0.01436 *
# I(h * b)    -0.001223   0.015200  -0.080  0.93652
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01596 on 25 degrees of freedom
# Multiple R-squared:  0.3877,	Adjusted R-squared:  0.2897
# F-statistic: 3.957 on 4 and 25 DF,  p-value: 0.01271
#
# [1] "Max reduction is 0.000600674255323719 using h"
# [1] "Max reduction is 0.000563800655051076 using b"
# [1] "Max reduction is 0.00176672927766044 using b"
# [1] "Max reduction is 0.000633987438692649 using Three Way Interactions with b"
# [1] "Max reduction is 0.00132339144775651 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X17 ~ h + b + I(b^2) + c + I(b * h) + I(c * h) +
#     I(c * b) + I(b * b * h) + I(b * c * h) + I(b * c * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0226541 -0.0059702 -0.0002619  0.0038128  0.0302379
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.004573   0.006256   0.731 0.473699
# h             0.076721   0.017649   4.347 0.000347 ***
# b            -0.005199   0.011540  -0.450 0.657461
# I(b^2)       -0.019412   0.015985  -1.214 0.239471
# c             0.016615   0.009131   1.820 0.084609 .
# I(b * h)      0.011346   0.016191   0.701 0.491933
# I(c * h)      0.013150   0.021107   0.623 0.540685
# I(c * b)     -0.029695   0.020019  -1.483 0.154384
# I(b * b * h) -0.062359   0.028075  -2.221 0.038691 *
# I(b * c * h)  0.026791   0.035144   0.762 0.455216
# I(b * c * b) -0.044651   0.019821  -2.253 0.036291 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01271 on 19 degrees of freedom
# Multiple R-squared:  0.6582,	Adjusted R-squared:  0.4783
# F-statistic: 3.659 on 10 and 19 DF,  p-value: 0.007274
#
# [1] "1 I(b * c * h)"
# [1] "2 I(c * h)"
# [1] "3 I(b * c * b)"
# [1] "4 I(c * b)"
# [1] "5 c"
# [1] "6 I(b * b * h)"
#
# Call:
# lm(formula = X17 ~ h + b + I(b^2) + I(b * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.019437 -0.008657 -0.001839  0.002704  0.053818
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.012704   0.005455   2.329  0.02823 *
# h            0.030229   0.010434   2.897  0.00772 **
# b            0.007621   0.008917   0.855  0.40085
# I(b^2)      -0.025669   0.009287  -2.764  0.01056 *
# I(b * h)     0.001665   0.013970   0.119  0.90610
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01467 on 25 degrees of freedom
# Multiple R-squared:  0.4012,	Adjusted R-squared:  0.3053
# F-statistic: 4.187 on 4 and 25 DF,  p-value: 0.0099
#
# [1] "Max reduction is 0.000224795045165961 using h"
# [1] "Max reduction is 0.000383765035588835 using h"
# [1] "Max reduction is 0.000199254884706596 using b"
# [1] "Max reduction is 0.00167484245698577 using b"
# [1] "Max reduction is 0.000865689071671281 using Three Way Interactions with b"
# [1] "Max reduction is 0.00168652700523046 using c"
# [1] "Max reduction is 0.000509573062776851 using h"
# [1] "Max reduction is 0.000340389136726252 using b"
# [1] "Max reduction is 0.00110735663764978 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X18 ~ h + I(h^2) + I(h^3) + b + I(b^2) + I(b^3) +
#     I(b^4) + c + I(b * h) + I(c * h) + I(c * b) + I(b * b * h) +
#     I(b * c * h) + I(b * c * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.016496 -0.004828 -0.001173  0.004175  0.019140
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.0025905  0.0060004   0.432  0.67208
# h             0.1325729  0.0393943   3.365  0.00425 **
# I(h^2)       -0.1366740  0.1118533  -1.222  0.24060
# I(h^3)        0.1410597  0.1070122   1.318  0.20722
# b            -0.0005196  0.0143209  -0.036  0.97154
# I(b^2)       -0.0519133  0.0370828  -1.400  0.18188
# I(b^3)       -0.0207547  0.0162394  -1.278  0.22066
# I(b^4)        0.0598893  0.0283584   2.112  0.05188 .
# c             0.0091812  0.0086194   1.065  0.30364
# I(b * h)      0.0261506  0.0212088   1.233  0.23655
# I(c * h)      0.0423850  0.0224223   1.890  0.07820 .
# I(c * b)     -0.0193068  0.0235748  -0.819  0.42563
# I(b * b * h) -0.1371915  0.0458332  -2.993  0.00910 **
# I(b * c * h)  0.0254582  0.0384385   0.662  0.51782
# I(b * c * b) -0.0593648  0.0217352  -2.731  0.01546 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01077 on 15 degrees of freedom
# Multiple R-squared:  0.8099,	Adjusted R-squared:  0.6324
# F-statistic: 4.564 on 14 and 15 DF,  p-value: 0.003001
#
# [1] "1 I(h^3)"
# [1] "2 I(b * c * h)"
# [1] "3 I(c * h)"
# [1] "4 I(b * c * b)"
# [1] "5 I(c * b)"
# [1] "6 I(b^4)"
# [1] "7 I(b^3)"
# [1] "8 c"
# [1] "9 I(h^2)"
# [1] "10 I(b * b * h)"
#
# Call:
# lm(formula = X18 ~ h + b + I(b^2) + I(b * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.019310 -0.009137 -0.000836  0.002506  0.053090
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.013776   0.005584   2.467  0.02082 *
# h            0.027934   0.010681   2.615  0.01490 *
# b            0.007472   0.009128   0.819  0.42073
# I(b^2)      -0.029916   0.009507  -3.147  0.00423 **
# I(b * h)    -0.001123   0.014300  -0.079  0.93804
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01502 on 25 degrees of freedom
# Multiple R-squared:  0.3837,	Adjusted R-squared:  0.285
# F-statistic:  3.89 on 4 and 25 DF,  p-value: 0.01368
#
# [1] "Max reduction is 0.000227483119972241 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X19 ~ c, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.022666 -0.008830 -0.003142  0.004202  0.071784
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.016569   0.003556   4.660 7.03e-05 ***
# c           0.007294   0.005576   1.308    0.201
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01866 on 28 degrees of freedom
# Multiple R-squared:  0.0576,	Adjusted R-squared:  0.02394
# F-statistic: 1.711 on 1 and 28 DF,  p-value: 0.2015
#
# [1] "Max reduction is 0.000496025593441189 using b"
# [1] "Max reduction is 0.00064855737585803 using h"
# [1] "Max reduction is 0.00152764664177469 using b"
# [1] "Max reduction is 0.000729016624650221 using c"
# [1] "Max reduction is 0.00135174970077936 using Three Way Interactions with b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X20 ~ b + I(b^2) + h + c + I(h * b) + I(c * b) +
#     I(c * h) + I(b * h * b) + I(b * c * b) + I(b * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.030240 -0.007201 -0.001379  0.005780  0.034908
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.007071   0.006948   1.018  0.32159
# b            -0.009437   0.012816  -0.736  0.47049
# I(b^2)       -0.024980   0.017752  -1.407  0.17551
# h             0.069549   0.019600   3.548  0.00215 **
# c             0.016447   0.010140   1.622  0.12129
# I(h * b)      0.019995   0.017981   1.112  0.28000
# I(c * b)     -0.030109   0.022233  -1.354  0.19154
# I(c * h)      0.030350   0.023441   1.295  0.21093
# I(b * h * b) -0.050373   0.031179  -1.616  0.12266
# I(b * c * b) -0.052648   0.022012  -2.392  0.02727 *
# I(b * c * h)  0.027129   0.039029   0.695  0.49540
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01412 on 19 degrees of freedom
# Multiple R-squared:  0.6333,	Adjusted R-squared:  0.4403
# F-statistic: 3.281 on 10 and 19 DF,  p-value: 0.01247
#
# [1] "1 I(b * c * h)"
# [1] "2 I(c * h)"
# [1] "3 I(b * h * b)"
# [1] "4 I(h * b)"
# [1] "5 I(b * c * b)"
# [1] "6 I(c * b)"
#
# Call:
# lm(formula = X20 ~ b + I(b^2) + h + c, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.021198 -0.007691 -0.001144  0.004616  0.055903
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.013351   0.005449   2.450  0.02163 *
# b            0.010424   0.004503   2.315  0.02912 *
# I(b^2)      -0.027369   0.009224  -2.967  0.00653 **
# h            0.029752   0.009735   3.056  0.00527 **
# c            0.008755   0.004535   1.931  0.06496 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01514 on 25 degrees of freedom
# Multiple R-squared:  0.4453,	Adjusted R-squared:  0.3565
# F-statistic: 5.017 on 4 and 25 DF,  p-value: 0.004153
#
# [1] "Max reduction is 0.0132967461337202 using h"
# [1] "Max reduction is 0.00183767754869862 using b"
# [1] "Max reduction is 7.52133657861906e-06 using b"
# [1] "Max reduction is 0.000494476865727914 using h"
# [1] "Max reduction is 0.00125858727157733 using Three Way Interactions with b"
# [1] "Max reduction is 0.00240396170967188 using c"
# [1] "Max reduction is 0.00171286949262929 using Three Way Interactions with h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X21 ~ h + I(h^2) + b + I(b^2) + c + I(b * h) + I(c *
#     h) + I(c * b) + I(b * b * h) + I(b * c * h) + I(b * c * b) +
#     I(h * b * h) + I(h * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.023146 -0.004252 -0.000372  0.002849  0.037420
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.016079   0.009078   1.771  0.09558 .
# h            -0.017480   0.051760  -0.338  0.73997
# I(h^2)        0.269641   0.074451   3.622  0.00229 **
# b            -0.097211   0.034190  -2.843  0.01174 *
# I(b^2)        0.055751   0.030657   1.819  0.08775 .
# c             0.008496   0.012440   0.683  0.50439
# I(b * h)      0.328802   0.114787   2.864  0.01124 *
# I(c * h)      0.071336   0.051226   1.393  0.18280
# I(c * b)      0.002028   0.028306   0.072  0.94376
# I(b * b * h) -0.249703   0.067201  -3.716  0.00188 **
# I(b * c * h) -0.007320   0.045368  -0.161  0.87384
# I(b * c * b) -0.139558   0.037247  -3.747  0.00176 **
# I(h * b * h) -0.236647   0.091850  -2.576  0.02029 *
# I(h * c * h)  0.052674   0.066021   0.798  0.43665
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01395 on 16 degrees of freedom
# Multiple R-squared:  0.9122,	Adjusted R-squared:  0.8408
# F-statistic: 12.79 on 13 and 16 DF,  p-value: 4.503e-06
#
# [1] "1 I(b * c * h)"
# [1] "2 I(h * c * h)"
# [1] "3 I(c * h)"
# [1] "4 I(h * b * h)"
# [1] "5 I(b * c * b)"
# [1] "6 I(c * b)"
# [1] "7 I(h^2)"
# [1] "8 I(b^2)"
# [1] "9 c"
#
# Call:
# lm(formula = X21 ~ h + b + I(b * h) + I(b * b * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.050199 -0.010003  0.000553  0.007038  0.042884
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.003586   0.007330  -0.489   0.6290
# h             0.124380   0.021785   5.709 6.02e-06 ***
# b             0.020697   0.011458   1.806   0.0829 .
# I(b * h)     -0.010389   0.017982  -0.578   0.5686
# I(b * b * h) -0.040034   0.024760  -1.617   0.1184
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01924 on 25 degrees of freedom
# Multiple R-squared:  0.739,	Adjusted R-squared:  0.6972
# F-statistic:  17.7 on 4 and 25 DF,  p-value: 5.229e-07
#
# [1] "Max reduction is 0.00093667220113244 using b"
# [1] "Max reduction is 0.00102022633582404 using b"
# [1] "Max reduction is 0.00188611679264592 using h"
# [1] "Max reduction is 0.000745041961659674 using Three Way Interactions with b"
# [1] "Max reduction is 0.00167508405999555 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X22 ~ b + I(b^2) + h + c + I(h * b) + I(c * b) +
#     I(c * h) + I(b * h * b) + I(b * c * b) + I(b * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.025554 -0.006088 -0.002684  0.004901  0.034746
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.005637   0.007130   0.790 0.438992
# b            -0.008649   0.013152  -0.658 0.518673
# I(b^2)       -0.028544   0.018218  -1.567 0.133667
# h             0.082024   0.020115   4.078 0.000642 ***
# c             0.021018   0.010407   2.020 0.057755 .
# I(h * b)      0.023528   0.018453   1.275 0.217677
# I(c * b)     -0.045450   0.022816  -1.992 0.060945 .
# I(c * h)      0.012831   0.024057   0.533 0.599967
# I(b * h * b) -0.065773   0.031998  -2.056 0.053833 .
# I(b * c * b) -0.057614   0.022591  -2.550 0.019544 *
# I(b * c * h)  0.055297   0.040054   1.381 0.183437
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01449 on 19 degrees of freedom
# Multiple R-squared:  0.6806,	Adjusted R-squared:  0.5125
# F-statistic: 4.049 on 10 and 19 DF,  p-value: 0.00428
#
# [1] "1 I(b * c * h)"
# [1] "2 I(c * h)"
# [1] "3 I(b * c * b)"
# [1] "4 I(c * b)"
# [1] "5 c"
# [1] "6 I(b * h * b)"
#
# Call:
# lm(formula = X22 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.018374 -0.008449 -0.002734  0.002617  0.062722
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.015139   0.006287   2.408  0.02374 *
# b            0.007276   0.010278   0.708  0.48552
# I(b^2)      -0.030187   0.010704  -2.820  0.00926 **
# h            0.027584   0.012027   2.294  0.03050 *
# I(h * b)     0.009752   0.016102   0.606  0.55021
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01691 on 25 degrees of freedom
# Multiple R-squared:  0.4277,	Adjusted R-squared:  0.3361
# F-statistic:  4.67 on 4 and 25 DF,  p-value: 0.005932
#
# [1] "Max reduction is 0.000511508011026549 using b"
# [1] "Max reduction is 0.000328357505383691 using b"
# [1] "Max reduction is 0.000590754690360611 using h"
# [1] "Max reduction is 0.000238154003085812 using Three Way Interactions with b"
# [1] "Max reduction is 0.00187114923350378 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X23 ~ b + I(b^2) + h + c + I(h * b) + I(c * b) +
#     I(c * h) + I(b * h * b) + I(b * c * b) + I(b * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.018126 -0.005267 -0.001800  0.006146  0.035540
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.008589   0.006680   1.286  0.21399
# b            -0.017472   0.012323  -1.418  0.17242
# I(b^2)       -0.021699   0.017069  -1.271  0.21897
# h             0.066609   0.018846   3.534  0.00222 **
# c             0.018829   0.009750   1.931  0.06852 .
# I(h * b)      0.003023   0.017289   0.175  0.86306
# I(c * b)     -0.038239   0.021377  -1.789  0.08961 .
# I(c * h)      0.023260   0.022539   1.032  0.31503
# I(b * h * b) -0.054135   0.029979  -1.806  0.08683 .
# I(b * c * b) -0.066268   0.021165  -3.131  0.00550 **
# I(b * c * h)  0.054170   0.037527   1.443  0.16517
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01357 on 19 degrees of freedom
# Multiple R-squared:  0.5878,	Adjusted R-squared:  0.3709
# F-statistic:  2.71 on 10 and 19 DF,  p-value: 0.02953
#
# [1] "1 I(b * c * h)"
# [1] "2 I(c * h)"
# [1] "3 I(b * h * b)"
# [1] "4 I(h * b)"
# [1] "5 I(b^2)"
# [1] "6 h"
#
# Call:
# lm(formula = X23 ~ b + c + I(c * b) + I(b * c * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.023718 -0.007834 -0.002790  0.002095  0.062832
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.017453   0.003234   5.397 1.34e-05 ***
# b            -0.009547   0.005307  -1.799   0.0841 .
# c             0.010481   0.008005   1.309   0.2023
# I(c * b)      0.003584   0.008568   0.418   0.6793
# I(b * c * b) -0.025123   0.018078  -1.390   0.1769
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01678 on 25 degrees of freedom
# Multiple R-squared:  0.1715,	Adjusted R-squared:  0.03892
# F-statistic: 1.294 on 4 and 25 DF,  p-value: 0.2994
#
# [1] "No permitted terms improve the fit"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X24 ~ 1, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.013655 -0.009257 -0.003100  0.001508  0.078334
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.012629   0.003153   4.005 0.000394 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01727 on 29 degrees of freedom
#
# [1] "Max reduction is 0.000645504255354434 using h"
# [1] "Max reduction is 0.000400117747624391 using h"
# [1] "Max reduction is 0.000241508592243214 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X25 ~ h + I(h^2) + I(h^3), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.029351 -0.010813 -0.005087  0.005280  0.069408
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.006441   0.007135   0.903    0.375
# h            0.028971   0.041238   0.703    0.489
# I(h^2)       0.110850   0.132890   0.834    0.412
# I(h^3)      -0.142650   0.110812  -1.287    0.209
#
# Residual standard error: 0.01996 on 26 degrees of freedom
# Multiple R-squared:  0.2088,	Adjusted R-squared:  0.1175
# F-statistic: 2.287 on 3 and 26 DF,  p-value: 0.1022
#
# [1] "Max reduction is 0.000376823854096618 using b"
# [1] "Max reduction is 0.000602322478985191 using h"
# [1] "Max reduction is 0.00133828848539443 using b"
# [1] "Max reduction is 0.000144651090970418 using c"
# [1] "Max reduction is 0.00186495613565429 using Three Way Interactions with b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X26 ~ b + I(b^2) + h + c + I(h * b) + I(c * b) +
#     I(c * h) + I(b * h * b) + I(b * c * b) + I(b * c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.026871 -0.006095 -0.001237  0.005814  0.033466
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.007030   0.006831   1.029   0.3163
# b            -0.011702   0.012600  -0.929   0.3647
# I(b^2)       -0.022295   0.017452  -1.278   0.2168
# h             0.069388   0.019270   3.601   0.0019 **
# c             0.017364   0.009969   1.742   0.0977 .
# I(h * b)      0.022642   0.017678   1.281   0.2157
# I(c * b)     -0.031352   0.021858  -1.434   0.1677
# I(c * h)      0.029269   0.023046   1.270   0.2194
# I(b * h * b) -0.052751   0.030653  -1.721   0.1015
# I(b * c * b) -0.057911   0.021641  -2.676   0.0149 *
# I(b * c * h)  0.035677   0.038371   0.930   0.3641
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01388 on 19 degrees of freedom
# Multiple R-squared:  0.6192,	Adjusted R-squared:  0.4188
# F-statistic:  3.09 on 10 and 19 DF,  p-value: 0.01653
#
# [1] "1 I(b * c * h)"
# [1] "2 I(c * h)"
# [1] "3 I(b * h * b)"
# [1] "4 I(h * b)"
# [1] "5 I(b * c * b)"
# [1] "6 I(c * b)"
#
# Call:
# lm(formula = X26 ~ b + I(b^2) + h + c, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.020529 -0.007888 -0.003275  0.006540  0.055708
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.013718   0.005426   2.528  0.01816 *
# b            0.009511   0.004484   2.121  0.04402 *
# I(b^2)      -0.025501   0.009185  -2.776  0.01026 *
# h            0.028377   0.009694   2.927  0.00719 **
# c            0.007647   0.004516   1.693  0.10281
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01507 on 25 degrees of freedom
# Multiple R-squared:  0.4091,	Adjusted R-squared:  0.3146
# F-statistic: 4.327 on 4 and 25 DF,  p-value: 0.008516
#
# [1] "Max reduction is 0.000229807036349238 using h"
# [1] "Max reduction is 0.000384068518612859 using h"
# [1] "Max reduction is 8.77058593480862e-05 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X27 ~ h + I(h^2) + I(h^3), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.022599 -0.006265 -0.004302  0.007578  0.061985
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.006733   0.005704   1.180    0.249
# h            0.024627   0.032964   0.747    0.462
# I(h^2)       0.071435   0.106227   0.672    0.507
# I(h^3)      -0.100902   0.088579  -1.139    0.265
#
# Residual standard error: 0.01596 on 26 degrees of freedom
# Multiple R-squared:  0.1774,	Adjusted R-squared:  0.08245
# F-statistic: 1.869 on 3 and 26 DF,  p-value: 0.1597
#
# [1] "Max reduction is 0.000145661733205446 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X28 ~ c, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.022379 -0.010510 -0.004044  0.004487  0.082037
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 0.015386   0.003927   3.918 0.000524 ***
# c           0.007316   0.006158   1.188 0.244816
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02061 on 28 degrees of freedom
# Multiple R-squared:  0.04799,	Adjusted R-squared:  0.01399
# F-statistic: 1.411 on 1 and 28 DF,  p-value: 0.2448
#
# [1] "Max reduction is 0.000531557885233482 using h"
# [1] "Max reduction is 6.71371812218727e-05 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X29 ~ h + I(h^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.022441 -0.009441 -0.005991  0.004908  0.075129
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.009555   0.006307   1.515    0.141
# h            0.048352   0.029707   1.628    0.115
# I(h^2)      -0.037739   0.034460  -1.095    0.283
#
# Residual standard error: 0.01889 on 27 degrees of freedom
# Multiple R-squared:  0.1253,	Adjusted R-squared:  0.0605
# F-statistic: 1.934 on 2 and 27 DF,  p-value: 0.1641
#
# [1] "Max reduction is 0.0126321435532069 using h"
# [1] "Max reduction is 0.00339528876784483 using b"
# [1] "Max reduction is 0.000163425155297464 using b"
# [1] "Max reduction is 0.00160547128079963 using b"
# [1] "Max reduction is 0.00121502851839676 using Three Way Interactions with b"
# [1] "Max reduction is 0.00224337465924484 using h"
# [1] "Max reduction is 0.00161626100010446 using b"
# [1] "Max reduction is 0.001307427588598 using c"
# [1] "Max reduction is 6.43786035589254e-05 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X30 ~ h + I(h^2) + b + I(b^2) + I(b^3) + I(b^4) +
#     I(b^5) + c + I(b * h) + I(c * h) + I(c * b) + I(b * b * h) +
#     I(b * c * h) + I(b * c * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.035159 -0.007163  0.000807  0.008347  0.025082
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.006113   0.010551  -0.579  0.57096
# h             0.107862   0.052901   2.039  0.05948 .
# I(h^2)        0.149658   0.065037   2.301  0.03615 *
# b             0.067756   0.043911   1.543  0.14366
# I(b^2)       -0.044997   0.052486  -0.857  0.40476
# I(b^3)       -0.235224   0.143999  -1.634  0.12317
# I(b^4)        0.087815   0.046731   1.879  0.07980 .
# I(b^5)        0.120296   0.114171   1.054  0.30872
# c            -0.005052   0.015495  -0.326  0.74891
# I(b * h)      0.067919   0.031940   2.126  0.05047 .
# I(c * h)      0.062700   0.034260   1.830  0.08717 .
# I(c * b)      0.012753   0.038782   0.329  0.74682
# I(b * b * h) -0.203581   0.057870  -3.518  0.00311 **
# I(b * c * h) -0.043497   0.064899  -0.670  0.51291
# I(b * c * b) -0.063192   0.030458  -2.075  0.05564 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01873 on 15 degrees of freedom
# Multiple R-squared:  0.9017,	Adjusted R-squared:   0.81
# F-statistic: 9.833 on 14 and 15 DF,  p-value: 3.683e-05
#
# [1] "1 I(b * c * h)"
# [1] "2 I(c * h)"
# [1] "3 I(h^2)"
# [1] "4 I(b * c * b)"
# [1] "5 I(c * b)"
# [1] "6 c"
# [1] "7 I(b * b * h)"
# [1] "8 I(b * h)"
# [1] "9 I(b^5)"
# [1] "10 I(b^4)"
#
# Call:
# lm(formula = X30 ~ h + b + I(b^2) + I(b^3), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.032285 -0.017558 -0.003125  0.009001  0.057990
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.001466   0.008881  -0.165   0.8702
# h            0.114913   0.015847   7.251 1.34e-07 ***
# b            0.064610   0.020383   3.170   0.0040 **
# I(b^2)      -0.018481   0.015004  -1.232   0.2295
# I(b^3)      -0.059826   0.028284  -2.115   0.0446 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02467 on 25 degrees of freedom
# Multiple R-squared:  0.7159,	Adjusted R-squared:  0.6705
# F-statistic: 15.75 on 4 and 25 DF,  p-value: 1.464e-06

# %%
tLOOs <- LOO.plot(Emulators = em_wave2, which.emulator = 4, ParamNames = cands)
# Out:
# Plot with title “”

# %% [markdown]
# ### Compute implausibility

# %%
sample_size <- 100000
nparam <- length(names(em_wave2$fitting.elements$Design))
Xp_wave2 <- as.data.frame(2*randomLHS(sample_size, nparam)-1)
names(Xp_wave2) <- names(em_wave2$fitting.elements$Design)
system.time(Timps_wave2 <- ImplausibilityMOGP(NewData=Xp_wave2, Emulator=em_wave2, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))
# Out:
#    user  system elapsed
#  17.476   4.962   4.181

# %%
valmax = 0 #Set to 2 in order to have a "more steady" NROY space
cutoff <- 3 #the implausibility cut off

# %%
NROY2 <- which(rowSums(Timps_wave2 <= cutoff) >= em_wave2$mogp$n_emulators -valmax)
scoreNROY2 <- length(NROY2)/dim(Xp_wave2)[1]

# %% [markdown]
# ### Layout of NROY space

# %%
ImpData_wave2 = cbind(Xp_wave2, Timps_wave2)
ImpListM2 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave2, nEms=em_wave2$mogp$n_emulators, whichMax=valmax+1)
imp.layoutm11(ImpListM2,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",scoreNROY2,sep=""), side=1)
# Out:
# plot without title

# %% [markdown]
# ## Third Wave

# %%
n <- ceiling(n_samples*1.6/scoreNROY2)

# %%
inputs_wave3_scaled_temp <- np$array(lhs$generate(space$dimensions, as.integer(n), random_state=as.integer(42)))

# %%
emulators <- list(em_wave1, em_wave2)
NROY_temp_wave3 <- parameters_space(emulators, inputs_wave3_scaled_temp, n_samples=30)

# %%
length(NROY_temp_wave3)
# Out:
# [1] 30

# %%
input_wave3_scaled <- inputs_wave3_scaled_temp[sample(NROY_temp_wave3, n_samples),]
input_wave3 <- rangeUnscale(input_wave3_scaled, my_bounds, range = c(-1, 1))

# %%
par(mfrow=c(2,2))
plot(input_wave3[,1], input_wave3[,2], xlab="h", ylab="c", xlim=c(-2,2), ylim=c(0,20))
points(1, 10, col='red', pch=18, cex=2)
plot(input_wave3[,1], input_wave3[,3], xlab="h", ylab="b", xlim=c(-2,2), ylim=c(-20,20))
points(1, 10, col='red', pch=18, cex=2)
plot(input_wave3[,2], input_wave3[,3], xlab="c", ylab="b", xlim=c(0,20), ylim=c(-20,20))
points(10, 10, col='red', pch=18, cex=2)
# Out:
# plot without title

# %%
metrics_wave3 = future_sapply(1:nrow(input_wave3), function(r) extract_metrics_AMIP(input_wave3[r,], n_iter, 0.001, X_hist), future.seed=NULL)

# %% [markdown]
# ### Create the data matrix

# %%
input_wave3_scaled <- data.frame(input_wave3_scaled)
names(input_wave3_scaled) <- c('h', 'c', 'b')


metrics_k_wave3 <- data.frame(t(metrics_wave3)[, metrics_index_k])
N = nrow(metrics_k_wave3) 
noise <- rnorm(N, 0, 0)
tData_wave3 <- data.frame(cbind(input_wave3_scaled, noise, metrics_k_wave3))
names(tData_wave3)[names(tData_wave3) == "noise"] <- "Noise"
         
head(tData_wave3)
# Out:
#   h         c          b          Noise X1          X2         X3
# 1 0.7000082  0.4568823  0.6098854 0      0.08697405 0.09598750  0.12488378
# 2 0.6428040  0.4828659  0.8566116 0      0.06093371 0.06959894  0.11260973
# 3 0.4630643 -0.1485233  0.4907544 0      0.10816766 0.12161869  0.08574133
# 4 0.6849875  0.8567796  0.5432950 0      0.12843641 0.13730965  0.11024035
# 5 0.7770775  0.9040029 -0.3041323 0     -0.07689518 0.22491535 -0.10764019
# 6 0.4089114  0.5602391  0.4211996 0      0.11902891 0.10114374  0.09760441
#   X4         X5          X6         ⋯ X56        X57         X58
# 1 0.10799416  0.10227512 0.10854848 ⋯ 0.09878873  0.02670620 0.007525556
# 2 0.07835828  0.06772412 0.08521250 ⋯ 0.06224068  0.01595211 0.003610132
# 3 0.11743890  0.10113689 0.08513294 ⋯ 0.04825797  0.02339612 0.007410846
# 4 0.14696728  0.13007793 0.10952540 ⋯ 0.11010608  0.03692457 0.005472267
# 5 0.18571119 -0.12644237 0.19048740 ⋯ 0.02728663 -0.01841342 0.017146485
# 6 0.13356120  0.09969331 0.08977878 ⋯ 0.06240545  0.03184812 0.011387712
#   X59         X60        X61         X62           X63        X64
# 1  0.02021904 0.08568707 0.019387965 -7.878848e-05 0.10732317  0.02934338
# 2  0.01351924 0.05485957 0.015831311 -2.031128e-03 0.07698508  0.01921164
# 3  0.01392696 0.05554142 0.024972046  7.969435e-03 0.05474679  0.02150597
# 4  0.02810377 0.10228291 0.032802321  2.699616e-03 0.09842996  0.02542183
# 5 -0.02207591 0.11856012 0.005553794  6.982830e-02 0.05129084 -0.02210485
# 6  0.02713015 0.04747153 0.020605393  1.366766e-02 0.03966768  0.02297749
#   X65
# 1 0.07811283
# 2 0.05668620
# 3 0.04671654
# 4 0.08465873
# 5 0.10130710
# 6 0.06133198

# %% [markdown]
# ### Training emulator

# %%
em_wave3 <- BuildNewEmulators(tData_wave3, HowManyEmulators = ncol(metrics_wave3), meanFun = "fitted", additionalVariables = cands) #
# Out:
# [1] "Max reduction is 0.0169446541813458 using b"
# [1] "Max reduction is 0.0138577036408359 using b"
# [1] "Max reduction is 0.000964070876630089 using b"
# [1] "Max reduction is 0.00290108736017817 using b"
# [1] "Max reduction is 0.000807332150832226 using h"
# [1] "Max reduction is 0.000868226713875268 using c"
# [1] "Max reduction is 0.0022401930301667 using b"
# [1] "Max reduction is 0.000963628025412295 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X1 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + I(b^6) +
#     h + c + I(h * b) + I(c * b) + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.027619 -0.007699 -0.001178  0.008289  0.027642
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.01270    0.04738  -0.268  0.79177
# b            0.62048    0.11550   5.372 4.18e-05 ***
# I(b^2)      -0.23353    0.44533  -0.524  0.60640
# I(b^3)      -2.84009    0.99171  -2.864  0.01032 *
# I(b^4)       1.99286    0.97014   2.054  0.05477 .
# I(b^5)       3.38304    2.79009   1.213  0.24099
# I(b^6)      -2.91960    1.60053  -1.824  0.08478 .
# h            0.03697    0.04857   0.761  0.45643
# c            0.10666    0.03241   3.291  0.00406 **
# I(h * b)     0.03788    0.03773   1.004  0.32864
# I(c * b)    -0.06755    0.02594  -2.604  0.01795 *
# I(c * h)    -0.09759    0.04887  -1.997  0.06117 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0162 on 18 degrees of freedom
# Multiple R-squared:  0.9476,	Adjusted R-squared:  0.9155
# F-statistic: 29.58 on 11 and 18 DF,  p-value: 2.923e-09
#
# [1] "1 I(b^6)"
# [1] "2 I(c * h)"
# [1] "3 I(b^5)"
# [1] "4 I(c * b)"
# [1] "5 c"
# [1] "6 I(h * b)"
# [1] "7 h"
#
# Call:
# lm(formula = X1 ~ b + I(b^2) + I(b^3) + I(b^4), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.047905 -0.011539  0.000382  0.014211  0.037454
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.02459    0.01872   1.314  0.20087
# b            0.31192    0.04490   6.947 2.79e-07 ***
# I(b^2)      -0.05632    0.10360  -0.544  0.59153
# I(b^3)      -0.81030    0.22874  -3.542  0.00159 **
# I(b^4)       0.60996    0.20741   2.941  0.00696 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02108 on 25 degrees of freedom
# Multiple R-squared:  0.8767,	Adjusted R-squared:  0.857
# F-statistic: 44.45 on 4 and 25 DF,  p-value: 5.165e-11
#
# [1] "Max reduction is 0.0158918368620481 using b"
# [1] "Max reduction is 0.00138802026335489 using h"
# [1] "Max reduction is 0.00160952948791972 using c"
# [1] "Max reduction is 0.00203972192239005 using b"
# [1] "Max reduction is 0.00327690652480208 using b"
# [1] "Max reduction is 0.000748196187972099 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X2 ~ b + I(b^2) + I(b^3) + I(b^4) + h + c + I(h *
#     b) + I(c * b) + I(c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0158066 -0.0073890 -0.0005531  0.0063908  0.0200875
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.13808    0.01931   7.153 6.28e-07 ***
# b           -0.05714    0.04719  -1.211  0.24008
# I(b^2)      -0.29374    0.08060  -3.644  0.00161 **
# I(b^3)       0.56642    0.16394   3.455  0.00250 **
# I(b^4)      -0.28467    0.14953  -1.904  0.07143 .
# h            0.06175    0.03606   1.713  0.10226
# c           -0.03081    0.02366  -1.302  0.20766
# I(h * b)    -0.07253    0.02794  -2.596  0.01728 *
# I(c * b)    -0.01802    0.01876  -0.961  0.34808
# I(c * h)     0.09022    0.03701   2.438  0.02424 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01234 on 20 degrees of freedom
# Multiple R-squared:  0.9245,	Adjusted R-squared:  0.8906
# F-statistic: 27.22 on 9 and 20 DF,  p-value: 2.562e-09
#
# [1] "1 I(c * b)"
# [1] "2 I(b^4)"
# [1] "3 I(c * h)"
# [1] "4 c"
# [1] "5 I(b^3)"
#
# Call:
# lm(formula = X2 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.037801 -0.011006 -0.000911  0.008465  0.059404
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.10048    0.01737   5.784 4.98e-06 ***
# b           -0.02293    0.03107  -0.738   0.4674
# I(b^2)      -0.04336    0.02175  -1.993   0.0573 .
# h            0.07323    0.02737   2.676   0.0130 *
# I(h * b)    -0.02187    0.03804  -0.575   0.5705
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01896 on 25 degrees of freedom
# Multiple R-squared:  0.7772,	Adjusted R-squared:  0.7416
# F-statistic: 21.81 on 4 and 25 DF,  p-value: 7.556e-08
#
# [1] "Max reduction is 0.022295944953816 using b"
# [1] "Max reduction is 0.0151852033816541 using b"
# [1] "Max reduction is 0.00302482085900916 using b"
# [1] "Max reduction is 0.00273255326343621 using b"
# [1] "Max reduction is 0.00275216983792105 using h"
# [1] "Max reduction is 0.000685534953265017 using c"
# [1] "Max reduction is 0.000711984750050555 using Three Way Interactions with b"
# [1] "Max reduction is 0.000511458210171824 using b"
# [1] "Max reduction is 0.00170099359819301 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X3 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + I(b^6) +
#     h + c + I(h * b) + I(c * b) + I(c * h) + I(b * h * b) + I(b *
#     c * b) + I(b * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0293321 -0.0066482  0.0008193  0.0086719  0.0229333
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.06269    0.10212  -0.614  0.54849
# b             0.41659    0.29302   1.422  0.17556
# I(b^2)        0.29894    0.50716   0.589  0.56435
# I(b^3)       -3.76142    1.19222  -3.155  0.00654 **
# I(b^4)        2.52431    1.29796   1.945  0.07079 .
# I(b^5)        4.74372    3.04741   1.557  0.14040
# I(b^6)       -4.09182    1.93689  -2.113  0.05181 .
# h             0.22639    0.18196   1.244  0.23251
# c            -0.01148    0.10955  -0.105  0.91792
# I(h * b)      0.44446    0.25344   1.754  0.09988 .
# I(c * b)     -0.09336    0.22643  -0.412  0.68593
# I(c * h)     -0.05922    0.16911  -0.350  0.73105
# I(b * h * b) -0.79710    0.24145  -3.301  0.00485 **
# I(b * c * b)  0.03829    0.10681   0.359  0.72493
# I(b * c * h)  0.19403    0.23286   0.833  0.41779
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01653 on 15 degrees of freedom
# Multiple R-squared:  0.9677,	Adjusted R-squared:  0.9375
# F-statistic: 32.09 on 14 and 15 DF,  p-value: 1.269e-08
#
# [1] "1 I(b * c * b)"
# [1] "2 I(c * b)"
# [1] "3 I(b^6)"
# [1] "4 I(b^5)"
# [1] "5 I(b * c * h)"
# [1] "6 I(c * h)"
# [1] "7 c"
# [1] "8 I(b * h * b)"
# [1] "9 I(h * b)"
# [1] "10 h"
#
# Call:
# lm(formula = X3 ~ b + I(b^2) + I(b^3) + I(b^4), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.042650 -0.011405 -0.003498  0.016422  0.040649
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.007169   0.020322   0.353 0.727227
# b            0.361371   0.048756   7.412 9.18e-08 ***
# I(b^2)       0.052878   0.112492   0.470 0.642383
# I(b^3)      -0.957628   0.248374  -3.856 0.000717 ***
# I(b^4)       0.619973   0.225209   2.753 0.010841 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02289 on 25 degrees of freedom
# Multiple R-squared:  0.8967,	Adjusted R-squared:  0.8802
# F-statistic: 54.26 on 4 and 25 DF,  p-value: 5.783e-12
#
# [1] "Max reduction is 0.00439402501371942 using b"
# [1] "Max reduction is 0.00270232499576116 using b"
# [1] "Max reduction is 0.00197852540750505 using h"
# [1] "Max reduction is 0.00256892935119235 using b"
# [1] "Max reduction is 0.00171043497073804 using c"
# [1] "Max reduction is 0.000583747519600645 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X4 ~ b + I(b^2) + I(b^3) + h + I(h^2) + c + I(h *
#     b) + I(c * b) + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.034106 -0.005070  0.000273  0.010096  0.021945
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.0719528  0.0281338   2.558 0.018770 *
# b            0.0008656  0.0492527   0.018 0.986153
# I(b^2)      -0.4163451  0.0940385  -4.427 0.000259 ***
# I(b^3)       0.3487734  0.0953729   3.657 0.001567 **
# h            0.3175300  0.1192197   2.663 0.014924 *
# I(h^2)      -0.1768796  0.1090757  -1.622 0.120544
# c            0.0138607  0.0291700   0.475 0.639814
# I(h * b)    -0.0624692  0.0376443  -1.659 0.112623
# I(c * b)     0.0155720  0.0241933   0.644 0.527114
# I(c * h)    -0.0184465  0.0456510  -0.404 0.690444
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01533 on 20 degrees of freedom
# Multiple R-squared:  0.8108,	Adjusted R-squared:  0.7256
# F-statistic: 9.522 on 9 and 20 DF,  p-value: 1.665e-05
#
# [1] "1 I(c * h)"
# [1] "2 I(c * b)"
# [1] "3 I(b^3)"
# [1] "4 I(h^2)"
# [1] "5 I(h * b)"
#
# Call:
# lm(formula = X4 ~ b + I(b^2) + h + c, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.029959 -0.010440 -0.000908  0.009964  0.049727
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.100108   0.012992   7.705 4.63e-08 ***
# b            0.018712   0.012925   1.448 0.160136
# I(b^2)      -0.088165   0.020316  -4.340 0.000206 ***
# h            0.046596   0.020984   2.221 0.035670 *
# c            0.014948   0.006498   2.301 0.030037 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01848 on 25 degrees of freedom
# Multiple R-squared:  0.6563,	Adjusted R-squared:  0.6014
# F-statistic: 11.94 on 4 and 25 DF,  p-value: 1.464e-05
#
# [1] "Max reduction is 0.0229625828099348 using b"
# [1] "Max reduction is 0.0209817802627479 using b"
# [1] "Max reduction is 0.00123829208395528 using b"
# [1] "Max reduction is 0.00342041070186639 using b"
# [1] "Max reduction is 0.00326152565311761 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X5 ~ b + I(b^2) + I(b^3) + I(b^4) + h + I(h * b),
#     data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.059564 -0.010545 -0.000241  0.011731  0.046331
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04866    0.02398   2.029 0.054215 .
# b            0.34222    0.05420   6.313 1.92e-06 ***
# I(b^2)       0.03826    0.13403   0.285 0.777821
# I(b^3)      -1.31310    0.27292  -4.811 7.45e-05 ***
# I(b^4)       0.92935    0.23840   3.898 0.000724 ***
# h           -0.08297    0.03861  -2.149 0.042431 *
# I(h * b)     0.15774    0.05117   3.083 0.005259 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02326 on 23 degrees of freedom
# Multiple R-squared:  0.924,	Adjusted R-squared:  0.9041
# F-statistic: 46.59 on 6 and 23 DF,  p-value: 9.873e-12
#
# [1] "1 I(h * b)"
# [1] "2 h"
#
# Call:
# lm(formula = X5 ~ b + I(b^2) + I(b^3) + I(b^4), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.064182 -0.016123  0.001239  0.014619  0.049723
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.01915    0.02355   0.813  0.42370
# b            0.40744    0.05649   7.212 1.47e-07 ***
# I(b^2)      -0.09121    0.13034  -0.700  0.49054
# I(b^3)      -0.99741    0.28778  -3.466  0.00192 **
# I(b^4)       0.74443    0.26094   2.853  0.00857 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02652 on 25 degrees of freedom
# Multiple R-squared:  0.8926,	Adjusted R-squared:  0.8754
# F-statistic: 51.92 on 4 and 25 DF,  p-value: 9.427e-12
#
# [1] "Max reduction is 0.0110467894612736 using b"
# [1] "Max reduction is 0.000933676549557116 using c"
# [1] "Max reduction is 0.00648191943098921 using h"
# [1] "Max reduction is 0.00138940595339312 using c"
# [1] "Max reduction is 0.00279462499643129 using Three Way Interactions with c"
# [1] "Max reduction is 0.00100347290659933 using h"
# [1] "Max reduction is 0.000198566293926557 using Three Way Interactions with h"
# [1] "Max reduction is 0.000386208678851254 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X6 ~ b + I(b^2) + c + I(c^2) + h + I(h^2) + I(c *
#     b) + I(h * b) + I(h * c) + I(c * c * b) + I(c * h * b) +
#     I(c * h * c) + I(h * h * b) + I(h * h * c), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0211747 -0.0053678  0.0009783  0.0071852  0.0198056
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.27508    0.09728   2.828  0.01273 *
# b            -0.31163    0.12850  -2.425  0.02840 *
# I(b^2)       -0.04564    0.03332  -1.370  0.19094
# c            -0.28956    0.08544  -3.389  0.00405 **
# I(c^2)        0.14150    0.05548   2.550  0.02218 *
# h            -0.47260    0.35803  -1.320  0.20663
# I(h^2)        0.26304    0.32459   0.810  0.43039
# I(c * b)      0.20459    0.07112   2.877  0.01153 *
# I(h * b)      0.87296    0.38365   2.275  0.03798 *
# I(h * c)      0.55108    0.36904   1.493  0.15611
# I(c * c * b)  0.01718    0.05326   0.323  0.75149
# I(c * h * b) -0.43912    0.17031  -2.578  0.02098 *
# I(c * h * c) -0.24505    0.11872  -2.064  0.05675 .
# I(h * h * b) -0.50336    0.27980  -1.799  0.09217 .
# I(h * h * c)  0.04901    0.42414   0.116  0.90953
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0143 on 15 degrees of freedom
# Multiple R-squared:  0.9288,	Adjusted R-squared:  0.8623
# F-statistic: 13.97 on 14 and 15 DF,  p-value: 3.841e-06
#
# [1] "1 I(h * h * c)"
# [1] "2 I(b^2)"
# [1] "3 I(c * h * b)"
# [1] "4 I(h * h * b)"
# [1] "5 I(h * b)"
# [1] "6 I(c * c * b)"
# [1] "7 I(h^2)"
# [1] "8 I(c * h * c)"
# [1] "9 I(c * b)"
# [1] "10 I(c^2)"
#
# Call:
# lm(formula = X6 ~ b + c + h + I(h * c), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.032041 -0.010590 -0.000098  0.011667  0.045904
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.164898   0.020153   8.182 1.55e-08 ***
# b           -0.055501   0.008133  -6.824 3.75e-07 ***
# c           -0.110396   0.024780  -4.455 0.000153 ***
# h           -0.056305   0.040202  -1.401 0.173643
# I(h * c)     0.190062   0.052117   3.647 0.001220 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01961 on 25 degrees of freedom
# Multiple R-squared:  0.7766,	Adjusted R-squared:  0.7409
# F-statistic: 21.73 on 4 and 25 DF,  p-value: 7.818e-08
#
# [1] "Max reduction is 0.0205938739130647 using b"
# [1] "Max reduction is 0.016396756328017 using b"
# [1] "Max reduction is 0.000823826798531976 using h"
# [1] "Max reduction is 0.00123441937843989 using Three Way Interactions with b"
# [1] "Max reduction is 0.00106924198480661 using b"
# [1] "Max reduction is 0.00232091443831393 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X7 ~ b + I(b^2) + I(b^3) + I(b^4) + h + I(h * b) +
#     I(b * h * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.025714 -0.010875  0.000402  0.011471  0.033255
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.05725    0.02330   2.458  0.02233 *
# b             0.25474    0.04468   5.701 9.84e-06 ***
# I(b^2)       -0.07382    0.11095  -0.665  0.51278
# I(b^3)       -0.79091    0.22865  -3.459  0.00223 **
# I(b^4)        0.58469    0.20866   2.802  0.01039 *
# h            -0.05182    0.04445  -1.166  0.25617
# I(h * b)      0.09058    0.08551   1.059  0.30099
# I(b * h * b)  0.05865    0.13323   0.440  0.66407
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01667 on 22 degrees of freedom
# Multiple R-squared:  0.9397,	Adjusted R-squared:  0.9205
# F-statistic: 48.96 on 7 and 22 DF,  p-value: 5.806e-12
#
# [1] "1 I(b * h * b)"
# [1] "2 I(b^4)"
# [1] "3 I(b^3)"
#
# Call:
# lm(formula = X7 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.071613 -0.010460 -0.000057  0.012051  0.033354
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.06091    0.01951   3.122 0.004494 **
# b            0.13848    0.03490   3.968 0.000538 ***
# I(b^2)      -0.17447    0.02443  -7.141 1.75e-07 ***
# h            0.00156    0.03074   0.051 0.959935
# I(h * b)     0.06444    0.04272   1.509 0.143953
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02129 on 25 degrees of freedom
# Multiple R-squared:  0.8881,	Adjusted R-squared:  0.8702
# F-statistic: 49.62 on 4 and 25 DF,  p-value: 1.553e-11
#
# [1] "Max reduction is 0.001574575012095 using h"
# [1] "Max reduction is 0.000995962758864814 using c"
# [1] "Max reduction is 0.000452217709710691 using h"
# [1] "Max reduction is 0.000229618301675526 using b"
# [1] "Max reduction is 0.00290693624760251 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X8 ~ h + I(h^2) + c + b + I(b^2) + I(c * h) + I(b *
#     h) + I(b * c), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.045812 -0.007280  0.001098  0.008395  0.040884
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.082891   0.036825   2.251   0.0352 *
# h           -0.002266   0.140584  -0.016   0.9873
# I(h^2)       0.033436   0.138099   0.242   0.8110
# c            0.011986   0.038046   0.315   0.7558
# b            0.095124   0.062717   1.517   0.1442
# I(b^2)      -0.104106   0.037197  -2.799   0.0108 *
# I(c * h)     0.062345   0.057255   1.089   0.2885
# I(b * h)    -0.036617   0.048251  -0.759   0.4564
# I(b * c)    -0.041581   0.031063  -1.339   0.1950
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02007 on 21 degrees of freedom
# Multiple R-squared:  0.576,	Adjusted R-squared:  0.4145
# F-statistic: 3.566 on 8 and 21 DF,  p-value: 0.009191
#
# [1] "1 I(b * h)"
# [1] "2 I(h^2)"
# [1] "3 I(b * c)"
# [1] "4 I(c * h)"
#
# Call:
# lm(formula = X8 ~ h + c + b + I(b^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.041098 -0.011208 -0.000544  0.011505  0.050200
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.085227   0.014112   6.039 2.61e-06 ***
# h            0.056215   0.022792   2.466  0.02085 *
# c            0.010547   0.007058   1.494  0.14760
# b            0.024295   0.014039   1.730  0.09588 .
# I(b^2)      -0.074853   0.022067  -3.392  0.00231 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02007 on 25 degrees of freedom
# Multiple R-squared:  0.4953,	Adjusted R-squared:  0.4145
# F-statistic: 6.133 on 4 and 25 DF,  p-value: 0.001397
#
# [1] "Max reduction is 0.0313863557416079 using b"
# [1] "Max reduction is 0.0196226534975256 using b"
# [1] "Max reduction is 0.00260125004800641 using b"
# [1] "Max reduction is 0.00148394049737636 using b"
# [1] "Max reduction is 0.00253483760661026 using h"
# [1] "Max reduction is 0.000125127859036518 using b"
# [1] "Max reduction is 0.00158334487364666 using b"
# [1] "Max reduction is 0.000976626633882798 using Three Way Interactions with b"
# [1] "Max reduction is 0.00233856551799593 using c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X9 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + I(b^6) +
#     h + c + I(h * b) + I(c * b) + I(c * h) + I(b * h * b) + I(b *
#     c * b) + I(b * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0159932 -0.0071061 -0.0006267  0.0056556  0.0293458
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.10750    0.08830   1.217  0.24224
# b             0.01333    0.25335   0.053  0.95874
# I(b^2)        0.96500    0.43851   2.201  0.04384 *
# I(b^3)       -3.60866    1.03084  -3.501  0.00322 **
# I(b^4)        0.59682    1.12226   0.532  0.60265
# I(b^5)        6.48206    2.63489   2.460  0.02651 *
# I(b^6)       -4.54608    1.67470  -2.715  0.01598 *
# h            -0.10587    0.15732  -0.673  0.51121
# c            -0.18129    0.09472  -1.914  0.07491 .
# I(h * b)      0.66271    0.21913   3.024  0.00854 **
# I(c * b)      0.39781    0.19578   2.032  0.06026 .
# I(c * h)      0.18587    0.14622   1.271  0.22303
# I(b * h * b) -0.53636    0.20877  -2.569  0.02137 *
# I(b * c * b) -0.22161    0.09235  -2.400  0.02984 *
# I(b * c * h) -0.20880    0.20134  -1.037  0.31613
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01429 on 15 degrees of freedom
# Multiple R-squared:  0.9822,	Adjusted R-squared:  0.9655
# F-statistic: 58.98 on 14 and 15 DF,  p-value: 1.597e-10
#
# [1] "1 I(b * c * h)"
# [1] "2 I(c * h)"
# [1] "3 I(b * c * b)"
# [1] "4 I(c * b)"
# [1] "5 c"
# [1] "6 I(b * h * b)"
# [1] "7 I(b^6)"
# [1] "8 I(b^5)"
# [1] "9 I(b^4)"
# [1] "10 I(h * b)"
#
# Call:
# lm(formula = X9 ~ b + I(b^2) + I(b^3) + h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.064154 -0.018677  0.001934  0.016738  0.036381
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.0117182  0.0225010   0.521   0.6071
# b            0.2715242  0.0215626  12.592 2.54e-12 ***
# I(b^2)       0.0821107  0.1238137   0.663   0.5133
# I(b^3)      -0.3077189  0.1245905  -2.470   0.0207 *
# h           -0.0004735  0.0281417  -0.017   0.9867
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.02379 on 25 degrees of freedom
# Multiple R-squared:  0.9176,	Adjusted R-squared:  0.9044
# F-statistic: 69.56 on 4 and 25 DF,  p-value: 3.53e-13
#
# [1] "Max reduction is 0.0280882926601989 using b"
# [1] "Max reduction is 0.00256839847839575 using h"
# [1] "Max reduction is 0.00125422887000608 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X10 ~ b + h + c + I(h * b) + I(c * b) + I(c * h),
#     data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.020743 -0.007272 -0.001336  0.007631  0.042440
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.1129793  0.0188191   6.003 4.02e-06 ***
# b           -0.0516446  0.0227293  -2.272   0.0327 *
# h           -0.0007515  0.0318811  -0.024   0.9814
# c           -0.0371980  0.0209760  -1.773   0.0894 .
# I(h * b)    -0.0309801  0.0280385  -1.105   0.2806
# I(c * b)    -0.0132793  0.0158179  -0.840   0.4098
# I(c * h)     0.1023979  0.0383765   2.668   0.0137 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01443 on 23 degrees of freedom
# Multiple R-squared:  0.9231,	Adjusted R-squared:  0.9031
# F-statistic: 46.03 on 6 and 23 DF,  p-value: 1.121e-11
#
# [1] "1 I(c * b)"
# [1] "2 I(h * b)"
#
# Call:
# lm(formula = X10 ~ b + h + c + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.020586 -0.008055 -0.000858  0.006762  0.046611
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.12893    0.01479   8.716 4.76e-09 ***
# b           -0.08170    0.00597 -13.686 4.08e-13 ***
# h           -0.01291    0.02951  -0.438   0.6655
# c           -0.04748    0.01819  -2.610   0.0151 *
# I(c * h)     0.10305    0.03825   2.694   0.0124 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0144 on 25 degrees of freedom
# Multiple R-squared:  0.9168,	Adjusted R-squared:  0.9035
# F-statistic: 68.85 on 4 and 25 DF,  p-value: 3.968e-13
#
# [1] "Max reduction is 0.00476771597576843 using h"
# [1] "Max reduction is 0.00209896477290573 using b"
# [1] "Max reduction is 0.0073263199953139 using b"
# [1] "Max reduction is 0.000472631456776219 using b"
# [1] "Max reduction is 0.00148140027989504 using b"
# [1] "Max reduction is 0.000204550579126271 using Three Way Interactions with b"
# [1] "Max reduction is 0.000243792271985198 using b"
# [1] "Max reduction is 0.00015290858765084 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X11 ~ h + b + I(b^2) + I(b^3) + I(b^4) + I(b^5) +
#     I(b^6) + I(b * h) + I(b * b * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0109410 -0.0050028  0.0000547  0.0032110  0.0211299
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.02448    0.02411  -1.015  0.32213
# h             0.17582    0.03338   5.268 3.73e-05 ***
# b             0.14328    0.04943   2.898  0.00889 **
# I(b^2)       -0.01880    0.23941  -0.079  0.93818
# I(b^3)       -1.24654    0.57509  -2.168  0.04244 *
# I(b^4)        1.05825    0.62367   1.697  0.10524
# I(b^5)        1.27684    1.51212   0.844  0.40843
# I(b^6)       -1.20369    0.91148  -1.321  0.20155
# I(b * h)      0.17904    0.06285   2.849  0.00992 **
# I(b * b * h) -0.26133    0.10572  -2.472  0.02255 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.008708 on 20 degrees of freedom
# Multiple R-squared:  0.9193,	Adjusted R-squared:  0.883
# F-statistic: 25.31 on 9 and 20 DF,  p-value: 4.913e-09
#
# [1] "1 I(b^6)"
# [1] "2 I(b^5)"
# [1] "3 I(b * b * h)"
# [1] "4 I(b * h)"
# [1] "5 I(b^4)"
#
# Call:
# lm(formula = X11 ~ h + b + I(b^2) + I(b^3), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0183620 -0.0070858  0.0004918  0.0048289  0.0280409
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.007369   0.010114  -0.729    0.473
# h            0.113994   0.012649   9.012 2.51e-09 ***
# b            0.074456   0.009692   7.682 4.88e-08 ***
# I(b^2)       0.002186   0.055653   0.039    0.969
# I(b^3)      -0.092900   0.056002  -1.659    0.110
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0107 on 25 degrees of freedom
# Multiple R-squared:  0.8478,	Adjusted R-squared:  0.8235
# F-statistic: 34.82 on 4 and 25 DF,  p-value: 6.974e-10
#
# [1] "Max reduction is 0.00367679062935104 using b"
# [1] "Max reduction is 0.00616294244328715 using b"
# [1] "Max reduction is 0.000165374797548168 using h"
# [1] "Max reduction is 0.000374184528328628 using Three Way Interactions with b"
# [1] "Max reduction is 0.000332763808127885 using b"
# [1] "Max reduction is 0.000688336315107588 using b"
# [1] "Max reduction is 0.000178676975363842 using c"
# [1] "Max reduction is 6.32632434256512e-05 using b"
# [1] "Max reduction is 0.000122225180018165 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X12 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + I(b^6) +
#     h + c + I(h * b) + I(c * b) + I(c * h) + I(b * h * b) + I(b *
#     c * b) + I(b * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0062080 -0.0022548 -0.0002335  0.0024663  0.0070077
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.0080465  0.0275039   0.293   0.7739
# b             0.1190309  0.0789149   1.508   0.1522
# I(b^2)       -0.0748998  0.1365878  -0.548   0.5915
# I(b^3)       -0.6927106  0.3210881  -2.157   0.0476 *
# I(b^4)        0.5781198  0.3495659   1.654   0.1189
# I(b^5)        0.7728790  0.8207240   0.942   0.3613
# I(b^6)       -0.7172845  0.5216411  -1.375   0.1893
# h             0.0186308  0.0490040   0.380   0.7091
# c             0.0130605  0.0295047   0.443   0.6643
# I(h * b)      0.0645680  0.0682564   0.946   0.3592
# I(c * b)     -0.0158729  0.0609814  -0.260   0.7982
# I(c * h)     -0.0192157  0.0455445  -0.422   0.6791
# I(b * h * b) -0.0635813  0.0650280  -0.978   0.3437
# I(b * c * b)  0.0003569  0.0287649   0.012   0.9903
# I(b * c * h)  0.0123292  0.0627135   0.197   0.8468
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004451 on 15 degrees of freedom
# Multiple R-squared:  0.961,	Adjusted R-squared:  0.9247
# F-statistic: 26.42 on 14 and 15 DF,  p-value: 4.995e-08
#
# [1] "1 I(b * c * h)"
# [1] "2 I(b * c * b)"
# [1] "3 I(c * h)"
# [1] "4 I(b * h * b)"
# [1] "5 I(c * b)"
# [1] "6 c"
# [1] "7 I(b^6)"
# [1] "8 I(b^5)"
# [1] "9 I(b^4)"
# [1] "10 I(b^3)"
#
# Call:
# lm(formula = X12 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0158463 -0.0024517 -0.0004746  0.0019429  0.0130005
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.024282   0.005691   4.267 0.000249 ***
# b            0.034074   0.010180   3.347 0.002585 **
# I(b^2)      -0.056718   0.007127  -7.958 2.58e-08 ***
# h           -0.009252   0.008967  -1.032 0.312025
# I(h * b)     0.022999   0.012461   1.846 0.076808 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.006211 on 25 degrees of freedom
# Multiple R-squared:  0.8735,	Adjusted R-squared:  0.8533
# F-statistic: 43.18 on 4 and 25 DF,  p-value: 7.086e-11
#
# [1] "Max reduction is 0.001179622609136 using b"
# [1] "Max reduction is 0.000820005410114047 using c"
# [1] "Max reduction is 6.77373315820691e-05 using h"
# [1] "Max reduction is 0.000178688858782422 using b"
# [1] "Max reduction is 0.00115665497336083 using Three Way Interactions with b"
# [1] "Max reduction is 6.36655958583449e-05 using c"
# [1] "Max reduction is 0.000374403136184158 using Three Way Interactions with c"
# [1] "Max reduction is 0.000380638901815726 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X13 ~ b + I(b^2) + I(b^3) + c + I(c^2) + h + I(c *
#     b) + I(h * b) + I(h * c) + I(b * c * b) + I(b * h * b) +
#     I(b * h * c) + I(c * c * b) + I(c * h * c), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0052278 -0.0010065 -0.0002659  0.0008869  0.0043628
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.082982   0.017885   4.640 0.000321 ***
# b            -0.119951   0.052677  -2.277 0.037859 *
# I(b^2)        0.087539   0.053048   1.650 0.119681
# I(b^3)       -0.051597   0.021476  -2.403 0.029677 *
# c            -0.044491   0.019062  -2.334 0.033912 *
# I(c^2)       -0.044236   0.013529  -3.270 0.005170 **
# h            -0.108235   0.028582  -3.787 0.001791 **
# I(c * b)      0.104855   0.039819   2.633 0.018807 *
# I(h * b)      0.108787   0.064548   1.685 0.112604
# I(h * c)      0.072694   0.036469   1.993 0.064740 .
# I(b * c * b) -0.048095   0.019971  -2.408 0.029350 *
# I(b * h * b) -0.002157   0.044811  -0.048 0.962243
# I(b * h * c) -0.112022   0.044234  -2.532 0.022982 *
# I(c * c * b)  0.029833   0.012604   2.367 0.031812 *
# I(c * h * c)  0.048292   0.023601   2.046 0.058687 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.00273 on 15 degrees of freedom
# Multiple R-squared:  0.9202,	Adjusted R-squared:  0.8457
# F-statistic: 12.36 on 14 and 15 DF,  p-value: 8.585e-06
#
# [1] "1 I(b * h * c)"
# [1] "2 I(c^2)"
# [1] "3 I(c * h * c)"
# [1] "4 I(b^3)"
# [1] "5 I(h * c)"
# [1] "6 I(c * c * b)"
# [1] "7 I(b * c * b)"
# [1] "8 I(c * b)"
# [1] "9 c"
# [1] "10 I(b^2)"
#
# Call:
# lm(formula = X13 ~ b + h + I(h * b) + I(b * h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0114784 -0.0031941 -0.0006294  0.0021046  0.0154532
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.007765   0.005368   1.446   0.1605
# b             0.003336   0.007357   0.453   0.6541
# h             0.012615   0.009381   1.345   0.1908
# I(h * b)     -0.008117   0.010789  -0.752   0.4589
# I(b * h * b) -0.021912   0.011033  -1.986   0.0581 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.005448 on 25 degrees of freedom
# Multiple R-squared:  0.4706,	Adjusted R-squared:  0.3859
# F-statistic: 5.556 on 4 and 25 DF,  p-value: 0.002427
#
# [1] "Max reduction is 0.00087734822821036 using b"
# [1] "Max reduction is 0.00524578753327163 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X14 ~ b + I(b^2), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0138201 -0.0029736 -0.0006602  0.0027258  0.0140284
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.020438   0.002225   9.186 8.50e-10 ***
# b            0.036632   0.004052   9.040 1.18e-09 ***
# I(b^2)      -0.054330   0.006699  -8.110 1.03e-08 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.006395 on 27 degrees of freedom
# Multiple R-squared:  0.757,	Adjusted R-squared:  0.739
# F-statistic: 42.06 on 2 and 27 DF,  p-value: 5.073e-09
#
# [1] "Max reduction is 3.47198316728928e-05 using b"
# [1] "Max reduction is 0.0044941699360208 using b"
# [1] "Max reduction is 0.000364637560499601 using c"
# [1] "Max reduction is 0.000570836448803406 using Three Way Interactions with b"
# [1] "Max reduction is 0.000309606407411631 using h"
# [1] "Max reduction is 0.000170271125842156 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X15 ~ b + I(b^2) + c + I(c^2) + h + I(c * b) + I(h *
#     b) + I(h * c) + I(b * c * b) + I(b * h * b) + I(b * h * c),
#     data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0074178 -0.0024923 -0.0004299  0.0023537  0.0124535
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.035380   0.022671   1.561    0.136
# b             0.071022   0.067751   1.048    0.308
# I(b^2)       -0.087072   0.051302  -1.697    0.107
# c             0.005468   0.028173   0.194    0.848
# I(c^2)       -0.007634   0.005129  -1.488    0.154
# h            -0.020121   0.032751  -0.614    0.547
# I(c * b)     -0.009272   0.057984  -0.160    0.875
# I(h * b)     -0.075101   0.074711  -1.005    0.328
# I(h * c)      0.013400   0.042138   0.318    0.754
# I(b * c * b) -0.017396   0.028718  -0.606    0.552
# I(b * h * b)  0.074500   0.061052   1.220    0.238
# I(b * h * c)  0.036492   0.057058   0.640    0.531
#
# Residual standard error: 0.005407 on 18 degrees of freedom
# Multiple R-squared:  0.8592,	Adjusted R-squared:  0.7731
# F-statistic: 9.984 on 11 and 18 DF,  p-value: 1.441e-05
#
# [1] "1 I(b * h * c)"
# [1] "2 I(b * h * b)"
# [1] "3 I(h * b)"
# [1] "4 I(b * c * b)"
# [1] "5 I(c * b)"
# [1] "6 I(c^2)"
# [1] "7 I(h * c)"
#
# Call:
# lm(formula = X15 ~ b + I(b^2) + c + h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.010860 -0.004392 -0.001352  0.003585  0.012510
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.021955   0.004479   4.902 4.81e-05 ***
# b            0.033416   0.004456   7.499 7.48e-08 ***
# I(b^2)      -0.055085   0.007004  -7.865 3.20e-08 ***
# c            0.003978   0.002240   1.776   0.0879 .
# h            0.008314   0.007234   1.149   0.2613
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.006371 on 25 degrees of freedom
# Multiple R-squared:  0.7284,	Adjusted R-squared:  0.685
# F-statistic: 16.76 on 4 and 25 DF,  p-value: 8.472e-07
#
# [1] "Max reduction is 0.00168431396801556 using b"
# [1] "Max reduction is 0.00452112293269528 using b"
# [1] "Max reduction is 0.000676658577498775 using b"
# [1] "Max reduction is 0.000777857866722879 using b"
# [1] "Max reduction is 0.00136467128280734 using c"
# [1] "Max reduction is 0.000721251467472547 using h"
# [1] "Max reduction is 0.000132056570822962 using Three Way Interactions with b"
# [1] "Max reduction is 0.000211891807315691 using b"
# [1] "Max reduction is 0.000713586529927882 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X16 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + I(b^6) +
#     c + h + I(c * b) + I(h * b) + I(h * c) + I(b * c * b) + I(b *
#     h * b) + I(b * h * c), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0044117 -0.0012646 -0.0008315  0.0017937  0.0071462
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.022491   0.021376  -1.052 0.309364
# b             0.153153   0.061332   2.497 0.024645 *
# I(b^2)        0.003645   0.106154   0.034 0.973065
# I(b^3)       -1.099950   0.249546  -4.408 0.000509 ***
# I(b^4)        0.755742   0.271678   2.782 0.013964 *
# I(b^5)        1.371476   0.637856   2.150 0.048263 *
# I(b^6)       -1.166697   0.405413  -2.878 0.011501 *
# c             0.031615   0.022931   1.379 0.188192
# h             0.067719   0.038085   1.778 0.095661 .
# I(c * b)     -0.019464   0.047394  -0.411 0.687102
# I(h * b)      0.079105   0.053048   1.491 0.156640
# I(h * c)     -0.047109   0.035397  -1.331 0.203100
# I(b * c * b) -0.006793   0.022356  -0.304 0.765420
# I(b * h * b) -0.150671   0.050539  -2.981 0.009321 **
# I(b * h * c)  0.041080   0.048740   0.843 0.412559
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.003459 on 15 degrees of freedom
# Multiple R-squared:  0.9696,	Adjusted R-squared:  0.9412
# F-statistic: 34.14 on 14 and 15 DF,  p-value: 8.178e-09
#
# [1] "1 I(b * h * c)"
# [1] "2 I(b^6)"
# [1] "3 I(b^5)"
# [1] "4 I(b * h * b)"
# [1] "5 I(h * c)"
# [1] "6 I(b * c * b)"
# [1] "7 I(c * b)"
# [1] "8 I(h * b)"
# [1] "9 h"
# [1] "10 I(b^4)"
#
# Call:
# lm(formula = X16 ~ b + I(b^2) + I(b^3) + c, data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0163024 -0.0031324 -0.0003304  0.0035488  0.0138025
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.001300   0.006120   0.212   0.8335
# b            0.056001   0.006327   8.851 3.55e-09 ***
# I(b^2)       0.026473   0.032099   0.825   0.4173
# I(b^3)      -0.088268   0.033018  -2.673   0.0130 *
# c            0.005447   0.002309   2.359   0.0265 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.006807 on 25 degrees of freedom
# Multiple R-squared:  0.8036,	Adjusted R-squared:  0.7722
# F-statistic: 25.58 on 4 and 25 DF,  p-value: 1.61e-08
#
# [1] "Max reduction is 0.00034932192833125 using b"
# [1] "Max reduction is 0.00362086118965007 using b"
# [1] "Max reduction is 0.000366200348269216 using h"
# [1] "Max reduction is 1.92452905257486e-05 using b"
# [1] "Max reduction is 9.50145021595085e-05 using b"
# [1] "Max reduction is 7.58301082269342e-05 using c"
# [1] "Max reduction is 0.00021377560108556 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X17 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + h +
#     c + I(h * b) + I(c * b) + I(c * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.006595 -0.002653  0.000057  0.001691  0.012905
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.011248   0.009052   1.243 0.229149
# b            0.079973   0.019111   4.185 0.000503 ***
# I(b^2)      -0.181122   0.086695  -2.089 0.050379 .
# I(b^3)      -0.127290   0.062818  -2.026 0.057005 .
# I(b^4)       0.496039   0.226299   2.192 0.041040 *
# I(b^5)      -0.285250   0.167854  -1.699 0.105560
# h            0.024269   0.013628   1.781 0.090945 .
# c            0.019083   0.009140   2.088 0.050514 .
# I(h * b)    -0.002540   0.010516  -0.242 0.811706
# I(c * b)    -0.012922   0.007331  -1.763 0.094054 .
# I(c * h)    -0.015581   0.013930  -1.119 0.277287
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004634 on 19 degrees of freedom
# Multiple R-squared:  0.8399,	Adjusted R-squared:  0.7556
# F-statistic: 9.968 on 10 and 19 DF,  p-value: 1.257e-05
#
# [1] "1 I(h * b)"
# [1] "2 I(b^5)"
# [1] "3 I(c * h)"
# [1] "4 I(b^4)"
# [1] "5 I(c * b)"
# [1] "6 c"
#
# Call:
# lm(formula = X17 ~ b + I(b^2) + I(b^3) + h, data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0076384 -0.0029022 -0.0002919  0.0024331  0.0138606
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.010706   0.004650   2.302   0.0299 *
# b            0.032334   0.004456   7.256 1.33e-07 ***
# I(b^2)      -0.014517   0.025586  -0.567   0.5755
# I(b^3)      -0.030711   0.025747  -1.193   0.2441
# h            0.010786   0.005815   1.855   0.0755 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004917 on 25 degrees of freedom
# Multiple R-squared:  0.7628,	Adjusted R-squared:  0.7249
# F-statistic:  20.1 on 4 and 25 DF,  p-value: 1.627e-07
#
# [1] "Max reduction is 0.000728554128282025 using b"
# [1] "Max reduction is 0.0033735875150236 using b"
# [1] "Max reduction is 0.000343244862681483 using b"
# [1] "Max reduction is 0.00151204003552732 using b"
# [1] "Max reduction is 0.00025164931838714 using h"
# [1] "Max reduction is 0.000274995464725349 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X18 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + h +
#     I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0072718 -0.0018166  0.0001741  0.0015185  0.0080257
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.026124   0.008242   3.170  0.00444 **
# b            0.078262   0.011310   6.919 6.01e-07 ***
# I(b^2)      -0.151489   0.081142  -1.867  0.07529 .
# I(b^3)      -0.283061   0.059167  -4.784 8.90e-05 ***
# I(b^4)       0.645134   0.209360   3.081  0.00546 **
# I(b^5)      -0.315204   0.162575  -1.939  0.06546 .
# h           -0.006986   0.007852  -0.890  0.38327
# I(h * b)     0.022387   0.010381   2.157  0.04223 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004719 on 22 degrees of freedom
# Multiple R-squared:  0.8654,	Adjusted R-squared:  0.8226
# F-statistic: 20.21 on 7 and 22 DF,  p-value: 3.288e-08
#
# [1] "1 I(b^5)"
# [1] "2 I(h * b)"
# [1] "3 h"
#
# Call:
# lm(formula = X18 ~ b + I(b^2) + I(b^3) + I(b^4), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0078015 -0.0034181  0.0001214  0.0039005  0.0102652
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.010054   0.004657   2.159 0.040644 *
# b            0.081602   0.011173   7.304 1.19e-07 ***
# I(b^2)      -0.014077   0.025778  -0.546 0.589840
# I(b^3)      -0.280906   0.056916  -4.935 4.40e-05 ***
# I(b^4)       0.219867   0.051607   4.260 0.000253 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.005245 on 25 degrees of freedom
# Multiple R-squared:  0.811,	Adjusted R-squared:  0.7808
# F-statistic: 26.82 on 4 and 25 DF,  p-value: 1.005e-08
#
# [1] "Max reduction is 0.000679622416667861 using b"
# [1] "Max reduction is 0.00276563783320642 using b"
# [1] "Max reduction is 0.000669277794891713 using h"
# [1] "Max reduction is 0.000146101142247164 using h"
# [1] "Max reduction is 6.13788328622106e-05 using h"
# [1] "Max reduction is 0.000227787018173819 using h"
# [1] "Max reduction is 7.04144873549016e-05 using h"
# [1] "Max reduction is 7.35142842073558e-05 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X19 ~ b + I(b^2) + h + I(h^2) + I(h^3) + I(h^4) +
#     I(h^5) + I(h^6) + I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0050921 -0.0018600 -0.0002147  0.0013604  0.0067837
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.098e+00  6.223e-01  -1.765 0.092794 .
# b            3.194e-02  8.136e-03   3.926 0.000837 ***
# I(b^2)      -4.128e-02  5.401e-03  -7.644 2.34e-07 ***
# h            1.265e+01  7.341e+00   1.723 0.100356
# I(h^2)      -5.673e+01  3.459e+01  -1.640 0.116676
# I(h^3)       1.298e+02  8.355e+01   1.553 0.135999
# I(h^4)      -1.609e+02  1.094e+02  -1.471 0.156809
# I(h^5)       1.031e+02  7.377e+01   1.398 0.177406
# I(h^6)      -2.683e+01  2.009e+01  -1.336 0.196681
# I(h * b)    -9.220e-05  1.101e-02  -0.008 0.993399
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.003976 on 20 degrees of freedom
# Multiple R-squared:  0.855,	Adjusted R-squared:  0.7897
# F-statistic:  13.1 on 9 and 20 DF,  p-value: 1.374e-06
#
# [1] "1 I(h * b)"
# [1] "2 I(h^6)"
# [1] "3 I(h^5)"
# [1] "4 I(h^4)"
# [1] "5 I(h^3)"
#
# Call:
# lm(formula = X19 ~ b + I(b^2) + h + I(h^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.006773 -0.002931 -0.000858  0.001736  0.011447
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.023475   0.007707   3.046   0.0054 **
# b            0.029797   0.003213   9.275 1.43e-09 ***
# I(b^2)      -0.041727   0.005081  -8.212 1.45e-08 ***
# h           -0.028405   0.026955  -1.054   0.3021
# I(h^2)       0.038859   0.023159   1.678   0.1058
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004325 on 25 degrees of freedom
# Multiple R-squared:  0.7854,	Adjusted R-squared:  0.7511
# F-statistic: 22.88 on 4 and 25 DF,  p-value: 4.772e-08
#
# [1] "Max reduction is 0.0021448150453724 using b"
# [1] "Max reduction is 0.00338294315965902 using b"
# [1] "Max reduction is 0.00053138386899993 using b"
# [1] "Max reduction is 0.0012303952213146 using b"
# [1] "Max reduction is 0.00145284467219088 using h"
# [1] "Max reduction is 0.000732613741662399 using c"
# [1] "Max reduction is 0.000245828069737936 using b"
# [1] "Max reduction is 0.000102121817183274 using Three Way Interactions with b"
# [1] "Max reduction is 0.000390432180598552 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X20 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + I(b^6) +
#     h + c + I(h * b) + I(c * b) + I(c * h) + I(b * h * b) + I(b *
#     c * b) + I(b * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0048311 -0.0012324 -0.0004255  0.0016479  0.0068321
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.020893   0.019827  -1.054  0.30865
# b             0.157185   0.056887   2.763  0.01450 *
# I(b^2)       -0.083792   0.098462  -0.851  0.40814
# I(b^3)       -0.936205   0.231462  -4.045  0.00106 **
# I(b^4)        0.897394   0.251990   3.561  0.00284 **
# I(b^5)        0.833011   0.591632   1.408  0.17952
# I(b^6)       -0.851756   0.376034  -2.265  0.03875 *
# h             0.062863   0.035325   1.780  0.09541 .
# c             0.037658   0.021269   1.771  0.09695 .
# I(h * b)      0.061435   0.049204   1.249  0.23095
# I(c * b)     -0.037889   0.043959  -0.862  0.40231
# I(c * h)     -0.057163   0.032831  -1.741  0.10213
# I(b * h * b) -0.116903   0.046876  -2.494  0.02481 *
# I(b * c * b)  0.004685   0.020736   0.226  0.82431
# I(b * c * h)  0.049711   0.045208   1.100  0.28884
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.003209 on 15 degrees of freedom
# Multiple R-squared:  0.9704,	Adjusted R-squared:  0.9429
# F-statistic: 35.17 on 14 and 15 DF,  p-value: 6.613e-09
#
# [1] "1 I(b * c * h)"
# [1] "2 I(b * c * b)"
# [1] "3 I(b^6)"
# [1] "4 I(b^5)"
# [1] "5 I(b * h * b)"
# [1] "6 I(c * b)"
# [1] "7 I(c * h)"
# [1] "8 c"
# [1] "9 I(h * b)"
# [1] "10 h"
#
# Call:
# lm(formula = X20 ~ b + I(b^2) + I(b^3) + I(b^4), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0107708 -0.0039047 -0.0000751  0.0037029  0.0140273
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.0007551  0.0054446   0.139 0.890802
# b            0.0899879  0.0130627   6.889  3.2e-07 ***
# I(b^2)       0.0001057  0.0301386   0.004 0.997229
# I(b^3)      -0.2904424  0.0665441  -4.365 0.000193 ***
# I(b^4)       0.2131522  0.0603376   3.533 0.001627 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.006132 on 25 degrees of freedom
# Multiple R-squared:   0.82,	Adjusted R-squared:  0.7912
# ...
# b            0.017709   0.008615   2.056   0.0504 .
# I(b^2)      -0.035114   0.007604  -4.618   0.0001 ***
# c           -0.009831   0.005901  -1.666   0.1082
# I(c * b)     0.013791   0.007836   1.760   0.0907 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.00611 on 25 degrees of freedom
# Multiple R-squared:  0.7308,	Adjusted R-squared:  0.6877
# F-statistic: 16.97 on 4 and 25 DF,  p-value: 7.616e-07
#
# [1] "Max reduction is 0.0103031167471722 using b"
# [1] "Max reduction is 0.00185363677914315 using h"
# [1] "Max reduction is 0.00062594890799423 using b"
# [1] "Max reduction is 0.00434790234312675 using b"
# [1] "Max reduction is 0.000760517511044197 using b"
# [1] "Max reduction is 0.000101131498939097 using Three Way Interactions with b"
# [1] "Max reduction is 0.000788941249560664 using c"
# [1] "Max reduction is 0.000154103348556323 using c"
# [1] "Max reduction is 0.000685829372640286 using Three Way Interactions with c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X25 ~ b + I(b^2) + I(b^3) + I(b^4) + h + c + I(c^2) +
#     I(h * b) + I(c * b) + I(c * h) + I(b * h * b) + I(b * c *
#     b) + I(b * c * h) + I(c * c * b) + I(c * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0076393 -0.0008821  0.0003765  0.0021135  0.0052284
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.036327   0.032091  -1.132 0.276653
# b             0.158693   0.094043   1.687 0.113660
# I(b^2)       -0.333651   0.093475  -3.569 0.003080 **
# I(b^3)        0.305459   0.072669   4.203 0.000885 ***
# I(b^4)       -0.050332   0.065906  -0.764 0.457727
# h             0.192107   0.051164   3.755 0.002133 **
# c             0.043200   0.033756   1.280 0.221425
# I(c^2)        0.032044   0.023777   1.348 0.199162
# I(h * b)     -0.246460   0.112353  -2.194 0.045643 *
# I(c * b)     -0.092867   0.069906  -1.328 0.205277
# I(c * h)     -0.084965   0.064073  -1.326 0.206045
# I(b * h * b)  0.025018   0.078239   0.320 0.753869
# I(b * c * b)  0.041008   0.035032   1.171 0.261301
# I(b * c * h)  0.116983   0.077180   1.516 0.151841
# I(c * c * b) -0.056523   0.021995  -2.570 0.022246 *
# I(c * c * h)  0.006868   0.041135   0.167 0.869781
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004752 on 14 degrees of freedom
# Multiple R-squared:  0.9817,	Adjusted R-squared:  0.962
# F-statistic: 49.93 on 15 and 14 DF,  p-value: 1.544e-09
#
# [1] "1 I(c * c * h)"
# [1] "2 I(b * c * h)"
# [1] "3 I(c^2)"
# [1] "4 I(c * h)"
# [1] "5 I(b * h * b)"
# [1] "6 I(c * c * b)"
# [1] "7 I(b^4)"
# [1] "8 I(b^3)"
# [1] "9 I(b^2)"
# [1] "10 I(b * c * b)"
# [1] "11 I(c * b)"
#
# Call:
# lm(formula = X25 ~ b + h + c + I(h * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.028899 -0.005072 -0.001803  0.005143  0.044903
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.0179206  0.0113531   1.578   0.1270
# b           -0.0116588  0.0168684  -0.691   0.4958
# h            0.0537716  0.0166149   3.236   0.0034 **
# c           -0.0003849  0.0044243  -0.087   0.9314
# I(h * b)    -0.0408714  0.0241874  -1.690   0.1035
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01246 on 25 degrees of freedom
# Multiple R-squared:  0.7748,	Adjusted R-squared:  0.7388
# F-statistic: 21.51 on 4 and 25 DF,  p-value: 8.61e-08
#
# [1] "Max reduction is 0.0034472682594623 using b"
# [1] "Max reduction is 0.00411170870003565 using b"
# [1] "Max reduction is 0.000271610075362559 using b"
# [1] "Max reduction is 0.000270336673479725 using h"
# [1] "Max reduction is 0.000700676140446891 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X26 ~ b + I(b^2) + I(b^3) + I(b^4) + h + I(h * b),
#     data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0092155 -0.0026691 -0.0003357  0.0028663  0.0134355
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.012627   0.005142   2.456 0.022034 *
# b            0.055935   0.011621   4.813 7.41e-05 ***
# I(b^2)       0.011525   0.028734   0.401 0.692056
# I(b^3)      -0.221890   0.058510  -3.792 0.000941 ***
# I(b^4)       0.146523   0.051110   2.867 0.008718 **
# h           -0.014528   0.008278  -1.755 0.092590 .
# I(h * b)     0.033560   0.010971   3.059 0.005561 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004987 on 23 degrees of freedom
# Multiple R-squared:  0.8963,	Adjusted R-squared:  0.8692
# F-statistic: 33.12 on 6 and 23 DF,  p-value: 3.328e-10
#
# [1] "1 I(b^4)"
# [1] "2 I(b^3)"
#
# Call:
# lm(formula = X26 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0229436 -0.0018610 -0.0006099  0.0028107  0.0107846
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.017398   0.005662   3.073  0.00506 **
# b            0.030925   0.010128   3.054  0.00531 **
# I(b^2)      -0.045152   0.007090  -6.368 1.15e-06 ***
# h           -0.001698   0.008920  -0.190  0.85060
# I(h * b)     0.016133   0.012397   1.301  0.20500
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.006179 on 25 degrees of freedom
# Multiple R-squared:  0.8269,	Adjusted R-squared:  0.7992
# F-statistic: 29.86 on 4 and 25 DF,  p-value: 3.414e-09
#
# [1] "Max reduction is 0.00613694273427962 using b"
# [1] "Max reduction is 0.000854314381615545 using h"
# [1] "Max reduction is 0.000320947954397282 using b"
# [1] "Max reduction is 0.00308506421321139 using b"
# [1] "Max reduction is 0.001607012492416 using b"
# [1] "Max reduction is 0.000116761051321452 using b"
# [1] "Max reduction is 9.27983411946826e-05 using b"
# [1] "Max reduction is 1.84665392145272e-05 using c"
# [1] "Max reduction is 0.000396397102206977 using Three Way Interactions with b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X27 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + I(b^6) +
#     h + c + I(h * b) + I(c * b) + I(c * h) + I(b * h * b) + I(b *
#     c * b) + I(b * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0069823 -0.0015969  0.0001768  0.0020228  0.0069006
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.058868   0.029107   2.022  0.06133 .
# b            -0.053835   0.083514  -0.645  0.52891
# I(b^2)       -0.510743   0.144548  -3.533  0.00301 **
# I(b^3)        0.910959   0.339800   2.681  0.01710 *
# I(b^4)        0.491647   0.369938   1.329  0.20371
# I(b^5)       -1.789577   0.868554  -2.060  0.05715 .
# I(b^6)        0.889356   0.552041   1.611  0.12801
# h             0.043091   0.051860   0.831  0.41906
# c            -0.007489   0.031224  -0.240  0.81371
# I(h * b)     -0.028485   0.072234  -0.394  0.69888
# I(c * b)     -0.013493   0.064535  -0.209  0.83719
# I(c * h)      0.040760   0.048199   0.846  0.41102
# I(b * h * b)  0.011807   0.068818   0.172  0.86607
# I(b * c * b)  0.023369   0.030441   0.768  0.45460
# I(b * c * h) -0.048871   0.066368  -0.736  0.47287
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.00471 on 15 degrees of freedom
# Multiple R-squared:  0.9618,	Adjusted R-squared:  0.9262
# F-statistic:    27 on 14 and 15 DF,  p-value: 4.296e-08
#
# [1] "1 I(b * h * b)"
# [1] "2 I(b * c * h)"
# [1] "3 I(c * h)"
# [1] "4 I(b * c * b)"
# [1] "5 I(c * b)"
# [1] "6 c"
# [1] "7 I(b^6)"
# [1] "8 I(b^5)"
# [1] "9 I(b^4)"
# [1] "10 I(b^3)"
#
# Call:
# lm(formula = X27 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.022310 -0.003834 -0.000851  0.002365  0.039256
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.016904   0.009188   1.840  0.07771 .
# b           -0.002430   0.016436  -0.148  0.88366
# I(b^2)      -0.018876   0.011506  -1.640  0.11344
# h            0.041710   0.014477   2.881  0.00802 **
# I(h * b)    -0.020244   0.020118  -1.006  0.32394
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01003 on 25 degrees of freedom
# Multiple R-squared:  0.7117,	Adjusted R-squared:  0.6656
# F-statistic: 15.43 on 4 and 25 DF,  p-value: 1.751e-06
#
# [1] "Max reduction is 0.00279514243230417 using b"
# [1] "Max reduction is 0.00444863495653572 using b"
# [1] "Max reduction is 0.000600821402875893 using h"
# [1] "Max reduction is 0.000270186754844813 using c"
# [1] "Max reduction is 0.000546317888227096 using b"
# [1] "Max reduction is 0.000954872813549841 using Three Way Interactions with b"
# [1] "Max reduction is 8.84230530509905e-05 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X28 ~ b + I(b^2) + I(b^3) + I(b^4) + h + c + I(h *
#     b) + I(c * b) + I(c * h) + I(b * h * b) + I(b * c * b) +
#     I(b * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0053236 -0.0023851 -0.0001444  0.0020165  0.0074362
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.06596    0.01807   3.651  0.00198 **
# b            -0.15307    0.05386  -2.842  0.01127 *
# I(b^2)        0.18636    0.05171   3.604  0.00219 **
# I(b^3)       -0.16655    0.06158  -2.705  0.01503 *
# I(b^4)        0.07380    0.05516   1.338  0.19860
# h            -0.07384    0.03011  -2.453  0.02527 *
# c            -0.08845    0.02324  -3.806  0.00141 **
# I(h * b)      0.23794    0.06090   3.907  0.00113 **
# I(c * b)      0.14603    0.04670   3.127  0.00614 **
# I(c * h)      0.11494    0.03509   3.276  0.00446 **
# I(b * h * b) -0.15815    0.04529  -3.492  0.00279 **
# I(b * c * b) -0.06308    0.02242  -2.813  0.01197 *
# I(b * c * h) -0.10715    0.04734  -2.264  0.03697 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004075 on 17 degrees of freedom
# Multiple R-squared:  0.9487,	Adjusted R-squared:  0.9125
# F-statistic: 26.21 on 12 and 17 DF,  p-value: 1.381e-08
#
# [1] "1 I(b^4)"
# [1] "2 I(b * c * b)"
# [1] "3 I(b * c * h)"
# [1] "4 I(b * h * b)"
# [1] "5 I(c * b)"
# [1] "6 I(b^3)"
# [1] "7 I(c * h)"
# [1] "8 c"
#
# Call:
# lm(formula = X28 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0159441 -0.0034921  0.0005862  0.0029440  0.0101222
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.015607   0.005439   2.870  0.00824 **
# b            0.029386   0.009729   3.020  0.00575 **
# I(b^2)      -0.049954   0.006811  -7.334  1.1e-07 ***
# h            0.004389   0.008569   0.512  0.61298
# I(h * b)     0.020742   0.011909   1.742  0.09384 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.005935 on 25 degrees of freedom
# Multiple R-squared:  0.8401,	Adjusted R-squared:  0.8145
# F-statistic: 32.83 on 4 and 25 DF,  p-value: 1.288e-09
#
# [1] "Max reduction is 0.00910622267011647 using b"
# [1] "Max reduction is 0.00148713051862811 using h"
# [1] "Max reduction is 0.000121816145877543 using c"
# [1] "Max reduction is 0.00013641359961445 using b"
# [1] "Max reduction is 0.00408610556726856 using b"
# [1] "Max reduction is 0.000155777464235163 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X29 ~ b + I(b^2) + I(b^3) + I(b^4) + h + c + I(h *
#     b) + I(c * b) + I(c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0074994 -0.0023709  0.0000949  0.0029735  0.0067996
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.031491   0.007259   4.338 0.000319 ***
# b           -0.018989   0.017745  -1.070 0.297300
# I(b^2)      -0.210880   0.030307  -6.958 9.38e-07 ***
# I(b^3)       0.298638   0.061646   4.844 9.84e-05 ***
# I(b^4)      -0.087721   0.056227  -1.560 0.134414
# h            0.072123   0.013559   5.319 3.32e-05 ***
# c           -0.002019   0.008897  -0.227 0.822814
# I(h * b)    -0.065251   0.010506  -6.211 4.57e-06 ***
# I(c * b)    -0.003797   0.007053  -0.538 0.596279
# I(c * h)     0.010051   0.013916   0.722 0.478476
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004639 on 20 degrees of freedom
# Multiple R-squared:  0.9619,	Adjusted R-squared:  0.9447
# F-statistic: 56.08 on 9 and 20 DF,  p-value: 3.132e-12
#
# [1] "1 I(c * b)"
# [1] "2 I(c * h)"
# [1] "3 c"
# [1] "4 I(b^4)"
# [1] "5 I(b^3)"
#
# Call:
# lm(formula = X29 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.018251 -0.004177 -0.001514  0.001581  0.034885
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.014006   0.008376   1.672  0.10697
# b           -0.005282   0.014983  -0.353  0.72739
# I(b^2)      -0.010437   0.010490  -0.995  0.32926
# h            0.046164   0.013197   3.498  0.00177 **
# I(h * b)    -0.032789   0.018341  -1.788  0.08594 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.009141 on 25 degrees of freedom
# Multiple R-squared:  0.815,	Adjusted R-squared:  0.7854
# F-statistic: 27.53 on 4 and 25 DF,  p-value: 7.731e-09
#
# [1] "Max reduction is 0.00510454422935634 using h"
# [1] "Max reduction is 0.00439595496719032 using b"
# [1] "Max reduction is 0.00520580296361075 using b"
# [1] "Max reduction is 0.000674635514142258 using b"
# [1] "Max reduction is 0.000204978912580884 using b"
# [1] "Max reduction is 0.00143731956144318 using Three Way Interactions with b"
# [1] "Max reduction is 0.000399363350801369 using b"
# [1] "Max reduction is 0.000408432324224288 using b"
# [1] "Max reduction is 0.000315267013794553 using h"
# [1] "Max reduction is 0.000607042476759407 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X30 ~ h + I(h^2) + I(h^3) + b + I(b^2) + I(b^3) +
#     I(b^4) + I(b^5) + I(b^6) + I(b * h) + I(b * b * h), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.010398 -0.004961  0.000231  0.003431  0.011855
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.14006    0.05239  -2.674  0.01550 *
# h             0.68497    0.28469   2.406  0.02709 *
# I(h^2)       -0.84204    0.45649  -1.845  0.08162 .
# I(h^3)        0.51340    0.24594   2.087  0.05133 .
# b             0.10837    0.04427   2.448  0.02483 *
# I(b^2)        0.16681    0.20840   0.800  0.43391
# I(b^3)       -1.89894    0.51210  -3.708  0.00161 **
# I(b^4)        1.35382    0.55489   2.440  0.02527 *
# I(b^5)        2.71540    1.35287   2.007  0.05999 .
# I(b^6)       -2.38826    0.83796  -2.850  0.01063 *
# I(b * h)      0.35806    0.06450   5.551 2.86e-05 ***
# I(b * b * h) -0.58636    0.11436  -5.127 7.06e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.007161 on 18 degrees of freedom
# Multiple R-squared:  0.9526,	Adjusted R-squared:  0.9236
# F-statistic: 32.89 on 11 and 18 DF,  p-value: 1.207e-09
#
# [1] "1 I(b^6)"
# [1] "2 I(b^5)"
# [1] "3 I(b^4)"
# [1] "4 I(b * b * h)"
# [1] "5 I(b * h)"
# [1] "6 I(b^3)"
# [1] "7 I(h^3)"
#
# Call:
# lm(formula = X30 ~ h + I(h^2) + b + I(b^2), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0263034 -0.0039174 -0.0007846  0.0047408  0.0289899
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.003330   0.020196   0.165    0.870
# h            0.074005   0.070640   1.048    0.305
# I(h^2)       0.044958   0.060691   0.741    0.466
# b            0.066164   0.008419   7.859 3.24e-08 ***
# I(b^2)      -0.079007   0.013316  -5.933 3.41e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01133 on 25 degrees of freedom
# Multiple R-squared:  0.8351,	Adjusted R-squared:  0.8087
# F-statistic: 31.65 on 4 and 25 DF,  p-value: 1.879e-09

# %%
tLOOs <- LOO.plot(Emulators = em_wave3, which.emulator = 12, ParamNames = cands)
# Out:
# Plot with title “”

# %% [markdown]
# ### Compute implausibility

# %%
sample_size <- 100000
nparam <- length(names(em_wave3$fitting.elements$Design))
Xp_wave3 <- as.data.frame(2*randomLHS(sample_size, nparam)-1)
names(Xp_wave3) <- names(em_wave3$fitting.elements$Design)
system.time(Timps_wave3 <- ImplausibilityMOGP(NewData=Xp_wave3, Emulator=em_wave3, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))
# Out:
#    user  system elapsed
#  17.130   3.370   3.733

# %%
valmax = 2 #how many outputs can be above the implausibility cut off
cutoff <- 3 #the implausibility cut off

# %%
NROY3 <- which(rowSums(Timps_wave3 <= cutoff) >= em_wave3$mogp$n_emulators -valmax)
scoreNROY3 <- length(NROY3)/dim(Xp_wave3)[1]

# %% [markdown]
# ### Layout of NROY space

# %%
ImpData_wave3 = cbind(Xp_wave3, Timps_wave3)
ImpListM3 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave3, nEms=em_wave3$mogp$n_emulators, whichMax=valmax+1)
imp.layoutm11(ImpListM3,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",scoreNROY3,sep=""), side=1)
# Out:
# plot without title

# %% [markdown]
# ## Fourth Wave

# %%
n <- ceiling(n_samples*4/scoreNROY3)

# %%
inputs_wave4_scaled_temp <- np$array(lhs$generate(space$dimensions, as.integer(n), random_state=as.integer(42)))

# %%
emulators <- list(em_wave1, em_wave2, em_wave3)
NROY_temp_wave4 <- parameters_space(emulators, inputs_wave4_scaled_temp, 30)

# %%
input_wave4_scaled <- inputs_wave4_scaled_temp[sample(NROY_temp_wave4, n_samples),]
input_wave4 <- rangeUnscale(input_wave4_scaled, my_bounds, range = c(-1, 1))

# %%
par(mfrow=c(2,2))
plot(input_wave4[,1], input_wave4[,2], xlab="h", ylab="c", xlim=c(-2,2), ylim=c(0,20))
points(1, 10, col='red', pch=18, cex=2)
plot(input_wave4[,1], input_wave4[,3], xlab="h", ylab="b", xlim=c(-2,2), ylim=c(-20,20))
points(1, 10, col='red', pch=18, cex=2)
plot(input_wave4[,2], input_wave4[,3], xlab="c", ylab="b", xlim=c(0,20), ylim=c(-20,20))
points(10, 10, col='red', pch=18, cex=2)
# Out:
# plot without title

# %%
metrics_wave4 = future_sapply(1:nrow(input_wave4), function(r) extract_metrics_AMIP(input_wave4[r,], n_iter, 0.001, X_hist), future.seed=NULL)

# %% [markdown]
# ### Create the data matrix

# %%
input_wave4_scaled <- data.frame(input_wave4_scaled)
names(input_wave4_scaled) <- c('h', 'c', 'b')


metrics_k_wave4 <- data.frame(t(metrics_wave4)[, metrics_index_k])
N = nrow(metrics_k_wave4) 
noise <- rnorm(N, 0, 0)
tData_wave4 <- data.frame(cbind(input_wave4_scaled, noise, metrics_k_wave4))
names(tData_wave4)[names(tData_wave4) == "noise"] <- "Noise"
         
head(tData_wave4)
# Out:
#   h         c          b         Noise X1         X2         X3
# 1 0.5125691  0.2983555 0.5036975 0     0.10641687 0.08891493 0.10676659
# 2 0.3831185 -0.6286202 0.4118371 0     0.09474141 0.13337213 0.13695590
# 3 0.3881903 -0.2677288 0.2428862 0     0.15131920 0.15886096 0.15811395
# 4 0.3288121  0.8796062 0.4669828 0     0.10886160 0.08440269 0.08643478
# 5 0.7653954 -0.2829753 0.5340643 0     0.10537084 0.10301892 0.13228769
# 6 0.4695863 -0.5347124 0.3531175 0     0.13830389 0.14244328 0.15317089
#   X4        X5         X6         ⋯ X56        X57        X58
# 1 0.1181666 0.10445329 0.10843071 ⋯ 0.07238095 0.02959019 0.005740267
# 2 0.1307762 0.09378861 0.13317199 ⋯ 0.05205572 0.03029614 0.021995861
# 3 0.1624435 0.11931373 0.14317511 ⋯ 0.07267445 0.05019273 0.042610543
# 4 0.1072499 0.09548127 0.07266489 ⋯ 0.03841884 0.02351667 0.008888847
# 5 0.1427311 0.11194454 0.11018134 ⋯ 0.12150794 0.03324402 0.002337051
# 6 0.1316076 0.08730770 0.17371519 ⋯ 0.07683569 0.04152692 0.031653256
#   X59        X60        X61        X62          X63        X64
# 1 0.02229359 0.06194760 0.01737908  0.008521716 0.04796978 0.02215594
# 2 0.02225675 0.03927216 0.02687263  0.015396699 0.05894113 0.03566301
# 3 0.05747622 0.06424324 0.04788769  0.039965424 0.06962987 0.05186433
# 4 0.01806240 0.03604708 0.01646690  0.011681712 0.02894494 0.01644853
# 5 0.02676369 0.08904866 0.02579678 -0.005363713 0.09003254 0.02737691
# 6 0.04467859 0.05516258 0.04041540  0.025436663 0.09425884 0.04679542
#   X65
# 1 0.06310514
# 2 0.05067344
# 3 0.07455951
# 4 0.04040079
# 5 0.10649477
# 6 0.07804129

# %% [markdown]
# ### Training emulator

# %%
em_wave4 <- BuildNewEmulators(tData_wave4, HowManyEmulators = ncol(metrics_wave4), meanFun = "fitted", additionalVariables = cands) #
# Out:
# [1] "Max reduction is 0.00395856653100607 using b"
# [1] "Max reduction is 0.00385076462978739 using h"
# [1] "Max reduction is 0.000674473965002417 using c"
# [1] "Max reduction is 0.000395408651699602 using c"
# [1] "Max reduction is 0.00291877786975382 using Three Way Interactions with c"
# [1] "Max reduction is 7.13415241465065e-05 using c"
# [1] "Max reduction is 0.00124990962532854 using c"
# [1] "Max reduction is 0.000407478606604266 using c"
# [1] "Max reduction is 0.00105439398680141 using c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X1 ~ b + h + c + I(c^2) + I(c^3) + I(c^4) + I(c^5) +
#     I(c^6) + I(h * b) + I(c * b) + I(c * h) + I(c * h * b) +
#     I(c * c * b) + I(c * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0163242 -0.0031181 -0.0009034  0.0044905  0.0128734
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.03383    0.07103  -0.476  0.64074
# b             0.25533    0.15697   1.627  0.12465
# h             0.64798    0.18914   3.426  0.00375 **
# c             0.36706    0.14072   2.608  0.01976 *
# I(c^2)       -0.40715    0.11125  -3.660  0.00232 **
# I(c^3)        0.11092    0.07349   1.509  0.15196
# I(c^4)        0.53083    0.20012   2.653  0.01810 *
# I(c^5)       -0.08522    0.06710  -1.270  0.22339
# I(c^6)       -0.32155    0.14785  -2.175  0.04605 *
# I(h * b)     -1.17713    0.37705  -3.122  0.00700 **
# I(c * b)     -0.79955    0.31587  -2.531  0.02304 *
# I(c * h)     -0.86629    0.28301  -3.061  0.00792 **
# I(c * h * b)  1.72265    0.61439   2.804  0.01336 *
# I(c * c * b)  0.23605    0.16423   1.437  0.17118
# I(c * c * h)  0.18243    0.09113   2.002  0.06372 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.009545 on 15 degrees of freedom
# Multiple R-squared:  0.919,	Adjusted R-squared:  0.8435
# F-statistic: 12.16 on 14 and 15 DF,  p-value: 9.514e-06
#
# [1] "1 I(c * c * b)"
# [1] "2 I(c * b)"
# [1] "3 I(c * h * b)"
# [1] "4 I(c * c * h)"
# [1] "5 I(c * h)"
# [1] "6 I(c^6)"
# [1] "7 I(c^5)"
# [1] "8 I(c^4)"
# [1] "9 I(h * b)"
# [1] "10 I(c^3)"
#
# Call:
# lm(formula = X1 ~ b + h + c + I(c^2), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.031646 -0.004112  0.002153  0.007487  0.034837
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.150807   0.013666  11.035 4.23e-11 ***
# b           -0.219969   0.036800  -5.978 3.05e-06 ***
# h            0.117876   0.031217   3.776 0.000879 ***
# c           -0.004738   0.005039  -0.940 0.356101
# I(c^2)       0.028188   0.009300   3.031 0.005605 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01541 on 25 degrees of freedom
# Multiple R-squared:  0.6483,	Adjusted R-squared:  0.592
# F-statistic: 11.52 on 4 and 25 DF,  p-value: 1.933e-05
#
# [1] "Max reduction is 0.00547195020485905 using b"
# [1] "Max reduction is 0.00428686220580338 using c"
# [1] "Max reduction is 0.0031479969945273 using h"
# [1] "Max reduction is 0.00151147349121552 using b"
# [1] "Max reduction is 0.000928077040886394 using c"
# [1] "Max reduction is 0.000624216869907745 using c"
# [1] "Max reduction is 0.000493833235743859 using Three Way Interactions with b"
# [1] "Max reduction is 5.64862107867523e-05 using Three Way Interactions with c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X2 ~ b + I(b^2) + c + I(c^2) + I(c^3) + h + I(c *
#     b) + I(h * b) + I(h * c) + I(b * c * b) + I(b * h * b) +
#     I(b * h * c) + I(c * c * b) + I(c * h * c), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0152348 -0.0026198  0.0002358  0.0041970  0.0102917
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.03340    0.31761  -0.105   0.9176
# b             0.50216    1.56266   0.321   0.7524
# I(b^2)       -0.48592    1.92399  -0.253   0.8040
# c            -0.03494    0.20543  -0.170   0.8672
# I(c^2)        0.08990    0.07479   1.202   0.2480
# I(c^3)       -0.03720    0.01731  -2.149   0.0484 *
# h             0.95639    0.79652   1.201   0.2485
# I(c * b)     -0.49837    0.78756  -0.633   0.5364
# I(h * b)     -3.97610    3.72512  -1.067   0.3027
# I(h * c)      0.45228    0.49634   0.911   0.3766
# I(b * c * b)  1.26617    1.10231   1.149   0.2687
# I(b * h * b)  4.12747    4.34041   0.951   0.3567
# I(b * h * c) -0.97683    1.12422  -0.869   0.3986
# I(c * c * b) -0.23539    0.16859  -1.396   0.1830
# I(c * h * c)  0.09531    0.09805   0.972   0.3464
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.008944 on 15 degrees of freedom
# Multiple R-squared:  0.9354,	Adjusted R-squared:  0.8751
# F-statistic: 15.52 on 14 and 15 DF,  p-value: 1.917e-06
#
# [1] "1 I(b * h * c)"
# [1] "2 I(c * h * c)"
# [1] "3 I(h * c)"
# [1] "4 I(c * c * b)"
# [1] "5 I(b * c * b)"
# [1] "6 I(b * h * b)"
# [1] "7 I(h * b)"
# [1] "8 I(c^3)"
# [1] "9 I(b^2)"
# [1] "10 I(c^2)"
#
# Call:
# lm(formula = X2 ~ b + c + h + I(c * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0242108 -0.0053665  0.0009969  0.0077379  0.0264774
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.16697    0.01097  15.221 3.77e-14 ***
# b           -0.22403    0.03013  -7.436 8.67e-08 ***
# c           -0.03608    0.01923  -1.876 0.072355 .
# h            0.09880    0.02550   3.874 0.000684 ***
# I(c * b)     0.04449    0.04647   0.957 0.347609
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01254 on 25 degrees of freedom
# Multiple R-squared:  0.7885,	Adjusted R-squared:  0.7547
# F-statistic:  23.3 on 4 and 25 DF,  p-value: 3.997e-08
#
# [1] "Max reduction is 0.00748299619215681 using c"
# [1] "Max reduction is 0.00407400596121828 using b"
# [1] "Max reduction is 0.00634987314237435 using h"
# [1] "Max reduction is 0.000839395089228548 using c"
# [1] "Max reduction is 0.00175032431195318 using Three Way Interactions with c"
# [1] "Max reduction is 0.00128758732527748 using b"
# [1] "Max reduction is 0.000799753999577319 using Three Way Interactions with b"
# [1] "Max reduction is 0.000168957050557628 using h"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X3 ~ c + I(c^2) + b + I(b^2) + h + I(h^2) + I(b *
#     c) + I(h * c) + I(h * b) + I(c * b * c) + I(c * h * c) +
#     I(c * h * b) + I(b * b * c) + I(b * h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0096401 -0.0047862 -0.0008843  0.0026387  0.0198577
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.31244    0.33131   0.943 0.360594
# c            -0.20933    0.19757  -1.060 0.306126
# I(c^2)        0.01468    0.06138   0.239 0.814192
# b            -1.27411    1.60967  -0.792 0.440970
# I(b^2)        1.50513    2.07331   0.726 0.479040
# h             0.28643    0.87535   0.327 0.748026
# I(h^2)       -0.41702    0.32702  -1.275 0.221630
# I(b * c)     -0.23477    0.76930  -0.305 0.764427
# I(h * c)      1.04596    0.47033   2.224 0.041936 *
# I(h * b)      0.07484    3.80464   0.020 0.984565
# I(c * b * c) -0.44181    0.16024  -2.757 0.014672 *
# I(c * h * c)  0.46309    0.09265   4.998 0.000159 ***
# I(c * h * b) -2.96426    1.08892  -2.722 0.015741 *
# I(b * b * c)  2.01853    1.06976   1.887 0.078682 .
# I(b * h * b)  0.04710    4.67983   0.010 0.992103
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.008718 on 15 degrees of freedom
# Multiple R-squared:  0.9603,	Adjusted R-squared:  0.9233
# F-statistic: 25.92 on 14 and 15 DF,  p-value: 5.707e-08
#
# [1] "1 I(b * h * b)"
# [1] "2 I(c * b * c)"
# [1] "3 I(h^2)"
# [1] "4 I(c * h * b)"
# [1] "5 I(h * b)"
# [1] "6 I(b * b * c)"
# [1] "7 I(b * c)"
# [1] "8 I(b^2)"
# [1] "9 I(c^2)"
# [1] "10 I(c * h * c)"
#
# Call:
# lm(formula = X3 ~ c + b + h + I(h * c), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.024537 -0.009078  0.001000  0.004950  0.053449
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.15881    0.01312  12.105 5.95e-12 ***
# c            0.01425    0.02228   0.640 0.528059
# b           -0.22177    0.03617  -6.131 2.07e-06 ***
# h            0.12936    0.03013   4.294 0.000232 ***
# I(h * c)    -0.09919    0.05062  -1.959 0.061306 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01489 on 25 degrees of freedom
# Multiple R-squared:  0.807,	Adjusted R-squared:  0.7761
# F-statistic: 26.13 on 4 and 25 DF,  p-value: 1.305e-08
#
# [1] "Max reduction is 0.00254690319446379 using c"
# [1] "Max reduction is 0.0024655006244028 using b"
# [1] "Max reduction is 0.00566952519129454 using h"
# [1] "Max reduction is 0.00163302554013556 using c"
# [1] "Max reduction is 0.00184522320519988 using Three Way Interactions with c"
# [1] "Max reduction is 0.000683491405507403 using b"
# [1] "Max reduction is 0.000677280018755907 using b"
# [1] "Max reduction is 0.000332694647419403 using b"
# [1] "Max reduction is 0.000129358905107069 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X4 ~ c + I(c^2) + b + I(b^2) + I(b^3) + I(b^4) +
#     I(b^5) + h + I(b * c) + I(h * c) + I(h * b) + I(c * b * c) +
#     I(c * h * c) + I(c * h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0123276 -0.0029328  0.0001656  0.0045909  0.0089941
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -1.37970    1.23309  -1.119 0.280784
# c              -0.26557    0.11057  -2.402 0.029720 *
# I(c^2)          0.02089    0.05050   0.414 0.684978
# b              25.35425   18.18467   1.394 0.183547
# I(b^2)       -149.89946  105.14062  -1.426 0.174432
# I(b^3)        412.13024  296.28004   1.391 0.184511
# I(b^4)       -539.77181  407.29149  -1.325 0.204914
# I(b^5)        271.48564  219.10123   1.239 0.234352
# h              -0.28132    0.15783  -1.782 0.094928 .
# I(b * c)        0.62974    0.24552   2.565 0.021551 *
# I(h * c)        0.34820    0.23746   1.466 0.163205
# I(h * b)        0.66889    0.34329   1.948 0.070315 .
# I(c * b * c)   -0.33161    0.13223  -2.508 0.024133 *
# I(c * h * c)    0.36163    0.08010   4.515 0.000411 ***
# I(c * h * b)   -0.92191    0.53105  -1.736 0.103049
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.007797 on 15 degrees of freedom
# Multiple R-squared:  0.9444,	Adjusted R-squared:  0.8925
# F-statistic:  18.2 on 14 and 15 DF,  p-value: 6.551e-07
#
# [1] "1 I(c * b * c)"
# [1] "2 I(c * h * b)"
# [1] "3 I(b^5)"
# [1] "4 I(b^4)"
# [1] "5 I(b^3)"
# [1] "6 I(h * b)"
# [1] "7 I(b^2)"
# [1] "8 I(c^2)"
# [1] "9 I(b * c)"
# [1] "10 I(c * h * c)"
#
# Call:
# lm(formula = X4 ~ c + b + h + I(h * c), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.023450 -0.006954 -0.001844  0.004947  0.046876
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.151108   0.012629  11.966 7.64e-12 ***
# c           -0.011837   0.021443  -0.552    0.586
# b           -0.196778   0.034820  -5.651 6.98e-06 ***
# h            0.141168   0.029000   4.868 5.25e-05 ***
# I(h * c)    -0.003247   0.048731  -0.067    0.947
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01434 on 25 degrees of freedom
# Multiple R-squared:  0.6867,	Adjusted R-squared:  0.6365
# F-statistic:  13.7 on 4 and 25 DF,  p-value: 4.804e-06
#
# [1] "Max reduction is 0.000603310620286689 using h"
# [1] "Max reduction is 0.00210075555956636 using b"
# [1] "Max reduction is 0.000307805869283615 using h"
# [1] "Max reduction is 0.000577276312937887 using c"
# [1] "Max reduction is 0.000603543712547859 using Three Way Interactions with h"
# [1] "Max reduction is 0.0018054824647477 using h"
# [1] "Max reduction is 0.00199386380851283 using b"
# [1] "Max reduction is 0.000314875727971665 using c"
# [1] "Max reduction is 0.00156337981823738 using c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X5 ~ h + I(h^2) + I(h^3) + b + I(b^2) + c + I(c^2) +
#     I(c^3) + I(b * h) + I(c * h) + I(c * b) + I(h * b * h) +
#     I(h * c * h) + I(h * c * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.019150 -0.003423  0.001149  0.005110  0.008680
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.354675   0.366673   0.967  0.34874
# h            -1.539522   1.783273  -0.863  0.40156
# I(h^2)        5.742589   2.763164   2.078  0.05527 .
# I(h^3)       -6.003608   2.095597  -2.865  0.01181 *
# b             0.226850   0.950595   0.239  0.81461
# I(b^2)        0.717839   0.365016   1.967  0.06801 .
# c            -0.313331   0.168021  -1.865  0.08189 .
# I(c^2)        0.023818   0.009778   2.436  0.02780 *
# I(c^3)       -0.050339   0.018883  -2.666  0.01762 *
# I(b * h)     -4.636040   4.225971  -1.097  0.28993
# I(c * h)      2.037175   0.568066   3.586  0.00270 **
# I(c * b)     -0.256835   0.458023  -0.561  0.58325
# I(h * b * h)  5.624059   5.234280   1.074  0.29959
# I(h * c * h) -2.618699   0.777271  -3.369  0.00422 **
# I(h * c * b)  0.411690   1.082428   0.380  0.70903
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.008911 on 15 degrees of freedom
# Multiple R-squared:  0.8836,	Adjusted R-squared:  0.7749
# F-statistic: 8.131 on 14 and 15 DF,  p-value: 0.0001184
#
# [1] "1 I(h * b * h)"
# [1] "2 I(h * c * b)"
# [1] "3 I(c * b)"
# [1] "4 I(b * h)"
# [1] "5 I(b^2)"
# [1] "6 I(h * c * h)"
# [1] "7 I(c * h)"
# [1] "8 I(h^3)"
# [1] "9 I(h^2)"
# [1] "10 h"
#
# Call:
# lm(formula = X5 ~ b + c + I(c^2) + I(c^3), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.030840 -0.010140 -0.000071  0.005429  0.032978
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.152557   0.015019  10.157 2.34e-10 ***
# b           -0.102465   0.035142  -2.916  0.00739 **
# c            0.044373   0.014074   3.153  0.00417 **
# I(c^2)       0.014999   0.009535   1.573  0.12829
# I(c^3)      -0.071072   0.020473  -3.471  0.00190 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01581 on 25 degrees of freedom
# Multiple R-squared:  0.3892,	Adjusted R-squared:  0.2915
# F-statistic: 3.982 on 4 and 25 DF,  p-value: 0.01236
#
# [1] "Max reduction is 0.00888110165223249 using c"
# [1] "Max reduction is 0.00366249637559252 using b"
# [1] "Max reduction is 0.00297700550735305 using h"
# [1] "Max reduction is 0.000727508828269819 using c"
# [1] "Max reduction is 0.00271141458166822 using Three Way Interactions with c"
# [1] "Max reduction is 0.000561639866463647 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X6 ~ c + I(c^2) + I(c^3) + b + h + I(b * c) + I(h *
#     c) + I(h * b) + I(c * b * c) + I(c * h * c) + I(c * h * b),
#     data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0199763 -0.0030492 -0.0001671  0.0055714  0.0146912
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.041503   0.069877  -0.594  0.55994
# c             0.261888   0.128893   2.032  0.05720 .
# I(c^2)       -0.009876   0.076125  -0.130  0.89822
# I(c^3)        0.034297   0.019309   1.776  0.09260 .
# b             0.170255   0.151392   1.125  0.27553
# h             0.562553   0.185682   3.030  0.00720 **
# I(b * c)     -0.736936   0.292882  -2.516  0.02157 *
# I(h * c)     -0.791134   0.279953  -2.826  0.01120 *
# I(h * b)     -0.884023   0.371835  -2.377  0.02872 *
# I(c * b * c)  0.154237   0.131941   1.169  0.25766
# I(c * h * c) -0.121138   0.091172  -1.329  0.20056
# I(c * h * b)  1.837649   0.597414   3.076  0.00651 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01018 on 18 degrees of freedom
# Multiple R-squared:  0.9271,	Adjusted R-squared:  0.8826
# F-statistic: 20.81 on 11 and 18 DF,  p-value: 5.205e-08
#
# [1] "1 I(c * h * c)"
# [1] "2 I(h * c)"
# [1] "3 I(c * h * b)"
# [1] "4 I(h * b)"
# [1] "5 I(c * b * c)"
# [1] "6 I(b * c)"
# [1] "7 b"
#
# Call:
# lm(formula = X6 ~ c + I(c^2) + I(c^3) + h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.029100 -0.012188 -0.002157  0.012130  0.041164
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.09786    0.01488   6.578 6.84e-07 ***
# c           -0.07532    0.01453  -5.183 2.32e-05 ***
# I(c^2)       0.01522    0.01124   1.354  0.18776
# I(c^3)       0.06013    0.02139   2.811  0.00946 **
# h            0.02494    0.03115   0.801  0.43095
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01862 on 25 degrees of freedom
# Multiple R-squared:  0.661,	Adjusted R-squared:  0.6068
# F-statistic: 12.19 on 4 and 25 DF,  p-value: 1.241e-05
#
# [1] "Max reduction is 0.00273887159796742 using b"
# [1] "Max reduction is 0.00434848417397703 using h"
# [1] "Max reduction is 0.000862249312607605 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X7 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0141596 -0.0077642  0.0006596  0.0052829  0.0273183
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.12847    0.03335   3.852 0.000724 ***
# b           -0.40132    0.15300  -2.623 0.014637 *
# I(b^2)       0.62987    0.26708   2.358 0.026487 *
# h            0.36735    0.10074   3.646 0.001221 **
# I(h * b)    -0.60095    0.22758  -2.641 0.014057 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01024 on 25 degrees of freedom
# Multiple R-squared:  0.7267,	Adjusted R-squared:  0.683
# F-statistic: 16.62 on 4 and 25 DF,  p-value: 9.146e-07
#
# [1] "Max reduction is 0.00318806761510656 using b"
# [1] "Max reduction is 0.00815168150045069 using h"
# [1] "Max reduction is 0.000145653564990333 using b"
# [1] "Max reduction is 0.00020094161897094 using h"
# [1] "Max reduction is 9.16284984611646e-05 using Three Way Interactions with h"
# [1] "Max reduction is 0.000402420495894442 using c"
# [1] "Max reduction is 9.43970675272455e-05 using Three Way Interactions with b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X8 ~ b + I(b^2) + h + I(h^2) + c + I(h * b) + I(c *
#     b) + I(c * h) + I(h * h * b) + I(h * c * b) + I(h * c * h) +
#     I(b * h * b) + I(b * c * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0107609 -0.0045769  0.0008118  0.0027937  0.0118507
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    0.7484     0.3144   2.380   0.0301 *
# b             -2.3038     1.3859  -1.662   0.1159
# I(b^2)         1.9886     2.1425   0.928   0.3671
# h             -2.3040     1.3908  -1.657   0.1171
# I(h^2)         2.5993     2.1430   1.213   0.2428
# c             -0.3176     0.1194  -2.661   0.0171 *
# I(h * b)       6.3942     3.3386   1.915   0.0735 .
# I(c * b)       1.1715     0.5666   2.068   0.0552 .
# I(c * h)       0.3971     0.4471   0.888   0.3876
# I(h * h * b)  -4.9251     4.3277  -1.138   0.2719
# I(h * c * b)   0.2639     1.2931   0.204   0.8408
# I(h * c * h)  -0.6387     0.5628  -1.135   0.2731
# I(b * h * b)  -3.6948     5.2663  -0.702   0.4930
# I(b * c * b)  -1.5094     1.0194  -1.481   0.1581
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.008212 on 16 degrees of freedom
# Multiple R-squared:  0.9108,	Adjusted R-squared:  0.8383
# F-statistic: 12.56 on 13 and 16 DF,  p-value: 5.08e-06
#
# [1] "1 I(b * h * b)"
# [1] "2 I(h * h * b)"
# [1] "3 I(h * c * b)"
# [1] "4 I(b * c * b)"
# [1] "5 I(c * b)"
# [1] "6 I(b^2)"
# [1] "7 I(h * c * h)"
# [1] "8 I(c * h)"
# [1] "9 c"
#
# Call:
# lm(formula = X8 ~ b + h + I(h^2) + I(h * b), data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.021999 -0.005346 -0.001276  0.007340  0.015778
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03953    0.02923   1.352 0.188345
# b            0.07467    0.10716   0.697 0.492350
# h            0.36393    0.08419   4.323 0.000215 ***
# I(h^2)       0.11743    0.14718   0.798 0.432446
# I(h * b)    -0.72552    0.26274  -2.761 0.010629 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.009145 on 25 degrees of freedom
# Multiple R-squared:  0.8271,	Adjusted R-squared:  0.7994
# F-statistic:  29.9 on 4 and 25 DF,  p-value: 3.363e-09
#
# [1] "Max reduction is 0.00434860081350074 using b"
# [1] "Max reduction is 0.00640619513417353 using h"
# [1] "Max reduction is 0.00153646223163391 using c"
# [1] "Max reduction is 0.000853828531982279 using h"
# [1] "Max reduction is 0.000169491339305789 using b"
# [1] "Max reduction is 0.000264464345103318 using b"
# [1] "Max reduction is 0.000505458178401946 using b"
# [1] "Max reduction is 5.56600645293549e-05 using b"
# [1] "Max reduction is 0.000341538766995666 using Three Way Interactions with b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X9 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + h +
#     I(h^2) + c + I(h * b) + I(c * b) + I(c * h) + I(b * h * b) +
#     I(b * c * b) + I(b * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0221220 -0.0059676  0.0002233  0.0065999  0.0278361
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)   6.612e-04  2.452e+00   0.000    1.000
# b             1.414e+01  3.274e+01   0.432    0.672
# I(b^2)       -1.329e+02  1.861e+02  -0.714    0.486
# I(b^3)        4.802e+02  5.274e+02   0.911    0.377
# I(b^4)       -7.891e+02  7.340e+02  -1.075    0.299
# I(b^5)        4.974e+02  4.027e+02   1.235    0.236
# h            -1.737e+00  2.345e+00  -0.740    0.470
# I(h^2)       -1.663e-01  6.366e-01  -0.261    0.797
# c            -2.917e-01  2.990e-01  -0.976    0.345
# I(h * b)      1.115e+01  1.052e+01   1.059    0.306
# I(c * b)      1.210e+00  1.274e+00   0.950    0.357
# I(c * h)      1.491e-01  6.702e-01   0.222    0.827
# I(b * h * b) -1.481e+01  1.338e+01  -1.106    0.286
# I(b * c * b) -1.098e+00  1.773e+00  -0.619    0.545
# I(b * c * h) -5.389e-01  1.537e+00  -0.351    0.731
#
# Residual standard error: 0.01381 on 15 degrees of freedom
# Multiple R-squared:  0.8674,	Adjusted R-squared:  0.7436
# F-statistic: 7.009 on 14 and 15 DF,  p-value: 0.0002854
#
# [1] "1 I(b * c * h)"
# [1] "2 I(b * h * b)"
# [1] "3 I(b * c * b)"
# [1] "4 I(c * b)"
# [1] "5 I(b^5)"
# [1] "6 I(h * b)"
# [1] "7 I(c * h)"
# [1] "8 I(b^4)"
# [1] "9 I(h^2)"
# [1] "10 I(b^3)"
#
# Call:
# lm(formula = X9 ~ b + I(b^2) + h + c, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.035212 -0.010337  0.002114  0.011412  0.028794
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.190561   0.043557   4.375 0.000188 ***
# b           -0.336440   0.220776  -1.524 0.140086
# I(b^2)       0.125972   0.300662   0.419 0.678807
# h            0.140564   0.032940   4.267 0.000249 ***
# c           -0.015645   0.004875  -3.210 0.003630 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01511 on 25 degrees of freedom
# Multiple R-squared:  0.7355,	Adjusted R-squared:  0.6932
# F-statistic: 17.38 on 4 and 25 DF,  p-value: 6.14e-07
#
# [1] "Max reduction is 0.00443258851079007 using c"
# [1] "Max reduction is 0.00195596513873262 using c"
# [1] "Max reduction is 0.00235557395263916 using b"
# [1] "Max reduction is 0.00228056218588991 using b"
# [1] "Max reduction is 0.00225000114896584 using c"
# [1] "Max reduction is 0.00132854679189262 using h"
# [1] "Max reduction is 0.000569515108303534 using Three Way Interactions with c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X10 ~ c + I(c^2) + I(c^3) + b + I(b^2) + h + I(b *
#     c) + I(h * c) + I(h * b) + I(c * b * c) + I(c * h * c) +
#     I(c * h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0157572 -0.0036037  0.0000909  0.0037283  0.0113054
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.21826    0.07010   3.113  0.00632 **
# c             0.08694    0.13068   0.665  0.51478
# I(c^2)       -0.07641    0.06815  -1.121  0.27776
# I(c^3)       -0.02983    0.01638  -1.821  0.08629 .
# b            -0.66023    0.25768  -2.562  0.02020 *
# I(b^2)        0.73624    0.38337   1.920  0.07174 .
# h             0.08761    0.15693   0.558  0.58392
# I(b * c)     -0.17006    0.29661  -0.573  0.57392
# I(h * c)     -0.22172    0.28501  -0.778  0.44730
# I(h * b)     -0.15245    0.32326  -0.472  0.64321
# I(c * b * c)  0.05731    0.15037   0.381  0.70782
# I(c * h * c)  0.19413    0.09402   2.065  0.05453 .
# I(c * h * b)  0.42143    0.62473   0.675  0.50901
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.008601 on 17 degrees of freedom
# Multiple R-squared:  0.9233,	Adjusted R-squared:  0.8691
# F-statistic: 17.05 on 12 and 17 DF,  p-value: 3.762e-07
#
# [1] "1 I(c * b * c)"
# [1] "2 I(c * h * b)"
# [1] "3 I(h * b)"
# [1] "4 I(c^3)"
# [1] "5 I(b * c)"
# [1] "6 I(b^2)"
# [1] "7 I(c * h * c)"
# [1] "8 I(h * c)"
#
# Call:
# lm(formula = X10 ~ c + I(c^2) + b + h, data = tData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.021823 -0.007028 -0.002291  0.009321  0.023054
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.115056   0.011604   9.915 3.81e-10 ***
# c           -0.023885   0.004279  -5.582 8.33e-06 ***
# I(c^2)       0.030057   0.007897   3.806 0.000814 ***
# b           -0.148658   0.031249  -4.757 6.99e-05 ***
# h            0.078557   0.026509   2.963 0.006591 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01309 on 25 degrees of freedom
# Multiple R-squared:  0.7388,	Adjusted R-squared:  0.697
# F-statistic: 17.68 on 4 and 25 DF,  p-value: 5.268e-07
#
# [1] "Max reduction is 0.00580229264769927 using h"
# [1] "Max reduction is 0.005007603181183 using b"
# [1] "Max reduction is 0.00341933621430866 using c"
# [1] "Max reduction is 0.00147112347509066 using c"
# [1] "Max reduction is 0.00252455468785454 using c"
# [1] "Max reduction is 0.00125868949195408 using Three Way Interactions with c"
# [1] "Max reduction is 0.000503582021812988 using h"
# [1] "Max reduction is 0.000386200961610197 using b"
# [1] "Max reduction is 0.000240473316480981 using Three Way Interactions with b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X11 ~ h + I(h^2) + b + I(b^2) + c + I(c^2) + I(c^3) +
#     I(b * h) + I(c * h) + I(c * b) + I(c * b * h) + I(c * c *
#     h) + I(c * c * b) + I(b * b * h) + I(b * c * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0051606 -0.0010315  0.0000068  0.0014166  0.0042043
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.389138   0.123125  -3.161 0.006945 **
# h             1.153456   0.329225   3.504 0.003510 **
# I(h^2)        0.257716   0.143945   1.790 0.095035 .
# b             1.746392   0.595385   2.933 0.010902 *
# I(b^2)       -1.940127   0.769114  -2.523 0.024380 *
# c             0.391236   0.074100   5.280 0.000116 ***
# I(c^2)       -0.139900   0.028342  -4.936 0.000219 ***
# I(c^3)        0.042330   0.007429   5.698 5.50e-05 ***
# I(b * h)     -4.111511   1.406618  -2.923 0.011125 *
# I(c * h)     -0.773285   0.179121  -4.317 0.000710 ***
# I(c * b)     -1.062539   0.284061  -3.741 0.002194 **
# I(c * b * h)  1.848354   0.405812   4.555 0.000450 ***
# I(c * c * h) -0.124865   0.040334  -3.096 0.007899 **
# I(c * c * b)  0.373310   0.060697   6.150 2.52e-05 ***
# I(b * b * h)  3.676864   1.737614   2.116 0.052743 .
# I(b * c * b)  0.250486   0.397238   0.631 0.538480
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.003219 on 14 degrees of freedom
# Multiple R-squared:  0.9912,	Adjusted R-squared:  0.9818
# F-statistic:   105 on 15 and 14 DF,  p-value: 9.568e-12
#
# [1] "1 I(b * c * b)"
# [1] "2 I(b^2)"
# [1] "3 I(h^2)"
# [1] "4 I(c * b * h)"
# [1] "5 I(b * b * h)"
# [1] "6 I(c * c * h)"
# [1] "7 I(c * h)"
# [1] "8 I(c * c * b)"
# [1] "9 I(c * b)"
# [1] "10 I(b * h)"
# [1] "11 I(c^3)"
#
# Call:
# lm(formula = X11 ~ h + b + c + I(c^2), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0153474 -0.0041406 -0.0009256  0.0045240  0.0191285
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.050950   0.007420   6.867 3.38e-07 ***
# h            0.225967   0.016949  13.332 7.28e-13 ***
# b           -0.174065   0.019980  -8.712 4.80e-09 ***
# c            0.013849   0.002736   5.062 3.18e-05 ***
# I(c^2)      -0.023404   0.005049  -4.635 9.60e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.008366 on 25 degrees of freedom
# Multiple R-squared:  0.8938,	Adjusted R-squared:  0.8768
# F-statistic: 52.58 on 4 and 25 DF,  p-value: 8.198e-12
#
# [1] "Max reduction is 0.00511989628626442 using b"
# [1] "Max reduction is 0.00461773158862518 using h"
# [1] "Max reduction is 0.00064292564149891 using b"
# [1] "Max reduction is 0.000454276072106381 using h"
# [1] "Max reduction is 0.000205413843135153 using c"
# [1] "Max reduction is 0.000259337996197644 using Three Way Interactions with h"
# [1] "Max reduction is 0.000306479105082579 using Three Way Interactions with b"
# [1] "Max reduction is 0.000194587977991976 using h"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X12 ~ b + I(b^2) + h + I(h^2) + I(h^3) + c + I(h *
#     b) + I(c * b) + I(c * h) + I(h * h * b) + I(h * c * b) +
#     I(h * c * h) + I(b * h * b) + I(b * c * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -1.604e-03 -7.481e-04 -1.246e-05  3.910e-04  2.865e-03
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.063093   0.055321  -1.140 0.271963
# b             0.188912   0.267089   0.707 0.490226
# I(b^2)        0.478575   0.553977   0.864 0.401252
# h             0.584627   0.242825   2.408 0.029385 *
# I(h^2)        0.346420   0.372062   0.931 0.366556
# I(h^3)       -1.023761   0.429333  -2.385 0.030739 *
# c             0.004731   0.021725   0.218 0.830555
# I(h * b)     -2.706918   0.620336  -4.364 0.000556 ***
# I(c * b)     -0.436228   0.099883  -4.367 0.000552 ***
# I(c * h)      0.393174   0.092731   4.240 0.000713 ***
# I(h * h * b)  2.501424   1.461126   1.712 0.107490
# I(h * c * b)  0.083895   0.225816   0.372 0.715447
# I(h * c * h) -0.510233   0.122490  -4.166 0.000829 ***
# I(b * h * b) -0.093349   1.358014  -0.069 0.946105
# I(b * c * b)  0.504970   0.176341   2.864 0.011836 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.00142 on 15 degrees of freedom
# Multiple R-squared:  0.994,	Adjusted R-squared:  0.9885
# F-statistic: 178.4 on 14 and 15 DF,  p-value: 4.615e-14
#
# [1] "1 I(h * h * b)"
# [1] "2 I(h * c * b)"
# [1] "3 I(b * h * b)"
# [1] "4 I(b * c * b)"
# [1] "5 I(h * c * h)"
# [1] "6 I(c * h)"
# [1] "7 I(c * b)"
# [1] "8 c"
# [1] "9 I(b^2)"
# [1] "10 I(h^3)"
#
# Call:
# lm(formula = X12 ~ b + h + I(h^2) + I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0071626 -0.0022956 -0.0000054  0.0015552  0.0101438
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.01552    0.01113   1.394  0.17553
# b           -0.01022    0.04080  -0.250  0.80426
# h            0.18584    0.03205   5.798 4.81e-06 ***
# I(h^2)       0.05527    0.05604   0.986  0.33347
# I(h * b)    -0.36637    0.10004  -3.662  0.00117 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.003482 on 25 degrees of freedom
# Multiple R-squared:  0.9402,	Adjusted R-squared:  0.9306
# F-statistic: 98.22 on 4 and 25 DF,  p-value: 6.557e-15
#
# [1] "Max reduction is 0.00604546811595011 using b"
# [1] "Max reduction is 0.00229021263293224 using c"
# [1] "Max reduction is 0.000699866643831157 using b"
# [1] "Max reduction is 0.000803615305255461 using c"
# [1] "Max reduction is 0.000150336341434793 using b"
# [1] "Max reduction is 0.00016028215300466 using b"
# [1] "Max reduction is 0.000430532399530193 using b"
# [1] "Max reduction is 2.90369829062014e-05 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X13 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + c +
#     I(c^2) + I(c^3) + I(c * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0040817 -0.0011866 -0.0003326  0.0005998  0.0059884
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -7.768e-01  4.411e-01  -1.761 0.093471 .
# b            1.447e+01  6.605e+00   2.190 0.040531 *
# I(b^2)      -9.386e+01  3.836e+01  -2.447 0.023779 *
# I(b^3)       2.855e+02  1.083e+02   2.637 0.015821 *
# I(b^4)      -4.153e+02  1.490e+02  -2.787 0.011372 *
# I(b^5)       2.329e+02  8.008e+01   2.909 0.008682 **
# c           -4.041e-02  6.136e-03  -6.586 2.05e-06 ***
# I(c^2)       8.953e-03  2.202e-03   4.065 0.000604 ***
# I(c^3)      -5.097e-03  4.301e-03  -1.185 0.249860
# I(c * b)     8.003e-02  1.320e-02   6.063 6.32e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.003029 on 20 degrees of freedom
# Multiple R-squared:  0.966,	Adjusted R-squared:  0.9507
# F-statistic: 63.09 on 9 and 20 DF,  p-value: 1.019e-12
#
# [1] "1 I(b^5)"
# [1] "2 I(c^3)"
# [1] "3 I(c^2)"
# [1] "4 I(b^4)"
# [1] "5 I(b^3)"
#
# Call:
# lm(formula = X13 ~ b + I(b^2) + c + I(c * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0061897 -0.0024326 -0.0001693  0.0015401  0.0151422
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.105739   0.012139   8.710 4.81e-09 ***
# b           -0.316243   0.066203  -4.777 6.64e-05 ***
# I(b^2)       0.266935   0.086572   3.083 0.004938 **
# c           -0.026634   0.007148  -3.726 0.000998 ***
# I(c * b)     0.042857   0.017286   2.479 0.020261 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004603 on 25 degrees of freedom
# Multiple R-squared:  0.9018,	Adjusted R-squared:  0.8861
# F-statistic:  57.4 on 4 and 25 DF,  p-value: 3.092e-12
#
# [1] "Max reduction is 0.00401405041377633 using b"
# [1] "Max reduction is 0.00223312895355211 using h"
# [1] "Max reduction is 0.000571248459704093 using b"
# [1] "Max reduction is 7.38333429459778e-06 using b"
# [1] "Max reduction is 1.97152092405581e-05 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X14 ~ b + I(b^2) + I(b^3) + h + c + I(h * b) + I(c *
#     b) + I(c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0118039 -0.0011291  0.0005201  0.0024180  0.0067989
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.130113   0.072400   1.797   0.0867 .
# b           -0.941963   0.561356  -1.678   0.1082
# I(b^2)       2.326794   1.532425   1.518   0.1438
# I(b^3)      -1.900491   1.429430  -1.330   0.1979
# h            0.151208   0.067218   2.250   0.0353 *
# c           -0.013198   0.011418  -1.156   0.2607
# I(h * b)    -0.224184   0.156277  -1.435   0.1661
# I(c * b)     0.040030   0.023320   1.717   0.1008
# I(c * h)    -0.006563   0.018760  -0.350   0.7299
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.00446 on 21 degrees of freedom
# Multiple R-squared:  0.8873,	Adjusted R-squared:  0.8444
# F-statistic: 20.67 on 8 and 21 DF,  p-value: 2.593e-08
#
# [1] "1 I(b^3)"
# [1] "2 I(c * h)"
# [1] "3 I(c * b)"
# [1] "4 c"
#
# Call:
# lm(formula = X14 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0126342 -0.0017678  0.0007185  0.0031529  0.0076406
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03085    0.01461   2.112 0.044884 *
# b           -0.20249    0.06703  -3.021 0.005743 **
# I(b^2)       0.33179    0.11701   2.836 0.008928 **
# h            0.22824    0.04413   5.171 2.39e-05 ***
# I(h * b)    -0.41247    0.09970  -4.137 0.000348 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004487 on 25 degrees of freedom
# Multiple R-squared:  0.8642,	Adjusted R-squared:  0.8425
# F-statistic: 39.77 on 4 and 25 DF,  p-value: 1.712e-10
#
# [1] "Max reduction is 0.0018930197527645 using b"
# [1] "Max reduction is 0.00216781305791396 using h"
# [1] "Max reduction is 0.00117784058195762 using c"
# [1] "Max reduction is 0.000674911646004344 using b"
# [1] "Max reduction is 0.000432502406038796 using c"
# [1] "Max reduction is 0.000478722289916163 using Three Way Interactions with b"
# [1] "Max reduction is 0.000259083199697892 using Three Way Interactions with c"
# [1] "Max reduction is 1.53646880479627e-05 using c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X15 ~ b + I(b^2) + h + c + I(c^2) + I(c^3) + I(h *
#     b) + I(c * b) + I(c * h) + I(b * h * b) + I(b * c * b) +
#     I(b * c * h) + I(c * c * b) + I(c * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0056568 -0.0021327 -0.0001411  0.0019864  0.0080854
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.011851   0.169989   0.070   0.9453
# b            -0.110813   0.836352  -0.132   0.8964
# I(b^2)        0.301265   1.029744   0.293   0.7739
# h             0.337441   0.426309   0.792   0.4410
# c             0.012851   0.109949   0.117   0.9085
# I(c^2)       -0.063675   0.040030  -1.591   0.1325
# I(c^3)        0.009732   0.009267   1.050   0.3103
# I(h * b)     -0.927581   1.993727  -0.465   0.6484
# I(c * b)      0.112507   0.421513   0.267   0.7932
# I(c * h)     -0.077720   0.265646  -0.293   0.7739
# I(b * h * b)  0.513240   2.323040   0.221   0.8281
# I(b * c * b) -0.288083   0.589972  -0.488   0.6324
# I(b * c * h)  0.153253   0.601698   0.255   0.8024
# I(c * c * b)  0.017642   0.090230   0.196   0.8476
# I(c * c * h)  0.107032   0.052478   2.040   0.0594 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004787 on 15 degrees of freedom
# Multiple R-squared:  0.9092,	Adjusted R-squared:  0.8244
# F-statistic: 10.73 on 14 and 15 DF,  p-value: 2.129e-05
#
# [1] "1 I(b * c * h)"
# [1] "2 I(c * c * b)"
# [1] "3 I(b * c * b)"
# [1] "4 I(c * b)"
# [1] "5 I(b * h * b)"
# [1] "6 I(c^3)"
# [1] "7 I(c * c * h)"
# [1] "8 I(c * h)"
# [1] "9 I(c^2)"
# [1] "10 I(b^2)"
#
# Call:
# lm(formula = X15 ~ b + h + c + I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0117471 -0.0050066  0.0006899  0.0031732  0.0137218
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.0006105  0.0202812   0.030 0.976227
# b           -0.0029345  0.0453434  -0.065 0.948913
# h            0.2025821  0.0524742   3.861 0.000708 ***
# c            0.0062661  0.0020784   3.015 0.005826 **
# I(h * b)    -0.2913240  0.1092318  -2.667 0.013228 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.006431 on 25 degrees of freedom
# Multiple R-squared:  0.7269,	Adjusted R-squared:  0.6831
# F-statistic: 16.63 on 4 and 25 DF,  p-value: 9.092e-07
#
# [1] "Max reduction is 0.00138249060496799 using b"
# [1] "Max reduction is 0.00492355874499141 using h"
# [1] "Max reduction is 0.000397789382332671 using h"
# [1] "Max reduction is 0.000594646510737968 using b"
# [1] "Max reduction is 0.000331885569885081 using h"
# [1] "Max reduction is 3.23210710287268e-05 using h"
# [1] "Max reduction is 0.000337279741109548 using h"
# [1] "Max reduction is 0.000189862320140012 using Three Way Interactions with b"
# [1] "Max reduction is 8.7557830363739e-05 using b"
# [1] "Max reduction is 0.000243829139841715 using c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X16 ~ b + I(b^2) + I(b^3) + h + I(h^2) + I(h^3) +
#     I(h^4) + I(h^5) + c + I(h * b) + I(c * b) + I(c * h) + I(b *
#     h * b) + I(b * c * b) + I(b * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0021286 -0.0008604  0.0000181  0.0004323  0.0032835
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -1.12891    0.49400  -2.285  0.03841 *
# b               0.76839    0.41793   1.839  0.08729 .
# I(b^2)          0.03437    0.76080   0.045  0.96461
# I(b^3)         -1.87880    0.79549  -2.362  0.03321 *
# h              11.81240    4.98902   2.368  0.03284 *
# I(h^2)        -49.11228   20.63629  -2.380  0.03208 *
# I(h^3)        108.10534   42.57909   2.539  0.02362 *
# I(h^4)       -115.92780   42.91975  -2.701  0.01722 *
# I(h^5)         48.27122   16.88988   2.858  0.01265 *
# c               0.08767    0.05261   1.666  0.11783
# I(h * b)       -4.30801    1.06105  -4.060  0.00117 **
# I(c * b)       -0.32969    0.13938  -2.365  0.03298 *
# I(c * h)       -0.04186    0.17000  -0.246  0.80907
# I(b * h * b)    5.37186    1.42613   3.767  0.00208 **
# I(b * c * b)    0.35762    0.25380   1.409  0.18064
# I(b * c * h)    0.03125    0.38480   0.081  0.93643
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.001922 on 14 degrees of freedom
# Multiple R-squared:  0.9836,	Adjusted R-squared:  0.966
# F-statistic: 55.97 on 15 and 14 DF,  p-value: 7.123e-10
#
# [1] "1 I(b * c * h)"
# [1] "2 I(c * h)"
# [1] "3 I(b * c * b)"
# [1] "4 I(c * b)"
# [1] "5 c"
# [1] "6 I(b * h * b)"
# [1] "7 I(h * b)"
# [1] "8 I(h^5)"
# [1] "9 I(h^4)"
# [1] "10 I(h^3)"
# [1] "11 I(h^2)"
#
# Call:
# lm(formula = X16 ~ b + I(b^2) + I(b^3) + h, data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0086412 -0.0019431  0.0005066  0.0021197  0.0091956
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.086090   0.042702   2.016   0.0547 .
# b           -0.492510   0.390752  -1.260   0.2192
# I(b^2)       1.000912   1.100053   0.910   0.3716
# I(b^3)      -0.843329   0.992583  -0.850   0.4036
# h            0.086550   0.009645   8.973 2.72e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004099 on 25 degrees of freedom
# Multiple R-squared:  0.8668,	Adjusted R-squared:  0.8455
# F-statistic: 40.68 on 4 and 25 DF,  p-value: 1.343e-10
#
# [1] "Max reduction is 0.00184478011129251 using b"
# [1] "Max reduction is 0.00268273767204784 using h"
# [1] "Max reduction is 0.000202014106917343 using b"
# [1] "Max reduction is 0.000252289723752199 using h"
# [1] "Max reduction is 0.00019263869009274 using c"
# [1] "Max reduction is 0.000219144963813049 using b"
# [1] "Max reduction is 7.75062509860694e-05 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X17 ~ b + I(b^2) + I(b^3) + h + I(h^2) + I(h^3) +
#     c + I(h * b) + I(c * b) + I(c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0064487 -0.0021877  0.0005882  0.0013190  0.0095561
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.11964    0.07736   1.546   0.1385
# b           -1.22254    0.54569  -2.240   0.0372 *
# I(b^2)       3.16271    1.46179   2.164   0.0434 *
# I(b^3)      -2.69063    1.37279  -1.960   0.0648 .
# h            0.42900    0.32025   1.340   0.1962
# I(h^2)      -0.73618    0.73092  -1.007   0.3265
# I(h^3)       0.57998    0.43935   1.320   0.2025
# c           -0.01762    0.01156  -1.523   0.1441
# I(h * b)    -0.17764    0.25963  -0.684   0.5021
# I(c * b)     0.02699    0.02294   1.176   0.2540
# I(c * h)     0.01922    0.02246   0.856   0.4029
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004213 on 19 degrees of freedom
# Multiple R-squared:  0.876,	Adjusted R-squared:  0.8107
# F-statistic: 13.42 on 10 and 19 DF,  p-value: 1.289e-06
#
# [1] "1 I(b^3)"
# [1] "2 I(c * h)"
# [1] "3 I(c * b)"
# [1] "4 c"
# [1] "5 I(h * b)"
# [1] "6 I(h^3)"
#
# Call:
# lm(formula = X17 ~ b + I(b^2) + h + I(h^2), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0082728 -0.0027712 -0.0002298  0.0022581  0.0105079
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.05009    0.01598   3.134  0.00436 **
# b           -0.16702    0.08220  -2.032  0.05292 .
# I(b^2)       0.08724    0.11129   0.784  0.44044
# h            0.08251    0.05064   1.629  0.11577
# I(h^2)      -0.02352    0.05312  -0.443  0.66171
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.005275 on 25 degrees of freedom
# Multiple R-squared:  0.7443,	Adjusted R-squared:  0.7033
# F-statistic: 18.19 on 4 and 25 DF,  p-value: 4.077e-07
#
# [1] "Max reduction is 0.00250105202866777 using b"
# [1] "Max reduction is 0.0020254522131803 using h"
# [1] "Max reduction is 0.00105016734940613 using c"
# [1] "Max reduction is 0.000620989570170148 using b"
# [1] "Max reduction is 4.17750838646895e-05 using c"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X18 ~ b + I(b^2) + h + c + I(c^2) + I(h * b) + I(c *
#     b) + I(c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0062750 -0.0018351 -0.0001189  0.0016333  0.0071170
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.018464   0.018661   0.989 0.333712
# b           -0.157034   0.061267  -2.563 0.018120 *
# I(b^2)       0.302841   0.095726   3.164 0.004682 **
# h            0.238222   0.054506   4.371 0.000268 ***
# c           -0.004534   0.011422  -0.397 0.695399
# I(c^2)      -0.003862   0.003137  -1.231 0.231897
# I(h * b)    -0.434017   0.119192  -3.641 0.001526 **
# I(c * b)     0.014316   0.021817   0.656 0.518809
# I(c * h)     0.007890   0.015649   0.504 0.619350
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.003586 on 21 degrees of freedom
# Multiple R-squared:  0.9036,	Adjusted R-squared:  0.8668
# F-statistic: 24.59 on 8 and 21 DF,  p-value: 5.308e-09
#
# [1] "1 I(c * h)"
# [1] "2 I(c * b)"
# [1] "3 I(c^2)"
# [1] "4 I(b^2)"
#
# Call:
# lm(formula = X18 ~ b + h + c + I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0074530 -0.0024289 -0.0005704  0.0019962  0.0105751
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.001714   0.014551  -0.118  0.90719
# b            0.010791   0.032533   0.332  0.74289
# h            0.188778   0.037649   5.014 3.59e-05 ***
# c            0.004545   0.001491   3.048  0.00538 **
# I(h * b)    -0.297665   0.078371  -3.798  0.00083 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004614 on 25 degrees of freedom
# Multiple R-squared:  0.8099,	Adjusted R-squared:  0.7795
# F-statistic: 26.63 on 4 and 25 DF,  p-value: 1.081e-08
#
# [1] "Max reduction is 0.00314660263742875 using b"
# [1] "Max reduction is 0.00172152608393328 using h"
# [1] "Max reduction is 0.0007151308807584 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X19 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0087867 -0.0032473 -0.0004736  0.0030766  0.0122682
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.02677    0.01679   1.594 0.123427
# b           -0.21840    0.07702  -2.836 0.008928 **
# I(b^2)       0.39683    0.13444   2.952 0.006779 **
# h            0.24147    0.05071   4.762 6.91e-05 ***
# I(h * b)    -0.45710    0.11456  -3.990 0.000508 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ...
# [1] "Max reduction is 0.000210869209713519 using Three Way Interactions with c"
# [1] "Max reduction is 0.000115409823810004 using b"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X25 ~ b + I(b^2) + I(b^3) + h + c + I(c^2) + I(h *
#     b) + I(c * b) + I(c * h) + I(b * h * b) + I(b * c * b) +
#     I(b * c * h) + I(c * c * b) + I(c * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0022592 -0.0005829  0.0001910  0.0006983  0.0026711
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.002831   0.065385  -0.043   0.9660
# b            -0.299841   0.349772  -0.857   0.4048
# I(b^2)        1.194337   0.672217   1.777   0.0959 .
# I(b^3)       -1.081932   0.614333  -1.761   0.0986 .
# h             0.460324   0.162359   2.835   0.0125 *
# c             0.003064   0.041368   0.074   0.9419
# I(c^2)        0.020227   0.012842   1.575   0.1361
# I(h * b)     -1.304074   0.762960  -1.709   0.1080
# I(c * b)     -0.209090   0.160761  -1.301   0.2130
# I(c * h)      0.132751   0.097860   1.357   0.1950
# I(b * h * b)  0.940973   0.896708   1.049   0.3106
# I(b * c * b)  0.450400   0.222975   2.020   0.0616 .
# I(b * c * h) -0.311674   0.223899  -1.392   0.1842
# I(c * c * b) -0.036498   0.033261  -1.097   0.2898
# I(c * c * h) -0.025750   0.018633  -1.382   0.1872
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.001813 on 15 degrees of freedom
# Multiple R-squared:  0.9876,	Adjusted R-squared:  0.9761
# F-statistic: 85.53 on 14 and 15 DF,  p-value: 1.056e-11
#
# [1] "1 I(b * h * b)"
# [1] "2 I(c * c * h)"
# [1] "3 I(b * c * h)"
# [1] "4 I(b * c * b)"
# [1] "5 I(c * h)"
# [1] "6 I(c * c * b)"
# [1] "7 I(c * b)"
# [1] "8 I(b^3)"
# [1] "9 I(c^2)"
# [1] "10 c"
#
# Call:
# lm(formula = X25 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0106539 -0.0013814  0.0004099  0.0026227  0.0054484
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.02385    0.01318   1.809  0.08242 .
# b           -0.20302    0.06047  -3.357  0.00252 **
# I(b^2)       0.33442    0.10555   3.168  0.00402 **
# h            0.26344    0.03981   6.617 6.22e-07 ***
# I(h * b)    -0.43418    0.08994  -4.827 5.83e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004048 on 25 degrees of freedom
# Multiple R-squared:  0.8972,	Adjusted R-squared:  0.8808
# F-statistic: 54.56 on 4 and 25 DF,  p-value: 5.442e-12
#
# [1] "Max reduction is 0.00257638076065612 using b"
# [1] "Max reduction is 0.00397816984656677 using h"
# [1] "Max reduction is 0.0003475947052003 using c"
# [1] "Max reduction is 0.000163939689100761 using b"
# [1] "Max reduction is 0.000425099100968485 using b"
# [1] "Max reduction is 0.000501509002426966 using Three Way Interactions with b"
# [1] "Max reduction is 0.000178919308088908 using b"
# [1] "Max reduction is 0.000101530147487892 using b"
# [1] "Max reduction is 2.67013305065402e-06 using c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X26 ~ b + I(b^2) + I(b^3) + I(b^4) + I(b^5) + h +
#     c + I(c^2) + I(h * b) + I(c * b) + I(c * h) + I(b * h * b) +
#     I(b * c * b) + I(b * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0057817 -0.0007142  0.0003257  0.0008909  0.0028205
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    0.257860   0.400031   0.645   0.5289
# b             -4.554879   5.365048  -0.849   0.4092
# I(b^2)        30.175470  30.499599   0.989   0.3382
# I(b^3)       -96.700819  86.519464  -1.118   0.2813
# I(b^4)       151.462616 120.673824   1.255   0.2286
# I(b^5)       -93.249243  66.362025  -1.405   0.1803
# h              0.410331   0.331594   1.237   0.2349
# c             -0.001851   0.048065  -0.039   0.9698
# I(c^2)        -0.002433   0.002389  -1.019   0.3245
# I(h * b)      -1.480801   1.626610  -0.910   0.3770
# I(c * b)      -0.252612   0.214353  -1.178   0.2570
# I(c * h)       0.225843   0.109092   2.070   0.0561 .
# I(b * h * b)   1.624281   1.959187   0.829   0.4201
# I(b * c * b)   0.623218   0.295270   2.111   0.0520 .
# I(b * c * h)  -0.568148   0.253286  -2.243   0.0404 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.002263 on 15 degrees of freedom
# Multiple R-squared:  0.9762,	Adjusted R-squared:  0.9539
# F-statistic: 43.86 on 14 and 15 DF,  p-value: 1.362e-09
#
# [1] "1 I(b * c * b)"
# [1] "2 I(b * c * h)"
# [1] "3 I(c * b)"
# [1] "4 I(b^5)"
# [1] "5 I(c * h)"
# [1] "6 I(b * h * b)"
# [1] "7 I(h * b)"
# [1] "8 I(b^4)"
# [1] "9 I(b^3)"
# [1] "10 I(c^2)"
#
# Call:
# lm(formula = X26 ~ b + I(b^2) + h + c, data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0107391 -0.0019540  0.0001843  0.0026532  0.0093826
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.047352   0.012660   3.740 0.000962 ***
# b           -0.111582   0.064167  -1.739 0.094347 .
# I(b^2)      -0.007686   0.087385  -0.088 0.930611
# h            0.068399   0.009574   7.144 1.73e-07 ***
# c           -0.002086   0.001417  -1.472 0.153391
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004391 on 25 degrees of freedom
# Multiple R-squared:  0.8503,	Adjusted R-squared:  0.8264
# F-statistic: 35.51 on 4 and 25 DF,  p-value: 5.677e-10
#
# [1] "Max reduction is 0.00241226746091861 using b"
# [1] "Max reduction is 0.00243208200234142 using h"
# [1] "Max reduction is 0.000175892095051433 using b"
# [1] "Max reduction is 1.3108485578249e-05 using b"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X27 ~ b + I(b^2) + I(b^3) + h + I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0070804 -0.0014410  0.0004991  0.0022471  0.0060275
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.06579    0.05089   1.293 0.208318
# b           -0.56457    0.42830  -1.318 0.199894
# I(b^2)       1.47670    1.19565   1.235 0.228761
# I(b^3)      -1.19403    1.10878  -1.077 0.292236
# h            0.17949    0.04303   4.171 0.000341 ***
# I(h * b)    -0.28443    0.10172  -2.796 0.010020 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004111 on 24 degrees of freedom
# Multiple R-squared:  0.8327,	Adjusted R-squared:  0.7979
# F-statistic:  23.9 on 5 and 24 DF,  p-value: 1.352e-08
#
# [1] "1 I(b^3)"
#
# Call:
# lm(formula = X27 ~ b + I(b^2) + h + I(h * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0077118 -0.0012290  0.0008898  0.0025579  0.0054466
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.01293    0.01343   0.963  0.34493
# b           -0.10810    0.06160  -1.755  0.09154 .
# I(b^2)       0.19431    0.10753   1.807  0.08282 .
# h            0.19534    0.04056   4.816    6e-05 ***
# I(h * b)    -0.33266    0.09163  -3.631  0.00127 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004124 on 25 degrees of freedom
# Multiple R-squared:  0.8247,	Adjusted R-squared:  0.7966
# F-statistic: 29.39 on 4 and 25 DF,  p-value: 3.999e-09
#
# [1] "Max reduction is 0.00338104320091187 using b"
# [1] "Max reduction is 0.00343529078674052 using h"
# [1] "Max reduction is 0.00111804927729911 using c"
# [1] "Max reduction is 0.000596035930073704 using b"
# [1] "Max reduction is 0.000407893268414294 using Three Way Interactions with b"
# [1] "Max reduction is 0.000225729081029446 using c"
# [1] "Max reduction is 2.51218642636202e-05 using c"
# [1] "Max reduction is 0.000179193784693299 using c"
# [1] "Max reduction is 1.78562044073657e-05 using Three Way Interactions with c"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X28 ~ b + I(b^2) + h + c + I(c^2) + I(c^3) + I(c^4) +
#     I(h * b) + I(c * b) + I(c * h) + I(b * h * b) + I(b * c *
#     b) + I(b * c * h) + I(c * c * b) + I(c * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0060257 -0.0006806 -0.0001135  0.0006589  0.0061618
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.049451   0.104186  -0.475   0.6424
# b             0.284462   0.504704   0.564   0.5819
# I(b^2)       -0.349222   0.616603  -0.566   0.5801
# h             0.412736   0.258415   1.597   0.1325
# c            -0.015698   0.065207  -0.241   0.8132
# I(c^2)        0.052186   0.023460   2.224   0.0431 *
# I(c^3)       -0.007385   0.005452  -1.355   0.1970
# I(c^4)       -0.020541   0.011796  -1.741   0.1035
# I(h * b)     -1.664366   1.183038  -1.407   0.1813
# I(c * b)      0.096973   0.267148   0.363   0.7220
# I(c * h)     -0.082131   0.151891  -0.541   0.5972
# I(b * h * b)  1.767382   1.365173   1.295   0.2164
# I(b * c * b) -0.127516   0.373563  -0.341   0.7379
# I(b * c * h)  0.174305   0.343056   0.508   0.6193
# I(c * c * b) -0.077392   0.052064  -1.486   0.1593
# I(c * c * h)  0.019327   0.036015   0.537   0.5999
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.002725 on 14 degrees of freedom
# Multiple R-squared:  0.9756,	Adjusted R-squared:  0.9494
# F-statistic: 37.26 on 15 and 14 DF,  p-value: 1.107e-08
#
# [1] "1 I(b * h * b)"
# [1] "2 I(b * c * b)"
# [1] "3 I(c * c * h)"
# [1] "4 I(b * c * h)"
# [1] "5 I(c * h)"
# [1] "6 I(c * c * b)"
# [1] "7 I(c * b)"
# [1] "8 I(b^2)"
# [1] "9 I(h * b)"
# [1] "10 I(c^4)"
# [1] "11 I(c^3)"
#
# Call:
# lm(formula = X28 ~ b + h + c + I(c^2), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0103886 -0.0037640 -0.0002613  0.0031241  0.0102489
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.052508   0.004820  10.895 5.53e-11 ***
# b           -0.123631   0.012978  -9.526 8.47e-10 ***
# h            0.059225   0.011010   5.379 1.40e-05 ***
# c           -0.005996   0.001777  -3.374  0.00242 **
# I(c^2)       0.002982   0.003280   0.909  0.37201
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.005435 on 25 degrees of freedom
# Multiple R-squared:  0.8264,	Adjusted R-squared:  0.7986
# F-statistic: 29.75 on 4 and 25 DF,  p-value: 3.534e-09
#
# [1] "Max reduction is 0.00259562476426805 using b"
# [1] "Max reduction is 0.00260379976669607 using h"
# [1] "Max reduction is 0.00108197832253803 using b"
# [1] "Max reduction is 0.000373293096294175 using c"
# [1] "Max reduction is 0.000157781659710357 using h"
# [1] "Max reduction is 0.000174054983411621 using Three Way Interactions with b"
# [1] "Max reduction is 0.000325430486968419 using Three Way Interactions with h"
# [1] "Max reduction is 0.000261892026078851 using h"
# [1] "No further terms permitted with the given degrees of freedom"
#
# Call:
# lm(formula = X29 ~ b + I(b^2) + h + I(h^2) + I(h^3) + c + I(h *
#     b) + I(c * b) + I(c * h) + I(b * h * b) + I(b * c * b) +
#     I(b * c * h) + I(h * h * b) + I(h * c * h), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0046071 -0.0005716  0.0000112  0.0006896  0.0045213
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.11522    0.09589   1.202  0.24817
# b            -0.37807    0.46297  -0.817  0.42692
# I(b^2)        0.95664    0.96026   0.996  0.33494
# h            -0.16656    0.42091  -0.396  0.69789
# I(h^2)        1.17776    0.64493   1.826  0.08779 .
# I(h^3)       -1.59375    0.74420  -2.142  0.04905 *
# c            -0.07115    0.03766  -1.890  0.07831 .
# I(h * b)     -1.09541    1.07528  -1.019  0.32449
# I(c * b)     -0.20140    0.17314  -1.163  0.26289
# I(c * h)      0.52778    0.16074   3.283  0.00503 **
# I(b * h * b) -1.14966    2.35396  -0.488  0.63233
# I(b * c * b)  0.29585    0.30567   0.968  0.34845
# I(b * c * h) -0.05308    0.39143  -0.136  0.89393
# I(h * h * b)  2.13624    2.53270   0.843  0.41222
# I(h * c * h) -0.62103    0.21232  -2.925  0.01045 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.002461 on 15 degrees of freedom
# Multiple R-squared:  0.967,	Adjusted R-squared:  0.9363
# F-statistic: 31.44 on 14 and 15 DF,  p-value: 1.468e-08
#
# [1] "1 I(b * c * b)"
# [1] "2 I(b * h * b)"
# [1] "3 I(h * h * b)"
# [1] "4 I(b * c * h)"
# [1] "5 I(h^3)"
# [1] "6 I(c * b)"
# [1] "7 I(h * c * h)"
# [1] "8 I(c * h)"
# [1] "9 I(h * b)"
# [1] "10 c"
#
# Call:
# lm(formula = X29 ~ b + I(b^2) + h + I(h^2), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0084359 -0.0019975 -0.0002923  0.0020356  0.0102500
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.04408    0.01217   3.622 0.001300 **
# b           -0.25921    0.06262  -4.140 0.000346 ***
# I(b^2)       0.20697    0.08477   2.442 0.022041 *
# h            0.19455    0.03857   5.044 3.33e-05 ***
# I(h^2)      -0.15300    0.04046  -3.781 0.000867 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.004018 on 25 degrees of freedom
# Multiple R-squared:  0.8536,	Adjusted R-squared:  0.8302
# F-statistic: 36.45 on 4 and 25 DF,  p-value: 4.323e-10
#
# [1] "Max reduction is 0.00735874922676602 using h"
# [1] "Max reduction is 0.00543920106433043 using b"
# [1] "Max reduction is 0.0020701353859477 using c"
# [1] "Max reduction is 0.000208942533919204 using h"
# [1] "Max reduction is 0.000949060735594049 using Three Way Interactions with h"
# [1] "Max reduction is 0.000823750856867951 using h"
# [1] "Max reduction is 0.00148439011554624 using h"
# [1] "No permitted terms improve the fit"
#
# Call:
# lm(formula = X30 ~ h + I(h^2) + I(h^3) + I(h^4) + b + c + I(b *
#     h) + I(c * h) + I(c * b) + I(h * b * h) + I(h * c * h) +
#     I(h * c * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0067921 -0.0028338 -0.0008192  0.0024792  0.0089222
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -0.91028    0.27080  -3.361 0.003704 **
# h              8.20896    2.35853   3.481 0.002862 **
# I(h^2)       -26.04702    8.05488  -3.234 0.004880 **
# I(h^3)        37.31182   11.55428   3.229 0.004927 **
# I(h^4)       -18.87447    5.34573  -3.531 0.002567 **
# b              0.26104    0.51933   0.503 0.621656
# c              0.15595    0.07769   2.007 0.060897 .
# I(b * h)      -1.05919    2.57757  -0.411 0.686262
# I(c * h)       0.10084    0.27913   0.361 0.722360
# I(c * b)      -0.98535    0.24879  -3.961 0.001010 **
# I(h * b * h)   0.12543    3.17003   0.040 0.968898
# I(h * c * h)  -1.38286    0.42976  -3.218 0.005051 **
# I(h * c * b)   2.61961    0.56962   4.599 0.000256 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.005312 on 17 degrees of freedom
# Multiple R-squared:  0.9704,	Adjusted R-squared:  0.9495
# F-statistic: 46.48 on 12 and 17 DF,  p-value: 1.422e-10
#
# [1] "1 I(h * c * h)"
# [1] "2 I(c * h)"
# [1] "3 I(h * c * b)"
# [1] "4 I(h^4)"
# [1] "5 I(h * b * h)"
# [1] "6 I(h^3)"
# [1] "7 I(b * h)"
# [1] "8 I(h^2)"
#
# Call:
# lm(formula = X30 ~ h + b + c + I(c * b), data = tData)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0300267 -0.0047055 -0.0002932  0.0053372  0.0192939
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.028686   0.008329   3.444  0.00203 **
# h            0.217241   0.019361  11.220 2.99e-11 ***
# b           -0.150637   0.022873  -6.586 6.71e-07 ***
# c           -0.036717   0.014600  -2.515  0.01870 *
# I(c * b)     0.075323   0.035285   2.135  0.04277 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.009518 on 25 degrees of freedom
# Multiple R-squared:  0.8603,	Adjusted R-squared:  0.838
# F-statistic:  38.5 on 4 and 25 DF,  p-value: 2.422e-10

# %% [markdown]
# We can use Leave One Out to verify if our GPs fit our metrics correctly.

# %%
tLOOs <- LOO.plot(Emulators = em_wave4, which.emulator = 12, ParamNames = cands)
# Out:
# Plot with title “”

# %% [markdown]
# ### Compute implausibility

# %%
sample_size <- 100000
nparam <- length(names(em_wave4$fitting.elements$Design))
Xp_wave4 <- as.data.frame(2*randomLHS(sample_size, nparam)-1)
names(Xp_wave4) <- names(em_wave4$fitting.elements$Design)
system.time(Timps_wave4 <- ImplausibilityMOGP(NewData=Xp_wave4, Emulator=em_wave4, Discrepancy=tDisc, Obs=tObs, ObsErr=tObsErr))
# Out:
#    user  system elapsed
#  16.550   3.792   3.345

# %%
valmax = 2 #how many outputs can be above the implausibility cut off
cutoff <- 3 #the implausibility cut off

# %%
NROY4 <- which(rowSums(Timps_wave4 <= cutoff) >= em_wave4$mogp$n_emulators -valmax)
scoreNROY4 <- length(NROY4)/dim(Xp_wave4)[1]

# %% [markdown]
# ### Layout of NROY space

# %%
ImpData_wave4 = cbind(Xp_wave4, Timps_wave4)
ImpListM4 = CreateImpList(whichVars = 1:nparam, VarNames=VarNames, ImpData=ImpData_wave4, nEms=em_wave4$mogp$n_emulators, whichMax=valmax+1)
imp.layoutm11(ImpListM4,VarNames,VariableDensity=FALSE,newPDF=FALSE,the.title=paste("InputSpace_wave",WAVEN,".pdf",sep=""),newPNG=FALSE,newJPEG=FALSE,newEPS=FALSE,Points=matrix(param.defaults.norm,ncol=nparam))
mtext(paste("Remaining space:",scoreNROY4,sep=""), side=1)
# Out:
# plot without title
